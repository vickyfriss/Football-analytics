# %%
install.packages("footballpenaltiesBL")
# Out:
# Installing package into 'C:/Users/vicky/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
# package 'footballpenaltiesBL' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\vicky\AppData\Local\Temp\RtmpGgPs0W\downloaded_packages

# %%
library(footballpenaltiesBL)

data("penalties")

# %%
head(penalties)
# Out:
#   date       season matchday goalkeeper        penaltytaker
# 1 1963-08-24 63/64  1        Loy, Egon         Neumann, Jürgen
# 2 1963-08-24 63/64  1        Schnarr, Wolfgang Schämer, Lothar
# 3 1963-08-24 63/64  1        Wabra, Roland     Schimmöller, Hans-Günther
# 4 1963-08-31 63/64  2        Tilkowski, Hans   Stemmer, Alfons
# 5 1963-09-07 63/64  3        Radenkovic, Petar Sturm, Hans
# 6 1963-09-07 63/64  3        Ewert, Fritz      Auernhammer, Hans
#   homegame result   minute goaldiff gkclub              ptclub
# 1 2        Tor      38     0        Eintracht Frankfurt 1.FC Kaiserslautern
# 2 1        Tor      40     1        1.FC Kaiserslautern Eintracht Frankfurt
# 3 1        Tor      62     1        1.FC Nürnberg       Hertha BSC
# 4 2        gehalten 65     0        Borussia Dortmund   TSV 1860 München
# 5 2        Tor      67     0        TSV 1860 München    1.FC Köln
# 6 1        Tor      55     1        1.FC Köln           TSV 1860 München
#   gkage ptage gkexp ptexp
# ...

# %%
str(penalties)
# Out:
# 'data.frame':	4599 obs. of  15 variables:
#  $ date        : Date, format: "1963-08-24" "1963-08-24" ...
#  $ season      : Factor w/ 54 levels "00/01","01/02",..: 18 18 18 18 18 18 18 18 18 18 ...
#  $ matchday    : num  1 1 1 2 3 3 3 3 3 4 ...
#  $ goalkeeper  : Factor w/ 353 levels "Adler, Rene",..: 189 269 320 304 238 58 196 320 39 52 ...
#  $ penaltytaker: Factor w/ 923 levels "Abdellaoue, Mohammed",..: 593 728 733 795 807 30 838 366 569 679 ...
#  $ homegame    : num  2 1 1 2 2 1 1 1 2 1 ...
#  $ result      : Factor w/ 6 levels "drüber","gehalten",..: 5 5 5 2 5 5 5 5 5 5 ...
#  $ minute      : num  38 40 62 65 67 55 72 82 72 2 ...
#  $ goaldiff    : num  0 1 1 0 0 1 -3 2 1 0 ...
#  $ gkclub      : Factor w/ 57 levels "1.FC Kaiserslautern",..: 15 1 4 11 53 2 31 4 5 33 ...
#  $ ptclub      : Factor w/ 57 levels "1.FC Kaiserslautern",..: 1 15 27 53 2 53 33 15 14 4 ...
#  $ gkage       : num  32 22 27 28 29 26 23 27 21 28 ...
# ...

# %%
summary(penalties)
# Out:
#       date                season        matchday                   goalkeeper
#  Min.   :1963-08-24   74/75  : 126   Min.   : 1.00   Immel, Eike        :  89
#  1st Qu.:1976-05-08   81/82  : 116   1st Qu.: 8.00   Schumacher2, Harald:  89
#  Median :1988-02-27   72/73  : 113   Median :17.00   Kargus, Rudolf     :  76
#  Mean   :1989-08-10   83/84  : 113   Mean   :17.31   Burdenski, Dieter  :  73
#  3rd Qu.:2002-03-09   85/86  : 111   3rd Qu.:26.00   Maier, Sepp        :  72
#  Max.   :2017-12-21   86/87  : 110   Max.   :38.00   Nigbur, Norbert    :  64
#                       (Other):3910                   (Other)            :4136
#                 penaltytaker     homegame          result         minute
#  Müller4, Gerd        :  63   Min.   :1.000   drüber  :  49   Min.   : 1.00
#  Kaltz, Manfred       :  60   1st Qu.:1.000   gehalten: 856   1st Qu.:33.00
#  Zorc, Michael        :  57   Median :1.000   Latte   :  39   Median :54.00
# ...

# %%
write.csv(
  penalties,
  file = "Datasets/bundesliga_penalties.csv",
  row.names = FALSE
)
