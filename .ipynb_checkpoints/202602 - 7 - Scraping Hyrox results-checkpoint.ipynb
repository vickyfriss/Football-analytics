# %% [markdown]
# # Scrape one at a time, only for PRO divisions.

# %%
import time
import random
import pandas as pd
import os
from concurrent.futures import ThreadPoolExecutor

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, TimeoutException

# ==========================
# CONFIG
# ==========================

BASE_URLS = {
    "Season_7": "https://results.hyrox.com/season-7/",
    "Season_8": "https://results.hyrox.com/season-8/"
}

SAVE_ROOT = r"Datasets\Hyrox"
MAX_THREADS = 3  # adjust depending on RAM / CPU

def human_pause(a=3, b=7):
    time.sleep(random.uniform(a, b))

# ==========================
# SELENIUM DRIVER
# ==========================

def create_driver():
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.add_argument("--headless=new")  # run headless for multiple threads
    options.add_argument(
        "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
    return webdriver.Chrome(options=options)

# ==========================
# SCRAPE FUNCTION
# ==========================

def scrape_pages(driver, race_name, division, gender_label, race_results):
    """Scrape all pages for a given race/division/gender."""
    is_doubles = "DOUBLES" in division.upper()
    page_number = 1

    while True:
        try:
            WebDriverWait(driver, 25).until(lambda d: 
                "There are currently no results available" in d.page_source
                or len(d.find_elements(By.CSS_SELECTOR, "li.list-group-item.row")) > 1
            )
        except TimeoutException:
            return False

        # Check no-results message
        try:
            no_result_elem = driver.find_element(By.XPATH,
                "//*[contains(text(),'There are currently no results available')]"
            )
            if no_result_elem.is_displayed():
                return False
        except NoSuchElementException:
            pass

        rows = driver.find_elements(By.CSS_SELECTOR, "li.list-group-item.row")
        rows = [r for r in rows if "list-group-header" not in r.get_attribute("class")]

        if not rows:
            return False

        scraped_any = False
        for row in rows:
            try:
                rank = row.find_element(By.CSS_SELECTOR, ".place-primary").text
                age_rank = row.find_element(By.CSS_SELECTOR, ".place-secondary").text
                total_time = row.find_element(By.CSS_SELECTOR, ".type-time").text.replace("Total", "").strip()
                age_group = row.find_element(By.CSS_SELECTOR, ".type-age_class").text.replace("Age Group", "").strip()

                if is_doubles:
                    members = row.find_elements(By.CSS_SELECTOR, ".type-relay_member a")
                    member_names = " & ".join([m.text for m in members])
                    race_results.append([
                        race_name, division, gender_label,
                        rank, age_rank, member_names, "",
                        age_group, total_time
                    ])
                else:
                    name = row.find_element(By.CSS_SELECTOR, "h4.type-fullname").text
                    nation = row.find_element(By.CSS_SELECTOR, ".nation__abbr").text
                    race_results.append([
                        race_name, division, gender_label,
                        rank, age_rank, name, nation,
                        age_group, total_time
                    ])
                scraped_any = True
            except:
                continue

        print(f"      Page {page_number} scraped")
        page_number += 1

        # Go to next page
        try:
            next_button = driver.find_element(By.XPATH, "//a[text()='>']")
            driver.execute_script("arguments[0].click();", next_button)
            human_pause(3, 6)
        except NoSuchElementException:
            break

    return scraped_any

# ==========================
# RACE SCRAPER (THREAD TARGET)
# ==========================

def scrape_race(season, base_url, race_name, race_value):
    """Scrape a single race (all divisions)."""
    driver = create_driver()
    season_folder = os.path.join(SAVE_ROOT, season)
    os.makedirs(season_folder, exist_ok=True)

    safe_name = race_name.replace(" ", "_").replace("/", "-")
    print(f"\nProcessing race: {race_name}")

    driver.get(base_url)
    human_pause(4, 6)
    Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
    human_pause(2,4)
    select_division = Select(driver.find_element(By.ID, "default-lists-event"))
    available = [o.text for o in select_division.options]

    def build_priority(base_name):
        priority = []
        if base_name in available:
            priority.append(base_name)
        overall = f"{base_name} - Overall"
        if overall in available:
            priority.append(overall)
        other = [d for d in available if d.startswith(f"{base_name} -") and d not in priority]
        priority.extend(other)
        return priority

    def process_group(base_name):
        priority_list = build_priority(base_name)
        if not priority_list:
            return

        for div in priority_list:
            div_safe = div.replace(" ", "_").replace("/", "-")
            file_path = os.path.join(season_folder, f"{safe_name}_{div_safe}.csv")
            if os.path.exists(file_path):
                print(f"   {div} already scraped")
                continue

            print(f"   Trying {div}")
            is_doubles = "DOUBLES" in div.upper()
            genders = [("M","Male"),("W","Women")] if not is_doubles else [("M","Male"),("W","Female"),("X","Mixed")]

            division_results = []
            division_has_data = False

            # Load division page
            driver.get(base_url)
            human_pause(3,6)
            Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
            human_pause(2,4)
            Select(driver.find_element(By.ID, "default-lists-event")).select_by_visible_text(div)
            human_pause(2,4)

            try:
                gender_dropdown = Select(driver.find_element(By.ID, "default-lists-sex"))
                available_gender_values = [o.get_attribute("value") for o in gender_dropdown.options]
            except NoSuchElementException:
                available_gender_values = []

            valid_genders = [(code, label) for code, label in genders if code in available_gender_values]
            if not valid_genders:
                print(f"   {div} has no gender categories")
                continue

            # Scrape all genders
            for idx, (gender_code, gender_label) in enumerate(valid_genders):
                print(f"      Gender: {gender_label}")
                driver.get(base_url)
                human_pause(3,6)
                Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
                human_pause(2,4)
                Select(driver.find_element(By.ID, "default-lists-event")).select_by_visible_text(div)
                human_pause(2,4)
                Select(driver.find_element(By.ID, "default-lists-sex")).select_by_value(gender_code)
                Select(driver.find_element(By.ID, "default-num_results")).select_by_value("100")
                human_pause(2,4)
                driver.find_element(By.ID, "default-submit").click()
                human_pause(5,10)

                has_data = scrape_pages(driver, race_name, div, gender_label, division_results)
                if idx == 0 and not has_data:
                    print(f"   {div} had NO DATA")
                    division_has_data = False
                    break
                if has_data:
                    division_has_data = True

            # Save CSV
            if division_has_data:
                df = pd.DataFrame(
                    division_results,
                    columns=["Race","Division","Gender",
                             "Rank Overall","Rank Age Group",
                             "Name","Nation","Age Group","Total Time"]
                )
                df.to_csv(file_path,index=False)
                print(f"   Saved {len(df)} rows")

    process_group("HYROX PRO")
    process_group("HYROX PRO DOUBLES")

    driver.quit()
    return f"Finished {race_name}"

# ==========================
# MAIN LOOP
# ==========================

all_tasks = []
for season, base_url in BASE_URLS.items():
    driver_main = create_driver()
    driver_main.get(base_url)
    human_pause(4,6)
    try:
        WebDriverWait(driver_main, 25).until(EC.presence_of_element_located((By.ID, "default-lists-event_main_group")))
    except TimeoutException:
        continue
    race_dropdown = Select(driver_main.find_element(By.ID, "default-lists-event_main_group"))
    races = [(race_dropdown.options[i].text, race_dropdown.options[i].get_attribute("value")) for i in range(len(race_dropdown.options))]
    driver_main.quit()
    for race_name, race_value in races:
        all_tasks.append((season, base_url, race_name, race_value))

# Threaded execution
with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
    futures = [executor.submit(scrape_race, *task) for task in all_tasks]
    for f in futures:
        print(f.result())

print("\nALL DONE.")
# Out:
# Processing race: 2025 Shanghai
# Processing race: 2025 Valencia
#
#
# Processing race: 2025 Atlanta
#    HYROX PRO - Overall already scraped
#    Trying HYROX PRO - Saturday
#    HYROX PRO already scraped
#    HYROX PRO DOUBLES already scraped
#    HYROX PRO - Overall already scraped
#    Trying HYROX PRO - Saturday
# Finished 2025 Shanghai
#
# Processing race: 2025 Maastricht
#       Gender: Male
#       Gender: Male
#    HYROX PRO already scraped
#    HYROX PRO DOUBLES already scraped
#
# Processing race: 2025 Mumbai
#    HYROX PRO already scraped
#    HYROX PRO DOUBLES already scraped
#
# Processing race: 2025 World Championships
#    Trying HYROX PRO - Overall
#       Page 1 scraped
#       Page 1 scraped
#       Page 2 scraped
#       Gender: Women
#       Gender: Male
#       Page 2 scraped
#       Gender: Women
#       Page 1 scraped
#    Saved 139 rows
#    Trying HYROX PRO - Sunday
#    HYROX PRO - Overall had NO DATA
#    HYROX PRO - Friday already scraped
#    HYROX PRO - Saturday already scraped
#    Trying HYROX PRO DOUBLES - Overall
#       Gender: Male
#       Page 1 scraped
#    Saved 292 rows
#    Trying HYROX PRO - Sunday
#       Gender: Male
#       Gender: Male
#       Page 1 scraped
#       Gender: Women
#    HYROX PRO DOUBLES - Overall had NO DATA
#    Trying HYROX PRO DOUBLES - Saturday
#       Gender: Male
#       Page 1 scraped
#       Gender: Women
#       Page 1 scraped
#    Saved 81 rows
#    Trying HYROX PRO DOUBLES - Overall
#       Gender: Male
#    HYROX PRO DOUBLES - Saturday had NO DATA
#    Trying HYROX PRO DOUBLES - Sunday
#       Page 1 scraped
#    Saved 119 rows
#    HYROX PRO DOUBLES - Overall already scraped
#    Trying HYROX PRO DOUBLES - Saturday
#       Gender: Male
#       Gender: Male
#    HYROX PRO DOUBLES - Overall had NO DATA
#    HYROX PRO DOUBLES - Saturday already scraped
#    HYROX PRO DOUBLES - Sunday already scraped
#
# Processing race: 2025 Cardiff

# %% [markdown]
# # Scrape 20 at a time, only for PRO divisions.

# %%
import time
import random
import pandas as pd
import os
from concurrent.futures import ThreadPoolExecutor

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, TimeoutException

# ==========================
# CONFIG
# ==========================

BASE_URLS = {
    "Season_6": "https://results.hyrox.com/season-6/",
    "Season_7": "https://results.hyrox.com/season-7/",
    "Season_8": "https://results.hyrox.com/season-8/"
}

SAVE_ROOT = r"Datasets\Hyrox"
MAX_THREADS = 20  # number of concurrent races

def human_pause(a=3, b=7):
    time.sleep(random.uniform(a, b))

# ==========================
# SELENIUM DRIVER
# ==========================

def create_driver():
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.add_argument("--headless=new")  # headless for parallel threads
    options.add_argument(
        "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
    return webdriver.Chrome(options=options)

# ==========================
# SCRAPE FUNCTION
# ==========================

def scrape_pages(driver, race_name, division, gender_label, race_results):
    """Scrape all pages for a given race/division/gender."""
    is_doubles = "DOUBLES" in division.upper()
    page_number = 1

    while True:
        try:
            WebDriverWait(driver, 25).until(lambda d: 
                "There are currently no results available" in d.page_source
                or len(d.find_elements(By.CSS_SELECTOR, "li.list-group-item.row")) > 1
            )
        except TimeoutException:
            print(f"[{race_name}] Timeout waiting for results in {division} - {gender_label}")
            return False

        # Check no-results message
        try:
            no_result_elem = driver.find_element(By.XPATH,
                "//*[contains(text(),'There are currently no results available')]"
            )
            if no_result_elem.is_displayed():
                print(f"[{race_name}] No results for {division} - {gender_label}")
                return False
        except NoSuchElementException:
            pass

        rows = driver.find_elements(By.CSS_SELECTOR, "li.list-group-item.row")
        rows = [r for r in rows if "list-group-header" not in r.get_attribute("class")]

        if not rows:
            print(f"[{race_name}] No rows found for {division} - {gender_label}")
            return False

        scraped_any = False
        for row in rows:
            try:
                rank = row.find_element(By.CSS_SELECTOR, ".place-primary").text
                age_rank = row.find_element(By.CSS_SELECTOR, ".place-secondary").text
                total_time = row.find_element(By.CSS_SELECTOR, ".type-time").text.replace("Total", "").strip()
                age_group = row.find_element(By.CSS_SELECTOR, ".type-age_class").text.replace("Age Group", "").strip()

                if is_doubles:
                    members = row.find_elements(By.CSS_SELECTOR, ".type-relay_member a")
                    member_names = " & ".join([m.text for m in members])
                    race_results.append([
                        race_name, division, gender_label,
                        rank, age_rank, member_names, "",
                        age_group, total_time
                    ])
                else:
                    name = row.find_element(By.CSS_SELECTOR, "h4.type-fullname").text
                    nation = row.find_element(By.CSS_SELECTOR, ".nation__abbr").text
                    race_results.append([
                        race_name, division, gender_label,
                        rank, age_rank, name, nation,
                        age_group, total_time
                    ])
                scraped_any = True
            except:
                continue

        print(f"[{race_name}] Page {page_number} scraped for {division} - {gender_label}")
        page_number += 1

        # Go to next page
        try:
            next_button = driver.find_element(By.XPATH, "//a[text()='>']")
            driver.execute_script("arguments[0].click();", next_button)
            human_pause(3, 6)
        except NoSuchElementException:
            break

    return scraped_any

# ==========================
# RACE SCRAPER (THREAD TARGET)
# ==========================

def scrape_race(season, base_url, race_name, race_value):
    driver = create_driver()
    season_folder = os.path.join(SAVE_ROOT, season)
    os.makedirs(season_folder, exist_ok=True)

    safe_name = race_name.replace(" ", "_").replace("/", "-")
    print(f"\n[{race_name}] Starting race scraping")

    driver.get(base_url)
    human_pause(4, 6)
    Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
    human_pause(2,4)
    select_division = Select(driver.find_element(By.ID, "default-lists-event"))
    available = [o.text for o in select_division.options]

    def build_priority(base_name):
        priority = []
        if base_name in available:
            priority.append(base_name)
        overall = f"{base_name} - Overall"
        if overall in available:
            priority.append(overall)
        other = [d for d in available if d.startswith(f"{base_name} -") and d not in priority]
        priority.extend(other)
        return priority

    def process_group(base_name):
        priority_list = build_priority(base_name)
        if not priority_list:
            print(f"[{race_name}] No {base_name} divisions available")
            return

        for div in priority_list:
            div_safe = div.replace(" ", "_").replace("/", "-")
            file_path = os.path.join(season_folder, f"{safe_name}_{div_safe}.csv")
            if os.path.exists(file_path):
                print(f"[{race_name}] {div} already scraped")
                continue

            print(f"[{race_name}] Trying {div}")
            is_doubles = "DOUBLES" in div.upper()
            genders = [("M","Male"),("W","Women")] if not is_doubles else [("M","Male"),("W","Female"),("X","Mixed")]

            division_results = []
            division_has_data = False

            driver.get(base_url)
            human_pause(3,6)
            Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
            human_pause(2,4)
            Select(driver.find_element(By.ID, "default-lists-event")).select_by_visible_text(div)
            human_pause(2,4)

            try:
                gender_dropdown = Select(driver.find_element(By.ID, "default-lists-sex"))
                available_gender_values = [o.get_attribute("value") for o in gender_dropdown.options]
            except NoSuchElementException:
                available_gender_values = []

            valid_genders = [(code, label) for code, label in genders if code in available_gender_values]
            if not valid_genders:
                print(f"[{race_name}] {div} has no gender categories")
                continue

            for idx, (gender_code, gender_label) in enumerate(valid_genders):
                print(f"[{race_name}] Scraping gender: {gender_label} in {div}")
                driver.get(base_url)
                human_pause(3,6)
                Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
                human_pause(2,4)
                Select(driver.find_element(By.ID, "default-lists-event")).select_by_visible_text(div)
                human_pause(2,4)
                Select(driver.find_element(By.ID, "default-lists-sex")).select_by_value(gender_code)
                Select(driver.find_element(By.ID, "default-num_results")).select_by_value("100")
                human_pause(2,4)
                driver.find_element(By.ID, "default-submit").click()
                human_pause(5,10)

                has_data = scrape_pages(driver, race_name, div, gender_label, division_results)
                if idx == 0 and not has_data:
                    print(f"[{race_name}] {div} had NO DATA")
                    division_has_data = False
                    break
                if has_data:
                    division_has_data = True

            if division_has_data:
                df = pd.DataFrame(
                    division_results,
                    columns=["Race","Division","Gender",
                             "Rank Overall","Rank Age Group",
                             "Name","Nation","Age Group","Total Time"]
                )
                df.to_csv(file_path,index=False)
                print(f"[{race_name}] Saved {len(df)} rows for {div}")

    process_group("HYROX PRO")
    process_group("HYROX PRO DOUBLES")

    driver.quit()
    return f"[{race_name}] Finished scraping"

# ==========================
# MAIN LOOP
# ==========================

all_tasks = []
for season, base_url in BASE_URLS.items():
    driver_main = create_driver()
    driver_main.get(base_url)
    human_pause(4,6)
    try:
        WebDriverWait(driver_main, 25).until(EC.presence_of_element_located((By.ID, "default-lists-event_main_group")))
    except TimeoutException:
        continue
    race_dropdown = Select(driver_main.find_element(By.ID, "default-lists-event_main_group"))
    races = [(race_dropdown.options[i].text, race_dropdown.options[i].get_attribute("value")) for i in range(len(race_dropdown.options))]
    driver_main.quit()
    for race_name, race_value in races:
        all_tasks.append((season, base_url, race_name, race_value))

# Threaded execution
with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
    futures = [executor.submit(scrape_race, *task) for task in all_tasks]
    for f in futures:
        print(f.result())

print("\nALL DONE.")
# Out:
# [2024 Incheon] Starting race scraping
#
# [2024 Taipei] Starting race scraping
#
# [2024 Madrid] Starting race scraping
#
# [2024 Gainful Anaheim] Starting race scraping
#
# [2024 Mexico City] Starting race scraping
#
# [2024 Rimini] Starting race scraping
#
# [2024 New York] Starting race scraping
#
# [2024 Doha All Women's Race] Starting race scraping
#
# [2024 Manchester] Starting race scraping
#
# [2024 World Championships Nice] Starting race scraping
#
# [2024 Doha] Starting race scraping
#
# [2024 Malaga] Starting race scraping
#
# [2024 Bordeaux] Starting race scraping
#
# [2024 Sports Direct HYROX London] Starting race scraping
#
# [2024 Berlin] Starting race scraping
#
# [2024 Köln] Starting race scraping
#
# [2024 Gdansk] Starting race scraping
# [2024 Houston] Starting race scraping
#
#
# [2024 Rotterdam] Starting race scraping
#
# [2024 Copenhagen] Starting race scraping
# [2024 New York] Trying HYROX PRO[2024 Doha All Women's Race] Trying HYROX PRO
#
# [2024 Gainful Anaheim] Trying HYROX PRO
# [2024 Bordeaux] Trying HYROX PRO
# [2024 Madrid] Trying HYROX PRO
# [2024 Taipei] Trying HYROX PRO
# [2024 World Championships Nice] Trying HYROX PRO
# [2024 Malaga] Trying HYROX PRO
# [2024 Incheon] Trying HYROX PRO
# [2024 Doha] Trying HYROX PRO
# [2024 Gdansk] Trying HYROX PRO
# [2024 Manchester] Trying HYROX PRO
# [2024 Mexico City] Trying HYROX PRO
# [2024 Rimini] Trying HYROX PRO
# [2024 Houston] Trying HYROX PRO
# [2024 Köln] Trying HYROX PRO
# [2024 Sports Direct HYROX London] Trying HYROX PRO
# [2024 Rotterdam] Trying HYROX PRO
# [2024 Berlin] Trying HYROX PRO
# [2024 Copenhagen] Trying HYROX PRO
# [2024 Doha All Women's Race] Scraping gender: Male in HYROX PRO
# [2024 Gainful Anaheim] Scraping gender: Male in HYROX PRO
# [2024 New York] Scraping gender: Male in HYROX PRO
# [2024 Mexico City] Scraping gender: Male in HYROX PRO
# [2024 Rimini] Scraping gender: Male in HYROX PRO
# [2024 Incheon] Scraping gender: Male in HYROX PRO
# [2024 Madrid] Scraping gender: Male in HYROX PRO
# [2024 Doha] Scraping gender: Male in HYROX PRO
# [2024 Bordeaux] Scraping gender: Male in HYROX PRO
# [2024 World Championships Nice] Scraping gender: Male in HYROX PRO
# [2024 Malaga] Scraping gender: Male in HYROX PRO
# [2024 Taipei] Scraping gender: Male in HYROX PRO
# [2024 Manchester] Scraping gender: Male in HYROX PRO
# [2024 Houston] Scraping gender: Male in HYROX PRO
# [2024 Gdansk] Scraping gender: Male in HYROX PRO
# [2024 Sports Direct HYROX London] Scraping gender: Male in HYROX PRO
# [2024 Rotterdam] Scraping gender: Male in HYROX PRO
# [2024 Berlin] Scraping gender: Male in HYROX PRO
# [2024 Köln] Scraping gender: Male in HYROX PRO
# [2024 Copenhagen] Scraping gender: Male in HYROX PRO
# [2024 Doha All Women's Race] No results for HYROX PRO - Male
# [2024 Doha All Women's Race] HYROX PRO had NO DATA
# [2024 Doha All Women's Race] Trying HYROX PRO DOUBLES
# [2024 Doha All Women's Race] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Doha] Page 1 scraped for HYROX PRO - Male
# [2024 Doha] Scraping gender: Women in HYROX PRO
# [2024 Taipei] Page 1 scraped for HYROX PRO - Male
# [2024 Taipei] Scraping gender: Women in HYROX PRO
# [2024 Doha All Women's Race] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Doha All Women's Race] Saved 7 rows for HYROX PRO DOUBLES
# [2024 Incheon] Page 1 scraped for HYROX PRO - Male
# [2024 Incheon] Scraping gender: Women in HYROX PRO
# [2024 Mexico City] Page 1 scraped for HYROX PRO - Male
#
# [2024 Karlsruhe] Starting race scraping
# [2024 World Championships Nice] Page 1 scraped for HYROX PRO - Male
# [2024 Houston] Page 1 scraped for HYROX PRO - Male
# [2024 Houston] Scraping gender: Women in HYROX PRO
# [2024 Gainful Anaheim] Page 1 scraped for HYROX PRO - Male
# [2024 New York] Page 1 scraped for HYROX PRO - Male
# [2024 Rimini] Page 1 scraped for HYROX PRO - Male
# [2024 Manchester] Page 1 scraped for HYROX PRO - Male
# [2024 Köln] Page 1 scraped for HYROX PRO - Male
# [2024 Madrid] Page 1 scraped for HYROX PRO - Male
# [2024 Bordeaux] Page 1 scraped for HYROX PRO - Male
# [2024 Malaga] Page 1 scraped for HYROX PRO - Male
# [2024 Berlin] Page 1 scraped for HYROX PRO - Male
# [2024 Sports Direct HYROX London] Page 1 scraped for HYROX PRO - Male
# [2024 Gdansk] Page 1 scraped for HYROX PRO - Male
# [2024 Rotterdam] Page 1 scraped for HYROX PRO - Male
# [2024 Karlsruhe] Trying HYROX PRO
# [2024 Copenhagen] Page 1 scraped for HYROX PRO - Male
# [2024 Malaga] Page 2 scraped for HYROX PRO - Male
# [2024 Malaga] Scraping gender: Women in HYROX PRO
# [2024 Gainful Anaheim] Page 2 scraped for HYROX PRO - Male
# [2024 Gainful Anaheim] Scraping gender: Women in HYROX PRO
# [2024 New York] Page 2 scraped for HYROX PRO - Male
# [2024 New York] Scraping gender: Women in HYROX PRO
# [2024 Mexico City] Page 2 scraped for HYROX PRO - Male
# [2024 Mexico City] Scraping gender: Women in HYROX PRO
# [2024 Taipei] Page 1 scraped for HYROX PRO - Women
# [2024 Taipei] Saved 95 rows for HYROX PRO
# [2024 Taipei] Trying HYROX PRO DOUBLES
# [2024 Gdansk] Page 2 scraped for HYROX PRO - Male
# [2024 Gdansk] Scraping gender: Women in HYROX PRO
# [2024 Doha] Page 1 scraped for HYROX PRO - Women
# [2024 Doha] Saved 76 rows for HYROX PRO
# [2024 Doha] Trying HYROX PRO DOUBLES
# [2024 Incheon] Page 1 scraped for HYROX PRO - Women
# [2024 Incheon] Saved 79 rows for HYROX PRO
# [2024 Incheon] Trying HYROX PRO DOUBLES
# [2024 Karlsruhe] Scraping gender: Male in HYROX PRO
# [2024 Madrid] Page 2 scraped for HYROX PRO - Male
# [2024 Madrid] Scraping gender: Women in HYROX PRO
# [2024 Rotterdam] Page 2 scraped for HYROX PRO - Male
# [2024 Rotterdam] Scraping gender: Women in HYROX PRO
# [2024 Taipei] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 World Championships Nice] Page 2 scraped for HYROX PRO - Male
# [2024 Doha] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Manchester] Page 2 scraped for HYROX PRO - Male
# [2024 Manchester] Scraping gender: Women in HYROX PRO
# [2024 Bordeaux] Page 2 scraped for HYROX PRO - Male
# [2024 Bordeaux] Scraping gender: Women in HYROX PRO
# [2024 Rimini] Page 2 scraped for HYROX PRO - Male
# [2024 Rimini] Scraping gender: Women in HYROX PRO
# [2024 Berlin] Page 2 scraped for HYROX PRO - Male
# [2024 Berlin] Scraping gender: Women in HYROX PRO
# [2024 Incheon] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Copenhagen] Page 2 scraped for HYROX PRO - Male
# [2024 Copenhagen] Scraping gender: Women in HYROX PRO
# [2024 Houston] Page 1 scraped for HYROX PRO - Women
# [2024 Houston] Saved 139 rows for HYROX PRO
# [2024 Houston] Trying HYROX PRO DOUBLES
# [2024 Köln] Page 2 scraped for HYROX PRO - Male
# [2024 Sports Direct HYROX London] Page 2 scraped for HYROX PRO - Male
# [2024 Malaga] Page 1 scraped for HYROX PRO - Women
# [2024 Malaga] Saved 151 rows for HYROX PRO
# [2024 Malaga] Trying HYROX PRO DOUBLES
# [2024 Houston] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Mexico City] Page 1 scraped for HYROX PRO - Women
# [2024 Mexico City] Saved 183 rows for HYROX PRO
# [2024 Mexico City] Trying HYROX PRO DOUBLES
# [2024 New York] Page 1 scraped for HYROX PRO - Women
# [2024 New York] Saved 173 rows for HYROX PRO
# [2024 New York] Trying HYROX PRO DOUBLES
# [2024 Köln] Page 3 scraped for HYROX PRO - Male
# [2024 Köln] Scraping gender: Women in HYROX PRO
# [2024 Gainful Anaheim] Page 1 scraped for HYROX PRO - Women
# [2024 Gainful Anaheim] Saved 200 rows for HYROX PRO
# [2024 Gainful Anaheim] Trying HYROX PRO DOUBLES
# [2024 Gdansk] Page 1 scraped for HYROX PRO - Women
# [2024 Sports Direct HYROX London] Page 3 scraped for HYROX PRO - Male
# [2024 Sports Direct HYROX London] Scraping gender: Women in HYROX PRO
# [2024 Gdansk] Saved 144 rows for HYROX PRO
# [2024 Gdansk] Trying HYROX PRO DOUBLES
# [2024 Malaga] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 World Championships Nice] Page 3 scraped for HYROX PRO - Male
# [2024 Doha] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Mexico City] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Doha] Saved 25 rows for HYROX PRO DOUBLES
# [2024 Madrid] Page 1 scraped for HYROX PRO - Women
# [2024 Madrid] Saved 181 rows for HYROX PRO
# [2024 Madrid] Trying HYROX PRO DOUBLES
# [2024 Taipei] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Taipei] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 New York] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Incheon] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Incheon] Scraping gender: Female in HYROX PRO DOUBLES
#
# [2024 Glasgow] Starting race scraping
# [2024 Gainful Anaheim] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Gdansk] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Rotterdam] Page 1 scraped for HYROX PRO - Women
# [2024 Rotterdam] Saved 214 rows for HYROX PRO
# [2024 Rotterdam] Trying HYROX PRO DOUBLES
# [2024 Karlsruhe] Page 1 scraped for HYROX PRO - Male
# [2024 Madrid] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Rimini] Page 1 scraped for HYROX PRO - Women
# [2024 Rimini] Saved 244 rows for HYROX PRO
# [2024 Rimini] Trying HYROX PRO DOUBLES
# [2024 Houston] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Houston] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Berlin] Page 1 scraped for HYROX PRO - Women
# [2024 Berlin] Saved 265 rows for HYROX PRO
# [2024 Berlin] Trying HYROX PRO DOUBLES
# [2024 Glasgow] Trying HYROX PRO
# [2024 Manchester] Page 1 scraped for HYROX PRO - Women
# [2024 Manchester] Saved 248 rows for HYROX PRO
# [2024 Manchester] Trying HYROX PRO DOUBLES
# [2024 Bordeaux] Page 1 scraped for HYROX PRO - Women
# [2024 Bordeaux] Saved 251 rows for HYROX PRO
# [2024 Bordeaux] Trying HYROX PRO DOUBLES
# [2024 Copenhagen] Page 1 scraped for HYROX PRO - Women
# [2024 Rotterdam] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Copenhagen] Saved 240 rows for HYROX PRO
# [2024 Copenhagen] Trying HYROX PRO DOUBLES
# [2024 Rimini] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Malaga] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Malaga] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 World Championships Nice] Page 4 scraped for HYROX PRO - Male
# [2024 Taipei] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Taipei] Saved 22 rows for HYROX PRO DOUBLES
# [2024 Bordeaux] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Manchester] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Incheon] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Incheon] Saved 21 rows for HYROX PRO DOUBLES
# [2024 Glasgow] Scraping gender: Male in HYROX PRO
#
# [2024 Washington - North American Championships] Starting race scraping
# [2024 Berlin] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Mexico City] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Mexico City] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Copenhagen] Scraping gender: Male in HYROX PRO DOUBLES
#
# [2024 Fort Lauderdale] Starting race scraping
# [2024 Köln] Page 1 scraped for HYROX PRO - Women
# [2024 Köln] Saved 314 rows for HYROX PRO
# [2024 Köln] Trying HYROX PRO DOUBLES
# [2024 Gdansk] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Gdansk] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Houston] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Houston] Saved 17 rows for HYROX PRO DOUBLES
# [2024 Gainful Anaheim] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Gainful Anaheim] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Washington - North American Championships] No HYROX PRO divisions available
# [2024 Washington - North American Championships] No HYROX PRO DOUBLES divisions available
# [2024 Karlsruhe] Page 2 scraped for HYROX PRO - Male
# [2024 Karlsruhe] Scraping gender: Women in HYROX PRO
# [2024 New York] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 New York] Scraping gender: Female in HYROX PRO DOUBLES
#
# [2024 Katowice] Starting race scraping
#
# [2024 Bilbao] Starting race scraping
# [2024 Madrid] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Madrid] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Sports Direct HYROX London] Page 1 scraped for HYROX PRO - Women
# [2024 Fort Lauderdale] Trying HYROX PRO
# [2024 Malaga] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Malaga] Saved 60 rows for HYROX PRO DOUBLES
# [2024 Köln] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Katowice] Trying HYROX PRO
#
# [2024 Dubai] Starting race scraping
# [2024 Bilbao] Trying HYROX PRO
# [2024 World Championships Nice] Page 5 scraped for HYROX PRO - Male
# [2024 Mexico City] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Mexico City] Saved 41 rows for HYROX PRO DOUBLES
# [2024 Fort Lauderdale] Scraping gender: Male in HYROX PRO
# [2024 Sports Direct HYROX London] Page 2 scraped for HYROX PRO - Women
# [2024 Sports Direct HYROX London] Saved 355 rows for HYROX PRO
# [2024 Sports Direct HYROX London] Trying HYROX PRO DOUBLES
# [2024 Rotterdam] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Berlin] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Berlin] Scraping gender: Female in HYROX PRO DOUBLES
#
# [2024 Vienna - European Championship] Starting race scraping
# [2024 Dubai] Trying HYROX PRO
# [2024 Gdansk] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Gdansk] Saved 39 rows for HYROX PRO DOUBLES
# [2024 Bilbao] Scraping gender: Male in HYROX PRO
# [2024 Gainful Anaheim] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Gainful Anaheim] Saved 38 rows for HYROX PRO DOUBLES
# [2024 Katowice] Scraping gender: Male in HYROX PRO
# [2024 Bordeaux] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Bordeaux] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Rotterdam] Page 2 scraped for HYROX PRO DOUBLES - Male
# [2024 Rotterdam] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Rimini] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Rimini] Scraping gender: Female in HYROX PRO DOUBLES
#
# [2024 Turin] Starting race scraping
#
# [2024 Maastricht] Starting race scraping
# [2024 New York] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 New York] Saved 47 rows for HYROX PRO DOUBLES
# [2024 Madrid] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Madrid] Saved 56 rows for HYROX PRO DOUBLES
# [2024 Sports Direct HYROX London] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Vienna - European Championship] No HYROX PRO divisions available
# [2024 Vienna - European Championship] No HYROX PRO DOUBLES divisions available
#
# [2023 Los Angeles] Starting race scraping
#
# [2023 Frankfurt] Starting race scraping
# [2024 Glasgow] Page 1 scraped for HYROX PRO - Male
# [2024 Manchester] Page 1 scraped for HYROX PRO DOUBLES - Male
#
# [2023 Stockholm] Starting race scraping
# [2024 Copenhagen] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Copenhagen] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Dubai] Scraping gender: Male in HYROX PRO
# [2024 Turin] Trying HYROX PRO
# [2024 Maastricht] Trying HYROX PRO
# [2024 Karlsruhe] Page 1 scraped for HYROX PRO - Women
# [2024 Karlsruhe] Saved 233 rows for HYROX PRO
# [2024 Karlsruhe] Trying HYROX PRO DOUBLES
# [2023 Los Angeles] Trying HYROX PRO
# [2024 Manchester] Page 2 scraped for HYROX PRO DOUBLES - Male
# [2024 Manchester] Scraping gender: Female in HYROX PRO DOUBLES
# [2023 Frankfurt] Trying HYROX PRO
# [2023 Stockholm] Trying HYROX PRO
# [2024 Turin] Scraping gender: Male in HYROX PRO
# [2024 Maastricht] Scraping gender: Male in HYROX PRO
# [2024 World Championships Nice] Page 6 scraped for HYROX PRO - Male
# [2024 Berlin] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Berlin] Saved 79 rows for HYROX PRO DOUBLES
# [2024 Karlsruhe] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Köln] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Köln] Scraping gender: Female in HYROX PRO DOUBLES
# [2023 Los Angeles] Scraping gender: Male in HYROX PRO
# [2024 Rimini] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Rimini] Saved 102 rows for HYROX PRO DOUBLES
#
# [2023 London] Starting race scraping
# [2024 Bordeaux] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Bordeaux] Saved 100 rows for HYROX PRO DOUBLES
# [2023 Frankfurt] Scraping gender: Male in HYROX PRO
# [2023 Stockholm] Scraping gender: Male in HYROX PRO
#
# [2023 Hong Kong] Starting race scraping
#
# [2023 Dallas] Starting race scraping
# [2024 Rotterdam] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Rotterdam] Saved 147 rows for HYROX PRO DOUBLES
# [2023 London] Trying HYROX PRO
#
# [2023 Barcelona] Starting race scraping
# [2024 Copenhagen] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Copenhagen] Saved 89 rows for HYROX PRO DOUBLES
# [2023 Hong Kong] Trying HYROX PRO
# [2024 Glasgow] Page 2 scraped for HYROX PRO - Male
# [2024 Glasgow] Scraping gender: Women in HYROX PRO
# [2023 Dallas] Trying HYROX PRO
#
# [2023 Hamburg] Starting race scraping
# [2024 Fort Lauderdale] Page 1 scraped for HYROX PRO - Male
# [2023 Barcelona] Trying HYROX PRO
# [2023 London] Scraping gender: Male in HYROX PRO
# [2024 Katowice] Page 1 scraped for HYROX PRO - Male
# [2023 Hong Kong] Scraping gender: Male in HYROX PRO
# [2024 Bilbao] Page 1 scraped for HYROX PRO - Male
# [2024 Bilbao] Scraping gender: Women in HYROX PRO
# [2024 Fort Lauderdale] Page 2 scraped for HYROX PRO - Male
# [2024 Fort Lauderdale] Scraping gender: Women in HYROX PRO
# [2023 Dallas] Scraping gender: Male in HYROX PRO
# [2023 Hamburg] Trying HYROX PRO
# [2024 Dubai] Page 1 scraped for HYROX PRO - Male
# [2024 Dubai] Scraping gender: Women in HYROX PRO
# [2024 Sports Direct HYROX London] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Köln] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Köln] Scraping gender: Mixed in HYROX PRO DOUBLES
# [2023 Barcelona] Scraping gender: Male in HYROX PRO
# [2024 Manchester] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Manchester] Saved 186 rows for HYROX PRO DOUBLES
# [2024 Katowice] Page 2 scraped for HYROX PRO - Male
# [2024 Katowice] Scraping gender: Women in HYROX PRO
# [2024 World Championships Nice] Page 7 scraped for HYROX PRO - Male
# [2024 Karlsruhe] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Karlsruhe] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Manchester] Finished scraping
# [2024 Madrid] Finished scraping
# [2024 Incheon] Finished scraping
#
# [2023 Chicago] Starting race scraping
# [2023 Hamburg] Scraping gender: Male in HYROX PRO
# [2024 Sports Direct HYROX London] Page 2 scraped for HYROX PRO DOUBLES - Male
# [2024 Sports Direct HYROX London] Scraping gender: Female in HYROX PRO DOUBLES
# [2023 Stockholm] Page 1 scraped for HYROX PRO - Male
# [2023 Stockholm] Scraping gender: Women in HYROX PRO
# [2024 Maastricht] Page 1 scraped for HYROX PRO - Male
# [2024 Turin] Page 1 scraped for HYROX PRO - Male
# [2023 Los Angeles] Page 1 scraped for HYROX PRO - Male
# [2023 Los Angeles] Scraping gender: Women in HYROX PRO
# [2023 Chicago] Trying HYROX PRO
# [2024 Maastricht] Page 2 scraped for HYROX PRO - Male
# [2024 Maastricht] Scraping gender: Women in HYROX PRO
# [2023 Frankfurt] Page 1 scraped for HYROX PRO - Male
# [2024 Köln] No results for HYROX PRO DOUBLES - Mixed
# [2024 Köln] Saved 118 rows for HYROX PRO DOUBLES
# [2024 Glasgow] Page 1 scraped for HYROX PRO - Women
# [2024 Glasgow] Saved 272 rows for HYROX PRO
# [2024 Glasgow] Trying HYROX PRO DOUBLES
# [2024 Dubai] Page 1 scraped for HYROX PRO - Women
# [2024 Dubai] Saved 88 rows for HYROX PRO
# [2024 Dubai] Trying HYROX PRO DOUBLES
#
# [2023 Paris] Starting race scraping
# [2023 Hong Kong] Page 1 scraped for HYROX PRO - Male
# [2023 Hong Kong] Scraping gender: Women in HYROX PRO
# [2023 Chicago] Scraping gender: Male in HYROX PRO
# [2024 Bilbao] Page 1 scraped for HYROX PRO - Women
# [2024 Bilbao] Saved 119 rows for HYROX PRO
# [2024 Bilbao] Trying HYROX PRO DOUBLES
# [2024 Karlsruhe] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Karlsruhe] Saved 68 rows for HYROX PRO DOUBLES
# [2024 Fort Lauderdale] Page 1 scraped for HYROX PRO - Women
# [2024 Fort Lauderdale] Saved 153 rows for HYROX PRO
# [2024 Fort Lauderdale] Trying HYROX PRO DOUBLES
# [2024 Turin] Page 2 scraped for HYROX PRO - Male
# [2024 Turin] Scraping gender: Women in HYROX PRO
# [2024 Katowice] Page 1 scraped for HYROX PRO - Women
# [2024 Katowice] Saved 142 rows for HYROX PRO
# [2024 Katowice] Trying HYROX PRO DOUBLES
# [2024 Dubai] Scraping gender: Male in HYROX PRO DOUBLES
#
# [2023 Amsterdam] Starting race scraping
# [2023 Paris] Trying HYROX PRO
# [2024 World Championships Nice] Page 8 scraped for HYROX PRO - Male
# [2024 Glasgow] Scraping gender: Male in HYROX PRO DOUBLES
# [2023 London] Page 1 scraped for HYROX PRO - Male
# [2023 Stockholm] Page 1 scraped for HYROX PRO - Women
# [2023 Stockholm] Saved 86 rows for HYROX PRO
# [2023 Stockholm] No HYROX PRO DOUBLES divisions available
# [2024 Fort Lauderdale] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Bilbao] Scraping gender: Male in HYROX PRO DOUBLES
#
# [2023 Dublin] Starting race scraping
# [2024 Katowice] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Sports Direct HYROX London] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Sports Direct HYROX London] Scraping gender: Mixed in HYROX PRO DOUBLES
# [2023 Amsterdam] Trying HYROX PRO
# [2023 Frankfurt] Page 2 scraped for HYROX PRO - Male
# [2023 Frankfurt] Scraping gender: Women in HYROX PRO
# [2023 Paris] Scraping gender: Male in HYROX PRO
# [2023 Dallas] Page 1 scraped for HYROX PRO - Male
# [2023 Los Angeles] Page 1 scraped for HYROX PRO - Women
# [2023 Los Angeles] Saved 131 rows for HYROX PRO
# [2023 Los Angeles] No HYROX PRO DOUBLES divisions available
# [2024 Maastricht] Page 1 scraped for HYROX PRO - Women
# [2024 Maastricht] Saved 141 rows for HYROX PRO
# [2024 Maastricht] Trying HYROX PRO DOUBLES
#
# [2023 Valencia] Starting race scraping
# [2024 World Championships Nice] Page 9 scraped for HYROX PRO - Male
# [2024 World Championships Nice] Scraping gender: Women in HYROX PRO
# [2023 Hamburg] Page 1 scraped for HYROX PRO - Male
# [2023 Barcelona] Page 1 scraped for HYROX PRO - Male
# [2023 Hong Kong] Page 1 scraped for HYROX PRO - Women
# [2023 Hong Kong] Saved 58 rows for HYROX PRO
# [2023 Hong Kong] No HYROX PRO DOUBLES divisions available
# [2023 Dublin] Trying HYROX PRO
# [2023 Dallas] Page 2 scraped for HYROX PRO - Male
# [2023 Dallas] Scraping gender: Women in HYROX PRO
# [2024 Dubai] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Dubai] Scraping gender: Female in HYROX PRO DOUBLES
# [2023 Amsterdam] Scraping gender: Male in HYROX PRO
#
# [2023 Birmingham] Starting race scraping
# [2023 Hamburg] Page 2 scraped for HYROX PRO - Male
# [2023 Hamburg] Scraping gender: Women in HYROX PRO
# [2024 Maastricht] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Fort Lauderdale] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Fort Lauderdale] Scraping gender: Female in HYROX PRO DOUBLES
# [2023 Valencia] Trying HYROX PRO
# [2024 Turin] Page 1 scraped for HYROX PRO - Women
# [2024 Turin] Saved 183 rows for HYROX PRO
# [2024 Turin] Trying HYROX PRO DOUBLES
# [2023 London] Page 2 scraped for HYROX PRO - Male
# [2023 Dublin] Scraping gender: Male in HYROX PRO
# [2024 Sports Direct HYROX London] No results for HYROX PRO DOUBLES - Mixed
# [2024 Sports Direct HYROX London] Saved 178 rows for HYROX PRO DOUBLES
# [2023 Barcelona] Page 2 scraped for HYROX PRO - Male
# [2023 Barcelona] Scraping gender: Women in HYROX PRO
# [2023 Birmingham] Trying HYROX PRO
# [2024 Bilbao] Page 1 scraped for HYROX PRO DOUBLES - Male
#
# [2023 München] Starting race scraping
# [2024 Bilbao] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Katowice] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Katowice] Scraping gender: Female in HYROX PRO DOUBLES
# [2023 Valencia] Scraping gender: Male in HYROX PRO
# [2024 Turin] Scraping gender: Male in HYROX PRO DOUBLES
# [2023 Chicago] Page 1 scraped for HYROX PRO - Male
# [2024 Glasgow] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Dubai] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Dubai] Saved 17 rows for HYROX PRO DOUBLES
# [2023 Birmingham] Scraping gender: Male in HYROX PRO
# [2023 Frankfurt] Page 1 scraped for HYROX PRO - Women
# [2023 Frankfurt] Saved 236 rows for HYROX PRO
# [2023 Frankfurt] No HYROX PRO DOUBLES divisions available
#
# [2023 Singapore] Starting race scraping
# [2023 Dallas] Page 1 scraped for HYROX PRO - Women
# [2023 Dallas] Saved 151 rows for HYROX PRO
# [2023 Dallas] No HYROX PRO DOUBLES divisions available
# [2023 München] Trying HYROX PRO
#
# [2023 Milan] Starting race scraping
#
# [2023 Malmö] Starting race scraping
# [2024 Fort Lauderdale] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Fort Lauderdale] Saved 17 rows for HYROX PRO DOUBLES
# [2023 Chicago] Page 2 scraped for HYROX PRO - Male
# [2023 Chicago] Scraping gender: Women in HYROX PRO
# [2023 Hamburg] Page 1 scraped for HYROX PRO - Women
# [2023 Hamburg] Saved 144 rows for HYROX PRO
# [2023 Hamburg] No HYROX PRO DOUBLES divisions available
# [2024 Glasgow] Page 2 scraped for HYROX PRO DOUBLES - Male
# [2024 Glasgow] Scraping gender: Female in HYROX PRO DOUBLES
# [2024 Maastricht] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Maastricht] Scraping gender: Female in HYROX PRO DOUBLES
#
# [2023 Madrid] Starting race scraping
# [2023 Singapore] Trying HYROX PRO
# [2023 Milan] Trying HYROX PRO
#
# [2023 Warschau] Starting race scraping
# [2023 München] Scraping gender: Male in HYROX PRO
# [2023 Malmö] Trying HYROX PRO
# [2023 Paris] Page 1 scraped for HYROX PRO - Male
# [2023 London] Page 3 scraped for HYROX PRO - Male
# [2024 Bilbao] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Bilbao] Saved 35 rows for HYROX PRO DOUBLES
# [2023 Barcelona] Page 1 scraped for HYROX PRO - Women
# [2023 Barcelona] Saved 180 rows for HYROX PRO
# [2023 Barcelona] No HYROX PRO DOUBLES divisions available
# [2024 Katowice] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Katowice] Saved 36 rows for HYROX PRO DOUBLES
# [2023 Madrid] Trying HYROX PRO
#
# [2023 Dubai] Starting race scraping
# [2023 Warschau] Trying HYROX PRO
# [2023 Milan] Scraping gender: Male in HYROX PRO
#
# [2023 Melbourne] Starting race scraping
# [2023 Singapore] Scraping gender: Male in HYROX PRO
#
# [2023 Sydney] Starting race scraping
# [2024 World Championships Nice] Page 1 scraped for HYROX PRO - Women
# [2023 Malmö] Scraping gender: Male in HYROX PRO
# [2023 Madrid] Scraping gender: Male in HYROX PRO
# [2023 London] Page 4 scraped for HYROX PRO - Male
# [2023 London] Scraping gender: Women in HYROX PRO
# [2023 Melbourne] Trying HYROX PRO
# [2023 Amsterdam] Page 1 scraped for HYROX PRO - Male
# [2023 Warschau] Scraping gender: Male in HYROX PRO
# [2023 Dubai] Trying HYROX PRO
# [2023 Sydney] Trying HYROX PRO
# [2023 Dublin] Page 1 scraped for HYROX PRO - Male
# [2023 Dublin] Scraping gender: Women in HYROX PRO
# [2024 Turin] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2024 Turin] Scraping gender: Female in HYROX PRO DOUBLES
# [2023 Paris] Page 2 scraped for HYROX PRO - Male
# [2023 Paris] Scraping gender: Women in HYROX PRO
# [2023 Amsterdam] Page 2 scraped for HYROX PRO - Male
# [2023 Amsterdam] Scraping gender: Women in HYROX PRO
# [2024 Maastricht] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Maastricht] Saved 45 rows for HYROX PRO DOUBLES
# [2023 Valencia] Page 1 scraped for HYROX PRO - Male
# [2023 Valencia] Scraping gender: Women in HYROX PRO
# [2023 Melbourne] Scraping gender: Male in HYROX PRO
# [2023 Chicago] Page 1 scraped for HYROX PRO - Women
# [2023 Chicago] Saved 168 rows for HYROX PRO
# [2023 Chicago] No HYROX PRO DOUBLES divisions available
#
# [2023 New York] Starting race scraping
# [2023 Dubai] Scraping gender: Male in HYROX PRO
# [2023 Sydney] Scraping gender: Male in HYROX PRO
#
# [2023 Rimini] Starting race scraping
# [2023 Birmingham] Page 1 scraped for HYROX PRO - Male
# [2024 Glasgow] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Glasgow] Saved 202 rows for HYROX PRO DOUBLES
# [2024 World Championships Nice] Page 2 scraped for HYROX PRO - Women
#
# [2025 Shanghai] Starting race scraping
# [2023 New York] Trying HYROX PRO
# [2023 Malmö] Page 1 scraped for HYROX PRO - Male
# [2023 Malmö] Scraping gender: Women in HYROX PRO
# [2023 Rimini] Trying HYROX PRO
# [2023 München] Page 1 scraped for HYROX PRO - Male
# [2023 Birmingham] Page 2 scraped for HYROX PRO - Male
# [2023 Birmingham] Scraping gender: Women in HYROX PRO
# [2023 Singapore] Page 1 scraped for HYROX PRO - Male
# [2023 Singapore] Scraping gender: Women in HYROX PRO
# [2025 Shanghai] HYROX PRO already scraped
# [2025 Shanghai] HYROX PRO DOUBLES already scraped
# [2023 New York] Scraping gender: Male in HYROX PRO
# [2023 Rimini] Scraping gender: Male in HYROX PRO
#
# [2025 Atlanta] Starting race scraping
# [2024 Turin] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2024 Turin] Scraping gender: Mixed in HYROX PRO DOUBLES
# [2023 Paris] Page 1 scraped for HYROX PRO - Women
# [2023 Paris] Saved 193 rows for HYROX PRO
# [2023 Paris] No HYROX PRO DOUBLES divisions available
# [2023 München] Page 2 scraped for HYROX PRO - Male
# [2023 München] Scraping gender: Women in HYROX PRO
# [2023 Warschau] Page 1 scraped for HYROX PRO - Male
# [2023 Warschau] Scraping gender: Women in HYROX PRO
# [2023 Amsterdam] Page 1 scraped for HYROX PRO - Women
# [2023 Amsterdam] Saved 152 rows for HYROX PRO
# [2023 Amsterdam] No HYROX PRO DOUBLES divisions available
# [2023 Milan] Page 1 scraped for HYROX PRO - Male
#
# [2025 Valencia] Starting race scraping
# [2023 Valencia] Page 1 scraped for HYROX PRO - Women
# [2023 Valencia] Saved 113 rows for HYROX PRO
# [2023 Valencia] No HYROX PRO DOUBLES divisions available
#
# [2025 Maastricht] Starting race scraping
# [2025 Atlanta] HYROX PRO - Overall already scraped
# [2025 Atlanta] Trying HYROX PRO - Saturday
# [2023 London] Page 1 scraped for HYROX PRO - Women
#
# [2025 Mumbai] Starting race scraping
# [2023 Dublin] Page 1 scraped for HYROX PRO - Women
# [2023 Dublin] Saved 173 rows for HYROX PRO
# [2023 Dublin] No HYROX PRO DOUBLES divisions available
# [2025 Valencia] HYROX PRO - Overall already scraped
# [2025 Valencia] HYROX PRO - Saturday already scraped
# [2025 Valencia] HYROX PRO - Sunday already scraped
# [2025 Valencia] Trying HYROX PRO DOUBLES - Overall
# [2023 Madrid] Page 1 scraped for HYROX PRO - Male
# [2023 Dubai] Page 1 scraped for HYROX PRO - Male
# [2023 Dubai] Scraping gender: Women in HYROX PRO
#
# [2025 World Championships] Starting race scraping
# [2025 Maastricht] HYROX PRO already scraped
# [2025 Maastricht] HYROX PRO DOUBLES already scraped
# [2025 Atlanta] Scraping gender: Male in HYROX PRO - Saturday
# [2024 World Championships Nice] Page 3 scraped for HYROX PRO - Women
# [2023 Milan] Page 2 scraped for HYROX PRO - Male
# [2023 Milan] Scraping gender: Women in HYROX PRO
# [2023 Melbourne] Page 1 scraped for HYROX PRO - Male[2023 London] Page 2 scraped for HYROX PRO - Women
#
# [2023 Melbourne] Scraping gender: Women in HYROX PRO
# [2023 London] Saved 444 rows for HYROX PRO
# [2023 London] No HYROX PRO DOUBLES divisions available
# [2023 Malmö] Page 1 scraped for HYROX PRO - Women
# [2023 Malmö] Saved 73 rows for HYROX PRO
# [2023 Malmö] No HYROX PRO DOUBLES divisions available
# [2025 Mumbai] HYROX PRO already scraped
# [2025 Mumbai] HYROX PRO DOUBLES already scraped
# [2024 Turin] Page 1 scraped for HYROX PRO DOUBLES - Mixed
# [2024 Turin] Saved 98 rows for HYROX PRO DOUBLES
#
# [2025 Cardiff] Starting race scraping
# [2023 Sydney] Page 1 scraped for HYROX PRO - Male
# [2023 Sydney] Scraping gender: Women in HYROX PRO
# [2023 Madrid] Page 2 scraped for HYROX PRO - Male
# [2023 Madrid] Scraping gender: Women in HYROX PRO
#
# [2025 New York] Starting race scraping
# [2025 Valencia] Scraping gender: Male in HYROX PRO DOUBLES - Overall
#
# [2025 Riga] Starting race scraping
#
# [2025 Rimini] Starting race scraping
# [2023 Warschau] Page 1 scraped for HYROX PRO - Women
# [2023 Warschau] Saved 66 rows for HYROX PRO
# [2023 Warschau] No HYROX PRO DOUBLES divisions available
#
# [2025 Bangkok] Starting race scraping
#
# [2025 Berlin] Starting race scraping
# [2025 World Championships] Trying HYROX PRO - Overall
# [2023 Singapore] Page 1 scraped for HYROX PRO - Women
# [2023 Singapore] Saved 122 rows for HYROX PRO
# [2023 Singapore] No HYROX PRO DOUBLES divisions available
# [2025 Cardiff] HYROX PRO - Overall already scraped
# [2025 Cardiff] HYROX PRO - Friday already scraped
# [2025 Cardiff] HYROX PRO - Saturday already scraped
# [2025 Cardiff] HYROX PRO DOUBLES - Overall already scraped
# [2025 Cardiff] HYROX PRO DOUBLES - Friday already scraped
# [2025 Cardiff] HYROX PRO DOUBLES - Saturday already scraped
# [2025 Rimini] HYROX PRO - Overall already scraped
# [2025 Rimini] HYROX PRO - Friday already scraped
# [2025 Rimini] HYROX PRO - Saturday already scraped
# [2025 Rimini] HYROX PRO DOUBLES - Friday already scraped
#
# [2025 Incheon] Starting race scraping
# [2025 Rimini] HYROX PRO DOUBLES - Saturday already scraped
# [2025 Rimini] HYROX PRO DOUBLES - Saturday already scraped
# [2025 New York] HYROX PRO - Overall already scraped
# [2025 New York] HYROX PRO - Friday already scraped
# [2025 New York] HYROX PRO - Saturday already scraped
# [2025 New York] HYROX PRO DOUBLES - Overall already scraped
# [2025 New York] HYROX PRO DOUBLES - Friday already scraped
# [2025 New York] HYROX PRO DOUBLES - Saturday already scraped
# [2025 Riga] HYROX PRO already scraped
# [2025 Riga] HYROX PRO DOUBLES already scraped
# [2023 München] Page 1 scraped for HYROX PRO - Women
# [2023 München] Saved 157 rows for HYROX PRO
# [2023 München] No HYROX PRO DOUBLES divisions available
# [2025 Bangkok] HYROX PRO - Saturday already scraped
# [2025 Bangkok] HYROX PRO DOUBLES - Saturday already scraped
# [2023 Birmingham] Page 1 scraped for HYROX PRO - Women
# [2023 Birmingham] Saved 200 rows for HYROX PRO
# [2023 Birmingham] No HYROX PRO DOUBLES divisions available
#
# [2025 Heerenveen] Starting race scraping
#
# [2025 London] Starting race scraping
#
# [2025 Barcelona] Starting race scraping
# [2025 World Championships] Scraping gender: Male in HYROX PRO - Overall
#
# [2025 Miami Beach] Starting race scraping
#
# [2025 Paris 1] Starting race scraping
#
# [2025 Cologne] Starting race scraping
#
# [2025 Sharjah] Starting race scraping
# [2025 Berlin] HYROX PRO - Overall already scraped
# [2025 Berlin] HYROX PRO - Friday already scraped
# [2025 Berlin] HYROX PRO - Saturday already scraped
# [2025 Berlin] Trying HYROX PRO DOUBLES - Friday
# [2025 Incheon] HYROX PRO already scraped
# [2025 Incheon] HYROX PRO DOUBLES already scraped
# [2025 Heerenveen] HYROX PRO - Saturday already scraped
# [2025 Heerenveen] HYROX PRO DOUBLES - Saturday already scraped
# [2023 Rimini] Page 1 scraped for HYROX PRO - Male
# [2023 Rimini] Scraping gender: Women in HYROX PRO
#
# [2025 Taipei] Starting race scraping
# [2025 Barcelona] HYROX PRO - Saturday already scraped
# [2025 Barcelona] HYROX PRO DOUBLES - Saturday already scraped
# [2025 Valencia] No results for HYROX PRO DOUBLES - Overall - Male
# [2025 Valencia] HYROX PRO DOUBLES - Overall had NO DATA
# [2025 Valencia] HYROX PRO DOUBLES - Saturday already scraped
# [2025 Valencia] HYROX PRO DOUBLES - Sunday already scraped
# [2025 London] HYROX PRO already scraped
# [2025 London] HYROX PRO DOUBLES already scraped
# [2025 Miami Beach] HYROX PRO already scraped
# [2025 Miami Beach] HYROX PRO DOUBLES already scraped
# [2025 Paris 1] HYROX PRO - Overall already scraped
# [2025 Paris 1] Trying HYROX PRO - Friday
# [2023 Milan] Page 1 scraped for HYROX PRO - Women
# [2023 Milan] Saved 157 rows for HYROX PRO
# [2023 Milan] No HYROX PRO DOUBLES divisions available
#
# [2025 Warsaw] Starting race scraping
# [2023 Melbourne] Page 1 scraped for HYROX PRO - Women
# [2023 Dubai] Page 1 scraped for HYROX PRO - Women
# [2023 Dubai] Saved 91 rows for HYROX PRO
# [2023 Dubai] No HYROX PRO DOUBLES divisions available
# [2023 Melbourne] Saved 98 rows for HYROX PRO
# [2023 Melbourne] No HYROX PRO DOUBLES divisions available
# [2023 Sydney] Page 1 scraped for HYROX PRO - Women
# [2023 Sydney] Saved 93 rows for HYROX PRO
# [2023 Sydney] No HYROX PRO DOUBLES divisions available
# [2025 Sharjah] HYROX PRO already scraped
# [2025 Sharjah] HYROX PRO DOUBLES already scraped
#
# [2025 Belgium] Starting race scraping
#
# [2025 Monterrey] Starting race scraping
#
# [2025 Washington D.C. Open North American Championships] Starting race scraping
#
# [2025 Malaga] Starting race scraping
# [2025 Berlin] Scraping gender: Male in HYROX PRO DOUBLES - Friday
#
# [2025 Copenhagen] Starting race scraping
#
# [2025 Houston] Starting race scraping
#
# [2025 Glasgow] Starting race scraping
#
# [2025 Brisbane] Starting race scraping
#
# [2025 Johannesburg I] Starting race scraping
# [2025 Cologne] HYROX PRO - Overall already scraped
# [2025 Cologne] Trying HYROX PRO - Thursday
# [2025 Taipei] HYROX PRO already scraped
# [2025 Taipei] HYROX PRO DOUBLES already scraped
# [2025 Belgium] HYROX PRO already scraped
# [2025 Belgium] HYROX PRO DOUBLES already scraped
# [2025 Warsaw] HYROX PRO - Overall already scraped
# [2025 Warsaw] Trying HYROX PRO - Saturday
# [2025 Paris 1] Scraping gender: Male in HYROX PRO - Friday
# [2025 Monterrey] HYROX PRO already scraped
# [2025 Monterrey] HYROX PRO DOUBLES already scraped
#
# [2025 Karlsruhe] Starting race scraping
#
# [2025 Rotterdam] Starting race scraping
# [2025 Washington D.C. Open North American Championships] No HYROX PRO divisions available
# [2025 Washington D.C. Open North American Championships] No HYROX PRO DOUBLES divisions available
# [2025 Johannesburg I] HYROX PRO already scraped
# [2025 Johannesburg I] HYROX PRO DOUBLES already scraped
# [2025 Malaga] HYROX PRO - Overall already scraped
# [2025 Malaga] Trying HYROX PRO - Friday
# [2025 Houston] HYROX PRO already scraped
# [2025 Houston] HYROX PRO DOUBLES already scraped
# [2023 New York] Page 1 scraped for HYROX PRO - Male
# [2025 World Championships] No results for HYROX PRO - Overall - Male
# [2025 World Championships] HYROX PRO - Overall had NO DATA
# [2025 World Championships] HYROX PRO - Friday already scraped
# [2025 World Championships] HYROX PRO - Saturday already scraped
# [2025 World Championships] Trying HYROX PRO DOUBLES - Overall
# [2025 Brisbane] HYROX PRO already scraped
# [2025 Brisbane] HYROX PRO DOUBLES already scraped
# [2023 Madrid] Page 1 scraped for HYROX PRO - Women
# [2023 Madrid] Saved 144 rows for HYROX PRO
# [2023 Madrid] No HYROX PRO DOUBLES divisions available
#
# [2025 Vienna] Starting race scraping
# [2025 Copenhagen] HYROX PRO already scraped
# [2025 Copenhagen] HYROX PRO DOUBLES already scraped
# [2025 Glasgow] HYROX PRO - Overall already scraped
# [2025 Glasgow] Trying HYROX PRO - Thursday
#
# [2025 Katowice] Starting race scraping
# [2024 World Championships Nice] Page 4 scraped for HYROX PRO - Women
#
# [2025 Bilbao] Starting race scraping
#
# [2025 Guadalajara] Starting race scraping
#
# [2025 St. Gallen] Starting race scraping
# [2025 Cologne] Scraping gender: Male in HYROX PRO - Thursday
#
# [2025 Toulouse] Starting race scraping
#
# [2025 Auckland] Starting race scraping
# [2025 Warsaw] Scraping gender: Male in HYROX PRO - Saturday
# [2025 Rotterdam] Trying HYROX PRO - Overall
# [2025 Karlsruhe] HYROX PRO already scraped
# [2025 Karlsruhe] HYROX PRO DOUBLES already scraped
# [2023 New York] Page 2 scraped for HYROX PRO - Male
# [2023 New York] Scraping gender: Women in HYROX PRO
# [2025 Katowice] HYROX PRO already scraped
# [2025 Katowice] HYROX PRO DOUBLES already scraped
# [2025 Malaga] Scraping gender: Male in HYROX PRO - Friday
# [2025 World Championships] Scraping gender: Male in HYROX PRO DOUBLES - Overall
# [2023 Rimini] Page 1 scraped for HYROX PRO - Women
# [2023 Rimini] Saved 86 rows for HYROX PRO
# [2023 Rimini] No HYROX PRO DOUBLES divisions available
#
# [2025 Las Vegas] Starting race scraping
# [2025 Vienna] No HYROX PRO divisions available
# [2025 Vienna] No HYROX PRO DOUBLES divisions available
# [2025 Guadalajara] HYROX PRO already scraped
# [2025 Guadalajara] HYROX PRO DOUBLES already scraped
# [2025 Glasgow] Scraping gender: Male in HYROX PRO - Thursday
# [2025 Bilbao] HYROX PRO - Overall already scraped
# [2025 Bilbao] Trying HYROX PRO - Saturday
#
# [2025 Turin] Starting race scraping
# [2025 St. Gallen] HYROX PRO already scraped
# [2025 St. Gallen] HYROX PRO DOUBLES already scraped
#
# [2025 Manchester] Starting race scraping
#
# [2024 Frankfurt] Starting race scraping
#
# [2024 Melbourne] Starting race scraping
# [2025 Toulouse] HYROX PRO already scraped
# [2025 Toulouse] HYROX PRO DOUBLES already scraped
#
# [2024 Anaheim] Starting race scraping
# [2025 Rotterdam] Scraping gender: Male in HYROX PRO - Overall
# [2025 Auckland] Trying HYROX PRO
# [2025 Atlanta] Page 1 scraped for HYROX PRO - Saturday - Male
#
# [2024 Marseille] Starting race scraping
# [2025 Las Vegas] HYROX PRO - Overall already scraped
# [2025 Las Vegas] Trying HYROX PRO - Saturday
# [2025 Turin] Trying HYROX PRO
# [2024 Melbourne] HYROX PRO already scraped
# [2024 Melbourne] HYROX PRO DOUBLES already scraped
# [2024 Frankfurt] HYROX PRO already scraped
# [2024 Frankfurt] HYROX PRO DOUBLES already scraped
# [2025 Manchester] Trying HYROX PRO
# [2025 Bilbao] Scraping gender: Male in HYROX PRO - Saturday
#
# [2024 Stockholm] Starting race scraping
#
# [2024 London] Starting race scraping
# [2024 Marseille] HYROX PRO already scraped
# [2024 Marseille] HYROX PRO DOUBLES already scraped
# [2025 Auckland] Scraping gender: Male in HYROX PRO
# [2024 Anaheim] HYROX PRO already scraped
# [2024 Anaheim] HYROX PRO DOUBLES already scraped
# [2025 World Championships] No results for HYROX PRO DOUBLES - Overall - Male
# [2025 World Championships] HYROX PRO DOUBLES - Overall had NO DATA
# [2025 World Championships] Trying HYROX PRO DOUBLES - Saturday
#
# [2024 Hong Kong] Starting race scraping
# [2025 Turin] Scraping gender: Male in HYROX PRO
#
# [2024 Dallas] Starting race scraping
# [2025 Manchester] Scraping gender: Male in HYROX PRO
# [2025 Las Vegas] Scraping gender: Male in HYROX PRO - Saturday
# [2024 World Championships Nice] Page 5 scraped for HYROX PRO - Women
# [2024 London] HYROX PRO - Overall already scraped
# [2024 London] Trying HYROX PRO - Friday
# [2024 Stockholm] HYROX PRO - Overall already scraped
# [2024 Stockholm] Trying HYROX PRO - Saturday
# [2025 World Championships] Scraping gender: Male in HYROX PRO DOUBLES - Saturday
# [2025 Berlin] Page 1 scraped for HYROX PRO DOUBLES - Friday - Male
# [2025 Berlin] Scraping gender: Female in HYROX PRO DOUBLES - Friday
# [2024 Dallas] HYROX PRO already scraped
# [2024 Dallas] HYROX PRO DOUBLES already scraped
# [2023 New York] Page 1 scraped for HYROX PRO - Women
# [2023 New York] Saved 160 rows for HYROX PRO
# [2023 New York] No HYROX PRO DOUBLES divisions available
# [2025 Cologne] Page 1 scraped for HYROX PRO - Thursday - Male
# [2025 Cologne] Scraping gender: Women in HYROX PRO - Thursday
# [2025 Rotterdam] No results for HYROX PRO - Overall - Male
# [2025 Rotterdam] HYROX PRO - Overall had NO DATA
# [2025 Rotterdam] HYROX PRO - Thursday already scraped
# [2025 Rotterdam] HYROX PRO - Friday already scraped
# [2025 Rotterdam] Trying HYROX PRO - Saturday
# [2025 Paris 1] Page 1 scraped for HYROX PRO - Friday - Male
# [2024 Hong Kong] No HYROX PRO divisions available
# [2024 Hong Kong] No HYROX PRO DOUBLES divisions available
#
# [2024 Beijing] Starting race scraping
#
# [2024 Chicago Navy Pier] Starting race scraping
#
# [2024 Dublin] Starting race scraping
# [2024 London] Scraping gender: Male in HYROX PRO - Friday
# [2024 Stockholm] Scraping gender: Male in HYROX PRO - Saturday
# [2025 Atlanta] Page 2 scraped for HYROX PRO - Saturday - Male
# [2025 Atlanta] Scraping gender: Women in HYROX PRO - Saturday
# [2025 Warsaw] Page 1 scraped for HYROX PRO - Saturday - Male
# [2025 Rotterdam] Scraping gender: Male in HYROX PRO - Saturday
# [2025 Glasgow] Page 1 scraped for HYROX PRO - Thursday - Male
# [2025 Malaga] Page 1 scraped for HYROX PRO - Friday - Male
# [2025 Turin] No results for HYROX PRO - Male
# [2025 Turin] HYROX PRO had NO DATA
# [2025 Turin] Trying HYROX PRO DOUBLES
# [2024 Dublin] HYROX PRO - Overall already scraped
# [2024 Dublin] Trying HYROX PRO - Friday
# [2024 Beijing] HYROX PRO already scraped
# [2024 Beijing] HYROX PRO DOUBLES already scraped
# [2024 Chicago Navy Pier] HYROX PRO already scraped
# [2024 Chicago Navy Pier] HYROX PRO DOUBLES already scraped
#
# [2024 Manchester] Starting race scraping
#
# [2024 Ciudad de Mexico] Starting race scraping
# [2025 Glasgow] Page 2 scraped for HYROX PRO - Thursday - Male
# [2025 Glasgow] Scraping gender: Women in HYROX PRO - Thursday
# [2025 World Championships] No results for HYROX PRO DOUBLES - Saturday - Male
# [2025 World Championships] HYROX PRO DOUBLES - Saturday had NO DATA
# [2025 World Championships] HYROX PRO DOUBLES - Sunday already scraped
# [2025 Turin] Scraping gender: Male in HYROX PRO DOUBLES
# [2024 Dublin] Scraping gender: Male in HYROX PRO - Friday
#
# [2024 Paris] Starting race scraping
# [2024 World Championships Nice] Page 6 scraped for HYROX PRO - Women
# [2025 Cologne] Page 1 scraped for HYROX PRO - Thursday - Women
# [2025 Cologne] Saved 79 rows for HYROX PRO - Thursday
# [2025 Cologne] Trying HYROX PRO - Friday
# [2024 Manchester] HYROX PRO already scraped
# [2024 Manchester] HYROX PRO DOUBLES already scraped
# [2024 Ciudad de Mexico] HYROX PRO already scraped
# [2024 Ciudad de Mexico] HYROX PRO DOUBLES already scraped
# [2025 Paris 1] Page 2 scraped for HYROX PRO - Friday - Male
# [2025 Bilbao] Page 1 scraped for HYROX PRO - Saturday - Male
#
# [2024 Poznan] Starting race scraping
# [2025 Auckland] Page 1 scraped for HYROX PRO - Male
#
# [2024 Hamburg] Starting race scraping
# [2025 Berlin] Page 1 scraped for HYROX PRO DOUBLES - Friday - Female
# [2025 Berlin] Scraping gender: Mixed in HYROX PRO DOUBLES - Friday
# [2024 Paris] HYROX PRO already scraped
# [2024 Paris] HYROX PRO DOUBLES already scraped
# [2025 Manchester] Page 1 scraped for HYROX PRO - Male
# [2025 Cologne] Scraping gender: Male in HYROX PRO - Friday
#
# [2024 Birmingham] Starting race scraping
# [2025 Las Vegas] Page 1 scraped for HYROX PRO - Saturday - Male
# [2025 Warsaw] Page 2 scraped for HYROX PRO - Saturday - Male
# [2025 Turin] No results for HYROX PRO DOUBLES - Male
# [2025 Turin] HYROX PRO DOUBLES had NO DATA
# [2024 Poznan] HYROX PRO already scraped
# [2024 Poznan] HYROX PRO DOUBLES already scraped
# [2025 Malaga] Page 2 scraped for HYROX PRO - Friday - Male
# [2025 Malaga] Scraping gender: Women in HYROX PRO - Friday
# [2024 Hamburg] HYROX PRO already scraped
# [2024 Hamburg] HYROX PRO DOUBLES already scraped
#
# [2024 Incheon] Starting race scraping
# [2024 Madrid] Starting race scraping
#
#
# [2024 Milan] Starting race scraping
# [2024 Birmingham] HYROX PRO - Overall already scraped
# [2024 Birmingham] Trying HYROX PRO - Friday
# [2025 Auckland] Page 2 scraped for HYROX PRO - Male
# [2025 Auckland] Scraping gender: Women in HYROX PRO
# [2025 Warsaw] Page 3 scraped for HYROX PRO - Saturday - Male
# [2025 Warsaw] Scraping gender: Women in HYROX PRO - Saturday
# [2025 Bilbao] Page 2 scraped for HYROX PRO - Saturday - Male
# [2025 Bilbao] Scraping gender: Women in HYROX PRO - Saturday
# [2024 World Championships Nice] Page 7 scraped for HYROX PRO - Women
# [2024 World Championships Nice] Saved 1520 rows for HYROX PRO
# [2024 World Championships Nice] Trying HYROX PRO DOUBLES
# [2024 Stockholm] Page 1 scraped for HYROX PRO - Saturday - Male
# [2024 Incheon] HYROX PRO already scraped
# [2024 Incheon] HYROX PRO DOUBLES already scraped
# [2024 London] Page 1 scraped for HYROX PRO - Friday - Male
# [2025 Atlanta] Page 1 scraped for HYROX PRO - Saturday - Women
# [2025 Atlanta] Saved 292 rows for HYROX PRO - Saturday
# [2025 Atlanta] Trying HYROX PRO - Sunday
# [2025 Berlin] No results for HYROX PRO DOUBLES - Friday - Mixed
# [2025 Berlin] Saved 172 rows for HYROX PRO DOUBLES - Friday
# [2025 Berlin] Trying HYROX PRO DOUBLES - Saturday
# [2025 Rotterdam] Page 1 scraped for HYROX PRO - Saturday - Male
# [2024 Madrid] HYROX PRO already scraped
# [2024 Madrid] HYROX PRO DOUBLES already scraped
# [2024 Milan] HYROX PRO already scraped
# [2024 Milan] HYROX PRO DOUBLES already scraped
# [2024 Birmingham] Scraping gender: Male in HYROX PRO - Friday
#
# [2024 Amsterdam] Starting race scraping
#
# [2024 Nice] Starting race scraping
#
# [2024 Toronto] Starting race scraping
# [2025 Paris 1] Page 3 scraped for HYROX PRO - Friday - Male
# [2025 Glasgow] Page 1 scraped for HYROX PRO - Thursday - Women
# [2024 World Championships Nice] Scraping gender: Male in HYROX PRO DOUBLES
# [2025 Atlanta] Scraping gender: Male in HYROX PRO - Sunday
# [2025 Manchester] Page 2 scraped for HYROX PRO - Male
# [2025 Manchester] Scraping gender: Women in HYROX PRO
# [2024 Dublin] Page 1 scraped for HYROX PRO - Friday - Male
# [2024 Dublin] Scraping gender: Women in HYROX PRO - Friday
# [2025 Las Vegas] Page 2 scraped for HYROX PRO - Saturday - Male
# [2024 London] Page 2 scraped for HYROX PRO - Friday - Male
# [2024 London] Scraping gender: Women in HYROX PRO - Friday
# [2025 Berlin] Scraping gender: Male in HYROX PRO DOUBLES - Saturday
# [2024 Amsterdam] HYROX PRO - Overall already scraped
# [2024 Amsterdam] Trying HYROX PRO - Friday
# [2025 Glasgow] Page 2 scraped for HYROX PRO - Thursday - Women
# [2025 Glasgow] Saved 224 rows for HYROX PRO - Thursday
# [2025 Glasgow] Trying HYROX PRO - Saturday
# [2024 Toronto] HYROX PRO - Overall already scraped
# [2024 Toronto] Trying HYROX PRO - Saturday
# [2024 Nice] HYROX PRO already scraped
# [2024 Nice] HYROX PRO DOUBLES already scraped
# [2024 Stockholm] Page 2 scraped for HYROX PRO - Saturday - Male
# ...
# [2025 Valencia] Scraping gender: Women in HYROX PRO - Overall
# [2026 Amsterdam] Saved 126 rows for HYROX PRO DOUBLES - Wednesday
# [2026 Amsterdam] Trying HYROX PRO DOUBLES - Thursday
# [2025 Chicago] Page 1 scraped for HYROX PRO DOUBLES - Friday - Male
# [2025 Birmingham] Page 3 scraped for HYROX PRO - Overall - Male
# [2026 Amsterdam] Scraping gender: Male in HYROX PRO DOUBLES - Thursday
# [2025 Utrecht] Page 1 scraped for HYROX PRO DOUBLES - Friday - Male
# [2025 Utrecht] Scraping gender: Female in HYROX PRO DOUBLES - Friday
# [2025 Gdansk] Page 1 scraped for HYROX PRO - Women
# [2025 London Excel] Page 1 scraped for HYROX PRO - Saturday - Male
# [2025 Bordeaux] Page 1 scraped for HYROX PRO - Saturday - Women
# [2025 Gdansk] Saved 166 rows for HYROX PRO
# [2025 Gdansk] Trying HYROX PRO DOUBLES
# [2025 Paris] Page 4 scraped for HYROX PRO - Overall - Male
# [2025 Paris] Scraping gender: Women in HYROX PRO - Overall
# [2025 Seoul] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2025 Bordeaux] Page 2 scraped for HYROX PRO - Saturday - Women
# [2025 Seoul] Saved 289 rows for HYROX PRO DOUBLES
# [2025 Bordeaux] Saved 332 rows for HYROX PRO - Saturday
# [2025 Bordeaux] HYROX PRO DOUBLES - Overall already scraped
# [2025 Bordeaux] Trying HYROX PRO DOUBLES - Thursday
# [2025 Gdansk] Scraping gender: Male in HYROX PRO DOUBLES
# [2025 Dublin] Page 3 scraped for HYROX PRO - Overall - Women
# [2025 Dublin] Saved 613 rows for HYROX PRO - Overall
# [2025 Dublin] Trying HYROX PRO - Wednesday
# [2025 Stuttgart] Page 2 scraped for HYROX PRO - Friday - Women
# [2025 Stuttgart] Saved 497 rows for HYROX PRO - Friday
# [2025 Stuttgart] Trying HYROX PRO DOUBLES - Sunday
# [2025 Bordeaux] Scraping gender: Male in HYROX PRO DOUBLES - Thursday
# [2025 Dallas] Page 4 scraped for HYROX PRO DOUBLES - Female
# [2025 Dallas] Scraping gender: Mixed in HYROX PRO DOUBLES
#
# [2025 Hamburg] Starting race scraping
#
# [2025 Toronto] Starting race scraping
# [2025 Dublin] Scraping gender: Male in HYROX PRO - Wednesday
# [2025 Stuttgart] Scraping gender: Male in HYROX PRO DOUBLES - Sunday
# [2025 Madrid] Page 2 scraped for HYROX PRO - Saturday - Male
# [2025 Hamburg] Trying HYROX PRO - Overall
# [2025 Stockholm] Page 1 scraped for HYROX PRO DOUBLES - Friday - Female
# [2026 Manchester] Page 1 scraped for HYROX PRO DOUBLES - Thursday - Male
# [2026 Manchester] Scraping gender: Female in HYROX PRO DOUBLES - Thursday
# [2025 Toronto] Trying HYROX PRO - Overall
# [2025 Melbourne] Page 1 scraped for HYROX PRO DOUBLES - Saturday - Male
# [2025 Dallas] Page 1 scraped for HYROX PRO DOUBLES - Mixed
# [2025 Mexico City] Page 2 scraped for HYROX PRO - Saturday - Male
# [2025 Hamburg] Scraping gender: Male in HYROX PRO - Overall
# [2025 Dallas] Saved 747 rows for HYROX PRO DOUBLES
# [2025 Utrecht] Page 1 scraped for HYROX PRO DOUBLES - Friday - Female
# [2025 Utrecht] Saved 148 rows for HYROX PRO DOUBLES - Friday
# [2025 Utrecht] Trying HYROX PRO DOUBLES - Saturday
# [2025 Toronto] Scraping gender: Male in HYROX PRO - Overall
# [2025 Stockholm] Page 2 scraped for HYROX PRO DOUBLES - Friday - Female
# [2025 Stockholm] Scraping gender: Mixed in HYROX PRO DOUBLES - Friday
# [2025 London Excel] Page 2 scraped for HYROX PRO - Saturday - Male
# [2025 Chicago] Page 2 scraped for HYROX PRO DOUBLES - Friday - Male
# [2025 Utrecht] Scraping gender: Male in HYROX PRO DOUBLES - Saturday
# [2025 Geneva] Page 1 scraped for HYROX PRO - Saturday - Women
# [2025 Birmingham] Page 4 scraped for HYROX PRO - Overall - Male
# [2026 Amsterdam] Page 1 scraped for HYROX PRO DOUBLES - Thursday - Male
# [2026 Amsterdam] Scraping gender: Female in HYROX PRO DOUBLES - Thursday
# [2025 Gdansk] Page 1 scraped for HYROX PRO DOUBLES - Male
# [2025 Gdansk] Scraping gender: Female in HYROX PRO DOUBLES
# [2025 Stockholm] Page 1 scraped for HYROX PRO DOUBLES - Friday - Mixed
# [2025 Stockholm] Saved 376 rows for HYROX PRO DOUBLES - Friday
# [2025 Geneva] Page 2 scraped for HYROX PRO - Saturday - Women
# [2025 Geneva] Saved 369 rows for HYROX PRO - Saturday
# [2025 Geneva] Trying HYROX PRO DOUBLES - Saturday
# [2025 Valencia] Page 1 scraped for HYROX PRO - Overall - Women
# [2026 Manchester] Page 1 scraped for HYROX PRO DOUBLES - Thursday - Female
# [2026 Manchester] Saved 81 rows for HYROX PRO DOUBLES - Thursday
# [2026 Manchester] Trying HYROX PRO DOUBLES - Friday
# [2025 Geneva] Scraping gender: Male in HYROX PRO DOUBLES - Saturday
# [2025 Madrid] Page 3 scraped for HYROX PRO - Saturday - Male
# [2025 Madrid] Scraping gender: Women in HYROX PRO - Saturday
# [2025 Birmingham] Page 5 scraped for HYROX PRO - Overall - Male
# [2025 Birmingham] Scraping gender: Women in HYROX PRO - Overall
# [2025 Bordeaux] Page 1 scraped for HYROX PRO DOUBLES - Thursday - Male
# [2026 Manchester] Scraping gender: Male in HYROX PRO DOUBLES - Friday
# [2025 Melbourne] Page 2 scraped for HYROX PRO DOUBLES - Saturday - Male
# [2025 Dublin] Page 1 scraped for HYROX PRO - Wednesday - Male
# [2025 Dublin] Scraping gender: Women in HYROX PRO - Wednesday
#
# [2025 Boston] Starting race scraping
# [2025 Stuttgart] Page 1 scraped for HYROX PRO DOUBLES - Sunday - Male
#
# [2025 Oslo] Starting race scraping
# [2025 Bordeaux] Page 2 scraped for HYROX PRO DOUBLES - Thursday - Male
# [2025 Bordeaux] Scraping gender: Female in HYROX PRO DOUBLES - Thursday
# [2025 Mexico City] Page 3 scraped for HYROX PRO - Saturday - Male
# [2025 Mexico City] Scraping gender: Women in HYROX PRO - Saturday
# [2025 Valencia] Page 2 scraped for HYROX PRO - Overall - Women
# [2025 Valencia] Saved 412 rows for HYROX PRO - Overall
# [2025 Valencia] Trying HYROX PRO - Friday
# [2025 Paris] Page 1 scraped for HYROX PRO - Overall - Women
# [2025 Boston] Trying HYROX PRO - Overall
# [2026 Amsterdam] Page 1 scraped for HYROX PRO DOUBLES - Thursday - Female
# [2025 Chicago] Page 3 scraped for HYROX PRO DOUBLES - Friday - Male
# [2026 Amsterdam] Saved 128 rows for HYROX PRO DOUBLES - Thursday
# [2026 Amsterdam] Trying HYROX PRO DOUBLES - Friday
# [2025 Chicago] Scraping gender: Female in HYROX PRO DOUBLES - Friday
# [2025 Valencia] Scraping gender: Male in HYROX PRO - Friday
# [2025 Oslo] Trying HYROX PRO - Overall
# [2025 Gdansk] Page 1 scraped for HYROX PRO DOUBLES - Female
# [2025 Gdansk] Scraping gender: Mixed in HYROX PRO DOUBLES
# [2025 Boston] Scraping gender: Male in HYROX PRO - Overall
# [2026 Amsterdam] Scraping gender: Male in HYROX PRO DOUBLES - Friday
# [2025 London Excel] Page 3 scraped for HYROX PRO - Saturday - Male
# [2025 Hamburg] Page 1 scraped for HYROX PRO - Overall - Male
# [2025 Oslo] Scraping gender: Male in HYROX PRO - Overall
# [2025 Utrecht] Page 1 scraped for HYROX PRO DOUBLES - Saturday - Male
# [2025 Gdansk] No results for HYROX PRO DOUBLES - Mixed
# [2025 Gdansk] Saved 109 rows for HYROX PRO DOUBLES
# [2025 Boston] No results for HYROX PRO - Overall - Male
# [2025 Boston] HYROX PRO - Overall had NO DATA
# [2025 Boston] Trying HYROX PRO - Sunday
# [2025 Dublin] Page 1 scraped for HYROX PRO - Wednesday - Women
# [2025 Dublin] Saved 140 rows for HYROX PRO - Wednesday
# [2025 Dublin] Trying HYROX PRO - Thursday
# [2025 Melbourne] Page 3 scraped for HYROX PRO DOUBLES - Saturday - Male
# [2025 Boston] Scraping gender: Male in HYROX PRO - Sunday
# [2025 Toronto] Page 1 scraped for HYROX PRO - Overall - Male
# [2025 Bordeaux] Page 1 scraped for HYROX PRO DOUBLES - Thursday - Female
# [2025 Bordeaux] Scraping gender: Mixed in HYROX PRO DOUBLES - Thursday
# [2025 Stuttgart] Page 2 scraped for HYROX PRO DOUBLES - Sunday - Male
# [2025 Geneva] Page 1 scraped for HYROX PRO DOUBLES - Saturday - Male
# [2025 Dublin] Scraping gender: Male in HYROX PRO - Thursday
# [2025 Utrecht] Page 2 scraped for HYROX PRO DOUBLES - Saturday - Male
# [2025 Utrecht] Scraping gender: Female in HYROX PRO DOUBLES - Saturday
# [2025 Madrid] Page 1 scraped for HYROX PRO - Saturday - Women
# [2025 Paris] Page 2 scraped for HYROX PRO - Overall - Women
# [2025 Birmingham] Page 1 scraped for HYROX PRO - Overall - Women
# [2025 Paris] Saved 507 rows for HYROX PRO - Overall
# [2025 Paris] Trying HYROX PRO - Wednesday
# [2026 Manchester] Page 1 scraped for HYROX PRO DOUBLES - Friday - Male
# [2025 Chicago] Page 1 scraped for HYROX PRO DOUBLES - Friday - Female
# [2025 Paris] Scraping gender: Male in HYROX PRO - Wednesday
# [2025 Bordeaux] Page 1 scraped for HYROX PRO DOUBLES - Thursday - Mixed
# [2025 Bordeaux] Saved 181 rows for HYROX PRO DOUBLES - Thursday
# [2025 Bordeaux] Trying HYROX PRO DOUBLES - Saturday
# [2025 London Excel] Page 4 scraped for HYROX PRO - Saturday - Male
# [2025 Geneva] Page 2 scraped for HYROX PRO DOUBLES - Saturday - Male
# [2025 Geneva] Scraping gender: Female in HYROX PRO DOUBLES - Saturday
# [2025 Valencia] Page 1 scraped for HYROX PRO - Friday - Male
# [2025 Valencia] Scraping gender: Women in HYROX PRO - Friday
# [2025 Hamburg] Page 2 scraped for HYROX PRO - Overall - Male
# [2026 Amsterdam] Page 1 scraped for HYROX PRO DOUBLES - Friday - Male
# [2025 Madrid] Page 2 scraped for HYROX PRO - Saturday - Women
# [2025 Madrid] Saved 438 rows for HYROX PRO - Saturday
# [2025 Madrid] HYROX PRO DOUBLES - Overall already scraped
# [2025 Madrid] Trying HYROX PRO DOUBLES - Thursday
# [2025 Bordeaux] Scraping gender: Male in HYROX PRO DOUBLES - Saturday
# [2025 Melbourne] Page 4 scraped for HYROX PRO DOUBLES - Saturday - Male
# [2025 Madrid] Scraping gender: Male in HYROX PRO DOUBLES - Thursday
# [2025 Mexico City] Page 1 scraped for HYROX PRO - Saturday - Women
#
# [2025 Rome] Starting race scraping
# [2025 Stuttgart] Page 3 scraped for HYROX PRO DOUBLES - Sunday - Male
# [2025 Rome] Trying HYROX PRO - Overall
# [2025 Rome] Scraping gender: Male in HYROX PRO - Overall
# [2025 Oslo] Page 1 scraped for HYROX PRO - Overall - Male
# [2025 London Excel] Page 5 scraped for HYROX PRO - Saturday - Male
# [2025 London Excel] Scraping gender: Women in HYROX PRO - Saturday
# [2025 Birmingham] Page 2 scraped for HYROX PRO - Overall - Women
# [2025 Boston] Page 1 scraped for HYROX PRO - Sunday - Male
# [2025 Mexico City] Page 2 scraped for HYROX PRO - Saturday - Women
# [2025 Mexico City] Saved 395 rows for HYROX PRO - Saturday
# [2025 Mexico City] Trying HYROX PRO DOUBLES - Overall
# [2025 Utrecht] Page 1 scraped for HYROX PRO DOUBLES - Saturday - Female
# [2025 Chicago] Page 2 scraped for HYROX PRO DOUBLES - Friday - Female
# [2025 Valencia] Page 1 scraped for HYROX PRO - Friday - Women
# [2025 Valencia] Saved 146 rows for HYROX PRO - Friday
# [2025 Valencia] Trying HYROX PRO - Saturday
# [2025 Dublin] Page 1 scraped for HYROX PRO - Thursday - Male
# [2025 Toronto] Page 2 scraped for HYROX PRO - Overall - Male
# [2025 Melbourne] Page 5 scraped for HYROX PRO DOUBLES - Saturday - Male
# [2025 Melbourne] Scraping gender: Female in HYROX PRO DOUBLES - Saturday
# [2025 Utrecht] Page 2 scraped for HYROX PRO DOUBLES - Saturday - Female
# [2025 Utrecht] Scraping gender: Mixed in HYROX PRO DOUBLES - Saturday
# [2025 Mexico City] Scraping gender: Male in HYROX PRO DOUBLES - Overall
# [2026 Amsterdam] Page 2 scraped for HYROX PRO DOUBLES - Friday - Male
# [2026 Manchester] Page 2 scraped for HYROX PRO DOUBLES - Friday - Male
# [2025 Hamburg] Page 3 scraped for HYROX PRO - Overall - Male
# [2025 Valencia] Scraping gender: Male in HYROX PRO - Saturday
# [2025 Dublin] Page 2 scraped for HYROX PRO - Thursday - Male
# [2025 Dublin] Scraping gender: Women in HYROX PRO - Thursday
# [2025 Stuttgart] Page 4 scraped for HYROX PRO DOUBLES - Sunday - Male
# [2025 Stuttgart] Scraping gender: Female in HYROX PRO DOUBLES - Sunday
# [2025 Geneva] Page 1 scraped for HYROX PRO DOUBLES - Saturday - Female
# [2025 Geneva] Scraping gender: Mixed in HYROX PRO DOUBLES - Saturday
# [2025 Chicago] Page 3 scraped for HYROX PRO DOUBLES - Friday - Female
# [2025 Chicago] Saved 513 rows for HYROX PRO DOUBLES - Friday
# [2025 Bordeaux] Page 1 scraped for HYROX PRO DOUBLES - Saturday - Male
# [2025 Utrecht] Page 1 scraped for HYROX PRO DOUBLES - Saturday - Mixed
# [2025 Utrecht] Saved 251 rows for HYROX PRO DOUBLES - Saturday
# [2025 Madrid] Page 1 scraped for HYROX PRO DOUBLES - Thursday - Male
# [2025 Hamburg] Page 4 scraped for HYROX PRO - Overall - Male
# [2025 Hamburg] Scraping gender: Women in HYROX PRO - Overall
# [2025 Mexico City] No results for HYROX PRO DOUBLES - Overall - Male
# [2025 Mexico City] HYROX PRO DOUBLES - Overall had NO DATA
# [2025 Mexico City] Trying HYROX PRO DOUBLES - Friday
# [2025 Paris] Page 1 scraped for HYROX PRO - Wednesday - Male
# [2025 Geneva] No results for HYROX PRO DOUBLES - Saturday - Mixed
# [2025 Geneva] Saved 243 rows for HYROX PRO DOUBLES - Saturday
# [2025 Madrid] Page 2 scraped for HYROX PRO DOUBLES - Thursday - Male
# [2025 Madrid] Scraping gender: Female in HYROX PRO DOUBLES - Thursday
# [2025 Mexico City] Scraping gender: Male in HYROX PRO DOUBLES - Friday
# [2025 Birmingham] Page 3 scraped for HYROX PRO - Overall - Women
# [2025 Toronto] Page 3 scraped for HYROX PRO - Overall - Male
# [2025 Toronto] Scraping gender: Women in HYROX PRO - Overall
# [2025 Boston] Page 2 scraped for HYROX PRO - Sunday - Male
# [2025 Paris] Page 2 scraped for HYROX PRO - Wednesday - Male
# [2025 Paris] Scraping gender: Women in HYROX PRO - Wednesday
# [2025 Bordeaux] Page 2 scraped for HYROX PRO DOUBLES - Saturday - Male
# [2025 Bordeaux] Scraping gender: Female in HYROX PRO DOUBLES - Saturday
# [2025 Rome] Page 1 scraped for HYROX PRO - Overall - Male
# [2026 Manchester] Page 3 scraped for HYROX PRO DOUBLES - Friday - Male
# [2026 Manchester] Scraping gender: Female in HYROX PRO DOUBLES - Friday
# [2026 Amsterdam] Page 3 scraped for HYROX PRO DOUBLES - Friday - Male
# [2025 London Excel] Page 1 scraped for HYROX PRO - Saturday - Women
# [2025 Melbourne] Page 1 scraped for HYROX PRO DOUBLES - Saturday - Female
#
# [2025 Maastricht] Starting race scraping
#
# [2025 Sao Paulo] Starting race scraping
#
# [2025 Acapulco] Starting race scraping
# [2025 Oslo] Page 2 scraped for HYROX PRO - Overall - Male
# [2025 Sao Paulo] Trying HYROX PRO
# [2025 Birmingham] Page 4 scraped for HYROX PRO - Overall - Women
# [2025 Acapulco] Trying HYROX PRO
# [2025 Maastricht] Trying HYROX PRO - Overall
#
# [2025 Mumbai] Starting race scraping
# [2025 Sao Paulo] Scraping gender: Male in HYROX PRO
# [2025 Maastricht] Scraping gender: Male in HYROX PRO - Overall
# [2025 Acapulco] Scraping gender: Male in HYROX PRO
# [2025 Mumbai] Trying HYROX PRO
# [2025 Stuttgart] Page 1 scraped for HYROX PRO DOUBLES - Sunday - Female
# [2025 Boston] Page 3 scraped for HYROX PRO - Sunday - Male
# [2025 Boston] Scraping gender: Women in HYROX PRO - Sunday
# [2025 Valencia] Page 1 scraped for HYROX PRO - Saturday - Male
# [2025 Paris] Page 1 scraped for HYROX PRO - Wednesday - Women
#
# [2025 Perth] Starting race scraping
# [2025 Madrid] Page 1 scraped for HYROX PRO DOUBLES - Thursday - Female
# [2025 Madrid] Saved 175 rows for HYROX PRO DOUBLES - Thursday
# [2025 Madrid] Trying HYROX PRO DOUBLES - Saturday
# [2025 Dublin] Page 1 scraped for HYROX PRO - Thursday - Women
# [2025 Dublin] Saved 207 rows for HYROX PRO - Thursday
# [2025 Dublin] Trying HYROX PRO - Saturday
# [2025 Mumbai] Scraping gender: Male in HYROX PRO
# [2025 Perth] Trying HYROX PRO - Overall
# [2025 Dublin] Scraping gender: Male in HYROX PRO - Saturday
# [2025 Madrid] Scraping gender: Male in HYROX PRO DOUBLES - Saturday
# [2026 Amsterdam] Page 4 scraped for HYROX PRO DOUBLES - Friday - Male
# [2025 Melbourne] Page 2 scraped for HYROX PRO DOUBLES - Saturday - Female
# [2025 Hamburg] Page 1 scraped for HYROX PRO - Overall - Women
# [2025 Bordeaux] Page 1 scraped for HYROX PRO DOUBLES - Saturday - Female
# [2025 Rome] Page 2 scraped for HYROX PRO - Overall - Male
# [2025 Perth] Scraping gender: Male in HYROX PRO - Overall
# [2025 Mexico City] Page 1 scraped for HYROX PRO DOUBLES - Friday - Male
# [2025 Mexico City] Scraping gender: Female in HYROX PRO DOUBLES - Friday
# [2025 London Excel] Page 2 scraped for HYROX PRO - Saturday - Women
# [2025 Oslo] Page 3 scraped for HYROX PRO - Overall - Male
# [2025 Oslo] Scraping gender: Women in HYROX PRO - Overall
# [2026 Manchester] Page 1 scraped for HYROX PRO DOUBLES - Friday - Female
# [2025 Bordeaux] Page 2 scraped for HYROX PRO DOUBLES - Saturday - Female
# [2025 Toronto] Page 1 scraped for HYROX PRO - Overall - Women
# [2025 Bordeaux] Saved 300 rows for HYROX PRO DOUBLES - Saturday
# [2025 Stuttgart] Page 2 scraped for HYROX PRO DOUBLES - Sunday - Female

# %% [markdown]
# # Scrape 100 at a time, for all divisions available for all seasons available, even the empty ones.

# %%
import time
import random
import pandas as pd
import os
from concurrent.futures import ThreadPoolExecutor

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, TimeoutException

# ==========================
# CONFIG
# ==========================

BASE_URLS = {f"Season_{i}": f"https://results.hyrox.com/season-{i}/" for i in range(1, 9)}
SAVE_ROOT = r"Datasets\Hyrox"
MAX_THREADS = 100  # adjust for your system

def human_pause(a=2, b=5):
    time.sleep(random.uniform(a, b))

# ==========================
# SELENIUM DRIVER
# ==========================

def create_driver():
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.add_argument("--headless=new")
    options.add_argument(
        "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
    return webdriver.Chrome(options=options)

# ==========================
# SCRAPE PAGES FUNCTION
# ==========================

def scrape_pages(driver, race_name, division, gender_label, race_results):
    is_doubles = "DOUBLES" in division.upper()
    page_number = 1

    while True:
        try:
            WebDriverWait(driver, 25).until(lambda d: 
                "There are currently no results available" in d.page_source
                or len(d.find_elements(By.CSS_SELECTOR, "li.list-group-item.row")) > 1
            )
        except TimeoutException:
            print(f"[{race_name}] Timeout waiting for {division} - {gender_label}")
            return False

        # No results?
        try:
            no_result_elem = driver.find_element(By.XPATH,
                "//*[contains(text(),'There are currently no results available')]"
            )
            if no_result_elem.is_displayed():
                print(f"[{race_name}] No results for {division} - {gender_label}")
                return False
        except NoSuchElementException:
            pass

        rows = driver.find_elements(By.CSS_SELECTOR, "li.list-group-item.row")
        rows = [r for r in rows if "list-group-header" not in r.get_attribute("class")]

        if not rows:
            print(f"[{race_name}] No rows found for {division} - {gender_label}")
            return False

        scraped_any = False
        for row in rows:
            try:
                rank = row.find_element(By.CSS_SELECTOR, ".place-primary").text
                age_rank = row.find_element(By.CSS_SELECTOR, ".place-secondary").text
                total_time = row.find_element(By.CSS_SELECTOR, ".type-time").text.replace("Total", "").strip()
                age_group = row.find_element(By.CSS_SELECTOR, ".type-age_class").text.replace("Age Group", "").strip()

                if is_doubles:
                    members = row.find_elements(By.CSS_SELECTOR, ".type-relay_member a")
                    member_names = " & ".join([m.text for m in members])
                    race_results.append([
                        race_name, division, gender_label,
                        rank, age_rank, member_names, "",
                        age_group, total_time
                    ])
                else:
                    name = row.find_element(By.CSS_SELECTOR, "h4.type-fullname").text
                    nation = row.find_element(By.CSS_SELECTOR, ".nation__abbr").text
                    race_results.append([
                        race_name, division, gender_label,
                        rank, age_rank, name, nation,
                        age_group, total_time
                    ])
                scraped_any = True
            except:
                continue

        print(f"[{race_name}] Page {page_number} scraped for {division} - {gender_label}")
        page_number += 1

        try:
            next_button = driver.find_element(By.XPATH, "//a[text()='>']")
            driver.execute_script("arguments[0].click();", next_button)
            human_pause(2,5)
        except NoSuchElementException:
            break

    return scraped_any

# ==========================
# SCRAPE RACE FUNCTION
# ==========================

def scrape_race(season, base_url, race_name, race_value):
    driver = create_driver()
    season_folder = os.path.join(SAVE_ROOT, season)
    os.makedirs(season_folder, exist_ok=True)

    safe_name = race_name.replace(" ", "_").replace("/", "-")
    print(f"\n[{race_name}] Starting scraping")

    driver.get(base_url)
    human_pause(2,5)
    Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
    human_pause(1,3)

    # Get all divisions
    select_division = Select(driver.find_element(By.ID, "default-lists-event"))
    divisions = [o.text for o in select_division.options]

    # Check if all division CSVs exist; if yes, skip the race entirely
    all_exist = True
    for div in divisions:
        div_safe = div.replace(" ", "_").replace("/", "-")
        file_path = os.path.join(season_folder, f"{safe_name}_{div_safe}.csv")
        if not os.path.exists(file_path):
            all_exist = False
            break
    if all_exist:
        print(f"[{race_name}] All division CSVs exist. Skipping race.")
        driver.quit()
        return f"[{race_name}] Skipped (all divisions exist)"

    for div in divisions:
        div_safe = div.replace(" ", "_").replace("/", "-")
        file_path = os.path.join(season_folder, f"{safe_name}_{div_safe}.csv")
        if os.path.exists(file_path):
            print(f"[{race_name}] {div} already exists, will check for data")
        
        print(f"[{race_name}] Scraping division: {div}")

        driver.get(base_url)
        human_pause(2,4)
        Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
        human_pause(1,2)
        Select(driver.find_element(By.ID, "default-lists-event")).select_by_visible_text(div)
        human_pause(1,2)

        try:
            gender_dropdown = Select(driver.find_element(By.ID, "default-lists-sex"))
            genders = [(o.get_attribute("value"), o.text) for o in gender_dropdown.options]
        except NoSuchElementException:
            genders = [("", "All")]

        division_results = []
        division_has_data = False

        for gender_code, gender_label in genders:
            print(f"[{race_name}] Scraping gender: {gender_label} in {div}")

            driver.get(base_url)
            human_pause(2,4)
            Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
            human_pause(1,2)
            Select(driver.find_element(By.ID, "default-lists-event")).select_by_visible_text(div)
            human_pause(1,2)
            if gender_code:
                Select(driver.find_element(By.ID, "default-lists-sex")).select_by_value(gender_code)
            Select(driver.find_element(By.ID, "default-num_results")).select_by_value("100")
            human_pause(1,2)
            driver.find_element(By.ID, "default-submit").click()
            human_pause(2,4)

            has_data = scrape_pages(driver, race_name, div, gender_label, division_results)
            if has_data:
                division_has_data = True

        # Save CSV even if empty (no data)
        df = pd.DataFrame(
            division_results,
            columns=["Race","Division","Gender",
                     "Rank Overall","Rank Age Group",
                     "Name","Nation","Age Group","Total Time"]
        )
        df.to_csv(file_path, index=False)
        if division_has_data:
            print(f"[{race_name}] Saved {len(df)} rows for {div}")
        else:
            print(f"[{race_name}] Division {div} had no data. Empty CSV saved.")

    driver.quit()
    return f"[{race_name}] Finished scraping"

# ==========================
# MAIN EXECUTION
# ==========================

all_tasks = []

for season, base_url in BASE_URLS.items():
    driver_main = create_driver()
    driver_main.get(base_url)
    human_pause(2,4)
    try:
        WebDriverWait(driver_main, 20).until(EC.presence_of_element_located((By.ID, "default-lists-event_main_group")))
    except TimeoutException:
        driver_main.quit()
        continue

    race_dropdown = Select(driver_main.find_element(By.ID, "default-lists-event_main_group"))
    races = [(race_dropdown.options[i].text, race_dropdown.options[i].get_attribute("value")) for i in range(len(race_dropdown.options))]
    driver_main.quit()

    for race_name, race_value in races:
        all_tasks.append((season, base_url, race_name, race_value))

with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
    futures = [executor.submit(scrape_race, *task) for task in all_tasks]
    for f in futures:
        print(f.result())

print("\nALL DONE.")
