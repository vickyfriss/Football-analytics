# %% [markdown]
# ## 📈 Predicting Premier League Final Positions Using Betting Odds & Simulation
#
# **Competition:** English Premier League 2025/26
# **Purpose:** Estimate probabilities of final league positions using betting market information and simulation
# **Methods:** Odds-implied probabilities, Monte Carlo simulation, scenario analysis
# **Author:** [Victoria Friss de Kereki](https://www.linkedin.com/in/victoria-friss-de-kereki/)
#
# ---
#
# **Notebook first written:** `17/01/2026`
# **Last updated:** `17/01/2026`
#
# > This notebook develops a probabilistic framework to predict final Premier League final positions using betting odds as market-based expectations.
# >
# > Betting odds are transformed into implied probabilities and adjusted for bookmaker margin. These probabilities are then used to simulate the remainder of the season via Monte Carlo methods, generating distributions over final points totals and league positions.
# >
# > The analysis focuses on estimating the likelihood of key outcomes such as title wins, top-four finishes, relegation, and mid-table placements. Results are presented at team level with uncertainty intervals, and the framework can be extended to incorporate form, fixture difficulty, or alternative predictive inputs beyond betting markets.

# %%
import os
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import requests
from scipy.stats import poisson
from dotenv import load_dotenv
import soccerdata as sd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Premier League Final Standings (ESPN Scraping)
# ##### Using the ESPN scraper I built in my previous project.

# %%
year = 2025  # current Premier League season start year

url = f"https://www.espn.com/soccer/standings/_/league/ENG.1/season/{year}"
tables = pd.read_html(url)

teams_raw = tables[0]
stats = tables[1]

teams = pd.DataFrame()
teams["position"] = teams_raw.iloc[:, 0].str.extract(r"^(\d+)").astype(int)
teams["team"] = (
    teams_raw.iloc[:, 0]
    .str.replace(r"^\d+", "", regex=True)
    .str.replace(r"^[A-Z]{2,3}", "", regex=True)
    .str.strip()
)

stats.columns = ["gp", "w", "d", "l", "gf", "ga", "gd", "pts"]
stats = stats.apply(lambda c: c.astype(str)
                              .str.replace("+", "", regex=False)
                              .astype(int))

premierleague = pd.concat([teams, stats], axis=1)
# premierleague["season"] = f"{year}-{year+1}"

premierleague
# Out:
#     position                     team  gp   w  d   l  gf  ga  gd  pts
# 0          1                  Arsenal  22  15  5   2  40  14  26   50
# 1          2          Manchester City  22  13  4   5  45  21  24   43
# 2          3              Aston Villa  22  13  4   5  33  25   8   43
# 3          4                Liverpool  22  10  6   6  33  29   4   36
# 4          5        Manchester United  22   9  8   5  38  32   6   35
# 5          6                  Chelsea  22   9  7   6  36  24  12   34
# 6          7                Brentford  22  10  3   9  35  30   5   33
# 7          8         Newcastle United  22   9  6   7  32  27   5   33
# 8          9               Sunderland  22   8  9   5  23  23   0   33
# 9         10                  Everton  22   9  5   8  24  25  -1   32
# 10        11                   Fulham  22   9  4   9  30  31  -1   31
# 11        12   Brighton & Hove Albion  22   7  9   6  32  29   3   30
# 12        13           Crystal Palace  22   7  7   8  23  25  -2   28
# 13        14        Tottenham Hotspur  22   7  6   9  31  29   2   27
# 14        15          AFC Bournemouth  22   6  9   7  35  41  -6   27
# 15        16             Leeds United  22   6  7   9  30  37  -7   25
# 16        17        Nottingham Forest  22   6  4  12  21  34 -13   22
# 17        18          West Ham United  22   4  5  13  24  44 -20   17
# 18        19                  Burnley  22   3  5  14  23  42 -19   14
# 19        20  Wolverhampton Wanderers  22   1  5  16  15  41 -26    8

# %% [markdown]
# ## 2. Get betting odds using API

# %%
# Load variables from API_KEY.env
load_dotenv("API_KEY.env")

API_KEY = os.getenv("ODDS_DATA_API_KEY")

if API_KEY is None:
    raise ValueError("API_KEY not found. Check API_KEY.env")

print("API key loaded successfully")
# Out:
# API key loaded successfully

# %%
url = "https://api.the-odds-api.com/v4/sports/soccer_epl/odds"

params = {
    "apiKey": API_KEY,
    "regions": "uk",
    "markets": "h2h",
    "oddsFormat": "decimal",
    "dateFormat": "iso",
    "days": 365  # get all upcoming matches for the next year
}

response = requests.get(url, params=params)
response.raise_for_status()

odds_data = response.json()
print("Total upcoming matches:", len(odds_data))
# Out:
# Total upcoming matches: 20

# %%
def flatten_odds(data):
    rows = []

    for match in data:
        match_id = match["id"]
        home = match["home_team"]
        away = match["away_team"]
        time = match["commence_time"]

        for book in match["bookmakers"]:
            bookmaker = book["title"]

            # Find head-to-head (h2h) market. Find the market where key == 'h2h' (win/draw/win odds). If not found, skip this bookmaker.
            h2h = next((m for m in book["markets"] if m["key"] == "h2h"), None)
            if not h2h:
                continue

            outcomes = {o["name"]: o["price"] for o in h2h["outcomes"]}

            rows.append({
                "match_id": match_id,
                "commence_time": time,
                "home_team": home,
                "away_team": away,
                "bookmaker": bookmaker,
                "home_odds": outcomes.get(home),
                "draw_odds": outcomes.get("Draw"),
                "away_odds": outcomes.get(away),
            })

    return pd.DataFrame(rows)

df = flatten_odds(odds_data)
df.head()
# Out:
#                            match_id         commence_time        home_team  \
# 0  a396966205b21287109ea8cae42e44c1  2026-01-24T12:30:00Z  West Ham United
# 1  a396966205b21287109ea8cae42e44c1  2026-01-24T12:30:00Z  West Ham United
# 2  a396966205b21287109ea8cae42e44c1  2026-01-24T12:30:00Z  West Ham United
# 3  a396966205b21287109ea8cae42e44c1  2026-01-24T12:30:00Z  West Ham United
# 4  a396966205b21287109ea8cae42e44c1  2026-01-24T12:30:00Z  West Ham United
#
#     away_team    bookmaker  home_odds  draw_odds  away_odds
# 0  Sunderland  Unibet (UK)       2.45       3.30       2.88
# 1  Sunderland  Paddy Power       2.38       3.20       3.00
# 2  Sunderland       Betway       2.50       3.20       2.80
# 3  Sunderland     Smarkets       2.56       3.35       2.98
# 4  Sunderland      Sky Bet       2.38       3.10       3.00

# %%
betting_odds_avg = (
    df.groupby(["match_id", "home_team", "away_team"])
      .agg({
          "home_odds": "mean",
          "draw_odds": "mean",
          "away_odds": "mean"
      })
      .reset_index()
)

betting_odds_avg.head()
# Out:
#                            match_id                 home_team  \
# 0  1ca6d3d9cde3e58a39211feb9188530c          Newcastle United
# 1  1e811fa7ead0a3e6ef920b15b2bbb95d                   Burnley
# 2  36820753efb36739a83c6e5e440827b2  Brighton and Hove Albion
# 3  38a3cb5e295f55e274d589fc646cf2dd         Tottenham Hotspur
# 4  4d6c0ac53b2b38aeb5bc8c8163f3f8b9            Crystal Palace
#
#            away_team  home_odds  draw_odds  away_odds
# 0        Aston Villa   1.953333   3.666667   3.563889
# 1  Tottenham Hotspur   3.683333   3.386111   2.021667
# 2            Everton   1.808571   3.607143   4.059286
# 3    Manchester City   4.411429   3.946429   1.690000
# 4            Chelsea   3.455556   3.622222   2.015556

# %%
# Convert odds -> raw probabilities
betting_odds_avg["p_home_raw"] = 1 / betting_odds_avg["home_odds"]
betting_odds_avg["p_draw_raw"] = 1 / betting_odds_avg["draw_odds"]
betting_odds_avg["p_away_raw"] = 1 / betting_odds_avg["away_odds"]

#2) Normalize (remove bookmaker margin)
betting_odds_avg["total_raw"] = (
    betting_odds_avg["p_home_raw"] +
    betting_odds_avg["p_draw_raw"] +
    betting_odds_avg["p_away_raw"]
)

betting_odds_avg["p_home_book"] = betting_odds_avg["p_home_raw"] / betting_odds_avg["total_raw"]
betting_odds_avg["p_draw_book"] = betting_odds_avg["p_draw_raw"] / betting_odds_avg["total_raw"]
betting_odds_avg["p_away_book"] = betting_odds_avg["p_away_raw"] / betting_odds_avg["total_raw"]

# %%
# Keep only useful columns
betting_odds_avg = betting_odds_avg[[
#match_id",
    "home_team",
    "away_team",
    "p_home_book",
    "p_draw_book",
    "p_away_book"
]]

betting_odds_avg.head()
# Out:
#                   home_team          away_team  p_home_book  p_draw_book  \
# 0          Newcastle United        Aston Villa     0.480580     0.256018
# 1                   Burnley  Tottenham Hotspur     0.255774     0.278225
# 2  Brighton and Hove Albion            Everton     0.513630     0.257527
# 3         Tottenham Hotspur    Manchester City     0.211500     0.236420
# 4            Crystal Palace            Chelsea     0.272596     0.260053
#
#    p_away_book
# 0     0.263401
# 1     0.466002
# 2     0.228843
# 3     0.552080
# 4     0.467351

# %% [markdown]
# ## 3. Get fixtures for upcoming EPL games

# %%
# Load variables from API_KEY.env
load_dotenv("API_KEY.env")

API_KEY = os.getenv("FOOTBALL_DATA_API_KEY")

if API_KEY is None:
    raise ValueError("API_KEY not found. Check API_KEY.env")

print("API key loaded successfully")
# Out:
# API key loaded successfully

# %%
url = "https://api.football-data.org/v4/competitions/PL/matches"

headers = {
    "X-Auth-Token": API_KEY
}

today = datetime.utcnow().date()
end_of_season = today + timedelta(days=365)  # big range to cover all remaining games

params = {
    "status": "SCHEDULED",
    "dateFrom": today.isoformat(),
    "dateTo": end_of_season.isoformat()
}

response = requests.get(url, headers=headers, params=params)
response.raise_for_status()

data = response.json()
fixtures = data["matches"]

df_fixtures = pd.DataFrame(fixtures)

df_fixtures_clean = df_fixtures[[
    "utcDate",
    "status",
    "homeTeam",
    "awayTeam"
]]

df_fixtures_clean.head()
print("Total scheduled matches:", len(df_fixtures_clean))
# Out:
# [01/19/26 19:25:37] WARNING  C:\Users\vicky\AppData\Local\Temp\ipykernel_21604\187534790.py:7:      ]8;id=935528;file://C:\ProgramData\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=272127;file://C:\ProgramData\anaconda3\Lib\warnings.py#112\112]8;;\
#                              DeprecationWarning: datetime.datetime.utcnow() is deprecated and
#                              scheduled for removal in a future version. Use timezone-aware objects
#                              to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#                                today = datetime.utcnow().date()
# Total scheduled matches: 160

# %%
df_fixtures_clean["homeTeam"] = df_fixtures_clean["homeTeam"].apply(lambda x: x["name"])
df_fixtures_clean["awayTeam"] = df_fixtures_clean["awayTeam"].apply(lambda x: x["name"])
# Out:
# [01/19/26 19:25:39] WARNING  C:\Users\vicky\AppData\Local\Temp\ipykernel_21604\2614041168.py:1:     ]8;id=546963;file://C:\ProgramData\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=742545;file://C:\ProgramData\anaconda3\Lib\warnings.py#112\112]8;;\
#                              SettingWithCopyWarning:
#                              A value is trying to be set on a copy of a slice from a DataFrame.
#                              Try using .loc = value instead
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df_fixtures_clean["homeTeam"] =
#                              df_fixtures_clean["homeTeam"].apply(lambda x: x["name"])
#                     WARNING  C:\Users\vicky\AppData\Local\Temp\ipykernel_21604\2614041168.py:2:     ]8;id=659313;file://C:\ProgramData\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=469563;file://C:\ProgramData\anaconda3\Lib\warnings.py#112\112]8;;\
#                              SettingWithCopyWarning:
#                              A value is trying to be set on a copy of a slice from a DataFrame.
#                              Try using .loc = value instead
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df_fixtures_clean["awayTeam"] =
#                              df_fixtures_clean["awayTeam"].apply(lambda x: x["name"])

# %%
df_fixtures_clean
# Out:
#                   utcDate status              homeTeam  \
# 0    2026-01-24T12:30:00Z  TIMED    West Ham United FC
# 1    2026-01-24T15:00:00Z  TIMED            Burnley FC
# 2    2026-01-24T15:00:00Z  TIMED             Fulham FC
# 3    2026-01-24T15:00:00Z  TIMED    Manchester City FC
# 4    2026-01-24T17:30:00Z  TIMED       AFC Bournemouth
# ..                    ...    ...                   ...
# 155  2026-05-24T15:00:00Z  TIMED          Liverpool FC
# 156  2026-05-24T15:00:00Z  TIMED    Manchester City FC
# 157  2026-05-24T15:00:00Z  TIMED  Nottingham Forest FC
# 158  2026-05-24T15:00:00Z  TIMED  Tottenham Hotspur FC
# 159  2026-05-24T15:00:00Z  TIMED    West Ham United FC
#
#                        awayTeam
# 0                Sunderland AFC
# 1          Tottenham Hotspur FC
# 2     Brighton & Hove Albion FC
# 3    Wolverhampton Wanderers FC
# 4                  Liverpool FC
# ..                          ...
# 155                Brentford FC
# 156              Aston Villa FC
# 157             AFC Bournemouth
# 158                  Everton FC
# 159             Leeds United FC
#
# [160 rows x 4 columns]

# %% [markdown]
# ## 4. Get this season (2025/26) and last season (2024/25) results

# %%
url = "https://api.football-data.org/v4/competitions/PL/matches"
params = {
    "season": 2025,   # season year
    "status": "FINISHED"
}

response = requests.get(url, headers=headers, params=params)
response.raise_for_status()
past_matches = response.json()["matches"]

# %%
clean_rows = []

for m in past_matches:
    row = {
        "utcDate": m["utcDate"],
        "matchday": m["matchday"],
        "status": m["status"],
        "homeTeam": m["homeTeam"]["name"],
        "awayTeam": m["awayTeam"]["name"],
        "homeGoals": m["score"]["fullTime"]["home"],
        "awayGoals": m["score"]["fullTime"]["away"],
        "winner": m["score"]["winner"]
    }
    clean_rows.append(row)

past_matches_25_clean = pd.DataFrame(clean_rows)
past_matches_25_clean.tail()
# Out:
#                   utcDate  matchday    status                    homeTeam  \
# 215  2026-01-17T15:00:00Z        22  FINISHED        Tottenham Hotspur FC
# 216  2026-01-17T17:30:00Z        22  FINISHED        Nottingham Forest FC
# 217  2026-01-18T14:00:00Z        22  FINISHED  Wolverhampton Wanderers FC
# 218  2026-01-18T16:30:00Z        22  FINISHED              Aston Villa FC
# 219  2026-01-19T20:00:00Z        22  FINISHED   Brighton & Hove Albion FC
#
#                 awayTeam  homeGoals  awayGoals     winner
# 215   West Ham United FC          1          2  AWAY_TEAM
# 216           Arsenal FC          0          0       DRAW
# 217  Newcastle United FC          0          0       DRAW
# 218           Everton FC          0          1  AWAY_TEAM
# 219      AFC Bournemouth          1          1       DRAW

# %%
url = "https://api.football-data.org/v4/competitions/PL/matches"
params = {
    "season": 2024,   # season year
    "status": "FINISHED"
}

response = requests.get(url, headers=headers, params=params)
response.raise_for_status()
past_matches_24 = response.json()["matches"]

# %%
clean_rows = []

for m in past_matches_24:
    row = {
        "utcDate": m["utcDate"],
        "matchday": m["matchday"],
        "status": m["status"],
        "homeTeam": m["homeTeam"]["name"],
        "awayTeam": m["awayTeam"]["name"],
        "homeGoals": m["score"]["fullTime"]["home"],
        "awayGoals": m["score"]["fullTime"]["away"],
        "winner": m["score"]["winner"]
    }
    clean_rows.append(row)

past_matches_24_clean = pd.DataFrame(clean_rows)
past_matches_24_clean.head()
# Out:
#                 utcDate  matchday    status              homeTeam  \
# 0  2024-08-16T19:00:00Z         1  FINISHED  Manchester United FC
# 1  2024-08-17T11:30:00Z         1  FINISHED       Ipswich Town FC
# 2  2024-08-17T14:00:00Z         1  FINISHED            Arsenal FC
# 3  2024-08-17T14:00:00Z         1  FINISHED            Everton FC
# 4  2024-08-17T14:00:00Z         1  FINISHED   Newcastle United FC
#
#                      awayTeam  homeGoals  awayGoals     winner
# 0                   Fulham FC          1          0  HOME_TEAM
# 1                Liverpool FC          0          2  AWAY_TEAM
# 2  Wolverhampton Wanderers FC          2          0  HOME_TEAM
# 3   Brighton & Hove Albion FC          0          3  AWAY_TEAM
# 4              Southampton FC          1          0  HOME_TEAM

# %% [markdown]
# ## 5. Combine and calculate probabilities of W/D/L for each match

# %%
# Load Dataframes
df_current = past_matches_25_clean
df_prev = past_matches_24_clean
df_future = df_fixtures_clean

# Combine all past fixtures together
df_all = pd.concat([df_prev, df_current], ignore_index=True)

# %% [raw]
# # Add weights: more recent games = more weight. EXPONENTIAL DECAY
# df_all["date"] = pd.to_datetime(df_all["utcDate"])
# df_all["days_ago"] = (pd.Timestamp.now(tz="UTC") - df_all["date"]).dt.days
#
# # decay rate (tune this)
# lambda_decay = 0.01
#
# df_all["weight"] = np.exp(-lambda_decay * df_all["days_ago"])
#
# ## When compared to bookmaker probabilities, the model made with Exponential Decay Weighting produces a bigger rmse_total. Simplear linear weighting is more aligned to bookmakers numbers.

# %%
# Add weights: more recent games = more weight
df_all["date"] = pd.to_datetime(df_all["utcDate"])
df_all["weight"] = np.linspace(1, 2, len(df_all))  # simple linear weighting

# %%
df_all.tail()
# Out:
#                   utcDate  matchday    status                    homeTeam  \
# 595  2026-01-17T15:00:00Z        22  FINISHED        Tottenham Hotspur FC
# 596  2026-01-17T17:30:00Z        22  FINISHED        Nottingham Forest FC
# 597  2026-01-18T14:00:00Z        22  FINISHED  Wolverhampton Wanderers FC
# 598  2026-01-18T16:30:00Z        22  FINISHED              Aston Villa FC
# 599  2026-01-19T20:00:00Z        22  FINISHED   Brighton & Hove Albion FC
#
#                 awayTeam  homeGoals  awayGoals     winner  \
# 595   West Ham United FC          1          2  AWAY_TEAM
# 596           Arsenal FC          0          0       DRAW
# 597  Newcastle United FC          0          0       DRAW
# 598           Everton FC          0          1  AWAY_TEAM
# 599      AFC Bournemouth          1          1       DRAW
#
#                          date    weight
# 595 2026-01-17 15:00:00+00:00  1.993322
# 596 2026-01-17 17:30:00+00:00  1.994992
# 597 2026-01-18 14:00:00+00:00  1.996661
# 598 2026-01-18 16:30:00+00:00  1.998331
# 599 2026-01-19 20:00:00+00:00  2.000000

# %%
# Compute home advantage
# Home advantage = average home goals - average away goals
home_avg = df_all["homeGoals"].mean()
away_avg = df_all["awayGoals"].mean()
home_advantage = home_avg - away_avg
home_advantage
# Out:
# 0.19333333333333336

# %%
#  Calculate attack & defense strengths
teams = pd.unique(df_all[["homeTeam", "awayTeam"]].values.ravel("K"))

attack = pd.Series(1.0, index=teams)
defense = pd.Series(1.0, index=teams)

# Initialize with goals per match
team_stats = {}

for team in teams:
    home_games = df_all[df_all["homeTeam"] == team]
    away_games = df_all[df_all["awayTeam"] == team]

    goals_scored = (home_games["homeGoals"] * home_games["weight"]).sum() + \
                   (away_games["awayGoals"] * away_games["weight"]).sum()

    goals_against = (home_games["awayGoals"] * home_games["weight"]).sum() + \
                    (away_games["homeGoals"] * away_games["weight"]).sum()

    matches = home_games["weight"].sum() + away_games["weight"].sum()

    team_stats[team] = {
        "scored": goals_scored / matches,
        "against": goals_against / matches
    }

# Strengths = relative to league average
league_avg_scored = df_all["homeGoals"].mean() + df_all["awayGoals"].mean()
league_avg_scored /= 2

for team in teams:
    attack[team] = team_stats[team]["scored"] / league_avg_scored
    defense[team] = team_stats[team]["against"] / league_avg_scored

# %% [markdown]
# 🔥 Summary
#
# This function:
# + Calculates expected goals for each team
# + Uses Poisson distribution to compute goal probabilities
# + Converts score probabilities into match outcome probabilities
# + Returns probabilities for:
# ++ home win
# ++ draw
# ++ away win

# %% [markdown]
# The Poisson distribution models the number of goals a team scores in a match based on an expected goal rate (λ). Using the formula \(P(X=k)=e^{-\lambda}\lambda^k/k!\), it calculates the probability of scoring 0, 1, 2, … goals, where λ is estimated from team attack/defense strengths and league averages. In the model, I compute separate Poisson probabilities for home and away goals, then combine them to get the probabilities of each possible scoreline and therefore the probabilities of a home win, draw, or away win.

# %%
# Calculate probabilities for each future match

def match_probabilities(home, away):
    # expected goals
    exp_home = np.exp(np.log(league_avg_scored) + np.log(attack[home]) + np.log(defense[away]) + home_advantage)
    exp_away = np.exp(np.log(league_avg_scored) + np.log(attack[away]) + np.log(defense[home]))

    # compute probabilities up to 6 goals
    max_goals = 6
    p_home = poisson.pmf(range(max_goals + 1), exp_home)
    p_away = poisson.pmf(range(max_goals + 1), exp_away)

    # result probabilities
    p_win = 0
    p_draw = 0
    p_loss = 0

    for i in range(max_goals + 1):
        for j in range(max_goals + 1):
            prob = p_home[i] * p_away[j]
            if i > j:
                p_win += prob
            elif i == j:
                p_draw += prob
            else:
                p_loss += prob

    return p_win, p_draw, p_loss

# %%
# Apply to all fixtures

results = []

for _, row in df_future.iterrows():
    home = row["homeTeam"]
    away = row["awayTeam"]

    p_win, p_draw, p_loss = match_probabilities(home, away)

    results.append({
        "utcDate": row["utcDate"],
        "homeTeam": home,
        "awayTeam": away,
        "p_home_win": p_win,
        "p_draw": p_draw,
        "p_away_win": p_loss,
    })

df_odds = pd.DataFrame(results)
df_odds.head()
# Out:
#                 utcDate            homeTeam                    awayTeam  \
# 0  2026-01-24T12:30:00Z  West Ham United FC              Sunderland AFC
# 1  2026-01-24T15:00:00Z          Burnley FC        Tottenham Hotspur FC
# 2  2026-01-24T15:00:00Z           Fulham FC   Brighton & Hove Albion FC
# 3  2026-01-24T15:00:00Z  Manchester City FC  Wolverhampton Wanderers FC
# 4  2026-01-24T17:30:00Z     AFC Bournemouth                Liverpool FC
#
#    p_home_win    p_draw  p_away_win
# 0    0.300547  0.279822    0.419160
# 1    0.264293  0.215537    0.514841
# 2    0.405496  0.228470    0.362613
# 3    0.775213  0.122029    0.071776
# 4    0.304759  0.214773    0.474532

# %% [markdown]
# ## 6. Compare calculated probabilities to bookmaker ones

# %%
unique_bet_home = betting_odds_avg["home_team"].unique()
unique_model_home = df_odds["homeTeam"].unique()

# %%
print(unique_bet_home)
print(unique_model_home)
# Out:
# ['Newcastle United' 'Burnley' 'Brighton and Hove Albion'
#  'Tottenham Hotspur' 'Crystal Palace' 'Sunderland' 'Arsenal' 'Bournemouth'
#  'Brentford' 'Liverpool' 'Aston Villa' 'West Ham United' 'Chelsea'
#  'Manchester City' 'Wolverhampton Wanderers' 'Nottingham Forest' 'Fulham'
#  'Manchester United' 'Leeds United' 'Everton']
# ['West Ham United FC' 'Burnley FC' 'Fulham FC' 'Manchester City FC'
#  'AFC Bournemouth' 'Crystal Palace FC' 'Brentford FC'
#  'Newcastle United FC' 'Arsenal FC' 'Everton FC'
#  'Brighton & Hove Albion FC' 'Leeds United FC'
#  'Wolverhampton Wanderers FC' 'Chelsea FC' 'Liverpool FC' 'Aston Villa FC'
#  'Manchester United FC' 'Nottingham Forest FC' 'Tottenham Hotspur FC'
#  'Sunderland AFC']

# %%
def normalize_team(name):
    name = name.lower()
    name = name.replace(" fc", "")
    name = name.replace(" afc", "")
    name = name.replace("&", "and")
    name = name.replace("afc ", "")   # <--- this removes AFC from start
    name = name.strip()
    return name

# %%
df_odds["home_norm"] = df_odds["homeTeam"].apply(normalize_team)
df_odds["away_norm"] = df_odds["awayTeam"].apply(normalize_team)

betting_odds_avg["home_norm"] = betting_odds_avg["home_team"].apply(normalize_team)
betting_odds_avg["away_norm"] = betting_odds_avg["away_team"].apply(normalize_team)

# %%
unique_model_norm = df_odds["home_norm"].unique()
unique_bet_norm = betting_odds_avg["home_norm"].unique()

set(unique_model_norm) == set(unique_bet_norm)
# Out:
# True

# %%
df_compare = df_odds.merge(
    betting_odds_avg,
    left_on=["home_norm", "away_norm"],
    right_on=["home_norm", "away_norm"],
    how="inner"
)

print("Matched rows:", len(df_compare))
df_compare.head()
# Out:
# Matched rows: 20
#                 utcDate            homeTeam                    awayTeam  \
# 0  2026-01-24T12:30:00Z  West Ham United FC              Sunderland AFC
# 1  2026-01-24T15:00:00Z          Burnley FC        Tottenham Hotspur FC
# 2  2026-01-24T15:00:00Z           Fulham FC   Brighton & Hove Albion FC
# 3  2026-01-24T15:00:00Z  Manchester City FC  Wolverhampton Wanderers FC
# 4  2026-01-24T17:30:00Z     AFC Bournemouth                Liverpool FC
#
#    p_home_win    p_draw  p_away_win        home_norm  \
# 0    0.300547  0.279822    0.419160  west ham united
# 1    0.264293  0.215537    0.514841          burnley
# 2    0.405496  0.228470    0.362613           fulham
# 3    0.775213  0.122029    0.071776  manchester city
# 4    0.304759  0.214773    0.474532      bournemouth
#
#                   away_norm        home_team                 away_team  \
# 0                sunderland  West Ham United                Sunderland
# 1         tottenham hotspur          Burnley         Tottenham Hotspur
# 2  brighton and hove albion           Fulham  Brighton and Hove Albion
# 3   wolverhampton wanderers  Manchester City   Wolverhampton Wanderers
# 4                 liverpool      Bournemouth                 Liverpool
#
#    p_home_book  p_draw_book  p_away_book
# 0     0.386261     0.289448     0.324291
# 1     0.255774     0.278225     0.466002
# 2     0.376212     0.280847     0.342941
# 3     0.795969     0.134538     0.069493
# 4     0.257024     0.243672     0.499304

# %%
df_compare["diff_home"] = df_compare["p_home_win"] - df_compare["p_home_book"]
df_compare["diff_draw"] = df_compare["p_draw"] - df_compare["p_draw_book"]
df_compare["diff_away"] = df_compare["p_away_win"] - df_compare["p_away_book"]

df_compare[["homeTeam", "awayTeam", "diff_home", "diff_draw", "diff_away"]].head()
# Out:
#              homeTeam                    awayTeam  diff_home  diff_draw  \
# 0  West Ham United FC              Sunderland AFC  -0.085714  -0.009627
# 1          Burnley FC        Tottenham Hotspur FC   0.008519  -0.062688
# 2           Fulham FC   Brighton & Hove Albion FC   0.029283  -0.052376
# 3  Manchester City FC  Wolverhampton Wanderers FC  -0.020756  -0.012509
# 4     AFC Bournemouth                Liverpool FC   0.047735  -0.028899
#
#    diff_away
# 0   0.094869
# 1   0.048840
# 2   0.019672
# 3   0.002283
# 4  -0.024772

# %%
import numpy as np

rmse_home = np.sqrt(np.mean((df_compare["p_home_win"] - df_compare["p_home_book"])**2))
rmse_draw = np.sqrt(np.mean((df_compare["p_draw"] - df_compare["p_draw_book"])**2))
rmse_away = np.sqrt(np.mean((df_compare["p_away_win"] - df_compare["p_away_book"])**2))

rmse_home, rmse_draw, rmse_away
# Out:
# (0.05503852146323975, 0.03854795251723141, 0.048998304404854046)

# %%
rmse_total = np.sqrt(np.mean((
    df_compare["p_home_win"] - df_compare["p_home_book"]
)**2 + (
    df_compare["p_draw"] - df_compare["p_draw_book"]
)**2 + (
    df_compare["p_away_win"] - df_compare["p_away_book"]
)**2 ))

rmse_total
# Out:
# 0.08316259569470502

# %%
df_compare["abs_diff"] = (
    abs(df_compare["diff_home"]) +
    abs(df_compare["diff_draw"]) +
    abs(df_compare["diff_away"])
)

df_compare.sort_values("abs_diff", ascending=False).head(10)[
    ["homeTeam", "awayTeam", "diff_home", "diff_draw", "diff_away"]
]
# Out:
#                       homeTeam              awayTeam  diff_home  diff_draw  \
# 8                   Arsenal FC  Manchester United FC   0.108539  -0.062273
# 16        Manchester United FC             Fulham FC  -0.110446   0.001523
# 0           West Ham United FC        Sunderland AFC  -0.085714  -0.009627
# 9                   Everton FC       Leeds United FC   0.092224  -0.049945
# 12  Wolverhampton Wanderers FC       AFC Bournemouth  -0.029397  -0.048658
# 19              Sunderland AFC            Burnley FC   0.066898  -0.033451
# 6                 Brentford FC  Nottingham Forest FC   0.063797  -0.060344
# 1                   Burnley FC  Tottenham Hotspur FC   0.008519  -0.062688
# 13                  Chelsea FC    West Ham United FC   0.053590  -0.039107
# 17        Nottingham Forest FC     Crystal Palace FC  -0.032759  -0.020610
#
#     diff_away
# 8   -0.053795
# 16   0.106377
# 0    0.094869
# 9   -0.043653
# 12   0.073666
# 19  -0.035140
# 6   -0.007581
# 1    0.048840
# 13  -0.027231
# 17   0.052612

# %% [markdown]
# ## 7. Replace my estimates probabilities with the ones I have from odds, creating my final match probabilities

# %%
df_odds.head(2)
# Out:
#                 utcDate            homeTeam              awayTeam  p_home_win  \
# 0  2026-01-24T12:30:00Z  West Ham United FC        Sunderland AFC    0.300547
# 1  2026-01-24T15:00:00Z          Burnley FC  Tottenham Hotspur FC    0.264293
#
#      p_draw  p_away_win        home_norm          away_norm
# 0  0.279822    0.419160  west ham united         sunderland
# 1  0.215537    0.514841          burnley  tottenham hotspur

# %%
betting_odds_avg.head(2)
# Out:
#           home_team          away_team  p_home_book  p_draw_book  p_away_book  \
# 0  Newcastle United        Aston Villa     0.480580     0.256018     0.263401
# 1           Burnley  Tottenham Hotspur     0.255774     0.278225     0.466002
#
#           home_norm          away_norm
# 0  newcastle united        aston villa
# 1           burnley  tottenham hotspur

# %%
df_final_probabilities = df_odds.merge(
    betting_odds_avg,
    left_on=["home_norm", "away_norm"],
    right_on=["home_norm", "away_norm"],
    how="left"
)

# %%
df_final_probabilities = df_final_probabilities[[
    "utcDate",
    "homeTeam",
    "awayTeam",
    "p_home_win",
    "p_draw",
    "p_away_win",
    "p_home_book",
    "p_draw_book",
    "p_away_book",
]]

df_final_probabilities
# Out:
#                   utcDate              homeTeam                    awayTeam  \
# 0    2026-01-24T12:30:00Z    West Ham United FC              Sunderland AFC
# 1    2026-01-24T15:00:00Z            Burnley FC        Tottenham Hotspur FC
# 2    2026-01-24T15:00:00Z             Fulham FC   Brighton & Hove Albion FC
# 3    2026-01-24T15:00:00Z    Manchester City FC  Wolverhampton Wanderers FC
# 4    2026-01-24T17:30:00Z       AFC Bournemouth                Liverpool FC
# ..                    ...                   ...                         ...
# 155  2026-05-24T15:00:00Z          Liverpool FC                Brentford FC
# 156  2026-05-24T15:00:00Z    Manchester City FC              Aston Villa FC
# 157  2026-05-24T15:00:00Z  Nottingham Forest FC             AFC Bournemouth
# 158  2026-05-24T15:00:00Z  Tottenham Hotspur FC                  Everton FC
# 159  2026-05-24T15:00:00Z    West Ham United FC             Leeds United FC
#
#      p_home_win    p_draw  p_away_win  p_home_book  p_draw_book  p_away_book
# 0      0.300547  0.279822    0.419160     0.386261     0.289448     0.324291
# 1      0.264293  0.215537    0.514841     0.255774     0.278225     0.466002
# 2      0.405496  0.228470    0.362613     0.376212     0.280847     0.342941
# 3      0.775213  0.122029    0.071776     0.795969     0.134538     0.069493
# 4      0.304759  0.214773    0.474532     0.257024     0.243672     0.499304
# ..          ...       ...         ...          ...          ...          ...
# 155    0.564764  0.197342    0.228107          NaN          NaN          NaN
# 156    0.582085  0.210743    0.201947          NaN          NaN          NaN
# 157    0.411739  0.237440    0.348489          NaN          NaN          NaN
# 158    0.420254  0.258064    0.320653          NaN          NaN          NaN
# 159    0.370484  0.227678    0.398293          NaN          NaN          NaN
#
# [160 rows x 9 columns]

# %%
df_final_probabilities["p_home_final"] = np.where(
    df_final_probabilities["p_home_book"].notna(),
    df_final_probabilities["p_home_book"],
    df_final_probabilities["p_home_win"]
)

df_final_probabilities["p_draw_final"] = np.where(
    df_final_probabilities["p_draw_book"].notna(),
    df_final_probabilities["p_draw_book"],
    df_final_probabilities["p_draw"]
)

df_final_probabilities["p_away_final"] = np.where(
    df_final_probabilities["p_away_book"].notna(),
    df_final_probabilities["p_away_book"],
    df_final_probabilities["p_away_win"]
)

# %%
print("Used betting odds:", df_final_probabilities["p_home_book"].notna().sum())
print("Used model:", df_final_probabilities["p_home_book"].isna().sum())
# Out:
# Used betting odds: 20
# Used model: 140

# %%
df_final_probabilities = df_final_probabilities[[
    "utcDate",
    "homeTeam",
    "awayTeam",
    "p_home_final",
    "p_draw_final",
    "p_away_final"
]]

# %%
df_final_probabilities
# Out:
#                   utcDate              homeTeam                    awayTeam  \
# 0    2026-01-24T12:30:00Z    West Ham United FC              Sunderland AFC
# 1    2026-01-24T15:00:00Z            Burnley FC        Tottenham Hotspur FC
# 2    2026-01-24T15:00:00Z             Fulham FC   Brighton & Hove Albion FC
# 3    2026-01-24T15:00:00Z    Manchester City FC  Wolverhampton Wanderers FC
# 4    2026-01-24T17:30:00Z       AFC Bournemouth                Liverpool FC
# ..                    ...                   ...                         ...
# 155  2026-05-24T15:00:00Z          Liverpool FC                Brentford FC
# 156  2026-05-24T15:00:00Z    Manchester City FC              Aston Villa FC
# 157  2026-05-24T15:00:00Z  Nottingham Forest FC             AFC Bournemouth
# 158  2026-05-24T15:00:00Z  Tottenham Hotspur FC                  Everton FC
# 159  2026-05-24T15:00:00Z    West Ham United FC             Leeds United FC
#
#      p_home_final  p_draw_final  p_away_final
# 0        0.386261      0.289448      0.324291
# 1        0.255774      0.278225      0.466002
# 2        0.376212      0.280847      0.342941
# 3        0.795969      0.134538      0.069493
# 4        0.257024      0.243672      0.499304
# ..            ...           ...           ...
# 155      0.564764      0.197342      0.228107
# 156      0.582085      0.210743      0.201947
# 157      0.411739      0.237440      0.348489
# 158      0.420254      0.258064      0.320653
# 159      0.370484      0.227678      0.398293
#
# [160 rows x 6 columns]

# %%
df_final_probabilities["homeTeam"].unique()
# Out:
# array(['West Ham United FC', 'Burnley FC', 'Fulham FC',
#        'Manchester City FC', 'AFC Bournemouth', 'Crystal Palace FC',
#        'Brentford FC', 'Newcastle United FC', 'Arsenal FC', 'Everton FC',
#        'Brighton & Hove Albion FC', 'Leeds United FC',
#        'Wolverhampton Wanderers FC', 'Chelsea FC', 'Liverpool FC',
#        'Aston Villa FC', 'Manchester United FC', 'Nottingham Forest FC',
#        'Tottenham Hotspur FC', 'Sunderland AFC'], dtype=object)

# %%
name_map = {
    "Aston Villa FC": "Aston Villa",
    "Brighton & Hove Albion FC": "Brighton & Hove Albion",
    "AFC Bournemouth": "AFC Bournemouth",   # keep as is
    "Bournemouth": "AFC Bournemouth",
    "Sunderland AFC": "Sunderland",
    "Newcastle United FC": "Newcastle United",
    "Manchester City FC": "Manchester City",
    "Manchester United FC": "Manchester United",
    "West Ham United FC": "West Ham United",
    "Wolverhampton Wanderers FC": "Wolverhampton Wanderers",
    "Tottenham Hotspur FC": "Tottenham Hotspur",
    "Crystal Palace FC": "Crystal Palace",
    "Brentford FC": "Brentford",
    "Everton FC": "Everton",
    "Leeds United FC": "Leeds United",
    "Chelsea FC": "Chelsea",
    "Liverpool FC": "Liverpool",
    "Nottingham Forest FC": "Nottingham Forest",
    "Burnley FC": "Burnley",
    "Fulham FC": "Fulham",
    "Arsenal FC": "Arsenal"
}

df_final_probabilities["home_team_norm"] = df_final_probabilities["homeTeam"].replace(name_map)
df_final_probabilities["away_team_norm"] = df_final_probabilities["awayTeam"].replace(name_map)

premierleague["team_norm"] = premierleague["team"].replace({
    "Brighton & Hove Albion": "Brighton & Hove Albion",
    "AFC Bournemouth": "AFC Bournemouth"
})
# Out:
# [01/19/26 19:25:44] WARNING  C:\Users\vicky\AppData\Local\Temp\ipykernel_21604\2477332962.py:25:    ]8;id=475982;file://C:\ProgramData\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=722214;file://C:\ProgramData\anaconda3\Lib\warnings.py#112\112]8;;\
#                              SettingWithCopyWarning:
#                              A value is trying to be set on a copy of a slice from a DataFrame.
#                              Try using .loc = value instead
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df_final_probabilities["home_team_norm"] =
#                              df_final_probabilities["homeTeam"].replace(name_map)
#                     WARNING  C:\Users\vicky\AppData\Local\Temp\ipykernel_21604\2477332962.py:26:    ]8;id=589474;file://C:\ProgramData\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=40496;file://C:\ProgramData\anaconda3\Lib\warnings.py#112\112]8;;\
#                              SettingWithCopyWarning:
#                              A value is trying to be set on a copy of a slice from a DataFrame.
#                              Try using .loc = value instead
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df_final_probabilities["away_team_norm"] =
#                              df_final_probabilities["awayTeam"].replace(name_map)

# %%
df_simulation = df_final_probabilities.copy()

# %%
# Normalize probabilities so they sum to 1
prob_cols = ["p_home_final", "p_draw_final", "p_away_final"]
df_simulation[prob_cols] = df_simulation[prob_cols].div(df_simulation[prob_cols].sum(axis=1), axis=0)

# %%
df_simulation.head()
# Out:
#                 utcDate            homeTeam                    awayTeam  \
# 0  2026-01-24T12:30:00Z  West Ham United FC              Sunderland AFC
# 1  2026-01-24T15:00:00Z          Burnley FC        Tottenham Hotspur FC
# 2  2026-01-24T15:00:00Z           Fulham FC   Brighton & Hove Albion FC
# 3  2026-01-24T15:00:00Z  Manchester City FC  Wolverhampton Wanderers FC
# 4  2026-01-24T17:30:00Z     AFC Bournemouth                Liverpool FC
#
#    p_home_final  p_draw_final  p_away_final   home_team_norm  \
# 0      0.386261      0.289448      0.324291  West Ham United
# 1      0.255774      0.278225      0.466002          Burnley
# 2      0.376212      0.280847      0.342941           Fulham
# 3      0.795969      0.134538      0.069493  Manchester City
# 4      0.257024      0.243672      0.499304  AFC Bournemouth
#
#             away_team_norm
# 0               Sunderland
# 1        Tottenham Hotspur
# 2   Brighton & Hove Albion
# 3  Wolverhampton Wanderers
# 4                Liverpool

# %% [markdown]
# ## 8. Run simulations to build the Premier League table probabilities

# %%
def simulate_once(fixtures, table):
    table_sim = table.copy()

    # Use normalized team name column
    points = dict(zip(table_sim["team_norm"], table_sim["pts"]))

    for _, row in fixtures.iterrows():
        home = row["home_team_norm"]
        away = row["away_team_norm"]

        # choose outcome
        probs = [row["p_home_final"], row["p_draw_final"], row["p_away_final"]]
        outcome = np.random.choice(["H", "D", "A"], p=probs)

        if outcome == "H":
            points[home] += 3
        elif outcome == "D":
            points[home] += 1
            points[away] += 1
        else:
            points[away] += 3

    result_df = table_sim.copy()
    result_df["pts"] = result_df["team_norm"].map(points)

    # sort by points and goal difference
    result_df = result_df.sort_values(["pts", "gd"], ascending=[False, False])
    result_df["position"] = np.arange(1, len(result_df)+1)

    return result_df


def run_simulations(fixtures, table, n_sim=10000):
    position_counts = {team: np.zeros(len(table)) for team in table["team_norm"]}

    for _ in range(n_sim):
        final_table = simulate_once(fixtures, table)

        for _, row in final_table.iterrows():
            position_counts[row["team_norm"]][row["position"]-1] += 1

    pos_df = pd.DataFrame(position_counts, index=np.arange(1, len(table)+1))
    pos_df.index.name = "position"
    return pos_df

# %%
# RUN
position_distribution = run_simulations(df_simulation, premierleague, n_sim=20000)

# %%
position_distribution_t = position_distribution.T

# %%
position_distribution_pct = position_distribution_t.div(
    position_distribution_t.sum(axis=1),
    axis=0
) * 100

# %% [markdown]
# ## 9. Preview and present the results graphically

# %%
# Build label mapping: "position  team" (extra space for 1-9)
team_labels = (
    premierleague[["team", "position"]]
    .set_index("team")["position"]
    .map(lambda pos: f"{pos}{'  ' if pos < 10 else ' '}")
)

# Join position and team name into one label
team_labels = (
    premierleague[["team", "position"]]
    .assign(
        label=lambda df: df.apply(
            lambda r: f"{r['position']}{'&nbsp;&nbsp;&nbsp;&nbsp;' if r['position'] < 10 else '&nbsp;&nbsp;'}{r['team']}",
            axis=1
        )
    )
    .set_index("team")["label"]
)


# Apply labels to your table index
position_distribution_pct.index = position_distribution_pct.index.map(team_labels)

# Drop position column if present
position_distribution_pct = position_distribution_pct.drop(columns=["position"], errors="ignore")

# Remove index name
position_distribution_pct.index.name = None

# %%
position_distribution_pct.style\
    .background_gradient(
        cmap=green_cmap,
        vmin=0,
        vmax=vmax
    )\
    .applymap(zero_style)\
    .format("{:.2f}%")\
    .set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#e6edf4"),
            ("color", "#333"),
            ("text-align", "center"),
            ("font-family", "Inter, Roboto, Arial, sans-serif"),
            ("font-size", "13px"),
            ("font-weight", "600")
        ]},

        # <-- LEFT align only the "position" column header
        {"selector": "th.col_heading:nth-child(1)", "props": [
            ("text-align", "left")
        ]},

        {"selector": "th.row_heading", "props": [
            ("text-align", "left"),
            ("font-size", "13px"),
            ("font-weight", "600"),
            ("white-space", "nowrap"),
            ("max-width", "250px"),
            ("overflow", "hidden"),
            ("text-overflow", "ellipsis")
        ]},

        {"selector": "tr:nth-child(odd) th.row_heading", "props": [
            ("background-color", "#fbfcfe")
        ]},
        {"selector": "tr:nth-child(even) th.row_heading", "props": [
            ("background-color", "#e6edf4")
        ]},

        {"selector": "td", "props": [
            ("text-align", "center"),
            ("font-family", "Inter, Roboto, Arial, sans-serif"),
            ("font-size", "12px"),
            ("font-weight", "500"),
            ("color", "#000")
        ]}
    ])
# Out:
# [01/19/26 20:20:30] WARNING  C:\Users\vicky\AppData\Local\Temp\ipykernel_21604\26831357.py:7:       ]8;id=153629;file://C:\ProgramData\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=214806;file://C:\ProgramData\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: Styler.applymap has been deprecated. Use Styler.map
#                              instead.
#                                .applymap(zero_style)\
# <style type="text/css">
# #T_775e5 th {
#   background-color: #e6edf4;
#   color: #333;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 13px;
#   font-weight: 600;
# }
# #T_775e5 th.col_heading:nth-child(1) {
#   text-align: left;
# }
# #T_775e5 th.row_heading {
#   text-align: left;
#   font-size: 13px;
#   font-weight: 600;
#   white-space: nowrap;
#   max-width: 250px;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# #T_775e5 tr:nth-child(odd) th.row_heading {
#   background-color: #fbfcfe;
# }
# #T_775e5 tr:nth-child(even) th.row_heading {
#   background-color: #e6edf4;
# }
# #T_775e5 td {
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_775e5_row0_col0, #T_775e5_row1_col1, #T_775e5_row2_col2, #T_775e5_row2_col3, #T_775e5_row3_col2, #T_775e5_row3_col3, #T_775e5_row5_col4, #T_775e5_row15_col15, #T_775e5_row15_col16, #T_775e5_row16_col15, #T_775e5_row16_col16, #T_775e5_row17_col17, #T_775e5_row17_col18, #T_775e5_row18_col17, #T_775e5_row18_col18, #T_775e5_row19_col19 {
#   background-color: #4aa66b;
#   color: #f1f1f1;
# }
# #T_775e5_row0_col1, #T_775e5_row8_col6, #T_775e5_row10_col8 {
#   background-color: #8fd79f;
#   color: #000000;
# }
# #T_775e5_row0_col2 {
#   background-color: #eaf8ed;
#   color: #000000;
# }
# #T_775e5_row0_col3, #T_775e5_row1_col6, #T_775e5_row2_col10, #T_775e5_row4_col1, #T_775e5_row6_col16, #T_775e5_row9_col2, #T_775e5_row12_col3, #T_775e5_row13_col3, #T_775e5_row14_col3, #T_775e5_row16_col6, #T_775e5_row17_col12, #T_775e5_row17_col13, #T_775e5_row19_col16 {
#   background-color: #f1fbf3;
#   color: #000000;
# }
# #T_775e5_row0_col4, #T_775e5_row0_col5, #T_775e5_row1_col7, #T_775e5_row1_col8, #T_775e5_row2_col11, #T_775e5_row2_col12, #T_775e5_row3_col13, #T_775e5_row3_col14, #T_775e5_row4_col0, #T_775e5_row5_col0, #T_775e5_row5_col15, #T_775e5_row5_col16, #T_775e5_row6_col0, #T_775e5_row7_col0, #T_775e5_row7_col16, #T_775e5_row8_col1, #T_775e5_row8_col17, #T_775e5_row9_col1, #T_775e5_row9_col17, #T_775e5_row10_col17, #T_775e5_row11_col0, #T_775e5_row11_col1, #T_775e5_row11_col17, #T_775e5_row12_col2, #T_775e5_row12_col18, #T_775e5_row13_col1, #T_775e5_row13_col2, #T_775e5_row13_col18, #T_775e5_row14_col1, #T_775e5_row14_col2, #T_775e5_row14_col18, #T_775e5_row15_col3, #T_775e5_row15_col4, #T_775e5_row15_col19, #T_775e5_row16_col4, #T_775e5_row16_col5, #T_775e5_row16_col19, #T_775e5_row17_col10, #T_775e5_row17_col11, #T_775e5_row18_col13, #T_775e5_row18_col14, #T_775e5_row19_col14, #T_775e5_row19_col15 {
#   background-color: #f2fbf4;
#   color: #000000;
# }
# #T_775e5_row0_col6, #T_775e5_row0_col7, #T_775e5_row0_col8, #T_775e5_row0_col9, #T_775e5_row0_col10, #T_775e5_row0_col11, #T_775e5_row0_col12, #T_775e5_row0_col13, #T_775e5_row0_col14, #T_775e5_row0_col15, #T_775e5_row0_col16, #T_775e5_row0_col17, #T_775e5_row0_col18, #T_775e5_row0_col19, #T_775e5_row1_col9, #T_775e5_row1_col10, #T_775e5_row1_col11, #T_775e5_row1_col12, #T_775e5_row1_col13, #T_775e5_row1_col14, #T_775e5_row1_col15, #T_775e5_row1_col16, #T_775e5_row1_col17, #T_775e5_row1_col18, #T_775e5_row1_col19, #T_775e5_row2_col13, #T_775e5_row2_col14, #T_775e5_row2_col15, #T_775e5_row2_col16, #T_775e5_row2_col17, #T_775e5_row2_col18, #T_775e5_row2_col19, #T_775e5_row3_col15, #T_775e5_row3_col16, #T_775e5_row3_col17, #T_775e5_row3_col18, #T_775e5_row3_col19, #T_775e5_row4_col17, #T_775e5_row4_col18, #T_775e5_row4_col19, #T_775e5_row5_col17, #T_775e5_row5_col18, #T_775e5_row5_col19, #T_775e5_row6_col17, #T_775e5_row6_col18, #T_775e5_row6_col19, #T_775e5_row7_col17, #T_775e5_row7_col18, #T_775e5_row7_col19, #T_775e5_row8_col0, #T_775e5_row8_col18, #T_775e5_row8_col19, #T_775e5_row9_col0, #T_775e5_row9_col18, #T_775e5_row9_col19, #T_775e5_row10_col0, #T_775e5_row10_col1, #T_775e5_row10_col18, #T_775e5_row10_col19, #T_775e5_row11_col18, #T_775e5_row11_col19, #T_775e5_row12_col0, #T_775e5_row12_col1, #T_775e5_row12_col19, #T_775e5_row13_col0, #T_775e5_row13_col19, #T_775e5_row14_col0, #T_775e5_row14_col19, #T_775e5_row15_col0, #T_775e5_row15_col1, #T_775e5_row15_col2, #T_775e5_row16_col0, #T_775e5_row16_col1, #T_775e5_row16_col2, #T_775e5_row16_col3, #T_775e5_row17_col0, #T_775e5_row17_col1, #T_775e5_row17_col2, #T_775e5_row17_col3, #T_775e5_row17_col4, #T_775e5_row17_col5, #T_775e5_row17_col6, #T_775e5_row17_col7, #T_775e5_row17_col8, #T_775e5_row17_col9, #T_775e5_row18_col0, #T_775e5_row18_col1, #T_775e5_row18_col2, #T_775e5_row18_col3, #T_775e5_row18_col4, #T_775e5_row18_col5, #T_775e5_row18_col6, #T_775e5_row18_col7, #T_775e5_row18_col8, #T_775e5_row18_col9, #T_775e5_row18_col10, #T_775e5_row18_col11, #T_775e5_row18_col12, #T_775e5_row19_col0, #T_775e5_row19_col1, #T_775e5_row19_col2, #T_775e5_row19_col3, #T_775e5_row19_col4, #T_775e5_row19_col5, #T_775e5_row19_col6, #T_775e5_row19_col7, #T_775e5_row19_col8, #T_775e5_row19_col9, #T_775e5_row19_col10, #T_775e5_row19_col11, #T_775e5_row19_col12, #T_775e5_row19_col13 {
#   background-color: #f2fbf4;
#   color: #000000;
#   background-color: white;
#   color: #000;
# }
# #T_775e5_row1_col0, #T_775e5_row4_col4, #T_775e5_row11_col6 {
#   background-color: #93d8a2;
#   color: #000000;
# }
# #T_775e5_row1_col2 {
#   background-color: #55ae73;
#   color: #f1f1f1;
# }
# #T_775e5_row1_col3 {
#   background-color: #bbe7c5;
#   color: #000000;
# }
# #T_775e5_row1_col4, #T_775e5_row10_col16 {
#   background-color: #e3f5e7;
#   color: #000000;
# }
# #T_775e5_row1_col5, #T_775e5_row2_col8, #T_775e5_row3_col10, #T_775e5_row8_col2 {
#   background-color: #eefaf0;
#   color: #000000;
# }
# #T_775e5_row2_col0, #T_775e5_row2_col7, #T_775e5_row5_col11, #T_775e5_row6_col14, #T_775e5_row11_col16 {
#   background-color: #e8f7ec;
#   color: #000000;
# }
# #T_775e5_row2_col1 {
#   background-color: #61b77c;
#   color: #f1f1f1;
# }
# #T_775e5_row2_col4, #T_775e5_row4_col9, #T_775e5_row5_col2 {
#   background-color: #8ad59a;
#   color: #000000;
# }
# #T_775e5_row2_col5, #T_775e5_row4_col12 {
#   background-color: #c4eacc;
#   color: #000000;
# }
# #T_775e5_row2_col6, #T_775e5_row9_col4 {
#   background-color: #dbf3e0;
#   color: #000000;
# }
# #T_775e5_row2_col9, #T_775e5_row3_col0, #T_775e5_row3_col12, #T_775e5_row4_col16, #T_775e5_row5_col14, #T_775e5_row10_col2, #T_775e5_row15_col5, #T_775e5_row15_col18, #T_775e5_row18_col15 {
#   background-color: #f0faf3;
#   color: #000000;
# }
# #T_775e5_row3_col1, #T_775e5_row6_col10, #T_775e5_row9_col6 {
#   background-color: #afe3ba;
#   color: #000000;
# }
# #T_775e5_row3_col4 {
#   background-color: #54ad72;
#   color: #f1f1f1;
# }
# #T_775e5_row3_col5 {
#   background-color: #89d499;
#   color: #000000;
# }
# #T_775e5_row3_col6, #T_775e5_row7_col10 {
#   background-color: #b7e6c1;
#   color: #000000;
# }
# #T_775e5_row3_col7, #T_775e5_row17_col19 {
#   background-color: #cdeed4;
#   color: #000000;
# }
# #T_775e5_row3_col8, #T_775e5_row8_col3, #T_775e5_row10_col4, #T_775e5_row16_col10 {
#   background-color: #e0f4e4;
#   color: #000000;
# }
# #T_775e5_row3_col9, #T_775e5_row9_col3, #T_775e5_row13_col17 {
#   background-color: #e9f8ec;
#   color: #000000;
# }
# #T_775e5_row3_col11, #T_775e5_row6_col15, #T_775e5_row7_col1, #T_775e5_row11_col2, #T_775e5_row15_col6, #T_775e5_row16_col18 {
#   background-color: #effaf1;
#   color: #000000;
# }
# #T_775e5_row4_col2 {
#   background-color: #e4f6e8;
#   color: #000000;
# }
# #T_775e5_row4_col3, #T_775e5_row5_col8, #T_775e5_row16_col12 {
#   background-color: #c1e9ca;
#   color: #000000;
# }
# #T_775e5_row4_col5, #T_775e5_row7_col7 {
#   background-color: #78c88d;
#   color: #000000;
# }
# #T_775e5_row4_col6 {
#   background-color: #72c388;
#   color: #000000;
# }
# #T_775e5_row4_col7, #T_775e5_row6_col7 {
#   background-color: #74c58a;
#   color: #000000;
# }
# #T_775e5_row4_col8, #T_775e5_row8_col7 {
#   background-color: #7ecc91;
#   color: #000000;
# }
# #T_775e5_row4_col10 {
#   background-color: #a2deaf;
#   color: #000000;
# }
# #T_775e5_row4_col11, #T_775e5_row16_col17 {
#   background-color: #b5e5bf;
#   color: #000000;
# }
# #T_775e5_row4_col13 {
#   background-color: #d8f1dd;
#   color: #000000;
# }
# #T_775e5_row4_col14 {
#   background-color: #e3f6e7;
#   color: #000000;
# }
# #T_775e5_row4_col15, #T_775e5_row10_col3, #T_775e5_row13_col5, #T_7
