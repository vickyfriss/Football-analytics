# %% [markdown]
# ## 📈 Predicting Final League Positions Using Betting Odds, Probabilistic Modelling & Simulation
#
# **Competition:** Premier League, Serie A, La Liga, Bundesliga, Ligue 1 (Season 2025/26)
# **Purpose:** Estimate probabilities of final league positions using betting market information and simulation
# **Methods:** Odds-implied probabilities, Monte Carlo simulation, scenario analysis
# **Author:** [Victoria Friss de Kereki](https://www.linkedin.com/in/victoria-friss-de-kereki/)
# **Medium Articles:** [Predicting Final Positions in Europe’s Top 5 Football Leagues](https://medium.com/@vickyfrissdekereki/predicting-final-positions-in-europes-top-5-football-leagues-c40fc3c4e4ca)
#
#
# ---
#
# **Notebook first written:** `07/02/2026`
# **Last updated:** `12/02/2026`
# **Last run:** `07/03/2026`
#
#
# > This notebook develops a probabilistic framework to predict final league positions across Europe’s top five leagues (England, Italy, Spain, Germany, France) using betting odds as market-based expectations.
# >
# > Betting odds are transformed into implied probabilities and adjusted for bookmaker margins. These probabilities are then used to simulate the remainder of each season via Monte Carlo methods, generating distributions over final points totals and league positions.
# >
# > The analysis estimates the likelihood of key outcomes such as league titles, European qualification, relegation, and mid-table finishes. Results are presented at the team level with uncertainty intervals. The framework can be extended to incorporate additional inputs such as recent form, fixture difficulty, or alternative predictive models beyond betting markets.

# %% [markdown]
# <div style="text-align: left;">
#     <img src="Images and others/Predicting Final League Positions For Europe's Top 5 Football Leagues.png" alt="Predicting Final League Positions For Europe's Top 5 Football Leagues" width="600">
# </di>
# >

# %%
# Core
from datetime import datetime, timedelta
import os

# Data manipulation
import numpy as np
import pandas as pd

# APIs & environment
import requests
from dotenv import load_dotenv
import time  # for delaying requests
from datetime import date

# Statistics
from scipy.stats import poisson

# Visualisation
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import dataframe_image as dfi # To download the final images

# Nicer printing of tables, no wrapping
pd.set_option("display.width", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.expand_frame_repr", False)

# %% [markdown]
# ## 1. Final Standings (ESPN Scraping) for the 5 leagues

# %%
year = 2025  # current season start year

leagues = {
    "ENG.1": "premierleague_england",
    "ITA.1": "seriea_italy",
    "ESP.1": "laliga_spain",
    "GER.1": "bundesliga_germany",
    "FRA.1": "ligue1_france",
}

for league_code, df_name in leagues.items():
    url = f"https://www.espn.com/soccer/standings/_/league/{league_code}/season/{year}"
    tables = pd.read_html(url)

    teams_raw = tables[0]
    stats = tables[1]

    teams = pd.DataFrame()
    teams["position"] = teams_raw.iloc[:, 0].str.extract(r"^(\d+)").astype(int)
    teams["team"] = (
        teams_raw.iloc[:, 0]
        .str.replace(r"^\d+", "", regex=True)
        .str.replace(r"^[A-Z]{2,3}", "", regex=True)
        .str.strip()
    )

    stats.columns = ["gp", "w", "d", "l", "gf", "ga", "gd", "pts"]
    stats = stats.apply(
        lambda c: c.astype(str)
                  .str.replace("+", "", regex=False)
                  .astype(int)
    )

    globals()[df_name] = pd.concat([teams, stats], axis=1)

# %%
TEAM_NAME_MAPPING = {
    # Italy
    "AAS Roma": "AS Roma",
    "OComo": "Como",

    # Germany
    "B04Bayer Leverkusen": "Bayer Leverkusen",
    "M05Mainz": "Mainz",

    # France
    "NLyon": "Lyon",
    "LLille": "Lille",
    "ENice": "Nice",
    "ZMetz": "Metz",
}

def clean_team_names(df, column="team"):
    df = df.copy()
    df[column] = df[column].replace(TEAM_NAME_MAPPING)
    return df

premierleague_england = clean_team_names(premierleague_england)
seriea_italy = clean_team_names(seriea_italy)
laliga_spain = clean_team_names(laliga_spain)
bundesliga_germany = clean_team_names(bundesliga_germany)
ligue1_france = clean_team_names(ligue1_france)

# %%
print("\nPremier League (England)")
print(premierleague_england.head(3))

print("\nSerie A (Italy)")
print(seriea_italy.head(3))

print("\nLa Liga (Spain)")
print(laliga_spain.head(3))

print("\nBundesliga (Germany)")
print(bundesliga_germany.head(3))

print("\nLigue 1 (France)")
print(ligue1_france.head(3))
# Out:
# Premier League (England)
#    position               team  gp   w  d  l  gf  ga  gd  pts
# 0         1            Arsenal  30  20  7  3  59  22  37   67
# 1         2    Manchester City  29  18  6  5  59  27  32   60
# 2         3  Manchester United  29  14  9  6  51  40  11   51
#
# Serie A (Italy)
#    position            team  gp   w  d  l  gf  ga  gd  pts
# 0         1  Internazionale  27  22  1  4  64  21  43   67
# 1         2        AC Milan  27  16  9  2  43  20  23   57
# 2         3          Napoli  28  17  5  6  43  29  14   56
#
# La Liga (Spain)
#    position             team  gp   w  d  l  gf  ga  gd  pts
# 0         1        Barcelona  26  21  1  4  71  26  45   64
# 1         2      Real Madrid  27  20  3  4  56  23  33   63
# 2         3  Atlético Madrid  26  15  6  5  43  23  20   51
#
# Bundesliga (Germany)
#    position               team  gp   w  d  l  gf  ga  gd  pts
# 0         1      Bayern Munich  25  21  3  1  92  24  68   66
# 1         2  Borussia Dortmund  24  15  7  2  51  25  26   52
# 2         3     TSG Hoffenheim  25  15  4  6  53  33  20   49
#
# Ligue 1 (France)
#    position                 team  gp   w  d  l  gf  ga  gd  pts
# 0         1  Paris Saint-Germain  25  18  3  4  54  22  32   57
# 1         2                 Lens  24  17  2  5  45  21  24   53
# 2         3                 Lyon  24  14  3  7  39  26  13   45

# %%
leagues_data = {
    "Premier League (England)": premierleague_england,
    "Serie A (Italy)": seriea_italy,
    "La Liga (Spain)": laliga_spain,
    "Bundesliga (Germany)": bundesliga_germany,
    "Ligue 1 (France)": ligue1_france,
}

matches_unplayed_ = {}

for league_name, df in leagues_data.items():
    num_teams = len(df)
    total_matches = num_teams * (num_teams - 1)  # double round-robin, total matches counted twice for GP
    matches_played = df["gp"].sum() /2              # GP already counts each match per team
    matches_unplayed = total_matches - matches_played
    
    matches_unplayed_[league_name] = matches_unplayed
    print(f"{league_name}: {matches_unplayed} matches unplayed")
# Out:
# Premier League (England): 89.0 matches unplayed
# Serie A (Italy): 108.0 matches unplayed
# La Liga (Spain): 118.0 matches unplayed
# Bundesliga (Germany): 84.0 matches unplayed
# Ligue 1 (France): 89.0 matches unplayed

# %% [markdown]
# ## 2. Get betting odds using API

# %%
# Load variables from API_KEY.env
load_dotenv("API_KEY.env")

API_KEY = os.getenv("ODDS_DATA_API_KEY")

if API_KEY is None:
    raise ValueError("API_KEY not found. Check API_KEY.env")

print("API key loaded successfully")
# Out:
# API key loaded successfully

# %%
API_KEY = API_KEY  # assuming already defined

leagues = {
    "soccer_epl": "odds_premierleague_england",
    "soccer_italy_serie_a": "odds_seriea_italy",
    "soccer_spain_la_liga": "odds_laliga_spain",
    "soccer_germany_bundesliga": "odds_bundesliga_germany",
    "soccer_france_ligue_one": "odds_ligue1_france",
}

base_url = "https://api.the-odds-api.com/v4/sports/{}/odds"

params = {
    "apiKey": API_KEY,
    "regions": "uk",
    "markets": "h2h",
    "oddsFormat": "decimal",
    "dateFormat": "iso",
    "days": 365
}

for sport_key, var_name in leagues.items():
    url = base_url.format(sport_key)

    response = requests.get(url, params=params)
    response.raise_for_status()

    globals()[var_name] = response.json()

# %%
print("Premier League (England):", len(odds_premierleague_england))
print("Serie A (Italy):", len(odds_seriea_italy))
print("La Liga (Spain):", len(odds_laliga_spain))
print("Bundesliga (Germany):", len(odds_bundesliga_germany))
print("Ligue 1 (France):", len(odds_ligue1_france))
# Out:
# Premier League (England): 18
# Serie A (Italy): 18
# La Liga (Spain): 19
# Bundesliga (Germany): 12
# Ligue 1 (France): 17

# %%
def flatten_odds(data):
    rows = []

    for match in data:
        match_id = match["id"]
        home = match["home_team"]
        away = match["away_team"]
        time = match["commence_time"]

        for book in match["bookmakers"]:
            bookmaker = book["title"]

            # Find head-to-head (h2h) market. Find the market where key == 'h2h' (win/draw/win odds). If not found, skip this bookmaker.
            h2h = next((m for m in book["markets"] if m["key"] == "h2h"), None)
            if not h2h:
                continue

            outcomes = {o["name"]: o["price"] for o in h2h["outcomes"]}

            rows.append({
                "match_id": match_id,
                "commence_time": time,
                "home_team": home,
                "away_team": away,
                "bookmaker": bookmaker,
                "home_odds": outcomes.get(home),
                "draw_odds": outcomes.get("Draw"),
                "away_odds": outcomes.get(away),
            })

    return pd.DataFrame(rows)

# %%
# Flatten odds into DataFrames
df_premierleague_england = flatten_odds(odds_premierleague_england)
df_seriea_italy = flatten_odds(odds_seriea_italy)
df_laliga_spain = flatten_odds(odds_laliga_spain)
df_bundesliga_germany = flatten_odds(odds_bundesliga_germany)
df_ligue1_france = flatten_odds(odds_ligue1_france)

# %%
print("\nPremier League (England)")
print(df_premierleague_england.head(3))

print("\nSerie A (Italy)")
print(df_seriea_italy.head(3))

print("\nLa Liga (Spain)")
print(df_laliga_spain.head(3))

print("\nBundesliga (Germany)")
print(df_bundesliga_germany.head(3))

print("\nLigue 1 (France)")
print(df_ligue1_france.head(3))
# Out:
# Premier League (England)
#                            match_id         commence_time home_team    away_team    bookmaker  home_odds  draw_odds  away_odds
# 0  07e3e6c1966c98bce260a6608d692f73  2026-03-14T15:00:00Z   Burnley  Bournemouth  Unibet (UK)       3.80       3.75       1.88
# 1  07e3e6c1966c98bce260a6608d692f73  2026-03-14T15:00:00Z   Burnley  Bournemouth  Paddy Power       3.75       3.80       1.91
# 2  07e3e6c1966c98bce260a6608d692f73  2026-03-14T15:00:00Z   Burnley  Bournemouth      Sky Bet       3.60       3.75       1.91
#
# Serie A (Italy)
#                            match_id         commence_time    home_team away_team    bookmaker  home_odds  draw_odds  away_odds
# 0  a838e5114db711ebe1f70e2ad66a5c50  2026-03-07T17:00:00Z  Atalanta BC   Udinese      Sky Bet       1.70       3.50        5.0
# 1  a838e5114db711ebe1f70e2ad66a5c50  2026-03-07T17:00:00Z  Atalanta BC   Udinese  Paddy Power       1.67       3.25        5.0
# 2  a838e5114db711ebe1f70e2ad66a5c50  2026-03-07T17:00:00Z  Atalanta BC   Udinese     888sport       1.61       3.60        5.0
#
# La Liga (Spain)
#                            match_id         commence_time home_team away_team bookmaker  home_odds  draw_odds  away_odds
# 0  2bd12aabed92d3dcafdb18c3d51d0d6c  2026-03-07T15:15:00Z   Levante    Girona   Sky Bet       1.08       8.50       91.0
# 1  2bd12aabed92d3dcafdb18c3d51d0d6c  2026-03-07T15:15:00Z   Levante    Girona  Smarkets      48.08       1.10       10.5
# 2  2bd12aabed92d3dcafdb18c3d51d0d6c  2026-03-07T15:15:00Z   Levante    Girona   Betfair      46.00       1.07       18.0
#
# Bundesliga (Germany)
#                            match_id         commence_time   home_team          away_team     bookmaker  home_odds  draw_odds  away_odds
# 0  76d82a37f015220c2a482182558b6d39  2026-03-07T17:30:00Z  1. FC Köln  Borussia Dortmund      888sport        4.0        3.8       1.75
# 1  76d82a37f015220c2a482182558b6d39  2026-03-07T17:30:00Z  1. FC Köln  Borussia Dortmund   Unibet (UK)        4.2        4.0       1.78
# 2  76d82a37f015220c2a482182558b6d39  2026-03-07T17:30:00Z  1. FC Köln  Borussia Dortmund  William Hill        4.0        3.8       1.75
#
# Ligue 1 (France)
#                            match_id         commence_time home_team away_team    bookmaker  home_odds  draw_odds  away_odds
# 0  37e553195814d3b7e431f26bdf2f9e6c  2026-03-07T16:00:00Z    Nantes    Angers  BoyleSports       11.0        3.6       1.40
# 1  37e553195814d3b7e431f26bdf2f9e6c  2026-03-07T16:00:00Z    Nantes    Angers       Betway        9.0        3.6       1.44
# 2  37e553195814d3b7e431f26bdf2f9e6c  2026-03-07T16:00:00Z    Nantes    Angers  Paddy Power       10.0        3.5       1.40

# %%
def bookmaker_implied_probs(df):
    # Convert odds to implied probabilities per bookmaker
    df = df.assign(
        p_home_raw=1 / df["home_odds"],
        p_draw_raw=1 / df["draw_odds"],
        p_away_raw=1 / df["away_odds"],
    )

    # Remove bookmaker margin (normalise)
    total = (
        df["p_home_raw"] +
        df["p_draw_raw"] +
        df["p_away_raw"]
    )

    df = df.assign(
        p_home_book=df["p_home_raw"] / total,
        p_draw_book=df["p_draw_raw"] / total,
        p_away_book=df["p_away_raw"] / total,
    )

    # Average normalised probabilities across bookmakers
    betting_odds_avg = (
        df.groupby(["home_team", "away_team"], as_index=False)
          .agg(
              p_home_book=("p_home_book", "mean"),
              p_draw_book=("p_draw_book", "mean"),
              p_away_book=("p_away_book", "mean"),
          )
    )

    # Keep only required fields
    betting_odds_avg = betting_odds_avg[
        [
            "home_team",
            "away_team",
            "p_home_book",
            "p_draw_book",
            "p_away_book",
        ]
    ]

    return betting_odds_avg

# %%
betting_odds_premierleague_england = bookmaker_implied_probs(df_premierleague_england)
betting_odds_seriea_italy = bookmaker_implied_probs(df_seriea_italy)
betting_odds_laliga_spain = bookmaker_implied_probs(df_laliga_spain)
betting_odds_bundesliga_germany = bookmaker_implied_probs(df_bundesliga_germany)
betting_odds_ligue1_france = bookmaker_implied_probs(df_ligue1_france)

# %%
leagues_odds = {
    "Premier League (England)": betting_odds_premierleague_england,
    "Serie A (Italy)": betting_odds_seriea_italy,
    "La Liga (Spain)": betting_odds_laliga_spain,
    "Bundesliga (Germany)": betting_odds_bundesliga_germany,
    "Ligue 1 (France)": betting_odds_ligue1_france
}

for league_name, df in leagues_odds.items():
    # Check duplicates based on home_team + away_team
    duplicates = df.duplicated(subset=["home_team", "away_team"], keep=False) # Do not include match id in the join because a same match may have different match ids (source's error).
    num_duplicates = duplicates.sum()
    
    print(f"\n{league_name}")
    print("Sample data:")
    display(df.head(3))
    
    if num_duplicates == 0:
        print("✅ No duplicate matches found.")
    else:
        print(f"🚨 Found {num_duplicates} duplicate row(s)!")
        display(df[duplicates])
# Out:
# Premier League (England)
# Sample data:
#      home_team          away_team  p_home_book  p_draw_book  p_away_book
# 0      Arsenal            Everton     0.724284     0.185199     0.090517
# 1  Aston Villa    West Ham United     0.523397     0.250476     0.226127
# 2  Bournemouth  Manchester United     0.299286     0.244339     0.456374
# ✅ No duplicate matches found.
#
# Serie A (Italy)
# Sample data:
#      home_team      away_team  p_home_book  p_draw_book  p_away_book
# 0     AC Milan    Inter Milan     0.273846     0.298770     0.427383
# 1  Atalanta BC        Udinese     0.552061     0.275716     0.172223
# 2      Bologna  Hellas Verona     0.600837     0.244461     0.154701
# ✅ No duplicate matches found.
#
# La Liga (Spain)
# Sample data:
#          home_team   away_team  p_home_book  p_draw_book  p_away_book
# 0           Alavés  Villarreal     0.283761     0.279150     0.437089
# 1  Athletic Bilbao   Barcelona     0.197538     0.223098     0.579364
# 2  Atlético Madrid      Getafe     0.616687     0.254818     0.128495
# ✅ No duplicate matches found.
#
# Bundesliga (Germany)
# Sample data:
#            home_team          away_team  p_home_book  p_draw_book  p_away_book
# 0         1. FC Köln  Borussia Dortmund     0.229158     0.238016     0.532826
# 1   Bayer Leverkusen      Bayern Munich     0.209231     0.219018     0.571751
# 2  Borussia Dortmund           Augsburg     0.656248     0.200803     0.142949
# ✅ No duplicate matches found.
#
# Ligue 1 (France)
# Sample data:
#    home_team   away_team  p_home_book  p_draw_book  p_away_book
# 0  AS Monaco       Brest     0.560571     0.236081     0.203348
# 1     Angers        Nice     0.286621     0.304879     0.408499
# 2    Auxerre  Strasbourg     0.265659     0.286664     0.447677
# ✅ No duplicate matches found.

# %% [markdown]
# ## 3. Get fixtures for upcoming EPL games

# %%
# Load variables from API_KEY.env
load_dotenv("API_KEY.env")

API_KEY = os.getenv("FOOTBALL_DATA_API_KEY")

if API_KEY is None:
    raise ValueError("API_KEY not found. Check API_KEY.env")

print("API key loaded successfully")
# Out:
# API key loaded successfully

# %%
competitions = {
    "PL": "fixtures_premierleague_england",
    "SA": "fixtures_seriea_italy",
    "PD": "fixtures_laliga_spain",
    "BL1": "fixtures_bundesliga_germany",
    "FL1": "fixtures_ligue1_france",
}

headers = {
    "X-Auth-Token": API_KEY
}

today = datetime.utcnow().date()
end_of_season = today + timedelta(days=365)

params = {
    "status": "SCHEDULED",
    "dateFrom": today.isoformat(),
    "dateTo": end_of_season.isoformat()
}

for comp_code, df_name in competitions.items():
    url = f"https://api.football-data.org/v4/competitions/{comp_code}/matches"

    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()

    data = response.json()
    fixtures = data["matches"]

    df_fixtures = pd.DataFrame(fixtures)

    df_fixtures_clean = df_fixtures[
        ["utcDate", "status", "homeTeam", "awayTeam"]
    ].copy()  # copy avoids SettingWithCopyWarning

    # Extract team names
    df_fixtures_clean["homeTeam"] = df_fixtures_clean["homeTeam"].apply(lambda x: x["name"])
    df_fixtures_clean["awayTeam"] = df_fixtures_clean["awayTeam"].apply(lambda x: x["name"])

    globals()[df_name] = df_fixtures_clean
# Out:
# C:\Users\vicky\AppData\Local\Temp\ipykernel_3376\3061059445.py:13: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow().date()

# %%
print("Premier League (England):", len(fixtures_premierleague_england))
print("Serie A (Italy):", len(fixtures_seriea_italy))
print("La Liga (Spain):", len(fixtures_laliga_spain))
print("Bundesliga (Germany):", len(fixtures_bundesliga_germany))
print("Ligue 1 (France):", len(fixtures_ligue1_france))
# Out:
# Premier League (England): 88
# Serie A (Italy): 107
# La Liga (Spain): 117
# Bundesliga (Germany): 84
# Ligue 1 (France): 87

# %%
print("Premier League (England):", fixtures_premierleague_england.head(3))
print("Serie A (Italy):", fixtures_seriea_italy.head(3))
print("La Liga (Spain):", fixtures_laliga_spain.head(3))
print("Bundesliga (Germany):", fixtures_bundesliga_germany.head(3))
print("Ligue 1 (France):", fixtures_ligue1_france.head(3))
# Out:
# Premier League (England):                 utcDate status        homeTeam                   awayTeam
# 0  2026-03-14T15:00:00Z  TIMED  Sunderland AFC  Brighton & Hove Albion FC
# 1  2026-03-14T15:00:00Z  TIMED      Burnley FC            AFC Bournemouth
# 2  2026-03-14T17:30:00Z  TIMED      Arsenal FC                 Everton FC
# Serie A (Italy):                 utcDate status         homeTeam          awayTeam
# 0  2026-03-07T19:45:00Z  TIMED      Juventus FC      AC Pisa 1909
# 1  2026-03-08T11:30:00Z  TIMED         US Lecce      US Cremonese
# 2  2026-03-08T14:00:00Z  TIMED  Bologna FC 1909  Hellas Verona FC
# La Liga (Spain):                 utcDate status                 homeTeam                 awayTeam
# 0  2026-03-07T17:30:00Z  TIMED  Club Atlético de Madrid  Real Sociedad de Fútbol
# 1  2026-03-07T20:00:00Z  TIMED            Athletic Club             FC Barcelona
# 2  2026-03-08T13:00:00Z  TIMED            Villarreal CF                 Elche CF
# Bundesliga (Germany):                 utcDate status            homeTeam             awayTeam
# 0  2026-03-07T17:30:00Z  TIMED          1. FC Köln    Borussia Dortmund
# 1  2026-03-08T14:30:00Z  TIMED   FC St. Pauli 1910  Eintracht Frankfurt
# 2  2026-03-08T16:30:00Z  TIMED  1. FC Union Berlin     SV Werder Bremen
# Ligue 1 (France):                 utcDate status             homeTeam                awayTeam
# 0  2026-03-07T18:00:00Z  TIMED           AJ Auxerre    RC Strasbourg Alsace
# 1  2026-03-07T20:05:00Z  TIMED          Toulouse FC  Olympique de Marseille
# 2  2026-03-08T14:00:00Z  TIMED  Racing Club de Lens                 FC Metz

# %% [markdown]
# ## 4. Get this season (2025/26) and last season (2024/25) results

# %%
competitions = {
    "PL": "premierleague_england",
    "SA": "seriea_italy",
    "PD": "laliga_spain",
    "BL1": "bundesliga_germany",
    "FL1": "ligue1_france",
}

seasons = [2025, 2024]  # finished seasons you want
headers = {
    "X-Auth-Token": API_KEY
}

for comp_code, league_name in competitions.items():
    for season in seasons:
        print(f"Fetching {league_name} season {season}...")
        url = f"https://api.football-data.org/v4/competitions/{comp_code}/matches"
        params = {
            "season": season,
            "status": "FINISHED"
        }

        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()

        matches = response.json()["matches"]

        clean_rows = []
        for m in matches:
            clean_rows.append({
                "utcDate": m["utcDate"],
                "matchday": m["matchday"],
                "status": m["status"],
                "homeTeam": m["homeTeam"]["name"],
                "awayTeam": m["awayTeam"]["name"],
                "homeGoals": m["score"]["fullTime"]["home"],
                "awayGoals": m["score"]["fullTime"]["away"],
                "winner": m["score"]["winner"],
            })

        df_clean = pd.DataFrame(clean_rows)

        globals()[f"past_matches_{league_name}_{season}_clean"] = df_clean
        
        # Wait a few seconds between each API request to avoid crushing
        time.sleep(10)

print("Done fetching all matches.")
# Out:
# Fetching premierleague_england season 2025...
# Fetching premierleague_england season 2024...
# Fetching seriea_italy season 2025...
# Fetching seriea_italy season 2024...
# Fetching laliga_spain season 2025...
# Fetching laliga_spain season 2024...
# Fetching bundesliga_germany season 2025...
# Fetching bundesliga_germany season 2024...
# Fetching ligue1_france season 2025...
# Fetching ligue1_france season 2024...
# Done fetching all matches.

# %%
for league in [
    "premierleague_england",
    "seriea_italy",
    "laliga_spain",
    "bundesliga_germany",
    "ligue1_france",
]:
    for season in [2025, 2024]:
        df = globals()[f"past_matches_{league}_{season}_clean"]
        print(f"\n{league.replace('_', ' ').title()} – Season {season}")
        print(df.tail(2))
# Out:
# Premierleague England – Season 2025
#                   utcDate  matchday    status              homeTeam              awayTeam  homeGoals  awayGoals     winner
# 289  2026-03-04T20:15:00Z        29  FINISHED   Newcastle United FC  Manchester United FC          2          1  HOME_TEAM
# 290  2026-03-05T20:00:00Z        29  FINISHED  Tottenham Hotspur FC     Crystal Palace FC          1          3  AWAY_TEAM
#
# Premierleague England – Season 2024
#                   utcDate  matchday    status                    homeTeam                   awayTeam  homeGoals  awayGoals     winner
# 378  2025-05-25T15:00:00Z        38  FINISHED        Tottenham Hotspur FC  Brighton & Hove Albion FC          1          4  AWAY_TEAM
# 379  2025-05-25T15:00:00Z        38  FINISHED  Wolverhampton Wanderers FC               Brentford FC          1          1       DRAW
#
# Seriea Italy – Season 2025
#                   utcDate  matchday    status         homeTeam   awayTeam  homeGoals  awayGoals     winner
# 270  2026-03-06T19:45:00Z        28  FINISHED       SSC Napoli  Torino FC          2          1  HOME_TEAM
# 271  2026-03-07T14:00:00Z        28  FINISHED  Cagliari Calcio  Como 1907          1          2  AWAY_TEAM
#
# Seriea Italy – Season 2024
#                   utcDate  matchday    status        homeTeam        awayTeam  homeGoals  awayGoals     winner
# 378  2025-05-25T18:45:00Z        38  FINISHED  Udinese Calcio  ACF Fiorentina          2          3  AWAY_TEAM
# 379  2025-05-25T18:45:00Z        38  FINISHED      Venezia FC     Juventus FC          2          3  AWAY_TEAM
#
# Laliga Spain – Season 2025
#                   utcDate  matchday    status    homeTeam      awayTeam  homeGoals  awayGoals winner
# 261  2026-03-07T13:00:00Z        27  FINISHED  CA Osasuna  RCD Mallorca          2          2   DRAW
# 262  2026-03-07T15:15:00Z        27  FINISHED  Levante UD     Girona FC          1          1   DRAW
#
# Laliga Spain – Season 2024
#                   utcDate  matchday    status       homeTeam      awayTeam  homeGoals  awayGoals     winner
# 378  2025-05-25T14:15:00Z        38  FINISHED  Villarreal CF    Sevilla FC          4          2  HOME_TEAM
# 379  2025-05-25T19:00:00Z        38  FINISHED  Athletic Club  FC Barcelona          0          3  AWAY_TEAM
#
# Bundesliga Germany – Season 2025
#                   utcDate  matchday    status               homeTeam             awayTeam  homeGoals  awayGoals     winner
# 220  2026-03-07T14:30:00Z        25  FINISHED  1. FC Heidenheim 1846  TSG 1899 Hoffenheim          2          4  AWAY_TEAM
# 221  2026-03-07T14:30:00Z        25  FINISHED          VfL Wolfsburg         Hamburger SV          1          2  AWAY_TEAM
#
# Bundesliga Germany – Season 2024
#                   utcDate  matchday    status           homeTeam         awayTeam  homeGoals  awayGoals     winner
# 303  2025-05-17T13:30:00Z        34  FINISHED  FC St. Pauli 1910  VfL Bochum 1848          0          2  AWAY_TEAM
# 304  2025-05-17T13:30:00Z        34  FINISHED  Borussia Dortmund    Holstein Kiel          3          0  HOME_TEAM
#
# Ligue1 France – Season 2025
#                   utcDate  matchday    status                homeTeam            awayTeam  homeGoals  awayGoals     winner
# 215  2026-03-01T19:45:00Z        24  FINISHED  Olympique de Marseille  Olympique Lyonnais          3          2  HOME_TEAM
# 216  2026-03-06T19:45:00Z        25  FINISHED  Paris Saint-Germain FC        AS Monaco FC          1          3  AWAY_TEAM
#
# Ligue1 France – Season 2024
#                   utcDate  matchday    status                homeTeam      awayTeam  homeGoals  awayGoals     winner
# 303  2025-05-17T19:00:00Z        34  FINISHED     Racing Club de Lens  AS Monaco FC          4          0  HOME_TEAM
# 304  2025-05-17T19:00:00Z        34  FINISHED  Paris Saint-Germain FC    AJ Auxerre          3          1  HOME_TEAM

# %%
# Combine datasets into past_matches_ and future_matches_

leagues = [
    "premierleague_england",
    "seriea_italy",
    "laliga_spain",
    "bundesliga_germany",
    "ligue1_france",
]

for league in leagues:
    # Load DataFrames
    df_current = globals()[f"past_matches_{league}_2025_clean"]
    df_prev = globals()[f"past_matches_{league}_2024_clean"]
    df_future = globals()[f"fixtures_{league}"]

    # Combine all past fixtures together
    df_all = pd.concat([df_prev, df_current], ignore_index=True)

    # Store results
    globals()[f"past_matches_{league}_all"] = df_all
    globals()[f"future_matches_{league}"] = df_future

# %% [markdown]
# ## 5. Unify team names across datasets

# %%
# === Premier League ===
mapping_premierleague_england = {
    # df_probabilities
    "Aston Villa FC": "Aston Villa",
    "Leeds United FC": "Leeds United",
    "Newcastle United FC": "Newcastle United",
    "Crystal Palace FC": "Crystal Palace",
    "Chelsea FC": "Chelsea",
    "Arsenal FC": "Arsenal",
    "Everton FC": "Everton",
    "Burnley FC": "Burnley",
    "Brighton & Hove Albion FC": "Brighton & Hove Albion",
    "Sunderland AFC": "Sunderland",
    "West Ham United FC": "West Ham United",
    "Manchester City FC": "Manchester City",
    "Manchester United FC": "Manchester United",
    "Fulham FC": "Fulham",
    "Liverpool FC": "Liverpool",
    "Brentford FC": "Brentford",
    "Wolverhampton Wanderers FC": "Wolverhampton Wanderers",
    "Nottingham Forest FC": "Nottingham Forest",
    "Tottenham Hotspur FC": "Tottenham Hotspur",
    # betting_odds
    "Brighton and Hove Albion": "Brighton & Hove Albion",
    "Bournemouth": "AFC Bournemouth"
}

# === Serie A ===
mapping_seriea_italy = {
    # df_probabilities
    "US Sassuolo Calcio": "Sassuolo",
    "Cagliari Calcio": "Cagliari",
    "Atalanta BC": "Atalanta",
    "SS Lazio": "Lazio",
    "Genoa CFC": "Genoa",
    "Udinese Calcio": "Udinese",
    "FC Internazionale Milano": "Internazionale",
    "Torino FC": "Torino",
    "AC Pisa 1909": "Pisa",
    "ACF Fiorentina": "Fiorentina",
    "AS Roma": "AS Roma",
    "Juventus FC": "Juventus",
    "Como 1907": "Como",
    "US Cremonese": "Cremonese",
    "Bologna FC 1909": "Bologna",
    "Parma Calcio 1913": "Parma",
    "Hellas Verona FC": "Hellas Verona",
    "SSC Napoli": "Napoli",
    "US Lecce": "Lecce",
    # betting_odds
    "Inter Milan": "Internazionale",
    "Como": "Como"
}

# === La Liga ===
mapping_laliga_spain = {
    # df_probabilities
    "Club Atlético de Madrid": "Atlético Madrid",
    "Rayo Vallecano de Madrid": "Rayo Vallecano",
    "Valencia CF": "Valencia",
    "Deportivo Alavés": "Alavés",
    "CA Osasuna": "Osasuna",
    "RCD Espanyol de Barcelona": "Espanyol",
    "Getafe CF": "Getafe",
    "Real Sociedad de Fútbol": "Real Sociedad",
    "Levante UD": "Levante",
    "Real Betis Balompié": "Real Betis",
    "RCD Mallorca": "Mallorca",
    "Girona FC": "Girona",
    "Villarreal CF": "Villarreal",
    "FC Barcelona": "Barcelona",
    "Elche CF": "Elche",
    "Sevilla FC": "Sevilla",
    "Real Madrid CF": "Real Madrid",
    "RC Celta de Vigo": "Celta Vigo",
    # betting_odds
    "Elche CF": "Elche",
    "Oviedo": "Real Oviedo",
    "CA Osasuna": "Osasuna",
    "Athletic Bilbao": "Athletic Club"
}

# === Bundesliga ===
mapping_bundesliga_germany = {
    # df_probabilities
    "1. FC Köln": "FC Cologne",
    "TSG 1899 Hoffenheim": "TSG Hoffenheim",
    "1. FSV Mainz 05": "Mainz",
    "SV Werder Bremen": "Werder Bremen",
    "Hamburger SV": "Hamburg SV",
    "Bayer 04 Leverkusen": "Bayer Leverkusen",
    "FC St. Pauli 1910": "St. Pauli",
    "FC Bayern München": "Bayern Munich",
    # betting_odds
    "1. FC Heidenheim": "1. FC Heidenheim 1846",
    "Union Berlin": "1. FC Union Berlin",
    "Borussia Monchengladbach": "Borussia Mönchengladbach",
    "FSV Mainz 05": "Mainz",
    "Bayer Leverkusen": "Bayer Leverkusen",
    "Augsburg": "FC Augsburg",
    "FC St. Pauli": "St. Pauli"
}

# === Ligue 1 ===
mapping_ligue1_france = {
    # df_probabilities
    "Racing Club de Lens": "Lens",
    "OGC Nice": "Nice",
    "FC Metz": "Metz",
    "Angers SCO": "Angers",
    "Stade Brestois 29": "Brest",
    "Olympique Lyonnais": "Lyon",
    "Paris Saint-Germain FC": "Paris Saint-Germain",
    "AS Monaco FC": "AS Monaco",
    "Lille OSC": "Lille",
    "Toulouse FC": "Toulouse",
    "FC Nantes": "Nantes",
    "RC Strasbourg Alsace": "Strasbourg",
    "FC Lorient": "Lorient",
    "Olympique de Marseille": "Marseille",
    "Stade Rennais FC 1901": "Stade Rennais",
    # betting_odds
    "RC Lens": "Lens",
    "Paris Saint Germain": "Paris Saint-Germain",
    "Auxerre": "AJ Auxerre",
    "Lyon": "Lyon",
    "Le Havre": "Le Havre AC",
    "Rennes": "Stade Rennais",
    "Metz": "Metz",
    "Nice": "Nice",
    "Lille": "Lille"
}

# %%
# Mapping dictionaries per league
mappings = {
    "premierleague_england": mapping_premierleague_england,
    "seriea_italy": mapping_seriea_italy,
    "laliga_spain": mapping_laliga_spain,
    "bundesliga_germany": mapping_bundesliga_germany,
    "ligue1_france": mapping_ligue1_france,
}

# Datasets to unify
datasets_templates = [
    "past_matches_{}_all",
    "future_matches_{}",
    "betting_odds_{}"
]

for league, mapping in mappings.items():
    print(f"Applying mapping for {league}...")
    
    for ds_template in datasets_templates:
        ds_name = ds_template.format(league)
        df = globals()[ds_name]
        
        # Replace team names using the mapping
        df.replace(mapping, inplace=True)

        print(f"  Updated {ds_name} team names.")
# Out:
# Applying mapping for premierleague_england...
#   Updated past_matches_premierleague_england_all team names.
#   Updated future_matches_premierleague_england team names.
#   Updated betting_odds_premierleague_england team names.
# Applying mapping for seriea_italy...
#   Updated past_matches_seriea_italy_all team names.
#   Updated future_matches_seriea_italy team names.
#   Updated betting_odds_seriea_italy team names.
# Applying mapping for laliga_spain...
#   Updated past_matches_laliga_spain_all team names.
#   Updated future_matches_laliga_spain team names.
#   Updated betting_odds_laliga_spain team names.
# Applying mapping for bundesliga_germany...
#   Updated past_matches_bundesliga_germany_all team names.
#   Updated future_matches_bundesliga_germany team names.
#   Updated betting_odds_bundesliga_germany team names.
# Applying mapping for ligue1_france...
#   Updated past_matches_ligue1_france_all team names.
#   Updated future_matches_ligue1_france team names.
#   Updated betting_odds_ligue1_france team names.

# %%
def get_team_columns(df):
    if {"homeTeam", "awayTeam"}.issubset(df.columns):
        return "homeTeam", "awayTeam"
    if {"home_team", "away_team"}.issubset(df.columns):
        return "home_team", "away_team"
    raise KeyError("No home/away team columns found")

def extract_teams(df):
    home_col, away_col = get_team_columns(df)
    return set(df[home_col]).union(set(df[away_col]))

print("\n🔎 TEAM NAME CONSISTENCY CHECK - Only relegated teams should appear here.\n")

for league in mappings.keys():

    print(f"=== {league.replace('_', ' ').title()} ===")

    past = globals()[f"past_matches_{league}_all"]
    future = globals()[f"future_matches_{league}"]
    odds = globals()[f"betting_odds_{league}"]

    teams_past = extract_teams(past)
    teams_future = extract_teams(future)
    teams_odds = extract_teams(odds)

    all_sets = {
        "past_matches": teams_past,
        "future_matches": teams_future,
        "betting_odds": teams_odds,
    }

    union = set.union(*all_sets.values())
    ok = True

    for name, team_set in all_sets.items():
        missing = union - team_set
        extra = team_set - union

        if missing or extra:
            ok = False
            print(f"\n⚠️ {name}:")
            if missing:
                print(f"  Missing teams ({len(missing)}): {sorted(missing)}")
            if extra:
                print(f"  Extra teams ({len(extra)}): {sorted(extra)}")

    if ok:
        print("✅ All datasets use identical team names")

    print()
# Out:
# 🔎 TEAM NAME CONSISTENCY CHECK - Only relegated teams should appear here.
#
# === Premierleague England ===
#
# ⚠️ future_matches:
#   Missing teams (3): ['Ipswich Town FC', 'Leicester City FC', 'Southampton FC']
#
# ⚠️ betting_odds:
#   Missing teams (3): ['Ipswich Town FC', 'Leicester City FC', 'Southampton FC']
#
# === Seriea Italy ===
#
# ⚠️ future_matches:
#   Missing teams (3): ['AC Monza', 'Empoli FC', 'Venezia FC']
#
# ⚠️ betting_odds:
#   Missing teams (3): ['AC Monza', 'Empoli FC', 'Venezia FC']
#
# === Laliga Spain ===
#
# ⚠️ future_matches:
#   Missing teams (3): ['CD Leganés', 'Real Valladolid CF', 'UD Las Palmas']
#
# ⚠️ betting_odds:
#   Missing teams (3): ['CD Leganés', 'Real Valladolid CF', 'UD Las Palmas']
#
# === Bundesliga Germany ===
#
# ⚠️ future_matches:
#   Missing teams (2): ['Holstein Kiel', 'VfL Bochum 1848']
#
# ⚠️ betting_odds:
#   Missing teams (2): ['Holstein Kiel', 'VfL Bochum 1848']
#
# === Ligue1 France ===
#
# ⚠️ future_matches:
#   Missing teams (3): ['AS Saint-Étienne', 'Montpellier HSC', 'Stade de Reims']
#
# ⚠️ betting_odds:
#   Missing teams (3): ['AS Saint-Étienne', 'Montpellier HSC', 'Stade de Reims']

# %% [markdown]
# ## 6. Check for missing fixtures (rescheduled matches)

# %%
for league in leagues:
    future_matches = globals()[f"future_matches_{league}"]
    betting_odds = globals()[f"betting_odds_{league}"]

    # Identify bookmaker matches missing from future_matches
    future_set = set(zip(future_matches["homeTeam"], future_matches["awayTeam"]))
    book_set = set(zip(betting_odds["home_team"], betting_odds["away_team"]))
    missing_matches = book_set - future_set

    # If any are missing, append them to the future_matches DataFrame
    if missing_matches:
        print(f"{league}: Adding {len(missing_matches)} missing matches from bookmaker to future_matches")
        rows_to_add = []
        for home_team, away_team in missing_matches:
            row = betting_odds[
                (betting_odds["home_team"] == home_team) &
                (betting_odds["away_team"] == away_team)
            ].iloc[0]  # take first row if duplicates
            rows_to_add.append({
                "utcDate": row.get("utcDate", pd.NaT),  # fallback if missing
                "homeTeam": home_team,
                "awayTeam": away_team,
            })

        future_matches = pd.concat([future_matches, pd.DataFrame(rows_to_add)], ignore_index=True)
        globals()[f"future_matches_{league}"] = future_matches
        print(f"✅ Added {len(rows_to_add)} matches to future_matches")
    else:
        print(f"{league}: No missing matches from bookmaker odds")
# Out:
# premierleague_england: No missing matches from bookmaker odds
# seriea_italy: Adding 1 missing matches from bookmaker to future_matches
# ✅ Added 1 matches to future_matches
# laliga_spain: Adding 1 missing matches from bookmaker to future_matches
# ✅ Added 1 matches to future_matches
# bundesliga_germany: No missing matches from bookmaker odds
# ligue1_france: Adding 2 missing matches from bookmaker to future_matches
# ✅ Added 2 matches to future_matches

# %%
SEASON_START_DATE = pd.Timestamp("2025-08-01")

leagues = [
    "premierleague_england",
    "seriea_italy",
    "laliga_spain",
    "bundesliga_germany",
    "ligue1_france",
]

# HELPERS

def filter_current_season(past_matches):
    """
    Keep only matches from 2025/2026 season using utcDate
    """
    df = past_matches.copy()

    if "utcDate" not in df.columns:
        raise ValueError("Expected column 'utcDate' not found in past matches")

    df["utcDate"] = pd.to_datetime(df["utcDate"], utc=True).dt.tz_localize(None)
    return df[df["utcDate"] >= SEASON_START_DATE]


def season_fixtures(past_matches, future_matches):
    """
    All fixtures (home, away) for this season only
    """
    return pd.concat(
        [
            past_matches[["homeTeam", "awayTeam"]],
            future_matches[["homeTeam", "awayTeam"]],
        ],
        ignore_index=True,
    )


def find_missing_reverse_fixture(team, opponent, fixtures):
    """
    Detect missing home/away direction for a team-opponent pair
    """
    team_home = (
        (fixtures.homeTeam == team)
        & (fixtures.awayTeam == opponent)
    ).any()

    team_away = (
        (fixtures.homeTeam == opponent)
        & (fixtures.awayTeam == team)
    ).any()

    if team_home and not team_away:
        return opponent, team   # opponent HOME vs team AWAY

    if team_away and not team_home:
        return team, opponent   # team HOME vs opponent AWAY

    return None


# MAIN LOGIC

missing_fixtures = []

for league in leagues:
    print(f"\n=== {league.replace('_',' ').title()} ===")

    league_table = globals()[league]
    future_matches = globals()[f"future_matches_{league}"]
    past_matches_all = globals()[f"past_matches_{league}_all"]

    # FILTER PAST MATCHES TO THIS SEASON ONLY
    past_matches = filter_current_season(past_matches_all)

    fixtures = season_fixtures(past_matches, future_matches)

    total_teams = len(league_table)
    matches_per_team = (total_teams - 1) * 2

    played_counts = (
        fixtures.homeTeam.value_counts()
        .add(fixtures.awayTeam.value_counts(), fill_value=0)
    )

    missing_teams = {
        team: matches_per_team - played_counts.get(team, 0)
        for team in league_table["team"]
        if matches_per_team - played_counts.get(team, 0) > 0
    }

    print(
        f"Past matches (this season): {len(past_matches)} | "
        f"Future matches: {len(future_matches)} | "
        f"Total fixtures: {len(fixtures)}"
    )

    if not missing_teams:
        print("✅ All teams have complete fixtures")
        continue

    print("⚠️ Teams missing fixtures:")
    for team, missing in missing_teams.items():
        print(f"  {team}: {missing}")

    league_teams = set(league_table["team"])

    for team in missing_teams:
        for opponent in league_teams - {team}:
            result = find_missing_reverse_fixture(team, opponent, fixtures)
            if result:
                home, away = result
                missing_fixtures.append(
                    {
                        "league": league,
                        "homeTeam": home,
                        "awayTeam": away,
                    }
                )


# FINAL OUTPUT

missing_df = (
    pd.DataFrame(missing_fixtures)
    .drop_duplicates()
    .sort_values(["league", "homeTeam"])
)

print("\n🚨 Missing fixtures detected:")
display(missing_df)
# Out:
# === Premierleague England ===
# Past matches (this season): 291 | Future matches: 88 | Total fixtures: 379
# ⚠️ Teams missing fixtures:
#   Manchester City: 1
#   Crystal Palace: 1
#
# === Seriea Italy ===
# Past matches (this season): 272 | Future matches: 108 | Total fixtures: 380
# ✅ All teams have complete fixtures
#
# === Laliga Spain ===
# Past matches (this season): 263 | Future matches: 118 | Total fixtures: 381
# ✅ All teams have complete fixtures
#
# === Bundesliga Germany ===
# Past matches (this season): 222 | Future matches: 84 | Total fixtures: 306
# ✅ All teams have complete fixtures
#
# === Ligue1 France ===
# Past matches (this season): 217 | Future matches: 89 | Total fixtures: 306
# ✅ All teams have complete fixtures
#
# 🚨 Missing fixtures detected:
#                   league         homeTeam        awayTeam
# 0  premierleague_england  Manchester City  Crystal Palace

# %%
# APPEND MISSING FIXTURES (IN-PLACE, WITH BACKUP)

# Optional safety backup (one-liner per league)
future_matches_backup = {}

for league in missing_df["league"].unique():
    print(f"\n➕ Appending missing fixtures to {league.replace('_',' ').title()}")

    # Backup original
    future_matches_backup[league] = globals()[f"future_matches_{league}"].copy()

    future_matches = globals()[f"future_matches_{league}"]

    league_missing = missing_df[missing_df["league"] == league]

    for _, row in league_missing.iterrows():
        # Create an empty row with same columns
        new_match = {col: pd.NA for col in future_matches.columns}
        new_match["homeTeam"] = row["homeTeam"]
        new_match["awayTeam"] = row["awayTeam"]

        # Append IN PLACE
        future_matches.loc[len(future_matches)] = new_match

        print(f"  Added: {row['homeTeam']} vs {row['awayTeam']}")

    print(f"  Total future matches now: {len(future_matches)}")
# Out:
# ➕ Appending missing fixtures to Premierleague England
#   Added: Manchester City vs Crystal Palace
#   Total future matches now: 89

# %%
# LEAGUE MATCH COUNT VALIDATION

league_map = {
    "Premier League (England)": "premierleague_england",
    "Serie A (Italy)": "seriea_italy",
    "La Liga (Spain)": "laliga_spain",
    "Bundesliga (Germany)": "bundesliga_germany",
    "Ligue 1 (France)": "ligue1_france",
}

print("\n📊 League match count validation (CORRECT)\n")

for league_name, league_key in league_map.items():
    league_table = globals()[league_key]

    past_matches = filter_current_season(
        globals()[f"past_matches_{league_key}_all"]
    )
    future_matches = globals()[f"future_matches_{league_key}"]

    num_teams = len(league_table)

    # ✅ Correct total matches (each match counted once)
    total_matches = num_teams * (num_teams - 1) 

    # Matches played
    matches_played_gp = league_table["gp"].sum() / 2
    matches_played_data = len(past_matches)

    # Matches unplayed
    matches_unplayed_gp = total_matches - matches_played_gp
    matches_unplayed_data = len(future_matches)

    print(f"{league_name}")
    print(f"  Teams: {num_teams}")
    print(f"  Total matches (theoretical): {total_matches}")
    print(f"  Matches played (GP-based):   {int(matches_played_gp)}")
    print(f"  Matches played (data):       {matches_played_data}")
    print(f"  Matches unplayed (GP-based): {int(matches_unplayed_gp)}")
    print(f"  Matches unplayed (data):     {matches_unplayed_data}")

    if (
        matches_played_gp == matches_played_data
        and matches_unplayed_gp == matches_unplayed_data
    ):
        print("  ✅ League is consistent\n")
    else:
        print("  🚨 MISMATCH DETECTED\n")
# Out:
# 📊 League match count validation (CORRECT)
#
# Premier League (England)
#   Teams: 20
#   Total matches (theoretical): 380
#   Matches played (GP-based):   291
#   Matches played (data):       291
#   Matches unplayed (GP-based): 89
#   Matches unplayed (data):     89
#   ✅ League is consistent
#
# Serie A (Italy)
#   Teams: 20
#   Total matches (theoretical): 380
#   Matches played (GP-based):   272
#   Matches played (data):       272
#   Matches unplayed (GP-based): 108
#   Matches unplayed (data):     108
#   ✅ League is consistent
#
# La Liga (Spain)
#   Teams: 20
#   Total matches (theoretical): 380
#   Matches played (GP-based):   262
#   Matches played (data):       263
#   Matches unplayed (GP-based): 118
#   Matches unplayed (data):     118
#   🚨 MISMATCH DETECTED
#
# Bundesliga (Germany)
#   Teams: 18
#   Total matches (theoretical): 306
#   Matches played (GP-based):   222
#   Matches played (data):       222
#   Matches unplayed (GP-based): 84
#   Matches unplayed (data):     84
#   ✅ League is consistent
#
# Ligue 1 (France)
#   Teams: 18
#   Total matches (theoretical): 306
#   Matches played (GP-based):   217
#   Matches played (data):       217
#   Matches unplayed (GP-based): 89
#   Matches unplayed (data):     89
#   ✅ League is consistent

# %% [markdown]
# ## 7. Combine and calculate probabilities of W/D/L for each match

# %%
leagues = [
    "premierleague_england",
    "seriea_italy",
    "laliga_spain",
    "bundesliga_germany",
    "ligue1_france",
]

for league in leagues:
    df_all = globals()[f"past_matches_{league}_all"].copy()

    # Convert date
    df_all["date"] = pd.to_datetime(df_all["utcDate"])

    # Sort so newer matches get higher weight
    df_all = df_all.sort_values("date").reset_index(drop=True)

    # Add linear weights (oldest → newest)
    df_all["weight"] = np.linspace(1, 2, len(df_all))

    # Store weighted dataset
    globals()[f"past_matches_{league}_weighted"] = df_all

# %%
for league in [
    "premierleague_england",
    "seriea_italy",
    "laliga_spain",
    "bundesliga_germany",
    "ligue1_france",
]:
    df = globals()[f"past_matches_{league}_weighted"]
    print(f"\n{league.replace('_', ' ').title()} – weighted past matches")
    print(df.tail(2))
# Out:
# Premierleague England – weighted past matches
#                   utcDate  matchday    status           homeTeam           awayTeam  homeGoals  awayGoals     winner                      date    weight
# 669  2026-03-04T20:15:00Z        29  FINISHED   Newcastle United  Manchester United          2          1  HOME_TEAM 2026-03-04 20:15:00+00:00  1.998507
# 670  2026-03-05T20:00:00Z        29  FINISHED  Tottenham Hotspur     Crystal Palace          1          3  AWAY_TEAM 2026-03-05 20:00:00+00:00  2.000000
#
# Seriea Italy – weighted past matches
#                   utcDate  matchday    status  homeTeam awayTeam  homeGoals  awayGoals     winner                      date    weight
# 650  2026-03-06T19:45:00Z        28  FINISHED    Napoli   Torino          2          1  HOME_TEAM 2026-03-06 19:45:00+00:00  1.998464
# 651  2026-03-07T14:00:00Z        28  FINISHED  Cagliari     Como          1          2  AWAY_TEAM 2026-03-07 14:00:00+00:00  2.000000
#
# Laliga Spain – weighted past matches
#                   utcDate  matchday    status homeTeam  awayTeam  homeGoals  awayGoals winner                      date    weight
# 641  2026-03-07T13:00:00Z        27  FINISHED  Osasuna  Mallorca          2          2   DRAW 2026-03-07 13:00:00+00:00  1.998442
# 642  2026-03-07T15:15:00Z        27  FINISHED  Levante    Girona          1          1   DRAW 2026-03-07 15:15:00+00:00  2.000000
#
# Bundesliga Germany – weighted past matches
#                   utcDate  matchday    status       homeTeam       awayTeam  homeGoals  awayGoals     winner                      date    weight
# 525  2026-03-07T14:30:00Z        25  FINISHED          Mainz  VfB Stuttgart          2          2       DRAW 2026-03-07 14:30:00+00:00  1.998099
# 526  2026-03-07T14:30:00Z        25  FINISHED  VfL Wolfsburg     Hamburg SV          1          2  AWAY_TEAM 2026-03-07 14:30:00+00:00  2.000000
#
# Ligue1 France – weighted past matches
#                   utcDate  matchday    status             homeTeam   awayTeam  homeGoals  awayGoals     winner                      date    weight
# 520  2026-03-01T19:45:00Z        24  FINISHED            Marseille       Lyon          3          2  HOME_TEAM 2026-03-01 19:45:00+00:00  1.998081
# 521  2026-03-06T19:45:00Z        25  FINISHED  Paris Saint-Germain  AS Monaco          1          3  AWAY_TEAM 2026-03-06 19:45:00+00:00  2.000000

# %%
# compute home advantage per league and save it to globals().

leagues = [
    "premierleague_england",
    "seriea_italy",
    "laliga_spain",
    "bundesliga_germany",
    "ligue1_france",
]

home_advantage_by_league = {}

for league in leagues:
    # Access the weighted past matches for this league
    df_all = globals()[f"past_matches_{league}_weighted"]

    # Compute home advantage
    home_adv = df_all["homeGoals"].mean() - df_all["awayGoals"].mean()

    # Save to dictionary
    home_advantage_by_league[league] = home_adv

    # Save to globals (for your Poisson model)
    globals()[f"home_advantage_{league}"] = home_adv

    # Print nicely
    print(f"{league.replace('_', ' ').title()}: {home_adv:.3f}")
# Out:
# Premierleague England: 0.164
# Seriea Italy: 0.124
# Laliga Spain: 0.336
# Bundesliga Germany: 0.220
# Ligue1 France: 0.326

# %%
leagues = [
    "premierleague_england",
    "seriea_italy",
    "laliga_spain",
    "bundesliga_germany",
    "ligue1_france",
]

for league in leagues:
    df_all = globals()[f"past_matches_{league}_weighted"]

    # All teams in the league
    teams = pd.unique(df_all[["homeTeam", "awayTeam"]].values.ravel("K"))

    attack = pd.Series(1.0, index=teams)
    defense = pd.Series(1.0, index=teams)

    team_stats = {}

    for team in teams:
        home_games = df_all[df_all["homeTeam"] == team]
        away_games = df_all[df_all["awayTeam"] == team]

        goals_scored = (
            (home_games["homeGoals"] * home_games["weight"]).sum() +
            (away_games["awayGoals"] * away_games["weight"]).sum()
        )

        goals_against = (
            (home_games["awayGoals"] * home_games["weight"]).sum() +
            (away_games["homeGoals"] * away_games["weight"]).sum()
        )

        matches = home_games["weight"].sum() + away_games["weight"].sum()

        team_stats[team] = {
            "scored": goals_scored / matches,
            "against": goals_against / matches
        }

    # League average goals per team per match
    league_avg_scored = (
        df_all["homeGoals"].mean() + df_all["awayGoals"].mean()
    ) / 2

    for team in teams:
        attack[team] = team_stats[team]["scored"] / league_avg_scored
        defense[team] = team_stats[team]["against"] / league_avg_scored

    # Store outputs
    globals()[f"attack_{league}"] = attack
    globals()[f"defense_{league}"] = defense
    globals()[f"league_avg_scored_{league}"] = league_avg_scored

# %% [markdown]
# 🔥 Summary
#
# This function:
# + Calculates expected goals for each team
# + Uses Poisson distribution to compute goal probabilities
# + Converts score probabilities into match outcome probabilities
# + Returns probabilities for:
# ++ home win
# ++ draw
# ++ away win

# %%
def match_probabilities_league(
    home,
    away,
    attack,
    defense,
    league_avg_scored,
    home_advantage,
    max_goals=6,
):
    # expected goals
    exp_home = np.exp(
        np.log(league_avg_scored)
        + np.log(attack[home])
        + np.log(defense[away])
        + home_advantage
    )

    exp_away = np.exp(
        np.log(league_avg_scored)
        + np.log(attack[away])
        + np.log(defense[home])
    )

    p_home = poisson.pmf(range(max_goals + 1), exp_home)
    p_away = poisson.pmf(range(max_goals + 1), exp_away)

    p_win = p_draw = p_loss = 0.0

    for i in range(max_goals + 1):
        for j in range(max_goals + 1):
            prob = p_home[i] * p_away[j]
            if i > j:
                p_win += prob
            elif i == j:
                p_draw += prob
            else:
                p_loss += prob

    return p_win, p_draw, p_loss

# %%
leagues = [
    "premierleague_england",
    "seriea_italy",
    "laliga_spain",
    "bundesliga_germany",
    "ligue1_france",
]

for league in leagues:
    df_future = globals()[f"fixtures_{league}"] 

    attack = globals()[f"attack_{league}"]
    defense = globals()[f"defense_{league}"]
    league_avg_scored = globals()[f"league_avg_scored_{league}"]
    home_advantage = globals()[f"home_advantage_{league}"]

    results = []

    for _, row in df_future.iterrows():
        home = row["homeTeam"]
        away = row["awayTeam"]

        p_win, p_draw, p_loss = match_probabilities_league(
            home,
            away,
            attack,
            defense,
            league_avg_scored,
            home_advantage,
        )

        results.append({
            "utcDate": row["utcDate"],
            "homeTeam": home,
            "awayTeam": away,
            "p_home_win": p_win,
            "p_draw": p_draw,
            "p_away_win": p_loss,
        })

    globals()[f"df_probabilities_{league}"] = pd.DataFrame(results)

# %%
for league in leagues:
    print(f"\n=== {league.upper()} ===")
    print(globals()[f"df_probabilities_{league}"].head(2))
# Out:
# === PREMIERLEAGUE_ENGLAND ===
#                 utcDate    homeTeam                awayTeam  p_home_win    p_draw  p_away_win
# 0  2026-03-14T15:00:00Z  Sunderland  Brighton & Hove Albion    0.341809  0.273823    0.383808
# 1  2026-03-14T15:00:00Z     Burnley         AFC Bournemouth    0.223656  0.207405    0.562466
#
# === SERIEA_ITALY ===
#                 utcDate  homeTeam   awayTeam  p_home_win    p_draw  p_away_win
# 0  2026-03-07T19:45:00Z  Juventus       Pisa    0.764805  0.150777    0.072728
# 1  2026-03-08T11:30:00Z     Lecce  Cremonese    0.345893  0.335986    0.318051
#
# === LALIGA_SPAIN ===
#                 utcDate         homeTeam       awayTeam  p_home_win    p_draw  p_away_win
# 0  2026-03-07T17:30:00Z  Atlético Madrid  Real Sociedad    0.737836  0.154483    0.093414
# 1  2026-03-07T20:00:00Z    Athletic Club      Barcelona    0.240370  0.205525    0.546685
#
# === BUNDESLIGA_GERMANY ===
#                 utcDate    homeTeam             awayTeam  p_home_win   p_draw  p_away_win
# 0  2026-03-07T17:30:00Z  FC Cologne    Borussia Dortmund    0.213656  0.19389    0.582003
# 1  2026-03-08T14:30:00Z   St. Pauli  Eintracht Frankfurt    0.252407  0.23308    0.511872
#
# === LIGUE1_FRANCE ===
#                 utcDate    homeTeam    awayTeam  p_home_win    p_draw  p_away_win
# 0  2026-03-07T18:00:00Z  AJ Auxerre  Strasbourg    0.308689  0.239053    0.450083
# 1  2026-03-07T20:05:00Z    Toulouse   Marseille    0.387914  0.219646    0.387377

# %% [markdown]
# ## 8. Compare calculated probabilities to bookmaker ones

# %%
rmse_results = {}

for league in leagues:
    print(f"\n=== {league.replace('_', ' ').title()} ===")
    
    # Load model probabilities and bookmaker odds
    df_model = globals()[f"df_probabilities_{league}"]
    df_book = globals()[f"betting_odds_{league}"]

    # Merge on home/away team names
    df_compare = df_model.merge(
        df_book,
        left_on=["homeTeam", "awayTeam"],
        right_on=["home_team", "away_team"],
        how="inner"
    )

    print("Matched rows:", len(df_compare))

    # RMSE per outcome
    rmse_home = np.sqrt(np.mean((df_compare["p_home_win"] - df_compare["p_home_book"])**2))
    rmse_draw = np.sqrt(np.mean((df_compare["p_draw"] - df_compare["p_draw_book"])**2))
    rmse_away = np.sqrt(np.mean((df_compare["p_away_win"] - df_compare["p_away_book"])**2))

    # Total RMSE across all outcomes
    rmse_total = np.sqrt(np.mean(
        (df_compare["p_home_win"] - df_compare["p_home_book"])**2 +
        (df_compare["p_draw"] - df_compare["p_draw_book"])**2 +
        (df_compare["p_away_win"] - df_compare["p_away_book"])**2
    ))

    rmse_results[league] = {
        "rmse_home": rmse_home,
        "rmse_draw": rmse_draw,
        "rmse_away": rmse_away,
        "rmse_total": rmse_total
    }

    print(f"RMSE Home: {rmse_home:.4f}, Draw: {rmse_draw:.4f}, Away: {rmse_away:.4f}")
    print(f"Total RMSE: {rmse_total:.4f}")
# Out:
# === Premierleague England ===
# Matched rows: 18
# RMSE Home: 0.0680, Draw: 0.0336, Away: 0.0649
# Total RMSE: 0.0998
#
# === Seriea Italy ===
# Matched rows: 17
# RMSE Home: 0.0614, Draw: 0.0344, Away: 0.0676
# Total RMSE: 0.0976
#
# === Laliga Spain ===
# Matched rows: 18
# RMSE Home: 0.0791, Draw: 0.0580, Away: 0.0582
# Total RMSE: 0.1141
#
# === Bundesliga Germany ===
# Matched rows: 12
# RMSE Home: 0.0624, Draw: 0.0477, Away: 0.0576
# Total RMSE: 0.0974
#
# === Ligue1 France ===
# Matched rows: 15
# RMSE Home: 0.0993, Draw: 0.0665, Away: 0.0682
# Total RMSE: 0.1376

# %% [markdown]
# ## 9. Replace my estimates probabilities with the ones I have from odds, creating my final match probabilities

# %%
df_final_probabilities_all = {}

for league in leagues:
    print(f"\n=== {league.replace('_', ' ').title()} ===")
    
    df_probabilities = globals()[f"df_probabilities_{league}"]
    betting_odds_avg = globals()[f"betting_odds_{league}"]

    # Drop duplicate bookmaker odds for the same fixture (keep first)
    betting_odds_avg = betting_odds_avg.drop_duplicates(
        subset=["home_team", "away_team"], keep="first"
    )

    # Merge model and bookmaker probabilities
    df_final_probabilities = df_probabilities.merge(
        betting_odds_avg,
        left_on=["homeTeam", "awayTeam"],
        right_on=["home_team", "away_team"],
        how="left"
    )

    # Keep relevant columns
    df_final_probabilities = df_final_probabilities[[
        "utcDate",
        "homeTeam",
        "awayTeam",
        "p_home_win",
        "p_draw",
        "p_away_win",
        "p_home_book",
        "p_draw_book",
        "p_away_book",
    ]]

    # Replace model probabilities with bookmaker odds where available
    df_final_probabilities["p_home_final"] = np.where(
        df_final_probabilities["p_home_book"].notna(),
        df_final_probabilities["p_home_book"],
        df_final_probabilities["p_home_win"]
    )
    df_final_probabilities["p_draw_final"] = np.where(
        df_final_probabilities["p_draw_book"].notna(),
        df_final_probabilities["p_draw_book"],
        df_final_probabilities["p_draw"]
    )
    df_final_probabilities["p_away_final"] = np.where(
        df_final_probabilities["p_away_book"].notna(),
        df_final_probabilities["p_away_book"],
        df_final_probabilities["p_away_win"]
    )

    # Count totals
    total_rows = len(df_final_probabilities)
    used_book = df_final_probabilities["p_home_book"].notna().sum()
    used_model = df_final_probabilities["p_home_book"].isna().sum()

    print(f"Total matches: {total_rows}")
    print(f"Used betting odds: {used_book}")
    print(f"Used model: {used_model}")

    # Keep only final probabilities
    df_final_probabilities = df_final_probabilities[[
        "utcDate",
        "homeTeam",
        "awayTeam",
        "p_home_final",
        "p_draw_final",
        "p_away_final"
    ]]

    df_final_probabilities_all[league] = df_final_probabilities
    display(df_final_probabilities.head(2))
# Out:
# === Premierleague England ===
# Total matches: 89
# Used betting odds: 18
# Used model: 71
#                 utcDate    homeTeam                awayTeam  p_home_final  p_draw_final  p_away_final
# 0  2026-03-14T15:00:00Z  Sunderland  Brighton & Hove Albion      0.289383      0.277256      0.433361
# 1  2026-03-14T15:00:00Z     Burnley         AFC Bournemouth      0.248762      0.254210      0.497028
# === Seriea Italy ===
# Total matches: 107
# Used betting odds: 17
# Used model: 90
#                 utcDate  homeTeam   awayTeam  p_home_final  p_draw_final  p_away_final
# 0  2026-03-07T19:45:00Z  Juventus       Pisa      0.793219      0.139756      0.067025
# 1  2026-03-08T11:30:00Z     Lecce  Cremonese      0.434016      0.322157      0.243827
# === Laliga Spain ===
# Total matches: 117
# Used betting odds: 18
# Used model: 99
#                 utcDate         homeTeam       awayTeam  p_home_final  p_draw_final  p_away_final
# 0  2026-03-07T17:30:00Z  Atlético Madrid  Real Sociedad      0.581796      0.237463      0.180741
# 1  2026-03-07T20:00:00Z    Athletic Club      Barcelona      0.197538      0.223098      0.579364
# === Bundesliga Germany ===
# Total matches: 84
# Used betting odds: 12
# Used model: 72
#                 utcDate    homeTeam             awayTeam  p_home_final  p_draw_final  p_away_final
# 0  2026-03-07T17:30:00Z  FC Cologne    Borussia Dortmund      0.229158      0.238016      0.532826
# 1  2026-03-08T14:30:00Z   St. Pauli  Eintracht Frankfurt      0.337969      0.285155      0.376875
# === Ligue1 France ===
# Total matches: 87
# Used betting odds: 15
# Used model: 72
#                 utcDate    homeTeam    awayTeam  p_home_final  p_draw_final  p_away_final
# 0  2026-03-07T18:00:00Z  AJ Auxerre  Strasbourg      0.265659      0.286664      0.447677
# 1  2026-03-07T20:05:00Z    Toulouse   Marseille      0.294741      0.264224      0.441035

# %%
# Dictionary to store simulation dataframes for each league
df_simulation_all = {}

# Columns for probability normalisation
prob_cols = ["p_home_final", "p_draw_final", "p_away_final"]

for league in leagues:
    df = df_final_probabilities_all[league].copy()
    
    # Normalise probabilities so each row sums to 1
    df[prob_cols] = df[prob_cols].div(df[prob_cols].sum(axis=1), axis=0)
    
    # Store in dictionary
    df_simulation_all[league] = df
    
    # Preview top 3 rows
    print(f"\n=== {league.replace('_', ' ').title()} ===")
    display(df.tail(3))

    # Number of matches
    print(f"Number of matches to be played:")
    display(len(df))
# Out:
# === Premierleague England ===
#                  utcDate           homeTeam        awayTeam  p_home_final  p_draw_final  p_away_final
# 86  2026-05-24T15:00:00Z  Tottenham Hotspur         Everton      0.370538      0.256849      0.372613
# 87  2026-05-24T15:00:00Z    West Ham United    Leeds United      0.404261      0.234979      0.360761
# 88                  <NA>    Manchester City  Crystal Palace      0.641820      0.203085      0.155095
# Number of matches to be played:
# 89
# === Seriea Italy ===
#                   utcDate   homeTeam awayTeam  p_home_final  p_draw_final  p_away_final
# 104  2026-05-24T00:00:00Z     Napoli  Udinese      0.663918      0.201903      0.134179
# 105  2026-05-24T00:00:00Z  Cremonese     Como      0.151093      0.236921      0.611986
# 106  2026-05-24T00:00:00Z      Lecce    Genoa      0.254541      0.293113      0.452346
# Number of matches to be played:
# 107
# === Laliga Spain ===
#                   utcDate    homeTeam         awayTeam  p_home_final  p_draw_final  p_away_final
# 114  2026-05-24T00:00:00Z  Villarreal  Atlético Madrid      0.384260      0.229983      0.385756
# 115  2026-05-24T00:00:00Z    Valencia        Barcelona      0.129257      0.150464      0.720279
# 116  2026-05-24T00:00:00Z      Girona            Elche      0.425560      0.228250      0.346190
# Number of matches to be played:
# 117
# === Bundesliga Germany ===
#                  utcDate                  homeTeam        awayTeam  p_home_final  p_draw_final  p_away_final
# 81  2026-05-16T13:30:00Z  Borussia Mönchengladbach  TSG Hoffenheim      0.368755      0.217668      0.413577
# 82  2026-05-16T13:30:00Z             Bayern Munich      FC Cologne      0.910004      0.060042      0.029954
# 83  2026-05-16T13:30:00Z          Bayer Leverkusen      Hamburg SV      0.673369      0.187563      0.139069
# Number of matches to be played:
# 84
# === Ligue1 France ===
#                  utcDate    homeTeam    awayTeam  p_home_final  p_draw_final  p_away_final
# 84  2026-05-16T19:00:00Z       Lille  AJ Auxerre      0.651876      0.198683      0.149441
# 85  2026-05-16T19:00:00Z  Strasbourg   AS Monaco      0.503308      0.210591      0.286101
# 86  2026-05-16T19:00:00Z       Brest      Angers      0.586532      0.220660      0.192808
# Number of matches to be played:
# 87

# %% [markdown]
# ## 10. Run simulations to build the Premier League table probabilities

# %%
def simulate_once(fixtures, table):
    """
    Simulate the remaining fixtures once and return the updated league table with positions.
    Assumes:
    - table has columns: 'team', 'pts', 'gd'
    - fixtures has columns: 'homeTeam', 'awayTeam', 'p_home_final', 'p_draw_final', 'p_away_final'
    """
    table_sim = table.copy()

    # Initialize points dict
    points = dict(zip(table_sim["team"], table_sim["pts"]))

    for _, row in fixtures.iterrows():
        home = row["homeTeam"]
        away = row["awayTeam"]

        # Outcome probabilities
        probs = [row["p_home_final"], row["p_draw_final"], row["p_away_final"]]
        outcome = np.random.choice(["H", "D", "A"], p=probs)

        if outcome == "H":
            points[home] += 3
        elif outcome == "D":
            points[home] += 1
            points[away] += 1
        else:
            points[away] += 3

    # Update table
    result_df = table_sim.copy()
    result_df["pts"] = result_df["team"].map(points)

    # Sort by points and goal difference
    result_df = result_df.sort_values(["pts", "gd"], ascending=[False, False])
    result_df["position"] = np.arange(1, len(result_df)+1)

    return result_df


def run_simulations(fixtures, table, n_sim=10000):
    """
    Run multiple simulations and return a DataFrame of position counts per team.
    """
    position_counts = {team: np.zeros(len(table)) for team in table["team"]}

    for _ in range(n_sim):
        final_table = simulate_once(fixtures, table)
        for _, row in final_table.iterrows():
            position_counts[row["team"]][row["position"]-1] += 1

    pos_df = pd.DataFrame(position_counts, index=np.arange(1, len(table)+1))
    pos_df.index.name = "position"
    return pos_df

# %%
n_sim = 10000  # total simulations

position_distribution_all = {}
position_distribution_pct_all = {}

for league in leagues:
    print(f"\n=== {league.replace('_', ' ').title()} ===")
    
    fixtures = df_simulation_all[league].copy()  # simulated/future fixtures
    table = globals()[league].copy()             # league table

    # Count positions for each team
    position_counts = {team: np.zeros(len(table)) for team in table["team"]}
    
    # Run simulations
    for i in range(n_sim):
        final_table = simulate_once(fixtures, table)  # make sure simulate_once uses 'team', 'homeTeam', 'awayTeam'
        for _, row in final_table.iterrows():
            position_counts[row["team"]][row["position"]-1] += 1
        
        # Optional progress print
        if (i+1) % 1000 == 0:
            print(f"{i+1}/{n_sim} simulations done...")
    
    pos_df = pd.DataFrame(position_counts, index=np.arange(1, len(table)+1))
    # pos_df.index.name = "position"
    pos_df_t = pos_df.T
    pos_df_pct = pos_df_t.div(pos_df_t.sum(axis=1), axis=0) * 100
    
    position_distribution_all[league] = pos_df
    position_distribution_pct_all[league] = pos_df_pct
    
    print(f"Finished simulations for {league} ✅")
# Out:
# === Premierleague England ===
# 1000/10000 simulations done...
# 2000/10000 simulations done...
# 3000/10000 simulations done...
# 4000/10000 simulations done...
# 5000/10000 simulations done...
# 6000/10000 simulations done...
# 7000/10000 simulations done...
# 8000/10000 simulations done...
# 9000/10000 simulations done...
# 10000/10000 simulations done...
# Finished simulations for premierleague_england ✅
#
# === Seriea Italy ===
# 1000/10000 simulations done...
# 2000/10000 simulations done...
# 3000/10000 simulations done...
# 4000/10000 simulations done...
# 5000/10000 simulations done...
# 6000/10000 simulations done...
# 7000/10000 simulations done...
# 8000/10000 simulations done...
# 9000/10000 simulations done...
# 10000/10000 simulations done...
# Finished simulations for seriea_italy ✅
#
# === Laliga Spain ===
# 1000/10000 simulations done...
# 2000/10000 simulations done...
# 3000/10000 simulations done...
# 4000/10000 simulations done...
# 5000/10000 simulations done...
# 6000/10000 simulations done...
# 7000/10000 simulations done...
# 8000/10000 simulations done...
# 9000/10000 simulations done...
# 10000/10000 simulations done...
# Finished simulations for laliga_spain ✅
#
# === Bundesliga Germany ===
# 1000/10000 simulations done...
# 2000/10000 simulations done...
# 3000/10000 simulations done...
# 4000/10000 simulations done...
# 5000/10000 simulations done...
# 6000/10000 simulations done...
# 7000/10000 simulations done...
# 8000/10000 simulations done...
# 9000/10000 simulations done...
# 10000/10000 simulations done...
# Finished simulations for bundesliga_germany ✅
#
# === Ligue1 France ===
# 1000/10000 simulations done...
# 2000/10000 simulations done...
# 3000/10000 simulations done...
# 4000/10000 simulations done...
# 5000/10000 simulations done...
# 6000/10000 simulations done...
# 7000/10000 simulations done...
# 8000/10000 simulations done...
# 9000/10000 simulations done...
# 10000/10000 simulations done...
# Finished simulations for ligue1_france ✅

# %% [markdown]
# ## 11. Preview and present the results graphically

# %%
## Multi indexes

position_distribution_pct_all_labeled = {}

for league in leagues:
    table = globals()[league].copy()  # league table with 'team', 'position', 'gp', 'pts'
    pos_pct = position_distribution_pct_all[league].copy()  # simulation % table

    # Build metadata aligned with pos_pct
    meta = (
        table[["team", "position", "gp", "pts"]]
        .set_index("team")
        .rename(columns={
            "position": "POS",
            "gp": "GP",
            "pts": "PTS"
        })
    )

    # Align order with pos_pct
    meta = meta.loc[pos_pct.index]

    # Create MultiIndex: POS → TEAM → GP → PTS
    pos_pct.index = pd.MultiIndex.from_arrays(
        [
            meta["POS"].astype(int),
            meta.index,              # team names
            meta["GP"].astype(int),
            meta["PTS"].astype(int)
        ],
        names=["POS", "TEAM", "GP", "PTS"]
    )

    # Drop position column if it exists (usually not needed now)
    pos_pct = pos_pct.drop(columns=["position"], errors="ignore")

    # Save labeled version
    position_distribution_pct_all_labeled[league] = pos_pct

    print(f"Labeled MultiIndex created for {league} ✅")
# Out:
# Labeled MultiIndex created for premierleague_england ✅
# Labeled MultiIndex created for seriea_italy ✅
# Labeled MultiIndex created for laliga_spain ✅
# Labeled MultiIndex created for bundesliga_germany ✅
# Labeled MultiIndex created for ligue1_france ✅

# %%
# Soft green colormap
greens = plt.cm.Greens
green_cmap = LinearSegmentedColormap.from_list(
    "Greens_soft",
    greens(np.linspace(0.05, 0.65, 256))
)

def zero_style(val):
    if val < 1:
        return "background-color: white !important;"
    return ""

# Set midpoint and max for visual scaling
mid_pct = 0.14   # e.g., 14% is mid-green
max_pct = 0.75    # e.g., 90% and above is full green

def color_scale(val, mid=mid_pct, max_val=max_pct):
    """
    Scale values 0–max_val so that:
    - small values → very light
    - mid values (mid_pct) → mid-green
    - >= max_val → full green
    """
    if val >= max_val:
        return 1.0
    elif val <= mid:
        return val / mid * 0.5
    else:
        return 0.5 + (val - mid) / (max_val - mid) * 0.5

styled_position_pct_all = {}

for league in leagues:
    pos_pct = position_distribution_pct_all_labeled[league].copy()
    
    if isinstance(pos_pct.index, pd.MultiIndex):
        pos_pct = pos_pct.reset_index()

    display_df = pos_pct.copy()
    display_df.index = range(len(display_df))
    display_df = display_df.reset_index(drop=True)

    text_cols = ["POS", "TEAM", "GP", "PTS"]
    num_cols = display_df.columns.difference(text_cols)

    vmax = max(display_df[num_cols].max().max(), 1)

    # Apply custom scaling to numeric columns with cap
    color_data = display_df[num_cols].divide(vmax).apply(lambda s: s.map(color_scale)) * vmax

    styled = (
        display_df.style
        # Gradient on numeric columns
        .background_gradient(cmap=green_cmap, vmin=0, vmax=vmax, gmap=color_data, axis=None)
        .map(zero_style, subset=num_cols)
        .format({col: "{:.2f}%" for col in num_cols})
        # Text columns formatting
        .set_properties(subset=["POS", "GP", "PTS"], **{
            "text-align": "center",
            "font-family": "Inter, Roboto, Arial, sans-serif",
            "font-size": "12px",
            "font-weight": "600",
            "color": "#000",
            "white-space": "nowrap"
        })
        .set_properties(subset=["TEAM"], **{
            "text-align": "left",
            "font-family": "Inter, Roboto, Arial, sans-serif",
            "font-size": "12px",
            "font-weight": "600",
            "color": "#000",
            "white-space": "nowrap"
        })
        # Numeric columns formatting
        .set_properties(subset=num_cols, **{
            "text-align": "center",
            "font-family": "Inter, Roboto, Arial, sans-serif",
            "font-size": "12px",
            "font-weight": "500",
            "color": "#000"
        })
        .hide(axis="index")
        # Table headers, row height, borders, zebra striping
        .set_table_styles([
            {"selector": "th", "props": [
                ("background-color", "#e6edf4"),
                ("color", "#333"),
                ("text-align", "center"),
                ("font-family", "Inter, Roboto, Arial, sans-serif"),
                ("font-size", "13px"),
                ("font-weight", "600")
            ]},
            {"selector": "tr", "props": [("height", "25px")]},
            {"selector": "th:nth-child(4), td:nth-child(4)", "props": [
                ("border-right", "2px solid #999")
            ]},
            {"selector": "td:nth-child(-n+4)", "props": [
                ("border-bottom", "1px solid #ccc")
            ]},
            {"selector": "tr:nth-child(odd) td:nth-child(-n+4)", "props": [
                ("background-color", "#f9f9f9")
            ]},
            {"selector": "tr:nth-child(even) td:nth-child(-n+4)", "props": [
                ("background-color", "#f2f2f2")
            ]}
        ])
    )

    styled_position_pct_all[league] = styled
    print(f"Styled table ready for {league} ✅")
# Out:
# Styled table ready for premierleague_england ✅
# Styled table ready for seriea_italy ✅
# Styled table ready for laliga_spain ✅
# Styled table ready for bundesliga_germany ✅
# Styled table ready for ligue1_france ✅

# %%
# Display all 5 leagues
for league in leagues:
    print(f"\n=== {league.replace('_',' ').title()} ===")
    display(styled_position_pct_all[league])
# Out:
# === Premierleague England ===
# <style type="text/css">
# #T_f2788 th {
#   background-color: #e6edf4;
#   color: #333;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 13px;
#   font-weight: 600;
# }
# #T_f2788 tr {
#   height: 25px;
# }
# #T_f2788 th:nth-child(4) {
#   border-right: 2px solid #999;
# }
# #T_f2788  td:nth-child(4) {
#   border-right: 2px solid #999;
# }
# #T_f2788 td:nth-child(-n+4) {
#   border-bottom: 1px solid #ccc;
# }
# #T_f2788 tr:nth-child(odd) td:nth-child(-n+4) {
#   background-color: #f9f9f9;
# }
# #T_f2788 tr:nth-child(even) td:nth-child(-n+4) {
#   background-color: #f2f2f2;
# }
# #T_f2788_row0_col0, #T_f2788_row0_col2, #T_f2788_row0_col3, #T_f2788_row1_col0, #T_f2788_row1_col2, #T_f2788_row1_col3, #T_f2788_row2_col0, #T_f2788_row2_col2, #T_f2788_row2_col3, #T_f2788_row3_col0, #T_f2788_row3_col2, #T_f2788_row3_col3, #T_f2788_row4_col0, #T_f2788_row4_col2, #T_f2788_row4_col3, #T_f2788_row5_col0, #T_f2788_row5_col2, #T_f2788_row5_col3, #T_f2788_row6_col0, #T_f2788_row6_col2, #T_f2788_row6_col3, #T_f2788_row7_col0, #T_f2788_row7_col2, #T_f2788_row7_col3, #T_f2788_row8_col0, #T_f2788_row8_col2, #T_f2788_row8_col3, #T_f2788_row9_col0, #T_f2788_row9_col2, #T_f2788_row9_col3, #T_f2788_row10_col0, #T_f2788_row10_col2, #T_f2788_row10_col3, #T_f2788_row11_col0, #T_f2788_row11_col2, #T_f2788_row11_col3, #T_f2788_row12_col0, #T_f2788_row12_col2, #T_f2788_row12_col3, #T_f2788_row13_col0, #T_f2788_row13_col2, #T_f2788_row13_col3, #T_f2788_row14_col0, #T_f2788_row14_col2, #T_f2788_row14_col3, #T_f2788_row15_col0, #T_f2788_row15_col2, #T_f2788_row15_col3, #T_f2788_row16_col0, #T_f2788_row16_col2, #T_f2788_row16_col3, #T_f2788_row17_col0, #T_f2788_row17_col2, #T_f2788_row17_col3, #T_f2788_row18_col0, #T_f2788_row18_col2, #T_f2788_row18_col3, #T_f2788_row19_col0, #T_f2788_row19_col2, #T_f2788_row19_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 600;
#   color: #000;
#   white-space: nowrap;
# }
# #T_f2788_row0_col1, #T_f2788_row1_col1, #T_f2788_row2_col1, #T_f2788_row3_col1, #T_f2788_row4_col1, #T_f2788_row5_col1, #T_f2788_row6_col1, #T_f2788_row7_col1, #T_f2788_row8_col1, #T_f2788_row9_col1, #T_f2788_row10_col1, #T_f2788_row11_col1, #T_f2788_row12_col1, #T_f2788_row13_col1, #T_f2788_row14_col1, #T_f2788_row15_col1, #T_f2788_row16_col1, #T_f2788_row17_col1, #T_f2788_row18_col1, #T_f2788_row19_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: left;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 600;
#   color: #000;
#   white-space: nowrap;
# }
# #T_f2788_row0_col4, #T_f2788_row1_col5 {
#   background-color: #3ba458;
#   color: #f1f1f1;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_f2788_row0_col5, #T_f2788_row1_col4 {
#   background-color: #d1edcb;
#   color: #000000;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_f2788_row0_col6, #T_f2788_row0_col7, #T_f2788_row0_col8, #T_f2788_row0_col9, #T_f2788_row0_col10, #T_f2788_row0_col11, #T_f2788_row0_col12, #T_f2788_row0_col13, #T_f2788_row0_col14, #T_f2788_row0_col15, #T_f2788_row0_col16, #T_f2788_row0_col17, #T_f2788_row0_col18, #T_f2788_row0_col19, #T_f2788_row0_col20, #T_f2788_row0_col21, #T_f2788_row0_col22, #T_f2788_row0_col23, #T_f2788_row1_col8, #T_f2788_row1_col9, #T_f2788_row1_col10, #T_f2788_row1_col11, #T_f2788_row1_col12, #T_f2788_row1_col13, #T_f2788_row1_col14, #T_f2788_row1_col15, #T_f2788_row1_col16, #T_f2788_row1_col17, #T_f2788_row1_col18, #T_f2788_row1_col19, #T_f2788_row1_col20, #T_f2788_row1_col21, #T_f2788_row1_col22, #T_f2788_row1_col23, #T_f2788_row2_col4, #T_f2788_row2_col14, #T_f2788_row2_col15, #T_f2788_row2_col16, #T_f2788_row2_col17, #T_f2788_row2_col18, #T_f2788_row2_col19, #T_f2788_row2_col20, #T_f2788_row2_col21, #T_f2788_row2_col22, #T_f2788_row2_col23, #T_f2788_row3_col4, #T_f2788_row3_col14, #T_f2788_row3_col15, #T_f2788_row3_col16, #T_f2788_row3_col17, #T_f2788_row3_col18, #T_f2788_row3_col19, #T_f2788_row3_col20, #T_f2788_row3_col21, #T_f2788_row3_col22, #T_f2788_row3_col23, #T_f2788_row4_col4, #T_f2788_row4_col15, #T_f2788_row4_col16, #T_f2788_row4_col17, #T_f2788_row4_col18, #T_f2788_row4_col19, #T_f2788_row4_col20, #T_f2788_row4_col21, #T_f2788_row4_col22, #T_f2788_row4_col23, #T_f2788_row5_col4, #T_f2788_row5_col14, #T_f2788_row5_col15, #T_f2788_row5_col16, #T_f2788_row5_col17, #T_f2788_row5_col18, #T_f2788_row5_col19, #T_f2788_row5_col20, #T_f2788_row5_col21, #T_f2788_row5_col22, #T_f2788_row5_col23, #T_f2788_row6_col4, #T_f2788_row6_col5, #T_f2788_row6_col18, #T_f2788_row6_col19, #T_f2788_row6_col20, #T_f2788_row6_col21, #T_f2788_row6_col22, #T_f2788_row6_col23, #T_f2788_row7_col4, #T_f2788_row7_col5, #T_f2788_row7_col6, #T_f2788_row7_col19, #T_f2788_row7_col20, #T_f2788_row7_col21, #T_f2788_row7_col22, #T_f2788_row7_col23, #T_f2788_row8_col4, #T_f2788_row8_col5, #T_f2788_row8_col6, #T_f2788_row8_col7, #T_f2788_row8_col20, #T_f2788_row8_col21, #T_f2788_row8_col22, #T_f2788_row8_col23, #T_f2788_row9_col4, #T_f2788_row9_col5, #T_f2788_row9_col6, #T_f2788_row9_col7, #T_f2788_row9_col20, #T_f2788_row9_col21, #T_f2788_row9_col22, #T_f2788_row9_col23, #T_f2788_row10_col4, #T_f2788_row10_col5, #T_f2788_row10_col6, #T_f2788_row10_col7, #T_f2788_row10_col21, #T_f2788_row10_col22, #T_f2788_row10_col23, #T_f2788_row11_col4, #T_f2788_row11_col5, #T_f2788_row11_col6, #T_f2788_row11_col7, #T_f2788_row11_col20, #T_f2788_row11_col21, #T_f2788_row11_col22, #T_f2788_row11_col23, #T_f2788_row12_col4, #T_f2788_row12_col5, #T_f2788_row12_col6, #T_f2788_row12_col7, #T_f2788_row12_col8, #T_f2788_row12_col21, #T_f2788_row12_col22, #T_f2788_row12_col23, #T_f2788_row13_col4, #T_f2788_row13_col5, #T_f2788_row13_col6, #T_f2788_row13_col7, #T_f2788_row13_col21, #T_f2788_row13_col22, #T_f2788_row13_col23, #T_f2788_row14_col4, #T_f2788_row14_col5, #T_f2788_row14_col6, #T_f2788_row14_col7, #T_f2788_row14_col8, #T_f2788_row14_col9, #T_f2788_row14_col10, #T_f2788_row14_col11, #T_f2788_row14_col23, #T_f2788_row15_col4, #T_f2788_row15_col5, #T_f2788_row15_col6, #T_f2788_row15_col7, #T_f2788_row15_col8, #T_f2788_row15_col9, #T_f2788_row15_col10, #T_f2788_row15_col11, #T_f2788_row15_col12, #T_f2788_row15_col13, #T_f2788_row15_col14, #T_f2788_row15_col23, #T_f2788_row16_col4, #T_f2788_row16_col5, #T_f2788_row16_col6, #T_f2788_row16_col7, #T_f2788_row16_col8, #T_f2788_row16_col9, #T_f2788_row16_col10, #T_f2788_row16_col11, #T_f2788_row16_col12, #T_f2788_row16_col13, #T_f2788_row16_col23, #T_f2788_row17_col4, #T_f2788_row17_col5, #T_f2788_row17_col6, #T_f2788_row17_col7, #T_f2788_row17_col8, #T_f2788_row17_col9, #T_f2788_row17_col10, #T_f2788_row17_col11, #T_f2788_row17_col12, #T_f2788_row17_col13, #T_f2788_row17_col14, #T_f2788_row17_col15, #T_f2788_row17_col23, #T_f2788_row18_col4, #T_f2788_row18_col5, #T_f2788_row18_col6, #T_f2788_row18_col7, #T_f2788_row18_col8, #T_f2788_row18_col9, ...
#   background-color: #f0f9ed;
#   color: #000000;
#   background-color: white !important;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_f2788_row1_col6 {
#   background-color: #e8f6e4;
#   color: #000000;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   col
# === Seriea Italy ===
# <style type="text/css">
# #T_f1df2 th {
#   background-color: #e6edf4;
#   color: #333;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 13px;
#   font-weight: 600;
# }
# #T_f1df2 tr {
#   height: 25px;
# }
# #T_f1df2 th:nth-child(4) {
#   border-right: 2px solid #999;
# }
# #T_f1df2  td:nth-child(4) {
#   border-right: 2px solid #999;
# }
# #T_f1df2 td:nth-child(-n+4) {
#   border-bottom: 1px solid #ccc;
# }
# #T_f1df2 tr:nth-child(odd) td:nth-child(-n+4) {
#   background-color: #f9f9f9;
# }
# #T_f1df2 tr:nth-child(even) td:nth-child(-n+4) {
#   background-color: #f2f2f2;
# }
# #T_f1df2_row0_col0, #T_f1df2_row0_col2, #T_f1df2_row0_col3, #T_f1df2_row1_col0, #T_f1df2_row1_col2, #T_f1df2_row1_col3, #T_f1df2_row2_col0, #T_f1df2_row2_col2, #T_f1df2_row2_col3, #T_f1df2_row3_col0, #T_f1df2_row3_col2, #T_f1df2_row3_col3, #T_f1df2_row4_col0, #T_f1df2_row4_col2, #T_f1df2_row4_col3, #T_f1df2_row5_col0, #T_f1df2_row5_col2, #T_f1df2_row5_col3, #T_f1df2_row6_col0, #T_f1df2_row6_col2, #T_f1df2_row6_col3, #T_f1df2_row7_col0, #T_f1df2_row7_col2, #T_f1df2_row7_col3, #T_f1df2_row8_col0, #T_f1df2_row8_col2, #T_f1df2_row8_col3, #T_f1df2_row9_col0, #T_f1df2_row9_col2, #T_f1df2_row9_col3, #T_f1df2_row10_col0, #T_f1df2_row10_col2, #T_f1df2_row10_col3, #T_f1df2_row11_col0, #T_f1df2_row11_col2, #T_f1df2_row11_col3, #T_f1df2_row12_col0, #T_f1df2_row12_col2, #T_f1df2_row12_col3, #T_f1df2_row13_col0, #T_f1df2_row13_col2, #T_f1df2_row13_col3, #T_f1df2_row14_col0, #T_f1df2_row14_col2, #T_f1df2_row14_col3, #T_f1df2_row15_col0, #T_f1df2_row15_col2, #T_f1df2_row15_col3, #T_f1df2_row16_col0, #T_f1df2_row16_col2, #T_f1df2_row16_col3, #T_f1df2_row17_col0, #T_f1df2_row17_col2, #T_f1df2_row17_col3, #T_f1df2_row18_col0, #T_f1df2_row18_col2, #T_f1df2_row18_col3, #T_f1df2_row19_col0, #T_f1df2_row19_col2, #T_f1df2_row19_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 600;
#   color: #000;
#   white-space: nowrap;
# }
# #T_f1df2_row0_col1, #T_f1df2_row1_col1, #T_f1df2_row2_col1, #T_f1df2_row3_col1, #T_f1df2_row4_col1, #T_f1df2_row5_col1, #T_f1df2_row6_col1, #T_f1df2_row7_col1, #T_f1df2_row8_col1, #T_f1df2_row9_col1, #T_f1df2_row10_col1, #T_f1df2_row11_col1, #T_f1df2_row12_col1, #T_f1df2_row13_col1, #T_f1df2_row14_col1, #T_f1df2_row15_col1, #T_f1df2_row16_col1, #T_f1df2_row17_col1, #T_f1df2_row18_col1, #T_f1df2_row19_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: left;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 600;
#   color: #000;
#   white-space: nowrap;
# }
# #T_f1df2_row0_col4 {
#   background-color: #3ba458;
#   color: #f1f1f1;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_f1df2_row0_col5, #T_f1df2_row1_col4, #T_f1df2_row7_col9, #T_f1df2_row10_col18 {
#   background-color: #eff9eb;
#   color: #000000;
#   background-color: white !important;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_f1df2_row0_col6, #T_f1df2_row0_col7, #T_f1df2_row0_col8, #T_f1df2_row0_col9, #T_f1df2_row0_col10, #T_f1df2_row0_col11, #T_f1df2_row0_col12, #T_f1df2_row0_col13, #T_f1df2_row0_col14, #T_f1df2_row0_col15, #T_f1df2_row0_col16, #T_f1df2_row0_col17, #T_f1df2_row0_col18, #T_f1df2_row0_col19, #T_f1df2_row0_col20, #T_f1df2_row0_col21, #T_f1df2_row0_col22, #T_f1df2_row0_col23, #T_f1df2_row1_col11, #T_f1df2_row1_col12, #T_f1df2_row1_col13, #T_f1df2_row1_col14, #T_f1df2_row1_col15, #T_f1df2_row1_col16, #T_f1df2_row1_col17, #T_f1df2_row1_col18, #T_f1df2_row1_col19, #T_f1df2_row1_col20, #T_f1df2_row1_col21, #T_f1df2_row1_col22, #T_f1df2_row1_col23, #T_f1df2_row2_col11, #T_f1df2_row2_col12, #T_f1df2_row2_col13, #T_f1df2_row2_col14, #T_f1df2_row2_col15, #T_f1df2_row2_col16, #T_f1df2_row2_col17, #T_f1df2_row2_col18, #T_f1df2_row2_col19, #T_f1df2_row2_col20, #T_f1df2_row2_col21, #T_f1df2_row2_col22, #T_f1df2_row2_col23, #T_f1df2_row3_col4, #T_f1df2_row3_col12, #T_f1df2_row3_col13, #T_f1df2_row3_col14, #T_f1df2_row3_col15, #T_f1df2_row3_col16, #T_f1df2_row3_col17, #T_f1df2_row3_col18, #T_f1df2_row3_col19, #T_f1df2_row3_col20, #T_f1df2_row3_col21, #T_f1df2_row3_col22, #T_f1df2_row3_col23, #T_f1df2_row4_col4, #T_f1df2_row4_col12, #T_f1df2_row4_col13, #T_f1df2_row4_col14, #T_f1df2_row4_col15, #T_f1df2_row4_col16, #T_f1df2_row4_col17, #T_f1df2_row4_col18, #T_f1df2_row4_col19, #T_f1df2_row4_col20, #T_f1df2_row4_col21, #T_f1df2_row4_col22, #T_f1df2_row4_col23, #T_f1df2_row5_col4, #T_f1df2_row5_col12, #T_f1df2_row5_col13, #T_f1df2_row5_col14, #T_f1df2_row5_col15, #T_f1df2_row5_col16, #T_f1df2_row5_col17, #T_f1df2_row5_col18, #T_f1df2_row5_col19, #T_f1df2_row5_col20, #T_f1df2_row5_col21, #T_f1df2_row5_col22, #T_f1df2_row5_col23, #T_f1df2_row6_col4, #T_f1df2_row6_col5, #T_f1df2_row6_col13, #T_f1df2_row6_col14, #T_f1df2_row6_col15, #T_f1df2_row6_col16, #T_f1df2_row6_col17, #T_f1df2_row6_col18, #T_f1df2_row6_col19, #T_f1df2_row6_col20, #T_f1df2_row6_col21, #T_f1df2_row6_col22, #T_f1df2_row6_col23, #T_f1df2_row7_col4, #T_f1df2_row7_col5, #T_f1df2_row7_col6, #T_f1df2_row7_col7, #T_f1df2_row7_col17, #T_f1df2_row7_col18, #T_f1df2_row7_col19, #T_f1df2_row7_col20, #T_f1df2_row7_col21, #T_f1df2_row7_col22, #T_f1df2_row7_col23, #T_f1df2_row8_col4, #T_f1df2_row8_col5, #T_f1df2_row8_col6, #T_f1df2_row8_col7, #T_f1df2_row8_col8, #T_f1df2_row8_col18, #T_f1df2_row8_col19, #T_f1df2_row8_col20, #T_f1df2_row8_col21, #T_f1df2_row8_col22, #T_f1df2_row8_col23, #T_f1df2_row9_col4, #T_f1df2_row9_col5, #T_f1df2_row9_col6, #T_f1df2_row9_col7, #T_f1df2_row9_col8, #T_f1df2_row9_col9, #T_f1df2_row9_col10, #T_f1df2_row9_col21, #T_f1df2_row9_col22, #T_f1df2_row9_col23, #T_f1df2_row10_col4, #T_f1df2_row10_col5, #T_f1df2_row10_col6, #T_f1df2_row10_col7, #T_f1df2_row10_col8, #T_f1df2_row10_col9, #T_f1df2_row10_col20, #T_f1df2_row10_col21, #T_f1df2_row10_col22, #T_f1df2_row10_col23, #T_f1df2_row11_col4, #T_f1df2_row11_col5, #T_f1df2_row11_col6, #T_f1df2_row11_col7, #T_f1df2_row11_col8, #T_f1df2_row11_col9, #T_f1df2_row11_col10, #T_f1df2_row11_col22, #T_f1df2_row11_col23, #T_f1df2_row12_col4, #T_f1df2_row12_col5, #T_f1df2_row12_col6, #T_f1df2_row12_col7, #T_f1df2_row12_col8, #T_f1df2_row12_col9, #T_f1df2_row12_col10, #T_f1df2_row12_col11, #T_f1df2_row12_col22, #T_f1df2_row12_col23, #T_f1df2_row13_col4, #T_f1df2_row13_col5, #T_f1df2_row13_col6, #T_f1df2_row13_col7, #T_f1df2_row13_col8, #T_f1df2_row13_col9, #T_f1df2_row13_col10, #T_f1df2_row13_col22, #T_f1df2_row13_col23, #T_f1df2_row14_col4, #T_f1df2_row14_col5, #T_f1df2_row14_col6, #T_f1df2_row14_col7, #T_f1df2_row14_col8, #T_f1df2_row14_col9, #T_f1df2_row14_col10, #T_f1df2_row14_col11, #T_f1df2_row14_col23, #T_f1df2_row15_col4, #T_f1df2_row15_col5, #T_f1df2_row15_col6, #T_f1df2_row15_col7, #T_f1df2_row15_col8, #T_f1df2_row15_col9, #T_f1df2_row15_col10, #T_f1df2_row15_col11, #T_f1df2_row15_col23, #T_f1df2_row16_col4, #T_f1df2_row16_col5, #T_f1df2_row16_col6, #T_f1df2_row16_col7, #T_f1df2_row16_col8, #T_f1df2_row16_col9, #T_f1df2_row16 ...
# === Laliga Spain ===
# <style type="text/css">
# #T_dda7e th {
#   background-color: #e6edf4;
#   color: #333;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 13px;
#   font-weight: 600;
# }
# #T_dda7e tr {
#   height: 25px;
# }
# #T_dda7e th:nth-child(4) {
#   border-right: 2px solid #999;
# }
# #T_dda7e  td:nth-child(4) {
#   border-right: 2px solid #999;
# }
# #T_dda7e td:nth-child(-n+4) {
#   border-bottom: 1px solid #ccc;
# }
# #T_dda7e tr:nth-child(odd) td:nth-child(-n+4) {
#   background-color: #f9f9f9;
# }
# #T_dda7e tr:nth-child(even) td:nth-child(-n+4) {
#   background-color: #f2f2f2;
# }
# #T_dda7e_row0_col0, #T_dda7e_row0_col2, #T_dda7e_row0_col3, #T_dda7e_row1_col0, #T_dda7e_row1_col2, #T_dda7e_row1_col3, #T_dda7e_row2_col0, #T_dda7e_row2_col2, #T_dda7e_row2_col3, #T_dda7e_row3_col0, #T_dda7e_row3_col2, #T_dda7e_row3_col3, #T_dda7e_row4_col0, #T_dda7e_row4_col2, #T_dda7e_row4_col3, #T_dda7e_row5_col0, #T_dda7e_row5_col2, #T_dda7e_row5_col3, #T_dda7e_row6_col0, #T_dda7e_row6_col2, #T_dda7e_row6_col3, #T_dda7e_row7_col0, #T_dda7e_row7_col2, #T_dda7e_row7_col3, #T_dda7e_row8_col0, #T_dda7e_row8_col2, #T_dda7e_row8_col3, #T_dda7e_row9_col0, #T_dda7e_row9_col2, #T_dda7e_row9_col3, #T_dda7e_row10_col0, #T_dda7e_row10_col2, #T_dda7e_row10_col3, #T_dda7e_row11_col0, #T_dda7e_row11_col2, #T_dda7e_row11_col3, #T_dda7e_row12_col0, #T_dda7e_row12_col2, #T_dda7e_row12_col3, #T_dda7e_row13_col0, #T_dda7e_row13_col2, #T_dda7e_row13_col3, #T_dda7e_row14_col0, #T_dda7e_row14_col2, #T_dda7e_row14_col3, #T_dda7e_row15_col0, #T_dda7e_row15_col2, #T_dda7e_row15_col3, #T_dda7e_row16_col0, #T_dda7e_row16_col2, #T_dda7e_row16_col3, #T_dda7e_row17_col0, #T_dda7e_row17_col2, #T_dda7e_row17_col3, #T_dda7e_row18_col0, #T_dda7e_row18_col2, #T_dda7e_row18_col3, #T_dda7e_row19_col0, #T_dda7e_row19_col2, #T_dda7e_row19_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 600;
#   color: #000;
#   white-space: nowrap;
# }
# #T_dda7e_row0_col1, #T_dda7e_row1_col1, #T_dda7e_row2_col1, #T_dda7e_row3_col1, #T_dda7e_row4_col1, #T_dda7e_row5_col1, #T_dda7e_row6_col1, #T_dda7e_row7_col1, #T_dda7e_row8_col1, #T_dda7e_row9_col1, #T_dda7e_row10_col1, #T_dda7e_row11_col1, #T_dda7e_row12_col1, #T_dda7e_row13_col1, #T_dda7e_row14_col1, #T_dda7e_row15_col1, #T_dda7e_row16_col1, #T_dda7e_row17_col1, #T_dda7e_row18_col1, #T_dda7e_row19_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: left;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 600;
#   color: #000;
#   white-space: nowrap;
# }
# #T_dda7e_row0_col4, #T_dda7e_row1_col5, #T_dda7e_row4_col8, #T_dda7e_row19_col23 {
#   background-color: #3ba458;
#   color: #f1f1f1;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_dda7e_row0_col5, #T_dda7e_row6_col12, #T_dda7e_row15_col20 {
#   background-color: #a0d99b;
#   color: #000000;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_dda7e_row0_col6, #T_dda7e_row4_col12, #T_dda7e_row5_col7, #T_dda7e_row5_col15, #T_dda7e_row7_col19, #T_dda7e_row8_col19, #T_dda7e_row11_col22, #T_dda7e_row12_col9, #T_dda7e_row15_col23, #T_dda7e_row16_col10, #T_dda7e_row18_col16, #T_dda7e_row19_col20 {
#   background-color: #eff9ec;
#   color: #000000;
#   background-color: white !important;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_dda7e_row0_col7, #T_dda7e_row0_col8, #T_dda7e_row0_col9, #T_dda7e_row0_col10, #T_dda7e_row0_col11, #T_dda7e_row0_col12, #T_dda7e_row0_col13, #T_dda7e_row0_col14, #T_dda7e_row0_col15, #T_dda7e_row0_col16, #T_dda7e_row0_col17, #T_dda7e_row0_col18, #T_dda7e_row0_col19, #T_dda7e_row0_col20, #T_dda7e_row0_col21, #T_dda7e_row0_col22, #T_dda7e_row0_col23, #T_dda7e_row1_col8, #T_dda7e_row1_col9, #T_dda7e_row1_col10, #T_dda7e_row1_col11, #T_dda7e_row1_col12, #T_dda7e_row1_col13, #T_dda7e_row1_col14, #T_dda7e_row1_col15, #T_dda7e_row1_col16, #T_dda7e_row1_col17, #T_dda7e_row1_col18, #T_dda7e_row1_col19, #T_dda7e_row1_col20, #T_dda7e_row1_col21, #T_dda7e_row1_col22, #T_dda7e_row1_col23, #T_dda7e_row2_col4, #T_dda7e_row2_col10, #T_dda7e_row2_col11, #T_dda7e_row2_col12, #T_dda7e_row2_col13, #T_dda7e_row2_col14, #T_dda7e_row2_col15, #T_dda7e_row2_col16, #T_dda7e_row2_col17, #T_dda7e_row2_col18, #T_dda7e_row2_col19, #T_dda7e_row2_col20, #T_dda7e_row2_col21, #T_dda7e_row2_col22, #T_dda7e_row2_col23, #T_dda7e_row3_col4, #T_dda7e_row3_col9, #T_dda7e_row3_col10, #T_dda7e_row3_col11, #T_dda7e_row3_col12, #T_dda7e_row3_col13, #T_dda7e_row3_col14, #T_dda7e_row3_col15, #T_dda7e_row3_col16, #T_dda7e_row3_col17, #T_dda7e_row3_col18, #T_dda7e_row3_col19, #T_dda7e_row3_col20, #T_dda7e_row3_col21, #T_dda7e_row3_col22, #T_dda7e_row3_col23, #T_dda7e_row4_col4, #T_dda7e_row4_col5, #T_dda7e_row4_col13, #T_dda7e_row4_col14, #T_dda7e_row4_col15, #T_dda7e_row4_col16, #T_dda7e_row4_col17, #T_dda7e_row4_col18, #T_dda7e_row4_col19, #T_dda7e_row4_col20, #T_dda7e_row4_col21, #T_dda7e_row4_col22, #T_dda7e_row4_col23, #T_dda7e_row5_col4, #T_dda7e_row5_col5, #T_dda7e_row5_col6, #T_dda7e_row5_col16, #T_dda7e_row5_col17, #T_dda7e_row5_col18, #T_dda7e_row5_col19, #T_dda7e_row5_col20, #T_dda7e_row5_col21, #T_dda7e_row5_col22, #T_dda7e_row5_col23, #T_dda7e_row6_col4, #T_dda7e_row6_col5, #T_dda7e_row6_col6, #T_dda7e_row6_col7, #T_dda7e_row6_col21, #T_dda7e_row6_col22, #T_dda7e_row6_col23, #T_dda7e_row7_col4, #T_dda7e_row7_col5, #T_dda7e_row7_col6, #T_dda7e_row7_col7, #T_dda7e_row7_col21, #T_dda7e_row7_col22, #T_dda7e_row7_col23, #T_dda7e_row8_col4, #T_dda7e_row8_col5, #T_dda7e_row8_col6, #T_dda7e_row8_col7, #T_dda7e_row8_col21, #T_dda7e_row8_col22, #T_dda7e_row8_col23, #T_dda7e_row9_col4, #T_dda7e_row9_col5, #T_dda7e_row9_col6, #T_dda7e_row9_col7, #T_dda7e_row9_col21, #T_dda7e_row9_col22, #T_dda7e_row9_col23, #T_dda7e_row10_col4, #T_dda7e_row10_col5, #T_dda7e_row10_col6, #T_dda7e_row10_col7, #T_dda7e_row10_col23, #T_dda7e_row11_col4, #T_dda7e_row11_col5, #T_dda7e_row11_col6, #T_dda7e_row11_col7, #T_dda7e_row11_col8, #T_dda7e_row11_col23, #T_dda7e_row12_col4, #T_dda7e_row12_col5, #T_dda7e_row12_col6, #T_dda7e_row12_col7, #T_dda7e_row12_col8, #T_dda7e_row12_col23, #T_dda7e_row13_col4, #T_dda7e_row13_col5, #T_dda7e_row13_col6, #T_dda7e_row13_col7, #T_dda7e_row13_col8, #T_dda7e_row13_col9, #T_dda7e_row13_col23, #T_dda7e_row14_col4, #T_dda7e_row14_col5, #T_dda7e_row14_col6, #T_dda7e_row14_col7, #T_dda7e_row14_col8, #T_dda7e_row14_col23, #T_dda7e_row15_col4, #T_dda7e_row15_col5, #T_dda7e_row15_col6, #T_dda7e_row15_col7, #T_dda7e_row15_col8, #T_dda7e_row15_col9, #T_dda7e_row16_col4, #T_dda7e_row16_col5, #T_dda7e_row16_col6, #T_dda7e_row16_col7, #T_dda7e_row16_col8, #T_dda7e_row16_col9, #T_dda7e_row17_col4, #T_dda7e_row17_col5, #T_dda7e_row17_col6, #T_dda7e_row17_col7, #T_dda7e_row17_col8, #T_dda7e_row17_col9, #T_dda7e_row17_col10, #T_dda7e_row18_col4, #T_dda7e_row18_col5, #T_dda7e_row18_col6, #T_dda7e_row18_col7, #T_dda7e_row18_col8, #T_dda7e_row18_col9, #T_dda7e_row18_col10, #T_dda7e_row18_col11, #T_dda7e_row18_col12, #T_dda7e_row18_col13, #T_dda7e_row18_col14, #T_dda7e_row19_col4, #T_dda7e_row19_col5, #T_dda7e_row19_col6, #T_dda7e_row19_col7, #T_dda7e_row19_col8, #T_dda7e_row19_col9, #T_dda7e_row19_col10, #T_dda7e_row19_col11, #T_dda7e_row19_col12, #T_dda7e_row19_col13, #T_dda7e_row19_col14, #T_dda7e_row19_col15, #T_dda7e_row19_col16, #T_dda7e_row19_col17, #T_dda7e_row19_col18 ...
#   background-color: #f0f9ed;
#   color: #000000;
#   background-color: white !important;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_dda7e_row1_col4, #T_dda7e_row15_col21 {
#   background-color: #9fd899;
#   color: #000000;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight
# === Bundesliga Germany ===
# <style type="text/css">
# #T_1d49d th {
#   background-color: #e6edf4;
#   color: #333;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 13px;
#   font-weight: 600;
# }
# #T_1d49d tr {
#   height: 25px;
# }
# #T_1d49d th:nth-child(4) {
#   border-right: 2px solid #999;
# }
# #T_1d49d  td:nth-child(4) {
#   border-right: 2px solid #999;
# }
# #T_1d49d td:nth-child(-n+4) {
#   border-bottom: 1px solid #ccc;
# }
# #T_1d49d tr:nth-child(odd) td:nth-child(-n+4) {
#   background-color: #f9f9f9;
# }
# #T_1d49d tr:nth-child(even) td:nth-child(-n+4) {
#   background-color: #f2f2f2;
# }
# #T_1d49d_row0_col0, #T_1d49d_row0_col2, #T_1d49d_row0_col3, #T_1d49d_row1_col0, #T_1d49d_row1_col2, #T_1d49d_row1_col3, #T_1d49d_row2_col0, #T_1d49d_row2_col2, #T_1d49d_row2_col3, #T_1d49d_row3_col0, #T_1d49d_row3_col2, #T_1d49d_row3_col3, #T_1d49d_row4_col0, #T_1d49d_row4_col2, #T_1d49d_row4_col3, #T_1d49d_row5_col0, #T_1d49d_row5_col2, #T_1d49d_row5_col3, #T_1d49d_row6_col0, #T_1d49d_row6_col2, #T_1d49d_row6_col3, #T_1d49d_row7_col0, #T_1d49d_row7_col2, #T_1d49d_row7_col3, #T_1d49d_row8_col0, #T_1d49d_row8_col2, #T_1d49d_row8_col3, #T_1d49d_row9_col0, #T_1d49d_row9_col2, #T_1d49d_row9_col3, #T_1d49d_row10_col0, #T_1d49d_row10_col2, #T_1d49d_row10_col3, #T_1d49d_row11_col0, #T_1d49d_row11_col2, #T_1d49d_row11_col3, #T_1d49d_row12_col0, #T_1d49d_row12_col2, #T_1d49d_row12_col3, #T_1d49d_row13_col0, #T_1d49d_row13_col2, #T_1d49d_row13_col3, #T_1d49d_row14_col0, #T_1d49d_row14_col2, #T_1d49d_row14_col3, #T_1d49d_row15_col0, #T_1d49d_row15_col2, #T_1d49d_row15_col3, #T_1d49d_row16_col0, #T_1d49d_row16_col2, #T_1d49d_row16_col3, #T_1d49d_row17_col0, #T_1d49d_row17_col2, #T_1d49d_row17_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 600;
#   color: #000;
#   white-space: nowrap;
# }
# #T_1d49d_row0_col1, #T_1d49d_row1_col1, #T_1d49d_row2_col1, #T_1d49d_row3_col1, #T_1d49d_row4_col1, #T_1d49d_row5_col1, #T_1d49d_row6_col1, #T_1d49d_row7_col1, #T_1d49d_row8_col1, #T_1d49d_row9_col1, #T_1d49d_row10_col1, #T_1d49d_row11_col1, #T_1d49d_row12_col1, #T_1d49d_row13_col1, #T_1d49d_row14_col1, #T_1d49d_row15_col1, #T_1d49d_row16_col1, #T_1d49d_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: left;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 600;
#   color: #000;
#   white-space: nowrap;
# }
# #T_1d49d_row0_col4, #T_1d49d_row1_col5, #T_1d49d_row17_col21 {
#   background-color: #3ba458;
#   color: #f1f1f1;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_1d49d_row0_col5, #T_1d49d_row0_col6, #T_1d49d_row0_col7, #T_1d49d_row0_col8, #T_1d49d_row0_col9, #T_1d49d_row0_col10, #T_1d49d_row0_col11, #T_1d49d_row0_col12, #T_1d49d_row0_col13, #T_1d49d_row0_col14, #T_1d49d_row0_col15, #T_1d49d_row0_col16, #T_1d49d_row0_col17, #T_1d49d_row0_col18, #T_1d49d_row0_col19, #T_1d49d_row0_col20, #T_1d49d_row0_col21, #T_1d49d_row1_col4, #T_1d49d_row1_col10, #T_1d49d_row1_col11, #T_1d49d_row1_col12, #T_1d49d_row1_col13, #T_1d49d_row1_col14, #T_1d49d_row1_col15, #T_1d49d_row1_col16, #T_1d49d_row1_col17, #T_1d49d_row1_col18, #T_1d49d_row1_col19, #T_1d49d_row1_col20, #T_1d49d_row1_col21, #T_1d49d_row2_col4, #T_1d49d_row2_col11, #T_1d49d_row2_col12, #T_1d49d_row2_col13, #T_1d49d_row2_col14, #T_1d49d_row2_col15, #T_1d49d_row2_col16, #T_1d49d_row2_col17, #T_1d49d_row2_col18, #T_1d49d_row2_col19, #T_1d49d_row2_col20, #T_1d49d_row2_col21, #T_1d49d_row3_col4, #T_1d49d_row3_col11, #T_1d49d_row3_col12, #T_1d49d_row3_col13, #T_1d49d_row3_col14, #T_1d49d_row3_col15, #T_1d49d_row3_col16, #T_1d49d_row3_col17, #T_1d49d_row3_col18, #T_1d49d_row3_col19, #T_1d49d_row3_col20, #T_1d49d_row3_col21, #T_1d49d_row4_col4, #T_1d49d_row4_col11, #T_1d49d_row4_col12, #T_1d49d_row4_col13, #T_1d49d_row4_col14, #T_1d49d_row4_col15, #T_1d49d_row4_col16, #T_1d49d_row4_col17, #T_1d49d_row4_col18, #T_1d49d_row4_col19, #T_1d49d_row4_col20, #T_1d49d_row4_col21, #T_1d49d_row5_col4, #T_1d49d_row5_col12, #T_1d49d_row5_col13, #T_1d49d_row5_col14, #T_1d49d_row5_col15, #T_1d49d_row5_col16, #T_1d49d_row5_col17, #T_1d49d_row5_col18, #T_1d49d_row5_col19, #T_1d49d_row5_col20, #T_1d49d_row5_col21, #T_1d49d_row6_col4, #T_1d49d_row6_col5, #T_1d49d_row6_col6, #T_1d49d_row6_col16, #T_1d49d_row6_col17, #T_1d49d_row6_col18, #T_1d49d_row6_col19, #T_1d49d_row6_col20, #T_1d49d_row6_col21, #T_1d49d_row7_col4, #T_1d49d_row7_col5, #T_1d49d_row7_col6, #T_1d49d_row7_col7, #T_1d49d_row7_col8, #T_1d49d_row7_col18, #T_1d49d_row7_col19, #T_1d49d_row7_col20, #T_1d49d_row7_col21, #T_1d49d_row8_col4, #T_1d49d_row8_col5, #T_1d49d_row8_col6, #T_1d49d_row8_col7, #T_1d49d_row8_col8, #T_1d49d_row8_col9, #T_1d49d_row8_col20, #T_1d49d_row8_col21, #T_1d49d_row9_col4, #T_1d49d_row9_col5, #T_1d49d_row9_col6, #T_1d49d_row9_col7, #T_1d49d_row9_col8, #T_1d49d_row9_col9, #T_1d49d_row9_col21, #T_1d49d_row10_col4, #T_1d49d_row10_col5, #T_1d49d_row10_col6, #T_1d49d_row10_col7, #T_1d49d_row10_col8, #T_1d49d_row10_col9, #T_1d49d_row10_col21, #T_1d49d_row11_col4, #T_1d49d_row11_col5, #T_1d49d_row11_col6, #T_1d49d_row11_col7, #T_1d49d_row11_col8, #T_1d49d_row11_col9, #T_1d49d_row11_col21, #T_1d49d_row12_col4, #T_1d49d_row12_col5, #T_1d49d_row12_col6, #T_1d49d_row12_col7, #T_1d49d_row12_col8, #T_1d49d_row12_col9, #T_1d49d_row12_col10, #T_1d49d_row12_col21, #T_1d49d_row13_col4, #T_1d49d_row13_col5, #T_1d49d_row13_col6, #T_1d49d_row13_col7, #T_1d49d_row13_col8, #T_1d49d_row13_col9, #T_1d49d_row13_col21, #T_1d49d_row14_col4, #T_1d49d_row14_col5, #T_1d49d_row14_col6, #T_1d49d_row14_col7, #T_1d49d_row14_col8, #T_1d49d_row14_col9, #T_1d49d_row14_col10, #T_1d49d_row15_col4, #T_1d49d_row15_col5, #T_1d49d_row15_col6, #T_1d49d_row15_col7, #T_1d49d_row15_col8, #T_1d49d_row15_col9, #T_1d49d_row15_col10, #T_1d49d_row16_col4, #T_1d49d_row16_col5, #T_1d49d_row16_col6, #T_1d49d_row16_col7, #T_1d49d_row16_col8, #T_1d49d_row16_col9, #T_1d49d_row16_col10, #T_1d49d_row16_col11, #T_1d49d_row17_col4, #T_1d49d_row17_col5, #T_1d49d_row17_col6, #T_1d49d_row17_col7, #T_1d49d_row17_col8, #T_1d49d_row17_col9, #T_1d49d_row17_col10, #T_1d49d_row17_col11, #T_1d49d_row17_col12, #T_1d49d_row17_col13, #T_1d49d_row17_col14, #T_1d49d_row17_col15, #T_1d49d_row17_col16, #T_1d49d_row17_col17, #T_1d49d_row17_col18 {
#   background-color: #f0f9ed;
#   color: #000000;
#   background-color: white !important;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_1d49d_row1_col6, #T_1d49d_row8_col11, #T_1d49d_row10_col16 {
#   background-color: #cdecc7;
#   color: #000000;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_1d49d_row1_col7 {
#   background-color: #eaf7e6;
#   color: #000000;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_1d49d_row1_col8, #T_1d49d_row2_col10, #T_1d49d_row16_col14, #T_1d49d_row17_col19 {
#   background-color: #eff9eb;
#   color: #000000;
#   background-color: white !important;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_1d49d_row1_col9, #T_1d49d_row5_col11, #T_1d49d_row6_col15, #T_1d49d_row7_col17, #T_1d49d_row11_col10, #T_1d49d_row13_col10, #T_1d49d_row16_col12, #T_1d49d_row16_col13 {
#   background-color: #f0f9ec;
#   color: #000000;
#   background-color: white !important;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_1d49d_row2_col5, #T_1d49d_row8_col17, #T_1d49d_row12_col12 {
#   background-color: #daf0d4;
#   color: #000000;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_1d49d_row2_col6 {
#   background-color: #81ca81;
#   color: #000000;
#   text
# === Ligue1 France ===
# <style type="text/css">
# #T_5c088 th {
#   background-color: #e6edf4;
#   color: #333;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 13px;
#   font-weight: 600;
# }
# #T_5c088 tr {
#   height: 25px;
# }
# #T_5c088 th:nth-child(4) {
#   border-right: 2px solid #999;
# }
# #T_5c088  td:nth-child(4) {
#   border-right: 2px solid #999;
# }
# #T_5c088 td:nth-child(-n+4) {
#   border-bottom: 1px solid #ccc;
# }
# #T_5c088 tr:nth-child(odd) td:nth-child(-n+4) {
#   background-color: #f9f9f9;
# }
# #T_5c088 tr:nth-child(even) td:nth-child(-n+4) {
#   background-color: #f2f2f2;
# }
# #T_5c088_row0_col0, #T_5c088_row0_col2, #T_5c088_row0_col3, #T_5c088_row1_col0, #T_5c088_row1_col2, #T_5c088_row1_col3, #T_5c088_row2_col0, #T_5c088_row2_col2, #T_5c088_row2_col3, #T_5c088_row3_col0, #T_5c088_row3_col2, #T_5c088_row3_col3, #T_5c088_row4_col0, #T_5c088_row4_col2, #T_5c088_row4_col3, #T_5c088_row5_col0, #T_5c088_row5_col2, #T_5c088_row5_col3, #T_5c088_row6_col0, #T_5c088_row6_col2, #T_5c088_row6_col3, #T_5c088_row7_col0, #T_5c088_row7_col2, #T_5c088_row7_col3, #T_5c088_row8_col0, #T_5c088_row8_col2, #T_5c088_row8_col3, #T_5c088_row9_col0, #T_5c088_row9_col2, #T_5c088_row9_col3, #T_5c088_row10_col0, #T_5c088_row10_col2, #T_5c088_row10_col3, #T_5c088_row11_col0, #T_5c088_row11_col2, #T_5c088_row11_col3, #T_5c088_row12_col0, #T_5c088_row12_col2, #T_5c088_row12_col3, #T_5c088_row13_col0, #T_5c088_row13_col2, #T_5c088_row13_col3, #T_5c088_row14_col0, #T_5c088_row14_col2, #T_5c088_row14_col3, #T_5c088_row15_col0, #T_5c088_row15_col2, #T_5c088_row15_col3, #T_5c088_row16_col0, #T_5c088_row16_col2, #T_5c088_row16_col3, #T_5c088_row17_col0, #T_5c088_row17_col2, #T_5c088_row17_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 600;
#   color: #000;
#   white-space: nowrap;
# }
# #T_5c088_row0_col1, #T_5c088_row1_col1, #T_5c088_row2_col1, #T_5c088_row3_col1, #T_5c088_row4_col1, #T_5c088_row5_col1, #T_5c088_row6_col1, #T_5c088_row7_col1, #T_5c088_row8_col1, #T_5c088_row9_col1, #T_5c088_row10_col1, #T_5c088_row11_col1, #T_5c088_row12_col1, #T_5c088_row13_col1, #T_5c088_row14_col1, #T_5c088_row15_col1, #T_5c088_row16_col1, #T_5c088_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: left;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 600;
#   color: #000;
#   white-space: nowrap;
# }
# #T_5c088_row0_col4, #T_5c088_row1_col5, #T_5c088_row15_col19, #T_5c088_row16_col20, #T_5c088_row17_col21 {
#   background-color: #3ba458;
#   color: #f1f1f1;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_5c088_row0_col5 {
#   background-color: #a0d99b;
#   color: #000000;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_5c088_row0_col6, #T_5c088_row9_col17, #T_5c088_row11_col12, #T_5c088_row13_col12 {
#   background-color: #edf8e9;
#   color: #000000;
#   background-color: white !important;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_5c088_row0_col7, #T_5c088_row0_col8, #T_5c088_row0_col9, #T_5c088_row0_col10, #T_5c088_row0_col11, #T_5c088_row0_col12, #T_5c088_row0_col13, #T_5c088_row0_col14, #T_5c088_row0_col15, #T_5c088_row0_col16, #T_5c088_row0_col17, #T_5c088_row0_col18, #T_5c088_row0_col19, #T_5c088_row0_col20, #T_5c088_row0_col21, #T_5c088_row1_col9, #T_5c088_row1_col10, #T_5c088_row1_col11, #T_5c088_row1_col12, #T_5c088_row1_col13, #T_5c088_row1_col14, #T_5c088_row1_col15, #T_5c088_row1_col16, #T_5c088_row1_col17, #T_5c088_row1_col18, #T_5c088_row1_col19, #T_5c088_row1_col20, #T_5c088_row1_col21, #T_5c088_row2_col12, #T_5c088_row2_col13, #T_5c088_row2_col14, #T_5c088_row2_col15, #T_5c088_row2_col16, #T_5c088_row2_col17, #T_5c088_row2_col18, #T_5c088_row2_col19, #T_5c088_row2_col20, #T_5c088_row2_col21, #T_5c088_row3_col12, #T_5c088_row3_col13, #T_5c088_row3_col14, #T_5c088_row3_col15, #T_5c088_row3_col16, #T_5c088_row3_col17, #T_5c088_row3_col18, #T_5c088_row3_col19, #T_5c088_row3_col20, #T_5c088_row3_col21, #T_5c088_row4_col4, #T_5c088_row4_col5, #T_5c088_row4_col15, #T_5c088_row4_col16, #T_5c088_row4_col17, #T_5c088_row4_col18, #T_5c088_row4_col19, #T_5c088_row4_col20, #T_5c088_row4_col21, #T_5c088_row5_col4, #T_5c088_row5_col15, #T_5c088_row5_col16, #T_5c088_row5_col17, #T_5c088_row5_col18, #T_5c088_row5_col19, #T_5c088_row5_col20, #T_5c088_row5_col21, #T_5c088_row6_col4, #T_5c088_row6_col5, #T_5c088_row6_col15, #T_5c088_row6_col16, #T_5c088_row6_col17, #T_5c088_row6_col18, #T_5c088_row6_col19, #T_5c088_row6_col20, #T_5c088_row6_col21, #T_5c088_row7_col4, #T_5c088_row7_col5, #T_5c088_row7_col17, #T_5c088_row7_col18, #T_5c088_row7_col19, #T_5c088_row7_col20, #T_5c088_row7_col21, #T_5c088_row8_col4, #T_5c088_row8_col5, #T_5c088_row8_col6, #T_5c088_row8_col7, #T_5c088_row8_col19, #T_5c088_row8_col20, #T_5c088_row8_col21, #T_5c088_row9_col4, #T_5c088_row9_col5, #T_5c088_row9_col6, #T_5c088_row9_col7, #T_5c088_row9_col19, #T_5c088_row9_col20, #T_5c088_row9_col21, #T_5c088_row10_col4, #T_5c088_row10_col5, #T_5c088_row10_col6, #T_5c088_row10_col7, #T_5c088_row10_col8, #T_5c088_row10_col19, #T_5c088_row10_col20, #T_5c088_row10_col21, #T_5c088_row11_col4, #T_5c088_row11_col5, #T_5c088_row11_col6, #T_5c088_row11_col7, #T_5c088_row11_col8, #T_5c088_row11_col9, #T_5c088_row11_col10, #T_5c088_row11_col20, #T_5c088_row11_col21, #T_5c088_row12_col4, #T_5c088_row12_col5, #T_5c088_row12_col6, #T_5c088_row12_col7, #T_5c088_row12_col8, #T_5c088_row12_col9, #T_5c088_row12_col10, #T_5c088_row12_col11, #T_5c088_row12_col21, #T_5c088_row13_col4, #T_5c088_row13_col5, #T_5c088_row13_col6, #T_5c088_row13_col7, #T_5c088_row13_col8, #T_5c088_row13_col9, #T_5c088_row13_col10, #T_5c088_row13_col21, #T_5c088_row14_col4, #T_5c088_row14_col5, #T_5c088_row14_col6, #T_5c088_row14_col7, #T_5c088_row14_col8, #T_5c088_row14_col9, #T_5c088_row14_col10, #T_5c088_row14_col21, #T_5c088_row15_col4, #T_5c088_row15_col5, #T_5c088_row15_col6, #T_5c088_row15_col7, #T_5c088_row15_col8, #T_5c088_row15_col9, #T_5c088_row15_col10, #T_5c088_row15_col11, #T_5c088_row15_col12, #T_5c088_row15_col13, #T_5c088_row15_col14, #T_5c088_row16_col4, #T_5c088_row16_col5, #T_5c088_row16_col6, #T_5c088_row16_col7, #T_5c088_row16_col8, #T_5c088_row16_col9, #T_5c088_row16_col10, #T_5c088_row16_col11, #T_5c088_row16_col12, #T_5c088_row16_col13, #T_5c088_row16_col14, #T_5c088_row16_col15, #T_5c088_row16_col16, #T_5c088_row17_col4, #T_5c088_row17_col5, #T_5c088_row17_col6, #T_5c088_row17_col7, #T_5c088_row17_col8, #T_5c088_row17_col9, #T_5c088_row17_col10, #T_5c088_row17_col11, #T_5c088_row17_col12, #T_5c088_row17_col13, #T_5c088_row17_col14, #T_5c088_row17_col15, #T_5c088_row17_col16, #T_5c088_row17_col17, #T_5c088_row17_col18 {
#   background-color: #f0f9ed;
#   color: #000000;
#   background-color: white !important;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_5c088_row1_col4, #T_5c088_row8_col14, #T_5c088_row16_col19 {
#   background-color: #9fd899;
#   color: #000000;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_5c088_row1_col6 {
#   background-color: #b8e3b2;
#   color: #000000;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_5c088_row1_col7, #T_5c088_row3_col10, #T_5c088_row4_col6, #T_5c088_row9_col10, #T_5c088_row10_col17, #T_5c088_row12_col13, #T_5c088_row15_col16 {
#   background-color: #e9f7e5;
#   color: #000000;
#   text-align: center;
#   font-family: Inter, Roboto, Arial, sans-serif;
#   font-size: 12px;
#   font-weight: 500;
#   color: #000;
# }
# #T_5c088_row1_col8, #T_5c088_row3_col4, #T_5c088_row5_col14, #T_5c088_row6_col14, #T_5c088_row7_col16, #T_5

# %%
today = date.today().strftime("%Y-%m-%d")

os.makedirs("league_tables", exist_ok=True)

for league in leagues:
    filename = f"league_tables/{league}_{today}.jpg"
    dfi.export(
        styled_position_pct_all[league],
        filename,
        table_conversion="chrome"
    )
    print(f"Saved: {filename}")
# Out:
# Saved: league_tables/premierleague_england_2026-03-07.jpg
# Saved: league_tables/seriea_italy_2026-03-07.jpg
# Saved: league_tables/laliga_spain_2026-03-07.jpg
# Saved: league_tables/bundesliga_germany_2026-03-07.jpg
# Saved: league_tables/ligue1_france_2026-03-07.jpg
