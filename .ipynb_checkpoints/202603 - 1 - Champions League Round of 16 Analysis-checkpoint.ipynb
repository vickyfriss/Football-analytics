# %%
# https://www.kaggle.com/datasets/michals22/champions-league-seasons-19911992-20232024?select=teams.csv

# %%
import pandas as pd

# Define the base path
base_path = r"Datasets\Champions League"

# Read the CSV files
knock_out_stage = pd.read_csv(f"{base_path}\\knock_out_stage.csv", sep=";")
seasons = pd.read_csv(f"{base_path}\\seasons.csv", sep=";")
teams = pd.read_csv(f"{base_path}\\teams.csv", sep=";")
group_stage = pd.read_csv(f"{base_path}\\group_stage.csv", sep=";")

# %%
teams.loc[teams["team_name"] == "Inter Mediolan", "team_name"] = "Inter Milan"
teams.loc[teams["team_name"] == "Feyenoord Rotterdam", "team_name"] = "Feyenoord"

new_team_id = teams["team_id"].max() + 1
new_team = pd.DataFrame([{
    "team_id": new_team_id,
    "team_name": "Bodø/Glimt",
    "country_code": "NOR",
    "country_name": "Norway",
    "city_name": "Bodø",
    "latitude": 67.280356,
    "longitude": 14.404916
}])
teams = pd.concat([teams, new_team], ignore_index=True)

teams.tail()
# Out:
#      team_id          team_name country_code country_name     city_name  \
# 148      149      SC Heerenveen          NLD  Netherlands    Heerenveen
# 149      150    Helsingborgs IF          SWE       Sweden  Helsingborgs
# 150      151  Leeds United F.C.          GBR      England         Leeds
# 151      152       RCD Mallorca          ESP        Spain      Mallorca
# 152      153         Bodø/Glimt          NOR       Norway          Bodø
#
#       latitude  longitude
# 148  52.950000   5.933333
# 149  56.045833  12.694444
# 150  53.799722  -1.549167
# 151  39.616667   2.983333
# 152  67.280356  14.404916

# %%
data = [

# ---- ROUND OF 16 ----
("FC Barcelona", "round 1 of 16", "advance to quater-final"),
("Inter Milan", "round 1 of 16", "advance to quater-final"),
("Paris Saint-Germain F.C.", "round 1 of 16", "advance to quater-final"),
("FC Bayern Munich", "round 1 of 16", "advance to quater-final"),
("Borussia Dortmund", "round 1 of 16", "advance to quater-final"),
("Arsenal F.C.", "round 1 of 16", "advance to quater-final"),
("Real Madrid", "round 1 of 16", "advance to quater-final"),

("SL Benfica", "round 1 of 16", "drop out"),
("Feyenoord", "round 1 of 16", "drop out"),
("Liverpool F.C.", "round 1 of 16", "drop out"),
("Bayer Leverkusen", "round 1 of 16", "drop out"),
("Lille OSC", "round 1 of 16", "drop out"),
("Club Brugge", "round 1 of 16", "drop out"),
("PSV Eindhoven", "round 1 of 16", "drop out"),
("Atletico Madrid", "round 1 of 16", "drop out"),

# ---- QUARTER-FINAL ----
("Inter Milan", "quater-final", "advance to semi-final"),
("Arsenal F.C.", "quater-final", "advance to semi-final"),
("FC Barcelona", "quater-final", "advance to semi-final"),
("Paris Saint-Germain F.C.", "quater-final", "advance to semi-final"),

("FC Bayern Munich", "quater-final", "drop out"),
("Real Madrid", "quater-final", "drop out"),
("Borussia Dortmund", "quater-final", "drop out"),

# ---- SEMI-FINAL ----
("Inter Milan", "semi-final", "advance to final"),
("Paris Saint-Germain F.C.", "semi-final", "advance to final"),

("Arsenal F.C.", "semi-final", "drop out"),
("FC Barcelona", "semi-final", "drop out"),

# ---- FINAL ----
("Paris Saint-Germain F.C.", "final", "winner"),
("Inter Milan", "final", "loser"),
]

# %%
new_rows = pd.DataFrame(
    data,
    columns=["team_name", "knock_out_stage", "knock_out_stage_status"]
)

new_rows["season_id"] = 34

# Merge with teams to fetch team_id
new_rows = new_rows.merge(
    teams[["team_id", "team_name"]],
    on="team_name",
    how="left"
)

# Reorder columns
new_rows = new_rows[
    ["season_id", "team_id", "team_name", 
     "knock_out_stage", "knock_out_stage_status"]
]

# Append
knock_out_stage = pd.concat([knock_out_stage, new_rows], ignore_index=True)

# %%
data_35 = [

# ROUND OF 16 (season 35)

("Sporting CP", "round 1 of 16", None),
("Chelsea F.C.", "round 1 of 16", None),
("Manchester City F.C.", "round 1 of 16", None),
("Arsenal F.C.", "round 1 of 16", None),
("FC Barcelona", "round 1 of 16", None),
("Tottenham Hotspur", "round 1 of 16", None),
("Liverpool F.C.", "round 1 of 16", None),
("FC Bayern Munich", "round 1 of 16", None),

("Bodø/Glimt", "round 1 of 16", None),  # will not match (not in table)
("Paris Saint-Germain F.C.", "round 1 of 16", None),
("Real Madrid", "round 1 of 16", None),
("Bayer Leverkusen", "round 1 of 16", None),
("Newcastle United F.C.", "round 1 of 16", None),
("Atletico Madrid", "round 1 of 16", None),
("Galatasaray SK", "round 1 of 16", None),
("Atalanta BC", "round 1 of 16", None),
]

# %%
new_rows_35 = pd.DataFrame(
    data_35,
    columns=["team_name", "knock_out_stage", "knock_out_stage_status"]
)

new_rows_35["season_id"] = 35

# Merge with teams to get team_id
new_rows_35 = new_rows_35.merge(
    teams[["team_id", "team_name"]],
    on="team_name",
    how="left"
)

# Reorder columns
new_rows_35 = new_rows_35[
    ["season_id", "team_id", "team_name",
     "knock_out_stage", "knock_out_stage_status"]
]

# Append to dataframe
knock_out_stage = pd.concat(
    [knock_out_stage, new_rows_35],
    ignore_index=True
)

# %%
knock_out_stage[knock_out_stage["season_id"] == 34]
# Out:
#      season_id  team_id                 team_name knock_out_stage  \
# 761         34        5              FC Barcelona   round 1 of 16
# 762         34       53               Inter Milan   round 1 of 16
# 763         34       23  Paris Saint-Germain F.C.   round 1 of 16
# 764         34       24          FC Bayern Munich   round 1 of 16
# 765         34       35         Borussia Dortmund   round 1 of 16
# 766         34       59              Arsenal F.C.   round 1 of 16
# 767         34       36               Real Madrid   round 1 of 16
# 768         34        7                SL Benfica   round 1 of 16
# 769         34       47                 Feyenoord   round 1 of 16
# 770         34       75            Liverpool F.C.   round 1 of 16
# 771         34       51          Bayer Leverkusen   round 1 of 16
# 772         34       78                 Lille OSC   round 1 of 16
# 773         34       11               Club Brugge   round 1 of 16
# ...

# %%
seasons.loc[len(seasons)] = [34, "2024/2025"]
seasons.loc[len(seasons)] = [35, "2025/2026"]
seasons.tail()
# Out:
#     season_id season_year
# 30         31   2021/2022
# 31         32   2022/2023
# 32         33   2023/2024
# 33         34   2024/2025
# 34         35   2025/2026

# %%
dataset = (
    knock_out_stage
        .merge(seasons, on="season_id", how="left")
        .merge(teams, on="team_id", how="left")
)

# %%
dataset.tail()
# Out:
#      season_id  team_id            team_name_x knock_out_stage  \
# 800         35       51       Bayer Leverkusen   round 1 of 16
# 801         35       49  Newcastle United F.C.   round 1 of 16
# 802         35       40        Atletico Madrid   round 1 of 16
# 803         35       19         Galatasaray SK   round 1 of 16
# 804         35      134            Atalanta BC   round 1 of 16
#
#     knock_out_stage_status season_year            team_name_y country_code  \
# 800                   None   2025/2026       Bayer Leverkusen          DEU
# 801                   None   2025/2026  Newcastle United F.C.          GBR
# 802                   None   2025/2026        Atletico Madrid          ESP
# 803                   None   2025/2026         Galatasaray SK          TUR
# 804                   None   2025/2026            Atalanta BC          ITA
#
#     country_name   city_name   latitude  longitude
# 800      Germany  Leverkusen  51.033333   6.983333
# ...

# %%
group_stage_extended = (
    group_stage
        .merge(seasons[["season_id", "season_year"]], 
               on="season_id", 
               how="left")
        .merge(teams[["team_id", "team_name", "country_name"]], 
               on="team_id", 
               how="left")
)

# %%
group_stage_extended.head()
# Out:
#    season_id  team_id        team_name_x group_name group_stage_place  \
# 0          1        1       UC Sampdoria          A  advance to final
# 1          1        2  Red Star Belgrade          A          drop out
# 2          1        3     RSC Anderlecht          A          drop out
# 3          1        4   Panathinaikos AO          A          drop out
# 4          1        5       FC Barcelona          B  advance to final
#
#   season_year        team_name_y country_name
# 0   1991/1992       UC Sampdoria        Italy
# 1   1991/1992  Red Star Belgrade       Serbia
# 2   1991/1992     RSC Anderlecht      Belgium
# 3   1991/1992   Panathinaikos AO       Greece
# 4   1991/1992       FC Barcelona        Spain

# %%
group_2024 = [
    ("2024/2025", "Liverpool", "England"),
    ("2024/2025", "Barcelona", "Spain"),
    ("2024/2025", "Arsenal", "England"),
    ("2024/2025", "Inter Milan", "Italy"),
    ("2024/2025", "Atlético Madrid", "Spain"),
    ("2024/2025", "Bayer Leverkusen", "Germany"),
    ("2024/2025", "Lille", "France"),
    ("2024/2025", "Aston Villa", "England"),
    ("2024/2025", "Atalanta", "Italy"),
    ("2024/2025", "Borussia Dortmund", "Germany"),
    ("2024/2025", "Real Madrid", "Spain"),
    ("2024/2025", "Bayern Munich", "Germany"),
    ("2024/2025", "Milan", "Italy"),
    ("2024/2025", "PSV Eindhoven", "Netherlands"),
    ("2024/2025", "Paris Saint-Germain", "France"),
    ("2024/2025", "Benfica", "Portugal"),
    ("2024/2025", "Monaco", "France"),
    ("2024/2025", "Brest", "France"),
    ("2024/2025", "Feyenoord", "Netherlands"),
    ("2024/2025", "Juventus", "Italy"),
    ("2024/2025", "Celtic", "Scotland"),
    ("2024/2025", "Manchester City", "England"),
    ("2024/2025", "Sporting CP", "Portugal"),
    ("2024/2025", "Club Brugge", "Belgium"),
    ("2024/2025", "Dinamo Zagreb", "Croatia"),
    ("2024/2025", "VfB Stuttgart", "Germany"),
    ("2024/2025", "Shakhtar Donetsk", "Ukraine"),
    ("2024/2025", "Bologna", "Italy"),
    ("2024/2025", "Red Star Belgrade", "Serbia"),
    ("2024/2025", "Sturm Graz", "Austria"),
    ("2024/2025", "Sparta Prague", "Czech Republic"),
    ("2024/2025", "RB Leipzig", "Germany"),
    ("2024/2025", "Girona", "Spain"),
    ("2024/2025", "Red Bull Salzburg", "Austria"),
    ("2024/2025", "Slovan Bratislava", "Slovakia"),
    ("2024/2025", "Young Boys", "Switzerland"),
]

group_2025 = [
    ("2025/2026", "Arsenal", "England"),
    ("2025/2026", "Bayern Munich", "Germany"),
    ("2025/2026", "Liverpool", "England"),
    ("2025/2026", "Tottenham Hotspur", "England"),
    ("2025/2026", "Barcelona", "Spain"),
    ("2025/2026", "Chelsea", "England"),
    ("2025/2026", "Sporting CP", "Portugal"),
    ("2025/2026", "Manchester City", "England"),
    ("2025/2026", "Real Madrid", "Spain"),
    ("2025/2026", "Inter Milan", "Italy"),
    ("2025/2026", "Paris Saint-Germain", "France"),
    ("2025/2026", "Newcastle United", "England"),
    ("2025/2026", "Juventus", "Italy"),
    ("2025/2026", "Atlético Madrid", "Spain"),
    ("2025/2026", "Atalanta", "Italy"),
    ("2025/2026", "Bayer Leverkusen", "Germany"),
    ("2025/2026", "Borussia Dortmund", "Germany"),
    ("2025/2026", "Olympiacos", "Greece"),
    ("2025/2026", "Club Brugge", "Belgium"),
    ("2025/2026", "Galatasaray", "Turkey"),
    ("2025/2026", "Monaco", "France"),
    ("2025/2026", "Qarabağ", "Azerbaijan"),
    ("2025/2026", "Bodø/Glimt", "Norway"),
    ("2025/2026", "Benfica", "Portugal"),
    ("2025/2026", "Marseille", "France"),
    ("2025/2026", "Pafos", "Cyprus"),
    ("2025/2026", "Union Saint-Gilloise", "Belgium"),
    ("2025/2026", "PSV Eindhoven", "Netherlands"),
    ("2025/2026", "Athletic Bilbao", "Spain"),
    ("2025/2026", "Napoli", "Italy"),
    ("2025/2026", "Copenhagen", "Denmark"),
    ("2025/2026", "Ajax", "Netherlands"),
    ("2025/2026", "Eintracht Frankfurt", "Germany"),
    ("2025/2026", "Slavia Prague", "Czech Republic"),
    ("2025/2026", "Villarreal", "Spain"),
    ("2025/2026", "Kairat", "Kazakhstan"),
]

# %%
new_group_df = pd.DataFrame(
    group_2024 + group_2025,
    columns=["season_year", "team_name", "country_name"]
)

group_stage_extended = pd.concat(
    [group_stage_extended, new_group_df],
    ignore_index=True
).drop_duplicates()

# %%
pivot_group_df = (
    group_stage_extended
        .groupby(["season_year", "country_name"])
        .size()
        .unstack(fill_value=0)
        .sort_index()
)

# %%
pivot_group_df.head()
# Out:
# country_name  Austria  Azerbaijan  Belarus  Belgium  Bulgaria  Croatia  \
# season_year
# 1991/1992           0           0        0        1         0        0
# 1992/1993           0           0        0        1         0        0
# 1993/1994           0           0        0        1         0        0
# 1994/1995           1           0        0        1         0        1
# 1995/1996           0           0        0        0         0        0
#
# country_name  Cyprus  Czech  Czech Republic  Denmark  ...  Russia  Scotland  \
# season_year                                           ...
# 1991/1992          0      1               0        0  ...       0         0
# 1992/1993          0      0               0        0  ...       1         1
# 1993/1994          0      0               0        0  ...       1         0
# 1994/1995          0      0               0        0  ...       1         0
# 1995/1996          0      0               0        1  ...       1         1
#
# ...

# %%
pivot_group_df.sum(axis=1)
# Out:
# season_year
# 1991/1992     8
# 1992/1993     8
# 1993/1994     8
# 1994/1995    16
# 1995/1996    16
# 1996/1997    16
# 1997/1998    24
# 1998/1999    24
# 1999/2000    32
# 2000/2001    32
# 2001/2002    32
# 2002/2003    32
# 2003/2004    32
# 2004/2005    32
# 2005/2006    32
# 2006/2007    32
# 2007/2008    32
# 2008/2009    32
# 2009/2010    32
# 2010/2011    32
# 2011/2012    32
# 2012/2013    32
# 2013/2014    32
# 2014/2015    32
# 2015/2016    32
# 2016/2017    32
# 2017/2018    32
# 2018/2019    32
# 2019/2020    32
# 2020/2021    32
# 2021/2022    32
# 2022/2023    32
# 2023/2024    32
# 2024/2025    36
# 2025/2026    36
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter only Round of 16
round16 = dataset[dataset["knock_out_stage"] == "round 1 of 16"]

# Group by season and country
grouped = (
    round16
    .groupby(["season_year", "country_name"])
    .size()
    .reset_index(name="num_teams_round16")
)

# Create pivot table
pivot_df = grouped.pivot(
    index="season_year",
    columns="country_name",
    values="num_teams_round16"
).fillna(0)

# Sort seasons chronologically
pivot_df = pivot_df.sort_index()

# Country colour mapping (dominant flag colour)
country_colors = {
    "Germany": "black",
    "England": "red",
    "Spain": "gold",
    "France": "blue",
    "Italy": "green",
    "Portugal": "darkgreen",
    "Netherlands": "orange",
    "Turkey": "crimson",
    "Norway": "navy",
    "Scotland": "darkblue"
}

plt.figure(figsize=(10, 6))

for country in pivot_df.columns:
    color = country_colors.get(country, None)  # default if not mapped
    plt.plot(
        pivot_df.index,
        pivot_df[country],
        marker="o",
        label=country,
        color=color
    )

plt.xlabel("Season")
plt.ylabel("Number of Teams in Round of 16")
plt.title("Round of 16 Teams per Country by Season")
plt.xticks(rotation=45)

# Legend outside (top-right)
plt.legend(
    bbox_to_anchor=(1.02, 1),
    loc="upper left",
    title="Country"
)

plt.tight_layout()
plt.show()

# %%
# Calculate total appearances
totals = pivot_df.sum().sort_values(ascending=False)

# Select top 5 countries
top_countries = totals.head(5).index

plt.figure(figsize=(10,6))

for country in top_countries:
    plt.plot(
        pivot_df.index,
        pivot_df[country],
        marker="o",
        linewidth=2.5,
        label=country,
        color=country_colors.get(country, None)
    )

plt.xlabel("Season")
plt.ylabel("Number of Teams in Round of 16")
plt.title("Top 5 Countries – Round of 16 Appearances")
plt.xticks(rotation=45)

plt.legend(
    bbox_to_anchor=(1.02, 1),
    loc="upper left",
    title="Country"
)

plt.tight_layout()
plt.show()

# %%
# Identify top 5
top_countries = pivot_df.sum().sort_values(ascending=False).head(5).index

plt.figure(figsize=(10,6))

for country in pivot_df.columns:
    if country in top_countries:
        plt.plot(
            pivot_df.index,
            pivot_df[country],
            marker="o",
            linewidth=2.5,
            label=country,
            color=country_colors.get(country, None)
        )
    else:
        plt.plot(
            pivot_df.index,
            pivot_df[country],
            color=country_colors.get(country, "grey"),
            alpha=0.25
        )

plt.xlabel("Season")
plt.ylabel("Number of Teams in Round of 16")
plt.title("Round of 16 Teams per Country by Season")
plt.xticks(rotation=45)

plt.legend(
    bbox_to_anchor=(1.02, 1),
    loc="upper left",
    title="Top 5 Countries"
)

plt.tight_layout()
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import matplotlib.image as mpimg

# -------------------------------
# Prepare heatmap data
# -------------------------------
ranked_countries = pivot_df.sum().sort_values(ascending=False).index
heatmap_df = pivot_df[ranked_countries].T

# Champions
champions = dataset[dataset["knock_out_stage_status"] == "winner"]
champions = champions[["season_year", "country_name"]].drop_duplicates()

vmax = int(heatmap_df.max().max())

# -------------------------------
# Colormap
# -------------------------------
colors = ["white"] + list(plt.cm.YlOrRd(np.linspace(0.3, 0.9, vmax)))
cmap = ListedColormap(colors)

bounds = np.arange(-0.5, vmax + 1.5, 1)
norm = BoundaryNorm(bounds, cmap.N)

# -------------------------------
# Plot
# -------------------------------
fig, ax = plt.subplots(figsize=(12,8))

im = ax.imshow(
    heatmap_df,
    aspect="auto",
    cmap=cmap,
    norm=norm
)

# -------------------------------
# Axis formatting
# -------------------------------
ax.set_yticks(range(len(heatmap_df.index)))
ax.set_yticklabels(heatmap_df.index, fontsize=13)

ax.set_xticks(range(len(heatmap_df.columns)))
ax.set_xticklabels(
    heatmap_df.columns,
    rotation=45,
    fontsize=13,
    ha="right"
)

#ax.tick_params(axis="x", pad=2)

# Grid
y_lines = np.arange(-0.5, heatmap_df.shape[0], 1) - 0.03
x_lines = np.arange(-0.5, heatmap_df.shape[1], 1)

ax.set_yticks(y_lines, minor=True)
ax.set_xticks(x_lines, minor=True)

ax.grid(
    which="minor",
    color="lightgrey",
    linestyle="-",
    linewidth=0.5
)

ax.tick_params(which="minor", bottom=False, left=False)

# -------------------------------
# Trophy overlay
# -------------------------------
image_path = os.path.join("Images and others", "Champions League Trophy.png")
trophy_img = mpimg.imread(image_path)

imagebox = OffsetImage(trophy_img, zoom=0.03)

for _, row in champions.iterrows():

    season = row["season_year"]
    country = row["country_name"]

    if season in heatmap_df.columns and country in heatmap_df.index:

        x = list(heatmap_df.columns).index(season)
        y = list(heatmap_df.index).index(country)

        ab = AnnotationBbox(
            imagebox,
            (x, y),
            frameon=False,
            box_alignment=(0.5,0.5),
            zorder=5
        )

        ax.add_artist(ab)

# -------------------------------
# Colorbar
# -------------------------------
cbar = fig.colorbar(
    im,
    ticks=np.arange(0, vmax + 1)
)

cbar.set_label(
    "Number of Teams",
    fontsize=14
)

cbar.ax.tick_params(labelsize=12)

# -------------------------------
# Titles
# -------------------------------
ax.set_title(
    "Round of 16 Teams per Country by Season",
    fontsize=18,
    pad=20
)

ax.set_xlabel(
    "Season",
    fontsize=15
)

ax.set_ylabel(
    "Country",
    fontsize=15
)

# -------------------------------
# Layout
# -------------------------------
plt.tight_layout()

plt.show()

fig.savefig(
    os.path.join("Images and others", "round_of_16_heatmap.png"),
    dpi=600,
    bbox_inches="tight"
)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import matplotlib.image as mpimg

# -------------------------------
# Filter from 2003/2004 onward
# -------------------------------

pivot_group_filtered = pivot_group_df.sort_index().loc["2003/2004":]

# Rank countries by total group stage appearances
ranked_countries = (
    pivot_group_filtered
    .sum()
    .sort_values(ascending=False)
    .index
)

heatmap_df = pivot_group_filtered[ranked_countries].T

# Filter champions to same seasons
champions = dataset[
    (dataset["knock_out_stage_status"] == "winner") &
    (dataset["season_year"] >= "2003/2004")
][["season_year", "country_name"]].drop_duplicates()

vmax = int(heatmap_df.max().max())

# -------------------------------
# SAME RED COLORMAP
# -------------------------------

colors = ["white"] + list(plt.cm.YlOrRd(np.linspace(0.3, 0.9, vmax)))
cmap = ListedColormap(colors)

bounds = np.arange(-0.5, vmax + 1.5, 1)
norm = BoundaryNorm(bounds, cmap.N)

# -------------------------------
# Plot
# -------------------------------

fig, ax = plt.subplots(figsize=(12,8))

im = ax.imshow(
    heatmap_df,
    aspect="auto",
    cmap=cmap,
    norm=norm
)

# -------------------------------
# Axis formatting
# -------------------------------

ax.set_yticks(range(len(heatmap_df.index)))
ax.set_yticklabels(
    heatmap_df.index,
    fontsize=13
)

ax.set_xticks(range(len(heatmap_df.columns)))
ax.set_xticklabels(
    heatmap_df.columns,
    rotation=45,
    fontsize=13,
    ha="right"
)

# -------------------------------
# Grid (same alignment)
# -------------------------------

y_lines = np.arange(-0.5, heatmap_df.shape[0], 1) - 0.03
x_lines = np.arange(-0.5, heatmap_df.shape[1], 1)

ax.set_yticks(y_lines, minor=True)
ax.set_xticks(x_lines, minor=True)

ax.grid(
    which="minor",
    color="lightgrey",
    linestyle="-",
    linewidth=0.5
)

ax.tick_params(which="minor", bottom=False, left=False)

# -------------------------------
# Trophy overlay
# -------------------------------

image_path = os.path.join("Images and others", "Champions League Trophy.png")
trophy_img = mpimg.imread(image_path)

imagebox = OffsetImage(trophy_img, zoom=0.03)

for _, row in champions.iterrows():

    season = row["season_year"]
    country = row["country_name"]

    if season in heatmap_df.columns and country in heatmap_df.index:

        x = list(heatmap_df.columns).index(season)
        y = list(heatmap_df.index).index(country)

        ab = AnnotationBbox(
            imagebox,
            (x, y),
            frameon=False,
            box_alignment=(0.5,0.5),
            zorder=5
        )

        ax.add_artist(ab)

# -------------------------------
# Colorbar
# -------------------------------

cbar = fig.colorbar(
    im,
    ticks=np.arange(0, vmax + 1)
)

cbar.set_label(
    "Number of Teams",
    fontsize=14
)

cbar.ax.tick_params(labelsize=12)

# -------------------------------
# Titles
# -------------------------------

ax.set_title(
    "Group Stage Teams per Country by Season (Since 2003/2004)",
    fontsize=18,
    pad=20
)

ax.set_xlabel(
    "Season",
    fontsize=15
)

ax.set_ylabel(
    "Country",
    fontsize=15
)

# -------------------------------
# Layout
# -------------------------------

plt.tight_layout()

plt.show()

fig.savefig(
    os.path.join("Images and others", "group_stage_heatmap_since_2003.png"),
    dpi=600,
    bbox_inches="tight"
)

# %%
import matplotlib.pyplot as plt
import numpy as np

# -------------------------------
# 1. Filter + Align
# -------------------------------

group = pivot_group_df.sort_index().loc["2003/2004":]
ro16 = pivot_df.sort_index().loc["2003/2004":]

group, ro16 = group.align(ro16, join="outer", fill_value=0)

top4 = ["England", "Spain", "Germany", "Italy"]

# -------------------------------
# 2. Compute shares + fractions
# -------------------------------

group_top4 = group[top4].sum(axis=1)
group_total = group.sum(axis=1)

ro16_top4 = ro16[top4].sum(axis=1)
ro16_total = ro16.sum(axis=1)

group_share = group_top4 / group_total * 100
ro16_share = ro16_top4 / ro16_total * 100

# -------------------------------
# 3. Plot
# -------------------------------

plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots(figsize=(14, 8))

color_group = "#1f77b4"
color_ro16 = "#d62728"

# Put grid BEHIND everything
ax.set_axisbelow(True)

# Horizontal gridlines (stronger)
ax.grid(axis="y", alpha=0.25)

# Vertical gridlines (subtle + dashed)
ax.grid(axis="x", alpha=0.12, linestyle="--")

# Plot RO16 FIRST (for legend order)
line_ro16, = ax.plot(
    ro16_share.index,
    ro16_share.values,
    marker="D",
    markersize=8,
    linewidth=3,
    color=color_ro16,
    label="Round of 16",
    zorder=3
)

line_group, = ax.plot(
    group_share.index,
    group_share.values,
    marker="o",
    markersize=8,
    linewidth=3,
    color=color_group,
    label="Group Stage",
    zorder=3
)

# -------------------------------
# 4. Annotate fractions (closer)
# -------------------------------

for i, season in enumerate(group_share.index):

    # Group stage BELOW
    ax.text(
        season,
        group_share.iloc[i] - 2,
        f"{int(group_top4.iloc[i])}/{int(group_total.iloc[i])}",
        ha="center",
        va="top",
        fontsize=11,
        fontweight="bold",
        color=color_group,
        zorder=4,
        bbox=dict(
            facecolor="white",
            alpha=0.5,
            edgecolor="none",
            boxstyle="round,pad=0.2"
        )
    )

    # RO16 ABOVE
    ax.text(
        season,
        ro16_share.iloc[i] + 1.5,
        f"{int(ro16_top4.iloc[i])}/{int(ro16_total.iloc[i])}",
        ha="center",
        va="bottom",
        fontsize=11,
        fontweight="bold",
        color=color_ro16,
        zorder=4,
        bbox=dict(
            facecolor="white",
            alpha=0.5,
            edgecolor="none",
            boxstyle="round,pad=0.2"
        )
    )

# -------------------------------
# 5. Styling
# -------------------------------

ax.set_ylim(28, 92)

# Bigger axis labels
ax.set_ylabel("Share of Total Teams (%)", fontsize=16)
ax.set_xlabel("Season", fontsize=16)

# Slightly larger title for hierarchy balance
ax.set_title(
    "Top 4 League Share: Group Stage vs Round of 16 (Since 2003/2004)",
    fontsize=20,
    pad=20
)

ax.margins(x=0)

# Bigger tick labels
ax.tick_params(axis="x", labelsize=12)
ax.tick_params(axis="y", labelsize=12)

plt.xticks(rotation=45)

ax.legend(
    handles=[line_ro16, line_group],
    frameon=False,
    fontsize=14,
    loc="upper left"
)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from PIL import Image
import os

clubs = [
    "Real Madrid", "FC Barcelona", "Bayern Munich", "Paris Saint-Germain",
    "Liverpool", "Manchester City", "Arsenal", "Manchester United",
    "Tottenham Hotspur", "Chelsea", "FC Internazionale Milano", "Borussia Dortmund",
    "Atlético de Madrid", "Aston Villa", "AC Milan", "Juventus",
    "Newcastle United", "VFB Stuttgart", "SL Benfica", "West Ham United"
]

revenue = [
    1161, 974.8, 860.6, 837,
    836.1, 829.3, 821.7, 793.1,
    672.6, 584.1, 537.5, 531.3,
    454.5, 450.2, 410.4, 401.7,
    398.4, 296.3, 283.4, 276
]

colors = [
    "#FFFFFF", "#A50044", "#DC052D", "#004170",
    "#E41E26", "#6CAFE8", "#DA0A2A", "#DA0A2A",
    "#132257", "#034694", "#0A1E3A", "#FFCC00",
    "#C60C30", "#95BFE5", "#F20000", "#000000",
    "#241F20", "#E31D29", "#E30613", "#7A263A"
]

countries = [
    "spain","spain","germany","france",
    "england","england","england","england",
    "england","england","italy","germany",
    "spain","england","italy","italy",
    "england","germany","portugal","england"
]

df = pd.DataFrame({
    "Club": clubs,
    "Revenue": revenue,
    "Color": colors,
    "Country": countries
})

df = df.sort_values("Revenue", ascending=True).reset_index(drop=True)
df["Rank"] = range(20, 0, -1)

sns.set_style("white")
fig, ax = plt.subplots(figsize=(12,10))

bars = ax.barh(
    df["Club"],
    df["Revenue"],
    color=df["Color"],
    edgecolor="black",
    alpha=0.8,
    height=0.6
)

# Revenue labels
for bar, value in zip(bars, df["Revenue"]):
    ax.text(
        value + 15,
        bar.get_y() + bar.get_height()/2,
        f"€{value:.0f}m",
        va="center",
        fontsize=17,
        fontweight="bold"
    )

# Ranking numbers
for bar, rank in zip(bars, df["Rank"]):
    ax.text(
        -90,
        bar.get_y() + bar.get_height()/2,
        f"#{rank}",
        va="center",
        fontsize=18,
        fontweight="bold"
    )

# Flags
flag_folder = "Images and others/Flags"

for bar, country in zip(bars, df["Country"]):

    flag_path = os.path.join(flag_folder, f"{country}.png")

    if os.path.exists(flag_path):

        img = Image.open(flag_path).convert("RGBA")
        img = img.resize((30,18), Image.LANCZOS)

        imagebox = OffsetImage(img, zoom=1)

        ab = AnnotationBbox(
            imagebox,
            (-140, bar.get_y() + bar.get_height()/2),
            frameon=True,
            pad=0,
            bboxprops=dict(
                edgecolor="grey",
                linewidth=0.5
            ),
            box_alignment=(0.5,0.5)
        )

        ax.add_artist(ab)

ax.set_title(
    "Top 20 Highest Revenue Football Clubs (2024/25)",
    fontsize=22,
    fontweight="bold",
    pad=20
)

ax.set_xlabel("Revenue (€ million)", fontsize=15, fontweight="bold")
ax.set_ylabel("")

ax.set_xlim(-200,1250)

plt.yticks(fontsize=14, fontweight="bold")
plt.xticks(fontsize=12)

sns.despine(left=True, bottom=True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from matplotlib.patches import Circle
from PIL import Image, ImageDraw
import os

# -----------------------------
# DATA
# -----------------------------

countries = [
"england","germany","spain","italy","france","russia","turkey",
"netherlands","belgium","portugal","scotland","switzerland",
"austria","denmark","greece","sweden","hungary","poland","croatia","norway"
]

num_clubs = [8,8,7,7,8,0,5,5,5,6,5,5,5,4,5,4,4,4,4,4]

average = [51,59,67,50,29,0,13,22,12,28,16,8.5,13,5.3,11,8,4,8.4,10,7.9]

change = [-14,42,22,-15,10,None,6,14,-24,-14,22,-1,2,-74,200,68,35,143,226,-9]

aggregate = [408,476,472,348,228,0,65,112,62,167,81,42,63,21,56,32,16,33,42,32]

df = pd.DataFrame({
    "country": countries,
    "clubs": num_clubs,
    "average": average,
    "change": change,
    "aggregate": aggregate
})

df = df.sort_values("aggregate", ascending=True).reset_index(drop=True)

# -----------------------------
# POSITIONS
# -----------------------------

flag_x = -235
clubs_x = -190
avg_x = -135
chg_x = -80

# -----------------------------
# FUNCTION TO CREATE CIRCULAR FLAG
# -----------------------------

def circular_flag(path, size=40):

    img = Image.open(path).convert("RGBA")
    img = img.resize((size, size), Image.LANCZOS)

    mask = Image.new("L", (size, size), 0)
    draw = ImageDraw.Draw(mask)
    draw.ellipse((0,0,size,size), fill=255)

    img.putalpha(mask)

    return img

# -----------------------------
# PLOT
# -----------------------------

sns.set_style("white")

fig, ax = plt.subplots(figsize=(11,9))

y = np.arange(len(df))

ax.barh(
    y,
    df["aggregate"],
    color="#2A5CAA",
    height=0.55
)

# Aggregate labels
for i,val in enumerate(df["aggregate"]):
    ax.text(val+6,i,str(val),va="center",fontsize=11,fontweight="bold")

# -----------------------------
# TABLE COLUMNS
# -----------------------------

for i in range(len(df)):

    ax.text(clubs_x,i,df["clubs"][i],
            va="center",ha="center",fontsize=11)

    ax.text(avg_x,i,df["average"][i],
            va="center",ha="center",fontsize=11)

    ch=df["change"][i]

    if pd.isna(ch):
        txt="N/A"
        col="grey"
    else:
        txt=f"{ch:+.0f}%"
        col="green" if ch>0 else "red"

    ax.text(chg_x,i,txt,
            va="center",ha="center",
            fontsize=11,color=col,fontweight="bold")

# -----------------------------
# FLAGS
# -----------------------------

flag_folder="Images and others/Flags"

for i,country in enumerate(df["country"]):

    path=os.path.join(flag_folder,f"{country}.png")

    if os.path.exists(path):

        img = circular_flag(path,40)

        imagebox = OffsetImage(img, zoom=0.6)

        ab = AnnotationBbox(
            imagebox,
            (flag_x,i),
            frameon=False
        )

        ax.add_artist(ab)

        # grey circular border
        border = Circle(
            (flag_x,i),
            0.28,
            transform=ax.transData,
            fill=False,
            edgecolor="grey",
            linewidth=0.8
        )

        ax.add_patch(border)

# -----------------------------
# HEADERS
# -----------------------------

header_y=len(df)-0.1

ax.text(clubs_x,header_y,"Number\nof clubs",
        fontsize=11,fontweight="bold",ha="center")

ax.text(avg_x,header_y,"Average",
        fontsize=11,fontweight="bold",ha="center")

ax.text(chg_x,header_y,"Change\nfrom 2023",
        fontsize=11,fontweight="bold",ha="center")

ax.text(0,header_y,"Aggregate",
        fontsize=11,fontweight="bold")

# -----------------------------
# TITLE
# -----------------------------

ax.set_title(
"Top-division clubs' UEFA revenue in 2024 (€m)",
fontsize=18,
fontweight="bold",
loc="left",
pad=25
)

# -----------------------------
# STYLE
# -----------------------------

ax.set_xlim(-260,520)

ax.set_yticks([])
ax.set_xlabel("")

ax.axvline(0,color="lightgrey",lw=1)

sns.despine(left=True,bottom=True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from matplotlib.patches import Circle
from PIL import Image, ImageDraw
import os

# -----------------------------
# DATA
# -----------------------------

countries = [
"england","germany","spain","italy","france","russia","turkey",
"netherlands","belgium","portugal","scotland","switzerland",
"austria","denmark","greece","sweden","hungary","poland","croatia","norway"
]

num_clubs = [8,8,7,7,8,0,5,5,5,6,5,5,5,4,5,4,4,4,4,4]

average = [51,59,67,50,29,0,13,22,12,28,16,8.5,13,5.3,11,8,4,8.4,10,7.9]

change = [-14,42,22,-15,10,None,6,14,-24,-14,22,-1,2,-74,200,68,35,143,226,-9]

aggregate = [408,476,472,348,228,0,65,112,62,167,81,42,63,21,56,32,16,33,42,32]

df = pd.DataFrame({
    "country": countries,
    "clubs": num_clubs,
    "average": average,
    "change": change,
    "aggregate": aggregate
})

df = df.sort_values("aggregate", ascending=True).reset_index(drop=True)

# -----------------------------
# COLUMN POSITIONS
# -----------------------------

clubs_x = -200
avg_x = -150
flag_x = -105
chg_x = -60

# -----------------------------
# FUNCTION TO CREATE CIRCULAR FLAG
# -----------------------------

def circular_flag(path, size=32):

    img = Image.open(path).convert("RGBA")
    img = img.resize((size, size), Image.LANCZOS)

    mask = Image.new("L", (size, size), 0)
    draw = ImageDraw.Draw(mask)
    draw.ellipse((0,0,size,size), fill=255)

    img.putalpha(mask)

    return img

# -----------------------------
# PLOT
# -----------------------------

sns.set_style("white")

fig, ax = plt.subplots(figsize=(11,9))

y = np.arange(len(df))

ax.barh(
    y,
    df["aggregate"],
    color="#2A5CAA",
    height=0.55
)

# Aggregate labels
for i,val in enumerate(df["aggregate"]):
    ax.text(val+6,i,str(val),va="center",fontsize=13,fontweight="bold")

# -----------------------------
# TABLE VALUES
# -----------------------------

for i in range(len(df)):

    ax.text(clubs_x,i,df["clubs"][i],
            va="center",ha="center",fontsize=13)

    ax.text(avg_x,i,df["average"][i],
            va="center",ha="center",fontsize=13)

    ch=df["change"][i]

    if pd.isna(ch):
        txt="N/A"
        col="grey"
    else:
        txt=f"{ch:+.0f}%"
        col="green" if ch>0 else "red"

    ax.text(chg_x,i,txt,
            va="center",ha="center",
            fontsize=13,color=col,fontweight="bold")

# -----------------------------
# FLAGS
# -----------------------------

flag_folder="Images and others/Flags"

for i,country in enumerate(df["country"]):

    path=os.path.join(flag_folder,f"{country}.png")

    if os.path.exists(path):

        img = circular_flag(path,32)

        imagebox = OffsetImage(img, zoom=0.55)

        ab = AnnotationBbox(
            imagebox,
            (flag_x,i),
            frameon=False
        )

        ax.add_artist(ab)

        # border
        border = Circle(
            (flag_x,i),
            0.23,
            transform=ax.transData,
            fill=False,
            edgecolor="grey",
            linewidth=0.8
        )

        ax.add_patch(border)

# -----------------------------
# HEADERS
# -----------------------------

header_y=len(df)-0.1

ax.text(clubs_x,header_y,"Number\nof clubs",
        fontsize=12,fontweight="bold",ha="center")

ax.text(avg_x,header_y,"Average",
        fontsize=12,fontweight="bold",ha="center")

ax.text(flag_x,header_y,"",
        fontsize=12,fontweight="bold",ha="center")

ax.text(chg_x,header_y,"Change\nfrom 2023",
        fontsize=12,fontweight="bold",ha="center")

ax.text(0,header_y,"Aggregate",
        fontsize=12,fontweight="bold")

# -----------------------------
# TITLE
# -----------------------------

ax.set_title(
"Top-division clubs' UEFA revenue in 2024 (€m)",
fontsize=20,
fontweight="bold",
loc="left",
pad=25
)

# -----------------------------
# STYLE
# -----------------------------

ax.set_xlim(-240,520)

ax.set_yticks([])
ax.set_xlabel("")

ax.axvline(0,color="lightgrey",lw=1)

sns.despine(left=True,bottom=True)

plt.tight_layout()
plt.show()
