# %% [markdown]
# ## Packages and configuration

# %%
from statsbombpy import sb
import pandas as pd
from mplsoccer import VerticalPitch,Pitch
from highlight_text import ax_text, fig_text
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import seaborn as sns
import pprint
import numpy as np

# %% [markdown]
# ## Load Competiton, Match, and Event Data from statsbombpy

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Call statsbombpy API to get all free competitions, then chec Women's comps
free_comps = sb.competitions()
women_comps = free_comps[free_comps['competition_gender'] == 'female']
women_comps
# Out:
#     competition_id  season_id              country_name  \
# 25              37         90                   England
# 26              37         42                   England
# 27              37          4                   England
# 63              49          3  United States of America
# 71              53        315                    Europe
# 72              53        106                    Europe
# 73              72        107             International
# 74              72         30             International
#
#            competition_name competition_gender  competition_youth  \
# 25  FA Women's Super League             female              False
# 26  FA Women's Super League             female              False
# 27  FA Women's Super League             female              False
# 63                     NWSL             female              False
# 71        UEFA Women's Euro             female              False
# 72        UEFA Women's Euro             female              False
# 73        Women's World Cup             female              False
# 74        Women's World Cup             female              False
#
#     competition_international season_name               match_updated  \
# 25                      False   2020/2021  2025-04-23T14:16:46.924831
# 26                      False   2019/2020  2024-02-12T15:05:34.211400
# 27                      False   2018/2019  2024-08-07T17:22:40.334287
# 63                      False        2018  2024-12-15T12:31:48.035735
# 71                       True        2025  2025-07-28T14:19:20.467348
# 72                       True        2022  2024-02-13T13:27:17.178263
# 73                       True        2023  2025-07-14T10:07:06.620906
# 74                       True        2019  2024-08-08T15:57:56.748740
#
#              match_updated_360         match_available_360  \
# 25     2021-06-13T16:17:31.694                        None
# 26     2021-06-13T16:17:31.694                        None
# 27     2021-06-13T16:17:31.694                        None
# 63     2021-06-13T16:17:31.694                        None
# 71  2025-07-29T16:03:07.355174  2025-07-29T16:03:07.355174
# 72  2024-02-13T13:30:52.820588  2024-02-13T13:30:52.820588
# 73  2025-07-14T10:10:27.224586  2025-07-14T10:10:27.224586
# 74     2021-06-13T16:17:31.694                        None
#
#                match_available
# 25  2025-04-23T14:16:46.924831
# 26  2024-02-12T15:05:34.211400
# 27  2024-08-07T17:22:40.334287
# 63  2024-12-15T12:31:48.035735
# 71  2025-07-28T14:19:20.467348
# 72  2024-02-13T13:27:17.178263
# 73  2025-07-14T10:07:06.620906
# 74  2024-08-08T15:57:56.748740

# %% [markdown]
# ## All women's matches

# %%
all_matches = []

for _, row in women_comps.iterrows():
    matches = sb.matches(
        competition_id=row["competition_id"],
        season_id=row["season_id"]
    )
    all_matches.append(matches)

matches_df = pd.concat(all_matches, ignore_index=True)

# %%
len(matches_df)
# Out:
# 540

# %% [markdown]
# ## All events, passes only

# %%
from pathlib import Path
import pandas as pd

CACHE_DIR = Path("statsbomb_cache/events")
CACHE_DIR.mkdir(parents=True, exist_ok=True)


def load_events(match_id):
    cache_file = CACHE_DIR / f"{match_id}.parquet"

    if cache_file.exists():
        return pd.read_parquet(cache_file)

    events = sb.events(match_id=match_id)
    events.to_parquet(cache_file)
    return events

# %%
all_passes = []

for match_id in matches_df["match_id"]:
    events = load_events(match_id)
    passes = events[events["type"] == "Pass"]
    all_passes.append(passes)

passes_df = pd.concat(all_passes, ignore_index=True)

# %%
len(passes_df)
# Out:
# 496100

# %%
passes_df.head(2)
# Out:
#   50_50 ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0  None                 None                           None             None
# 1  None                 None                           None             None
#
#   block_offensive carry_end_location clearance_aerial_won clearance_body_part  \
# 0            None               None                 None                None
# 1            None               None                 None                None
#
#   clearance_head clearance_left_foot clearance_right_foot counterpress  \
# 0           None                None                 None         None
# 1           None                None                 None         None
#
#   dribble_nutmeg dribble_outcome duel_outcome duel_type  duration  \
# 0           None            None         None      None  0.311672
# 1           None            None         None      None  1.125058
#
#   foul_committed_advantage foul_committed_card foul_committed_type  \
# 0                     None                None                None
# 1                     None                None                None
#
#   foul_won_advantage foul_won_defensive goalkeeper_body_part  \
# 0               None               None                 None
# 1               None               None                 None
#
#   goalkeeper_end_location goalkeeper_outcome goalkeeper_position  \
# 0                    None               None                None
# 1                    None               None                None
#
#   goalkeeper_punched_out goalkeeper_technique goalkeeper_type  \
# 0                   None                 None            None
# 1                   None                 None            None
#
#                                      id  index interception_outcome  \
# 0  4c33f2eb-7392-419d-b6ac-bedaa573ddc6      5                 None
# 1  4467e274-205f-41be-ab7e-62ece2697dbc      8                 None
#
#        location  match_id  minute off_camera   out pass_aerial_won  \
# 0  [61.0, 40.1]   3775648       0       None  None            None
# 1  [59.3, 40.8]   3775648       0       None  None            None
#
#    pass_angle pass_assisted_shot_id pass_body_part pass_cross pass_cut_back  \
# 0    1.144169                  None     Right Foot       None          None
# 1   -3.089616                  None     Right Foot       None          None
#
#   pass_deflected pass_end_location pass_goal_assist  pass_height  \
# 0           None      [62.0, 42.3]             None  Ground Pass
# 1           None      [42.0, 39.9]             None  Ground Pass
#
#   pass_inswinging  pass_length pass_miscommunication pass_no_touch  \
# 0            None     2.416609                  None          None
# 1            None    17.323395                  None          None
#
#   pass_outcome pass_outswinging pass_recipient  pass_recipient_id  \
# 0         None             None   Bethany Mead            15619.0
# 1         None             None      Lia Wälti            10405.0
#
#   pass_shot_assist pass_straight pass_switch pass_technique pass_through_ball  \
# 0             None          None        None           None              None
# 1             None          None        None           None              None
#
#   pass_type  period   play_pattern            player  player_id  \
# 0  Kick Off       1  From Kick Off  Vivianne Miedema    15623.0
# 1      None       1  From Kick Off      Bethany Mead    15619.0
#
#          position  possession possession_team  possession_team_id  \
# 0       Left Wing           2     Arsenal WFC                 968
# 1  Center Forward           2     Arsenal WFC                 968
#
#                            related_events  second shot_aerial_won  \
# 0  [a2016066-fbb9-4d5a-8f6b-2f9d7411a4dd]       0            None
# 1  [0e9e4a0c-46ea-4aea-9c62-b4883bf1d993]       0            None
#
#   shot_body_part shot_end_location shot_first_time shot_freeze_frame  \
# 0           None              None            None              None
# 1           None              None            None              None
#
#   shot_key_pass_id shot_one_on_one shot_open_goal shot_outcome  \
# 0             None            None           None         None
# 1             None            None           None         None
#
#    shot_statsbomb_xg shot_technique shot_type substitution_outcome  \
# 0                NaN           None      None                 None
# 1                NaN           None      None                 None
#
#    substitution_outcome_id substitution_replacement  \
# 0                      NaN                     None
# 1                      NaN                     None
#
#    substitution_replacement_id tactics         team  team_id     timestamp  \
# 0                          NaN    None  Arsenal WFC      968  00:00:00.340
# 1                          NaN    None  Arsenal WFC      968  00:00:00.692
#
#    type under_pressure dribble_overrun injury_stoppage_in_chain  \
# 0  Pass           None             NaN                      NaN
# 1  Pass           None             NaN                      NaN
#
#   clearance_other goalkeeper_shot_saved_off_target shot_deflected  \
# 0             NaN                              NaN            NaN
# 1             NaN                              NaN            NaN
#
#   shot_saved_off_target foul_committed_offensive foul_committed_penalty  \
# 0                   NaN                      NaN                    NaN
# 1                   NaN                      NaN                    NaN
#
#   foul_won_penalty miscontrol_aerial_won shot_redirect  \
# 0              NaN                   NaN           NaN
# 1              NaN                   NaN           NaN
#
#   ball_recovery_offensive block_save_block goalkeeper_success_in_play  \
# 0                     NaN              NaN                        NaN
# 1                     NaN              NaN                        NaN
#
#   bad_behaviour_card dribble_no_touch shot_follows_dribble  \
# 0                NaN              NaN                  NaN
# 1                NaN              NaN                  NaN
#
#   goalkeeper_saved_to_post half_start_late_video_start  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
#
#   goalkeeper_shot_saved_to_post shot_saved_to_post goalkeeper_lost_out  \
# 0                           NaN                NaN                 NaN
# 1                           NaN                NaN                 NaN
#
#   goalkeeper_lost_in_play half_end_early_video_end pass_backheel  \
# 0                     NaN                      NaN           NaN
# 1                     NaN                      NaN           NaN
#
#   player_off_permanent goalkeeper_success_out  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
#
#   goalkeeper_penalty_saved_to_post shot_kick_off
# 0                              NaN           NaN
# 1                              NaN           NaN

# %%
passes_df["play_pattern"].unique()
# Out:
# array(['From Kick Off', 'Regular Play', 'From Keeper', 'From Free Kick',
#        'From Throw In', 'From Corner', 'From Counter', 'From Goal Kick',
#        'Other'], dtype=object)

# %% [markdown]
# ## Check pass positions

# %%
df = passes_df.copy()

PITCH_LENGTH = 120
PITCH_WIDTH = 80

# Extract coordinates
df["start_x"] = df["location"].str[0]
df["start_y"] = df["location"].str[1]
df["end_x"] = df["pass_end_location"].str[0]
df["end_y"] = df["pass_end_location"].str[1]

# Start location checks
start_outside = df[
    (df["start_x"] < 0) | (df["start_x"] > PITCH_LENGTH) |
    (df["start_y"] < 0) | (df["start_y"] > PITCH_WIDTH)
]

# End (reception) location checks
end_outside = df[
    (df["end_x"] < 0) | (df["end_x"] > PITCH_LENGTH) |
    (df["end_y"] < 0) | (df["end_y"] > PITCH_WIDTH)
]

print(f"Start locations outside pitch: {len(start_outside)}")
print(f"End locations outside pitch: {len(end_outside)}")
# Out:
# Start locations outside pitch: 10
# End locations outside pitch: 41

# %%
start_outside[[
    "start_x",
    "start_y",
    "team",
    "player",
    "play_pattern",
    "pass_type",
    "pass_outcome"
]].sort_values(["start_x", "start_y"])
# Out:
#         start_x  start_y                        team                   player  \
# 153125     21.8     80.2  Brighton & Hove Albion WFC  Matilde Lundorf Skovsen
# 177719     30.4     80.2            Bristol City WFC              Loren Dykes
# 175716     44.6     80.1               Liverpool WFC           Melissa Lawley
# 171959     50.4     80.2         West Ham United LFC           Kate Longhurst
# 175906     54.9     80.1               Liverpool WFC             Rebecca Jane
# 175754     58.6     80.2               Liverpool WFC             Rebecca Jane
# 175905     60.0     80.1               Liverpool WFC      Jessica Anne Clarke
# 175931     71.7     80.2               Liverpool WFC             Rebecca Jane
# 175686     74.5     80.2               Liverpool WFC             Rebecca Jane
# 171517    120.4     27.5         West Ham United LFC           Kate Longhurst
#
#           play_pattern pass_type pass_outcome
# 153125   From Throw In      None         None
# 177719   From Throw In      None         None
# 175716   From Throw In      None   Incomplete
# 171959    Regular Play      None         None
# 175906  From Goal Kick      None   Incomplete
# 175754   From Throw In      None         None
# 175905  From Goal Kick      None         None
# 175931   From Throw In      None         None
# 175686   From Throw In      None         None
# 171517   From Throw In      None          Out

# %%
end_outside[[
    "end_x",
    "end_y",
    "team",
    "player",
    "play_pattern",
    "pass_type",
    "pass_outcome"
]].sort_values(["end_x", "end_y"])
# Out:
#         end_x  end_y                        team  \
# 171483   10.1   80.9         West Ham United LFC
# 172280   11.8   80.9                 Arsenal WFC
# 177871   47.0   80.9            Bristol City WFC
# 171958   50.4   80.2         West Ham United LFC
# 175871   50.4   80.9               Liverpool WFC
# 175905   55.2   80.1               Liverpool WFC
# 176099   58.6   80.9               Liverpool WFC
# 175385   66.0   80.9     Tottenham Hotspur Women
# 177824   70.8   80.9            Bristol City WFC
# 171764   73.3   80.9         West Ham United LFC
# 172314   75.5   80.1                 Arsenal WFC
# 175469   80.8   80.9     Tottenham Hotspur Women
# 175356   84.5   80.9     Tottenham Hotspur Women
# 175733   84.9   80.9               Liverpool WFC
# 153261   86.6   80.9                 Chelsea FCW
# 152926   94.4   80.9  Brighton & Hove Albion WFC
# 153312   95.3   80.9                 Chelsea FCW
# 175251   96.1   80.9     Tottenham Hotspur Women
# 172062   96.5   80.2                 Arsenal WFC
# 175793  100.4   80.8               Liverpool WFC
# 153534  100.5   80.9                 Chelsea FCW
# 153621  100.6   80.9                 Chelsea FCW
# 153505  116.2   80.9                 Chelsea FCW
# 177907  120.9   12.4            Bristol City WFC
# 153573  120.9   14.6                 Chelsea FCW
# 153374  120.9   26.5                 Chelsea FCW
# 153564  120.9   31.1                 Chelsea FCW
# 171517  120.9   32.9         West Ham United LFC
# 177254  120.9   49.6                 Everton LFC
# 153294  120.9   53.2                 Chelsea FCW
# 172386  120.9   57.1                 Arsenal WFC
# 175981  120.9   57.4               Liverpool WFC
# 172151  120.9   58.2                 Arsenal WFC
# 172034  120.9   59.5                 Arsenal WFC
# 172231  120.9   59.9                 Arsenal WFC
# 175281  120.9   60.2     Tottenham Hotspur Women
# 175360  120.9   61.1     Tottenham Hotspur Women
# 177883  120.9   61.7            Bristol City WFC
# 153557  120.9   64.3                 Chelsea FCW
# 177614  120.9   68.9            Bristol City WFC
# 177197  120.9   72.7                 Everton LFC
#
#                                 player    play_pattern  pass_type  \
# 171483                Laura Vetterlein   From Throw In       None
# 172280                 Leah Williamson  From Free Kick       None
# 177871                    Yana Daniëls    Regular Play       None
# 171958  Gilly Louise Scarlett Flaherty    Regular Play       None
# 175871                 Leigh-Anne Robe  From Free Kick       None
# 175905             Jessica Anne Clarke  From Goal Kick       None
# 176099                    Rebecca Jane    Regular Play   Recovery
# 175385                  Hannah Godfrey    Regular Play       None
# 177824                 Sophie Baggaley     From Keeper       None
# 171764                      Kenza Dali    Regular Play       None
# 172314                      Kim Little    Regular Play       None
# 175469                    Chloe Peplow    Regular Play       None
# 175356                    Chloe Peplow  From Free Kick       None
# 175733                     Jade Bailey    Regular Play       None
# 153261             Sophie Louise Ingle  From Goal Kick       None
# 152926                  Megan Connolly   From Throw In       None
# 153312                       So-Yun Ji   From Throw In       None
# 175251                Ashleigh Neville  From Goal Kick   Recovery
# 172062                      Jill Roord   From Throw In       None
# 175793                     Jade Bailey  From Goal Kick       None
# 153534                       So-Yun Ji   From Throw In       None
# 153621        Magdalena Lilly Eriksson   From Throw In       None
# 153505   Jonna Ann-Charlotte Andersson    Regular Play       None
# 177907                Jasmine Matthews  From Goal Kick       None
# 153573                   Erin Cuthbert    Regular Play       None
# 153374             Maren Nævdal Mjelde  From Goal Kick       None
# 153564                 Ramona Bachmann    Regular Play       None
# 171517                  Kate Longhurst   From Throw In       None
# 177254                     Chloe Kelly     From Corner     Corner
# 153294                     Guro Reiten  From Free Kick  Free Kick
# 172386                    Jordan Nobbs   From Throw In       None
# 175981                   Ashley Hodson   From Throw In       None
# 172151                    Katie McCabe  From Free Kick       None
# 172034                      Kim Little    Regular Play       None
# 172231                 Leah Williamson           Other       None
# 175281                  Rachel Furness  From Goal Kick       None
# 175360                Ashleigh Neville   From Throw In   Throw-in
# 177883                Jasmine Matthews   From Throw In       None
# 153557                 Ramona Bachmann   From Throw In       None
# 177614                Meaghan Sargeant    Regular Play       None
# 177197                Esme Beth Morgan    Regular Play       None
#
#             pass_outcome
# 171483               Out
# 172280               Out
# 177871               Out
# 171958              None
# 175871               Out
# 175905              None
# 176099               Out
# 175385               Out
# 177824  Injury Clearance
# 171764               Out
# 172314              None
# 175469               Out
# 175356               Out
# 175733               Out
# 153261               Out
# 152926               Out
# 153312               Out
# 175251               Out
# 172062              None
# 175793               Out
# 153534               Out
# 153621               Out
# 153505               Out
# 177907               Out
# 153573               Out
# 153374               Out
# 153564               Out
# 171517               Out
# 177254               Out
# 153294               Out
# 172386               Out
# 175981               Out
# 172151               Out
# 172034               Out
# 172231               Out
# 175281               Out
# 175360               Out
# 177883               Out
# 153557               Out
# 177614               Out
# 177197               Out

# %% [markdown]
# ### Pass start position

# %%
df["completed"] = df["pass_outcome"].isna().astype(int)

# %%
# Filter out passes that are Injury Clearance first
df = df[df["pass_outcome"].ne("Injury Clearance")]

# Define pitch bins (10-yard grid)
x_bins = np.linspace(0, 120, 13)
y_bins = np.linspace(0, 80, 9)

df["x_zone"] = pd.cut(df["start_x"], bins=x_bins, labels=False)
df["y_zone"] = pd.cut(df["start_y"], bins=y_bins, labels=False)

# %%
zone_stats = (
    df
    .groupby(["x_zone", "y_zone"])
    .agg(
        passes=("completed", "count"),
        completion_rate=("completed", "mean")
    )
    .reset_index()
)

# %%
zone_stats = zone_stats[zone_stats["passes"] >= 20]

# %%
completion_grid = zone_stats.pivot(
    index="y_zone",
    columns="x_zone",
    values="completion_rate"
)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))

# Pitch outline
ax.plot([0, 120, 120, 0, 0], [0, 0, 80, 80, 0], color="black")
ax.plot([60, 60], [0, 80], color="black")

# Penalty areas
ax.plot([102, 120], [18, 18], color="black")
ax.plot([102, 102], [18, 62], color="black")
ax.plot([102, 120], [62, 62], color="black")

ax.plot([0, 18], [18, 18], color="black")
ax.plot([18, 18], [18, 62], color="black")
ax.plot([0, 18], [62, 62], color="black")

# Heatmap of completion rate
im = ax.imshow(
    completion_grid.values,
    extent=[0, 120, 0, 80],
    origin="lower",
    cmap="RdYlGn",
    alpha=0.85
)

# Colorbar
cbar = plt.colorbar(im, ax=ax)
cbar.set_label("Pass Completion Rate")

# Formatting
ax.set_title("Empirical Pass Completion Rate by Pitch Location - Pass Start Position")
ax.set_xticks([])
ax.set_yticks([])
ax.set_aspect("equal")

plt.savefig("heatmap_start.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ### Pass reception position

# %%
# Filter out passes that are Injury Clearance first
df = df[df["pass_outcome"].ne("Injury Clearance")]

# Define pitch bins (10-yard grid)
x_bins = np.linspace(0, 120, 13)
y_bins = np.linspace(0, 80, 9)

df["x_zone"] = pd.cut(df["end_x"], bins=x_bins, labels=False)
df["y_zone"] = pd.cut(df["end_y"], bins=y_bins, labels=False)

# %%
zone_stats = (
    df
    .groupby(["x_zone", "y_zone"])
    .agg(
        passes=("completed", "count"),
        completion_rate=("completed", "mean")
    )
    .reset_index()
)

# %%
zone_stats = zone_stats[zone_stats["passes"] >= 20]

# %%
completion_grid = zone_stats.pivot(
    index="y_zone",
    columns="x_zone",
    values="completion_rate"
)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))

# Pitch outline
ax.plot([0, 120, 120, 0, 0], [0, 0, 80, 80, 0], color="black")
ax.plot([60, 60], [0, 80], color="black")

# Penalty areas
ax.plot([102, 120], [18, 18], color="black")
ax.plot([102, 102], [18, 62], color="black")
ax.plot([102, 120], [62, 62], color="black")

ax.plot([0, 18], [18, 18], color="black")
ax.plot([18, 18], [18, 62], color="black")
ax.plot([0, 18], [62, 62], color="black")

# Heatmap of completion rate
im = ax.imshow(
    completion_grid.values,
    extent=[0, 120, 0, 80],
    origin="lower",
    cmap="RdYlGn",
    alpha=0.85
)

# Colorbar
cbar = plt.colorbar(im, ax=ax)
cbar.set_label("Pass Completion Rate")

# Formatting
ax.set_title("Empirical Pass Completion Rate by Pitch Location - Pass End Position")
ax.set_xticks([])
ax.set_yticks([])
ax.set_aspect("equal")

plt.savefig("heatmap_end.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Feature engineering

# %% [raw]
# df = passes_df.copy()
#
# # -------------------------------
# # Pitch dimensions
# # -------------------------------
# PITCH_LENGTH = 120  # StatsBomb fixed pitch length
# PITCH_WIDTH = 80    # StatsBomb fixed pitch width
# GOAL_X = PITCH_LENGTH
# GOAL_Y = PITCH_WIDTH / 2
#
# # -------------------------------
# # Extract start / end locations
# # -------------------------------
# df["start_x"] = df["location"].str[0]
# df["start_y"] = df["location"].str[1]
# df["end_x"] = df["pass_end_location"].str[0]
# df["end_y"] = df["pass_end_location"].str[1]
#
# # -------------------------------
# # Remove Injury Clearance passes
# # -------------------------------
# df = df[df["pass_outcome"].ne("Injury Clearance")].copy()
#
# # -------------------------------
# # Define pitch bins (10-yard grid)
# # -------------------------------
# x_bins = np.linspace(0, PITCH_LENGTH, 13)  # 12 vertical zones
# y_bins = np.linspace(0, PITCH_WIDTH, 9)    # 8 horizontal zones
#
# df["start_x_zone"] = pd.cut(df["start_x"], bins=x_bins, labels=False)
# df["start_y_zone"] = pd.cut(df["start_y"], bins=y_bins, labels=False)
# df["end_x_zone"] = pd.cut(df["end_x"], bins=x_bins, labels=False)
# df["end_y_zone"] = pd.cut(df["end_y"], bins=y_bins, labels=False)
#
# # -------------------------------
# # Combine x/y zones into single square for start location
# # -------------------------------
# # df["start_square"] = df["start_x_zone"].astype(str) + "_" + df["start_y_zone"].astype(str)
# # When creating start_square in feature function, always use int format
# df["start_square"] = df["start_x_zone"].astype(int).astype(str) + "_" + df["start_y_zone"].astype(int).astype(str)
#
#
# # One-hot encode start squares
# start_square_dummies = pd.get_dummies(df["start_square"], prefix="sq")
# df = pd.concat([df, start_square_dummies], axis=1)
#
# # -------------------------------
# # Straight-line pass distance
# # -------------------------------
# df["pass_distance"] = np.sqrt(
#     (df["end_x"] - df["start_x"])**2 +
#     (df["end_y"] - df["start_y"])**2
# )
#
# # Distance from ball to opponent goal
# df["start_dist_goal"] = np.sqrt(
#     (GOAL_X - df["start_x"])**2 +
#     (GOAL_Y - df["start_y"])**2
# )
# df["end_dist_goal"] = np.sqrt(
#     (GOAL_X - df["end_x"])**2 +
#     (GOAL_Y - df["end_y"])**2
# )
#
# # -------------------------------
# # How much closer the pass moves the ball towards goal
# # -------------------------------
# df["progression"] = df["start_dist_goal"] - df["end_dist_goal"]
#
# # Progressive pass (>10 yards closer to goal)
# df["progressive"] = (df["progression"] > 10).astype(int)
#
# # -------------------------------
# # Combined difficulty features
# # -------------------------------
#
# # Progressive passes in opposition half (start zone)
# df["progressive_opp_half"] = df["progressive"] * (df["start_x_zone"] >= 6).astype(int)
#
# # Central progressive passes (start zone)
# df["central_progressive"] = df["progressive"] * (
#     (df["start_y_zone"] >= 3) & (df["start_y_zone"] <= 5)
# ).astype(int)
#
# # Crosses under pressure
# df["under_pressure"] = df["under_pressure"].fillna(False).astype(int)
# df["cross"] = df["pass_cross"].fillna(False).astype(int)
# df["cross_under_pressure"] = df["cross"] * df["under_pressure"]
#
# # Long passes under pressure
# df["long_pass"] = (df["pass_distance"] > 25).astype(int)
# df["very_long_pass"] = (df["pass_distance"] > 40).astype(int)
# df["long_under_pressure"] = df["long_pass"] * df["under_pressure"]
#
# # High balls / through balls / switches
# df["high_pass"] = (df["pass_height"] == "High Pass").astype(int)
# df["through_ball"] = df["pass_through_ball"].fillna(False).astype(int)
# df["switch"] = df["pass_switch"].fillna(False).astype(int)
#
# # -------------------------------
# # Play pattern one-hot encoding
# # -------------------------------
# play_pattern_dummies = pd.get_dummies(
#     df["play_pattern"],
#     prefix="pp",
#     drop_first=True  # Regular Play as baseline
# )
# df = pd.concat([df, play_pattern_dummies], axis=1)
#
# # -------------------------------
# # Completed pass flag
# # -------------------------------
# df["completed"] = df["pass_outcome"].isna().astype(int)
#
# # -------------------------------
# # Final feature list for xP model
# # -------------------------------
# FEATURES = [
#     "pass_distance",
#     "progression",
#     "start_dist_goal",
#     "under_pressure",
#     "high_pass",
#     "through_ball",
#     "cross",
#     "switch",
#     "long_under_pressure",
#     "very_long_pass",
#     "progressive_opp_half",
#     "cross_under_pressure",
#     "central_progressive",
# ]
#
# # Add play pattern one-hot features
# FEATURES += list(play_pattern_dummies.columns)
#
# # Add start square one-hot features
# FEATURES += list(start_square_dummies.columns)
#
# # -------------------------------
# # Model inputs
# # -------------------------------
# X = df[FEATURES]
# y = df["completed"]

# %%
def prepare_pass_features(df_passes):
    df = df_passes.copy()

    # Metadata kept for later aggregation (not used in model)
    META_COLS = ["match_id", "team", "player"]

    # Pitch constants
    PITCH_LENGTH = 120
    PITCH_WIDTH = 80
    GOAL_X = PITCH_LENGTH
    GOAL_Y = PITCH_WIDTH / 2

    # Start / end locations
    df["start_x"] = df["location"].str[0]
    df["start_y"] = df["location"].str[1]
    df["end_x"] = df["pass_end_location"].str[0]
    df["end_y"] = df["pass_end_location"].str[1]

    # Remove non-football actions
    df = df[df["pass_outcome"].ne("Injury Clearance")].copy()

    # Spatial bins (10-yard grid)
    x_bins = np.linspace(0, PITCH_LENGTH, 13)
    y_bins = np.linspace(0, PITCH_WIDTH, 9)

    df["start_x_zone"] = pd.cut(
        df["start_x"], bins=x_bins, labels=False, include_lowest=True
    )
    df["start_y_zone"] = pd.cut(
        df["start_y"], bins=y_bins, labels=False, include_lowest=True
    )

    # Drop passes without valid spatial info
    df = df.dropna(subset=["start_x_zone", "start_y_zone"]).copy()

    df["start_x_zone"] = df["start_x_zone"].clip(0, 11).astype("int8")
    df["start_y_zone"] = df["start_y_zone"].clip(0, 7).astype("int8")

    # Start square encoding
    df["start_square"] = (
        df["start_x_zone"].astype(str) + "_" +
        df["start_y_zone"].astype(str)
    )

    all_squares = [f"{i}_{j}" for i in range(12) for j in range(8)]
    start_square_dummies = (
        pd.get_dummies(df["start_square"], prefix="sq")
        .reindex(columns=[f"sq_{s}" for s in all_squares], fill_value=0)
    )

    df = pd.concat([df, start_square_dummies], axis=1)

    # Distances and progression
    df["pass_distance"] = np.hypot(
        df["end_x"] - df["start_x"],
        df["end_y"] - df["start_y"]
    )

    df["start_dist_goal"] = np.hypot(
        GOAL_X - df["start_x"],
        GOAL_Y - df["start_y"]
    )
    df["end_dist_goal"] = np.hypot(
        GOAL_X - df["end_x"],
        GOAL_Y - df["end_y"]
    )

    df["progression"] = df["start_dist_goal"] - df["end_dist_goal"]
    df["progressive"] = (df["progression"] > 10).astype("int8")

    df["progressive_opp_half"] = (
        df["progressive"] * (df["start_x_zone"] >= 6)
    ).astype("int8")

    df["central_progressive"] = (
        df["progressive"] * df["start_y_zone"].between(3, 5)
    ).astype("int8")

    # Pass context flags
    df["under_pressure"] = df["under_pressure"].eq(True).astype("int8")
    df["cross"] = df["pass_cross"].eq(True).astype("int8")
    df["through_ball"] = df["pass_through_ball"].eq(True).astype("int8")
    df["switch"] = df["pass_switch"].eq(True).astype("int8")

    df["cross_under_pressure"] = (
        df["cross"] * df["under_pressure"]
    ).astype("int8")

    df["long_pass"] = (df["pass_distance"] > 25).astype("int8")
    df["very_long_pass"] = (df["pass_distance"] > 40).astype("int8")

    df["long_under_pressure"] = (
        df["long_pass"] * df["under_pressure"]
    ).astype("int8")

    df["high_pass"] = (
        df["pass_height"] == "High Pass"
    ).astype("int8")

    # Play pattern encoding
    play_pattern_dummies = pd.get_dummies(
        df["play_pattern"], prefix="pp", drop_first=True
    )
    df = pd.concat([df, play_pattern_dummies], axis=1)

    # Target variable
    df["completed"] = df["pass_outcome"].isna().astype("int8")

    # Feature list for xP model
    FEATURES = [
        "pass_distance",
        "progression",
        "start_dist_goal",
        "under_pressure",
        "high_pass",
        "through_ball",
        "cross",
        "switch",
        "long_under_pressure",
        "very_long_pass",
        "progressive_opp_half",
        "cross_under_pressure",
        "central_progressive",
    ]

    FEATURES += list(play_pattern_dummies.columns)
    FEATURES += list(start_square_dummies.columns)

    X = df[FEATURES]
    y = df["completed"]
    
    # Keep only metadata columns that actually exist
    META_COLS = [c for c in META_COLS if c in df.columns]
    meta = df[META_COLS].copy()
    
    return df, X, y, FEATURES, meta

# %%
df, X, y, FEATURES, meta = prepare_pass_features(passes_df)

# %%
meta.columns
# Out:
# Index(['match_id', 'team', 'player'], dtype='object')

# %% [markdown]
# ## Train global xP model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
import pandas as pd
import numpy as np

# --------------------------------------------------
# Fit expected pass completion (xP) model
# --------------------------------------------------

# Simple logistic regression is enough here.
# The goal is interpretability, not squeezing every last % of performance.
model = LogisticRegression(max_iter=1000)

model.fit(X, y)

# --------------------------------------------------
# Check coefficients to see if they make football sense
# --------------------------------------------------

coef_table = pd.DataFrame({
    "feature": FEATURES,
    "coef": model.coef_[0]
}).sort_values("coef")

coef_table
# Out:
#              feature      coef
# 28            sq_0_7 -1.352997
# 22            sq_0_1 -1.243274
# 27            sq_0_6 -1.229401
# 4          high_pass -1.187940
# 21            sq_0_0 -1.184283
# ..               ...       ...
# 24            sq_0_3  0.604131
# 101          sq_10_0  0.633355
# 25            sq_0_4  0.668696
# 93            sq_9_0  0.682343
# 13   pp_From Counter  1.171898
#
# [117 rows x 2 columns]

# %%
# --------------------------------------------------
# Generate expected completion probability (xP)
# --------------------------------------------------

df["xP"] = model.predict_proba(X)[:, 1]

# Basic discrimination check
auc = roc_auc_score(y, df["xP"])
print(f"AUC: {auc:.3f}")
# Out:
# AUC: 0.838

# %% [markdown]
# ## Apply the xP model to Euros and Worlds final matches

# %%
matches_euros = sb.matches(competition_id=53, season_id=315) 
matches_worlds = sb.matches(competition_id=72, season_id=107)

# %%
final_euros = matches_euros[matches_euros['competition_stage'] == 'Final'].iloc[0] 
final_euros_id = final_euros['match_id']
events_final_euros = sb.events(match_id=final_euros_id)

# %%
final_world = matches_worlds[matches_worlds['competition_stage'] == 'Final'].iloc[0] 
final_world_id = final_world['match_id']
events_final_world = sb.events(match_id=final_world_id)

# %%
# Filter only passes

passes_final_euros = events_final_euros[events_final_euros['type'] == 'Pass'].copy()
passes_final_euros = passes_final_euros[passes_final_euros['pass_outcome'].ne("Injury Clearance")]

passes_final_world = events_final_world[events_final_world['type'] == 'Pass'].copy()
passes_final_world = passes_final_world[passes_final_world['pass_outcome'].ne("Injury Clearance")]

# %%
# Feature engineering for Euros final
df_euros_feat, X_euros, y_euros, FEATURES_euros, meta_euros = prepare_pass_features(passes_final_euros)

# Feature engineering for Worlds final
df_world_feat, X_world, y_world, FEATURES_world, meta_world = prepare_pass_features(passes_final_world)

# %%
meta_euros.columns
# Out:
# Index(['match_id', 'team', 'player'], dtype='object')

# %%
def aggregate_xP(df_feat, X, meta, model):
    df = df_feat.copy()
    X_use = X.copy()

    # Align features with model
    model_features = model.feature_names_in_
    for col in model_features:
        if col not in X_use.columns:
            X_use[col] = 0
    X_use = X_use[model_features]

    # Predict xP per pass
    df["xP"] = model.predict_proba(X_use)[:, 1]

    # Attach metadata without duplicating columns
    meta_use = meta.loc[:, ~meta.columns.isin(df.columns)]
    df = pd.concat(
        [df.reset_index(drop=True), meta_use.reset_index(drop=True)],
        axis=1
    )

    # Team-level aggregation
    team_stats = (
        df.groupby("team")
        .agg(
            total_passes=("completed", "count"),
            completed_passes=("completed", "sum"),
            total_xP=("xP", "sum"),
        )
        .reset_index()
    )
    team_stats["diff"] = team_stats["completed_passes"] - team_stats["total_xP"]

    # Player-level aggregation (keep country)
    player_stats = (
        df.groupby(["player", "team"])
        .agg(
            total_passes=("completed", "count"),
            completed_passes=("completed", "sum"),
            total_xP=("xP", "sum"),
        )
        .reset_index()
    )
    player_stats["diff"] = player_stats["completed_passes"] - player_stats["total_xP"]

    return {
        "team": team_stats,
        "player": player_stats
    }

# %%
euros_results = aggregate_xP(df_euros_feat, X_euros, meta_euros, model)
world_results = aggregate_xP(df_world_feat, X_world, meta_world, model)

team_euros = euros_results["team"]
player_euros = euros_results["player"]

team_world = world_results["team"]
player_world = world_results["player"]

# %%
team_euros
# Out:
#               team  total_passes  completed_passes    total_xP       diff
# 0  England Women's           473               341  339.055202   1.944798
# 1    Spain Women's           832               699  647.574674  51.425326

# %%
player_euros
# Out:
#                               player             team  total_passes  \
# 0               Aitana Bonmati Conca    Spain Women's            86
# 1                      Alessia Russo  England Women's             8
# 2                     Alex Greenwood  England Women's            51
# 3             Alexia Putellas Segura    Spain Women's            49
# 4       Athenea del Castillo Belvide    Spain Women's            29
# 5                       Bethany Mead  England Women's             5
# 6         Catalina Thomas Coll Lluch    Spain Women's            32
# 7                        Chloe Kelly  England Women's            18
# 8                Claudia Pina Medina    Spain Women's            33
# 9                         Ella Toone  England Women's            21
# 10         Esther Gonzalez Rodríguez    Spain Women's            14
# 11                   Georgia Stanway  England Women's            43
# 12                     Grace Clinton  England Women's             2
# 13                    Hannah Hampton  England Women's            57
# 14           Irene Paredes Hernandez    Spain Women's            84
# 15                    Jessica Carter  England Women's            51
# 16                       Keira Walsh  England Women's            41
# 17             Laia Aleixandri López    Spain Women's           103
# 18                       Lauren Hemp  England Women's            36
# 19                      Lauren James  England Women's            10
# 20                   Leah Williamson  England Women's            56
# 21          Leila Ouahabi El Ouahabi    Spain Women's             7
# 22                       Lucy Bronze  England Women's            66
# 23  María Francesca Caldentey Oliver    Spain Women's            83
# 24                 Michelle Agyemang  England Women's             6
# 25                     Niamh Charles  England Women's             2
# 26              Olga  Carmona García    Spain Women's            85
# 27                Ona Batlle Pascual    Spain Women's           115
# 28       Patricia Guijarro Gutiérrez    Spain Women's            76
# 29         Salma Paralluelo Ayingono    Spain Women's             8
# 30                    Victoria López    Spain Women's            28
#
#     completed_passes   total_xP       diff
# 0                 73  68.530373   4.469627
# 1                  4   6.370856  -2.370856
# 2                 42  38.661975   3.338025
# 3                 39  37.340311   1.659689
# 4                 19  19.216081  -0.216081
# 5                  5   4.324936   0.675064
# 6                 26  24.445195   1.554805
# 7                 11  11.057538  -0.057538
# 8                 20  20.900115  -0.900115
# 9                 18  17.929414   0.070586
# 10                12  11.991716   0.008284
# 11                35  34.827507   0.172493
# 12                 2   1.924215   0.075785
# 13                31  30.544354   0.455646
# 14                78  71.292512   6.707488
# 15                45  41.933428   3.066572
# 16                30  29.186265   0.813735
# 17                97  85.555530  11.444470
# 18                20  23.113301  -3.113301
# 19                 7   7.877319  -0.877319
# 20                47  39.546764   7.453236
# 21                 7   4.593060   2.406940
# 22                40  46.065973  -6.065973
# 23                66  64.787897   1.212103
# 24                 3   4.324813  -1.324813
# 25                 1   1.366544  -0.366544
# 26                67  62.671731   4.328269
# 27                98  89.752753   8.247247
# 28                66  60.201694   5.798306
# 29                 8   6.314523   1.685477
# 30                23  19.981183   3.018817

# %%
import matplotlib.pyplot as plt

df_plot = player_euros.copy()

# Optional: filter out very low volume players
df_plot = df_plot[df_plot["total_passes"] >= 10]

# Sort by difference
df_plot = df_plot.sort_values("diff")

# Team → colour mapping
team_colors = {
    "Spain Women's": "red",
    "England Women's": "blue",
}

colors = df_plot["team"].map(team_colors).fillna("grey")

plt.figure(figsize=(8, 10))
plt.barh(df_plot["player"], df_plot["diff"], color=colors)
plt.axvline(0, linewidth=1)

plt.xlabel("Completed passes − Expected passes (xP)")
plt.title("Pass completion vs expected (xP) — Player level")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 7))

plt.scatter(
    player_euros["total_xP"],
    player_euros["completed_passes"]
)

max_val = max(
    player_euros["total_xP"].max(),
    player_euros["completed_passes"].max()
)

plt.plot([0, max_val], [0, max_val])

plt.xlabel("Expected passes (xP)")
plt.ylabel("Completed passes")
plt.title("Actual vs expected pass completion (xP)")

plt.tight_layout()
plt.show()

# %%
team_world
# Out:
#               team  total_passes  completed_passes    total_xP       diff
# 0  England Women's           408               293  291.962372   1.037628
# 1    Spain Women's           519               421  390.860064  30.139936

# %%
player_world
# Out:
#                               player  total_passes  completed_passes  \
# 0               Aitana Bonmati Conca            45                41
# 1          Alba María Redondo Ferrer            12                 7
# 2                      Alessia Russo            12                 5
# 3                     Alex Greenwood            54                40
# 4             Alexia Putellas Segura             8                 5
# 5                    Bethany England             4                 3
# 6         Catalina Thomas Coll Lluch            23                17
# 7                        Chloe Kelly            21                 9
# 8                         Ella Toone            21                19
# 9                    Georgia Stanway            30                21
# 10           Irene Paredes Hernandez            49                42
# 11                 Ivana Andrés Sanz             6                 6
# 12          Jennifer Hermoso Fuentes            56                39
# 13                    Jessica Carter            46                31
# 14                       Keira Walsh            44                41
# 15               Laia Codina Panedas            47                44
# 16                       Lauren Hemp            19                11
# 17                      Lauren James            16                13
# 18                       Lucy Bronze            62                43
# 19              Mary Alexandra Earps            30                21
# 20  María Francesca Caldentey Oliver            60                55
# 21                     Millie Bright            33                25
# 22          Oihane Hernández Zurbano             8                 5
# 23              Olga  Carmona García            77                61
# 24                Ona Batlle Pascual            48                35
# 25                       Rachel Daly            16                11
# 26         Salma Paralluelo Ayingono            23                17
# 27           Teresa Abelleira Dueñas            57                47
#
#      total_xP      diff
# 0   34.084375  6.915625
# 1    9.505659 -2.505659
# 2    7.952564 -2.952564
# 3   40.706881 -0.706881
# 4    6.048855 -1.048855
# 5    3.278598 -0.278598
# 6   16.692044  0.307956
# 7   14.860769 -5.860769
# 8   17.262107  1.737893
# 9   22.963044 -1.963044
# 10  36.561552  5.438448
# 11   4.808960  1.191040
# 12  41.570991 -2.570991
# 13  30.967741  0.032259
# 14  36.085950  4.914050
# 15  40.133066  3.866934
# 16  12.295286 -1.295286
# 17  12.352143  0.647857
# 18  38.848033  4.151967
# 19  19.945476  1.054524
# 20  49.119535  5.880465
# 21  24.075925  0.924075
# 22   5.289358 -0.289358
# 23  52.600382  8.399618
# 24  32.736363  2.263637
# 25  10.367855  0.632145
# 26  17.324222 -0.324222
# 27  44.384701  2.615299

# %% [markdown]
# ## Combined plots

# %%
df_euros_plot = player_euros.copy()
df_euros_plot["final"] = "Euros"

df_world_plot = player_world.copy()
df_world_plot["final"] = "World Cup"

df_plot = pd.concat([df_euros_plot, df_world_plot], ignore_index=True)

# Optional: filter low-volume performances
df_plot = df_plot[df_plot["total_passes"] >= 10]

# %%
df_plot = df_plot.sort_values(
    ["player", "final"],
    ascending=[True, False]  # World Cup first, Euros second
)

# %%
team_colors = {
    "Spain Women's": "red",
    "England Women's": "blue",
}

df_plot["color"] = df_plot["team"].map(team_colors).fillna("grey")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 12))

bars = plt.barh(
    y=df_plot["player"] + " — " + df_plot["final"],
    width=df_plot["diff"],
    color=df_plot["color"],
    edgecolor=df_plot["final"].eq("World Cup").map(
        {True: "black", False: "none"}
    ),
    linewidth=df_plot["final"].eq("World Cup").map(
        {True: 1.5, False: 0}
    ),
)

plt.axvline(0, color="black", linestyle="--", linewidth=1)

plt.xlabel("Completed passes − Expected passes (xP)")
plt.title("Pass completion vs expected (xP)\nEuros vs World Cup finals")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

df_plot = df_plot.copy()

# Sort so World Cup is always above Euros for the same player
df_plot["final_order"] = df_plot["final"].map({"World Cup": 0, "Euros": 1})
df_plot = df_plot.sort_values(["player", "final_order"])

# Base y positions per player
players = df_plot["player"].unique()
player_to_y = {p: i for i, p in enumerate(players)}

# Small offset so the two finals don't overlap
offset = df_plot["final"].map({"World Cup": -0.15, "Euros": 0.15})
df_plot["y"] = df_plot["player"].map(player_to_y) + offset

# %%
plt.figure(figsize=(9, 12))

plt.barh(
    y=df_plot["y"],
    width=df_plot["diff"],
    color=df_plot["color"],
    edgecolor=df_plot["final"].eq("World Cup").map(
        {True: "black", False: "none"}
    ),
    linewidth=df_plot["final"].eq("World Cup").map(
        {True: 1.5, False: 0}
    ),
)

# Zero line
plt.axvline(0, color="black", linestyle="--", linewidth=1)

# Y-axis labels: player names only
plt.yticks(
    ticks=range(len(players)),
    labels=players
)

plt.xlabel("Completed passes − Expected passes (xP)")
plt.title("Pass completion vs expected (xP)\nEuros vs World Cup finals")

plt.tight_layout()
plt.show()
