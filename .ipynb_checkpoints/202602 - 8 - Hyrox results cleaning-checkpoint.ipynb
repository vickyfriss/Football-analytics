# %% [markdown]
# # Read all HYROX results CSV files, combining DOUBLES and SINGLES.

# %%
import os
import re
from collections import defaultdict

root_folder = r"Datasets\Hyrox"

raw_divisions = set()

suffix_words = {
    "overall", "saturday", "sunday", "friday",
    "thursday", "wednesday"
}

# -----------------------------
# STEP 1: Extract divisions
# -----------------------------
for subdir, _, files in os.walk(root_folder):
    for file in files:
        if not file.lower().endswith(".csv"):
            continue

        name = file.replace(".csv", "")

        if name.lower() in ["doubles", "singles", "hyrox_pro"]:
            continue

        parts = name.split("_")

        # Find first HYROX
        hyrox_index = None
        for i, p in enumerate(parts):
            if p.lower() == "hyrox":
                hyrox_index = i
                break

        if hyrox_index is None:
            continue

        division_parts = parts[hyrox_index:]

        # Remove trailing weekday/overall
        while division_parts and division_parts[-1].lower() in suffix_words:
            division_parts = division_parts[:-1]

        division = "_".join(division_parts)
        raw_divisions.add(division)


# -----------------------------
# STEP 2: Clean divisions
# -----------------------------
clean_divisions = set()

for d in raw_divisions:
    d = d.upper()
    d = d.replace("-", "_")
    d = re.sub(r"_+$", "", d)
    d = re.sub(r"_+", "_", d)
    clean_divisions.add(d)


# -----------------------------
# STEP 3: Detect categories
# -----------------------------
categories = defaultdict(list)

for d in clean_divisions:

    if "DOUBLES" in d:
        categories["DOUBLES"].append(d)

    elif "RELAY" in d or "TEAM" in d:
        categories["RELAY / TEAM"].append(d)

    elif "GORUCK" in d:
        categories["GORUCK"].append(d)

    elif "ADAPTIVE" in d:
        categories["ADAPTIVE"].append(d)

    elif "YOUNGSTARS" in d:
        categories["YOUTH"].append(d)

    elif "ELITE" in d:
        categories["ELITE"].append(d)

    elif "PRO" in d:
        categories["PRO (SINGLES)"].append(d)

    elif d == "HYROX":
        categories["OPEN (SINGLES)"].append(d)

    else:
        categories["OTHER / SPECIAL"].append(d)


# -----------------------------
# STEP 4: Print results
# -----------------------------
print("\n===== DIVISION DETECTION SUMMARY =====\n")

for cat in sorted(categories.keys()):
    print(f"\n{cat} ({len(categories[cat])})")
    print("-" * 40)
    for div in sorted(categories[cat]):
        print(div)

print("\nTotal cleaned divisions:", len(clean_divisions))
# Out:
# ===== DIVISION DETECTION SUMMARY =====
#
#
# ADAPTIVE (1)
# ----------------------------------------
# HYROX_ADAPTIVE
#
# DOUBLES (4)
# ----------------------------------------
# HYROX_DOUBLES
# HYROX_ELITE_15_DOUBLES
# HYROX_GORUCK_DOUBLES
# HYROX_PRO_DOUBLES
#
# ELITE (2)
# ----------------------------------------
# HYROX_ELITE
# HYROX_ELITE_15
#
# GORUCK (1)
# ----------------------------------------
# HYROX_GORUCK
#
# OPEN (SINGLES) (1)
# ----------------------------------------
# HYROX
#
# OTHER / SPECIAL (1)
# ----------------------------------------
# HYROX_MIXED_ASIEN_CHAMPIONSHIP_INVITATIONAL
#
# PRO (SINGLES) (1)
# ----------------------------------------
# HYROX_PRO
#
# RELAY / TEAM (4)
# ----------------------------------------
# HYROX_CORPORATE_RELAY
# HYROX_SECONDARY_SCHOOL_RELAY
# HYROX_TEAM_CHALLENGE
# HYROX_TEAM_RELAY
#
# YOUTH (1)
# ----------------------------------------
# HYROX_YOUNGSTARS_8_9_YRS
#
# Total cleaned divisions: 16

# %%
import os
import pandas as pd
import re
from collections import defaultdict

root_folder = r"Datasets\Hyrox"
output_folder = os.path.join(root_folder, "Processed dataset")

os.makedirs(output_folder, exist_ok=True)

division_files = defaultdict(list)
division_datasets = {}
empty_files_detected = []

suffix_words = {
    "overall", "saturday", "sunday", "friday",
    "thursday", "wednesday"
}

# ---------------------------------
# STEP 1: Group files by division
# ---------------------------------
for subdir, _, files in os.walk(root_folder):
    for file in files:

        if not file.lower().endswith(".csv"):
            continue

        if "processed dataset" in subdir.lower():
            continue

        filename_without_ext = file.replace(".csv", "")

        if filename_without_ext.lower() in ["doubles", "singles", "hyrox_pro"]:
            continue

        parts = filename_without_ext.split("_")

        hyrox_index = None
        for i, p in enumerate(parts):
            if p.lower() == "hyrox":
                hyrox_index = i
                break

        if hyrox_index is None:
            continue

        division_parts = parts[hyrox_index:]

        while division_parts and division_parts[-1].lower() in suffix_words:
            division_parts = division_parts[:-1]

        division = "_".join(division_parts)

        division = division.upper()
        division = division.replace("-", "_")
        division = re.sub(r"_+$", "", division)
        division = re.sub(r"_+", "_", division)

        file_path = os.path.join(subdir, file)
        division_files[division].append((file_path, filename_without_ext))


# ---------------------------------
# STEP 2: Create dataset per division
# ---------------------------------
for division, files in division_files.items():

    dfs = []

    for file_path, filename_without_ext in files:
        try:
            df = pd.read_csv(file_path)

            if df.empty:
                empty_files_detected.append(filename_without_ext)
                continue

            df["source_file"] = filename_without_ext
            dfs.append(df)

        except:
            continue

    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)

        output_path = os.path.join(output_folder, f"{division}.csv")
        combined_df.to_csv(output_path, index=False)

        division_datasets[division] = combined_df
        globals()[division] = combined_df


# ---------------------------------
# FINAL SUMMARY
# ---------------------------------
print("\n============================")
print("EMPTY FILES SUMMARY")
print("============================")
print(f"Total empty files: {len(empty_files_detected)}\n")

if empty_files_detected:
    for file in sorted(empty_files_detected):
        print(f"- {file}")
else:
    print("No empty files detected.")

print("\n============================")
print("DATASETS CREATED")
print("============================")

if division_datasets:
    for name in sorted(division_datasets.keys()):
        print(f"{name} → {len(division_datasets[name])} rows")
else:
    print("No datasets created.")
# Out:
# ============================
# EMPTY FILES SUMMARY
# ============================
# Total empty files: 148
#
# - 2019_Hannover_HYROX_TEAM-CHALLENGE
# - 2021_Austin_HYROX_ELITE
# - 2021_New_York_Hyrox_Team_Relay
# - 2021_Orlando_HYROX_ELITE
# - 2022_Basel_HYROX_TEAM_RELAY
# - 2022_Birmingham_HYROX_TEAM_RELAY
# - 2022_Bremen_Hyrox_Team_Relay
# - 2022_Essen_HYROX_TEAM_RELAY
# - 2022_Essen_Hyrox_Team_Relay
# - 2022_Las_Vegas_HYROX_ELITE
# - 2022_Leipzig_HYROX_TEAM_RELAY
# - 2022_London_HYROX_TEAM_RELAY
# - 2022_Los_Angeles_HYROX_TEAM_RELAY
# - 2022_Maastricht_Hyrox_Team_Relay
# - 2022_Manchester_Hyrox_Team_Relay
# - 2022_New_York_HYROX_TEAM_RELAY
# - 2022_Wien_Hyrox_Team_Relay
# - 2023_Amsterdam_HYROX_TEAM_RELAY
# - 2023_Barcelona_HYROX_TEAM_RELAY
# - 2023_Chicago_HYROX_ELITE
# - 2023_Chicago_HYROX_TEAM_RELAY
# - 2023_Dallas_HYROX_GORUCK
# - 2023_Dallas_HYROX_GORUCK_DOUBLES
# - 2023_Dallas_HYROX_TEAM_RELAY
# - 2023_Dallas_HYROX_TEAM_RELAY
# - 2023_Dublin_HYROX_TEAM_RELAY
# - 2023_Glasgow_HYROX_TEAM_RELAY
# - 2023_Hamburg_HYROX_TEAM_RELAY
# - 2023_Hong_Kong_HYROX_TEAM_RELAY
# - 2023_Köln_HYROX_TEAM_RELAY
# - 2023_London_HYROX_TEAM_RELAY
# - 2023_Los_Angeles_HYROX_TEAM_RELAY
# - 2023_Maastricht_European_Championships_HYROX_ELITE
# - 2023_Maastricht_European_Championships_HYROX_TEAM_RELAY
# - 2023_Manchester_HYROX_TEAM_RELAY
# - 2023_Melbourne_HYROX_TEAM_RELAY
# - 2023_New_York_HYROX_TEAM_RELAY
# - 2023_Paris_HYROX_TEAM_RELAY
# - 2023_Stockholm_HYROX_ELITE
# - 2023_Stockholm_HYROX_TEAM_RELAY
# - 2023_Stuttgart_HYROX_TEAM_RELAY
# - 2023_Sydney_HYROX_TEAM_RELAY
# - 2024_Amsterdam_HYROX_ELITE_-_Thursday
# - 2024_Anaheim_HYROX_ADAPTIVE
# - 2024_Anaheim_HYROX_TEAM_RELAY
# - 2024_Cape_Town_HYROX_TEAM_RELAY
# - 2024_Ciudad_de_Mexico_HYROX_TEAM_RELAY
# - 2024_Dallas_HYROX_ADAPTIVE
# - 2024_Dallas_HYROX_TEAM_RELAY
# - 2024_Doha_All_Women's_Race_HYROX_PRO
# - 2024_Doha_All_Women's_Race_HYROX_TEAM_RELAY
# - 2024_Hong_Kong_HYROX_CORPORATE_RELAY
# - 2024_Hong_Kong_HYROX_ELITE
# - 2024_Hong_Kong_HYROX_MIXED_ASIEN_CHAMPIONSHIP_INVITATIONAL
# - 2024_Hong_Kong_HYROX_SECONDARY_SCHOOL_RELAY
# - 2024_Hong_Kong_HYROX_TEAM_RELAY
# - 2024_Karlsruhe_HYROX_TEAM_RELAY
# - 2024_Manchester_HYROX_TEAM_RELAY
# - 2024_Marseille_HYROX_TEAM_RELAY
# - 2024_Mexico_City_HYROX_TEAM_RELAY
# - 2024_Nice_HYROX_TEAM_RELAY
# - 2024_Vienna_-_European_Championship_HYROX_ELITE
# - 2025_Abu_Dhabi_HYROX
# - 2025_Abu_Dhabi_HYROX_ADAPTIVE
# - 2025_Abu_Dhabi_HYROX_DOUBLES
# - 2025_Abu_Dhabi_HYROX_PRO
# - 2025_Abu_Dhabi_HYROX_PRO_DOUBLES
# - 2025_Abu_Dhabi_HYROX_TEAM_RELAY
# - 2025_Acapulco_HYROX_TEAM_RELAY
# - 2025_Auckland_HYROX_TEAM_RELAY
# - 2025_Beijing_HYROX_ADAPTIVE
# - 2025_Beijing_HYROX_TEAM_RELAY
# - 2025_Bordeaux_HYROX_TEAM_RELAY_-_Sunday
# - 2025_Boston_HYROX_-_Overall
# - 2025_Boston_HYROX_ADAPTIVE_-_Overall
# - 2025_Boston_HYROX_DOUBLES_-_Overall
# - 2025_Boston_HYROX_PRO_-_Overall
# - 2025_Boston_HYROX_PRO_DOUBLES_-_Overall
# - 2025_Boston_HYROX_TEAM_RELAY_-_Friday
# - 2025_Boston_HYROX_TEAM_RELAY_-_Overall
# - 2025_Brisbane_HYROX_TEAM_RELAY
# - 2025_Delhi_HYROX_ADAPTIVE
# - 2025_Delhi_HYROX_TEAM_RELAY
# - 2025_Gdansk_HYROX_ADAPTIVE
# - 2025_Gdansk_HYROX_TEAM_RELAY
# - 2025_Geneva_HYROX_TEAM_RELAY_-_Sunday
# - 2025_Glasgow_HYROX_ELITE_-_Wednesday
# - 2025_Hamburg_HYROX_ELITE_15_-_Friday
# - 2025_Hamburg_HYROX_ELITE_15_DOUBLES_-_Saturday
# - 2025_Hong_Kong_HYROX_CORPORATE_RELAY_-_Saturday
# - 2025_Hong_Kong_HYROX_CORPORATE_RELAY_-_Sunday
# - 2025_Hong_Kong_HYROX_TEAM_RELAY_-_Saturday
# - 2025_Hong_Kong_HYROX_TEAM_RELAY_-_Sunday
# - 2025_Las_Vegas_HYROX_ADAPTIVE_-_Overall
# - 2025_Las_Vegas_HYROX_ADAPTIVE_-_Saturday
# - 2025_Las_Vegas_HYROX_ADAPTIVE_-_Sunday
# - 2025_Las_Vegas_HYROX_ELITE_-_Friday
# - 2025_Las_Vegas_HYROX_TEAM_RELAY_-_Overall
# - 2025_Las_Vegas_HYROX_TEAM_RELAY_-_Saturday
# - 2025_Las_Vegas_HYROX_TEAM_RELAY_-_Sunday
# - 2025_Melbourne_HYROX_ELITE_15_-_Friday
# - 2025_Melbourne_HYROX_ELITE_15_DOUBLES_-_Saturday
# - 2025_Mumbai_HYROX_TEAM_RELAY
# - 2025_Oslo_HYROX_ADAPTIVE_-_Friday
# - 2025_Oslo_HYROX_TEAM_RELAY_-_Overall
# - 2025_Oslo_HYROX_TEAM_RELAY_-_Sunday
# - 2025_Rio_de_Janeiro_HYROX_PRO_DOUBLES
# - 2025_Sao_Paulo_HYROX_TEAM_RELAY
# - 2025_Seoul_HYROX_TEAM_RELAY
# - 2025_Singapore_Expo_HYROX_PRO_DOUBLES
# - 2025_Singapore_HYROX_CORPORATE_RELAY
# - 2025_Singapore_HYROX_DOUBLES
# - 2025_Singapore_HYROX_TEAM_RELAY
# - 2025_Sydney_HYROX_-_Overall
# - 2025_Sydney_HYROX_ADAPTIVE_-_Overall
# - 2025_Sydney_HYROX_TEAM_RELAY_-_Friday
# - 2025_Toronto_HYROX_TEAM_RELAY_-_Sunday
# - 2025_Turin_HYROX
# - 2025_Turin_HYROX_PRO
# - 2025_Valencia_HYROX_-_Overall
# - 2025_Valencia_HYROX_ADAPTIVE_-_Friday
# - 2025_Valencia_HYROX_DOUBLES_-_Overall
# - 2025_Valencia_HYROX_PRO_DOUBLES_-_Overall
# - 2025_Valencia_HYROX_TEAM_RELAY_-_Overall
# - 2025_Valencia_HYROX_TEAM_RELAY_-_Overall
# - 2025_Valencia_HYROX_TEAM_RELAY_-_Saturday
# - 2025_Valencia_HYROX_TEAM_RELAY_-_Sunday
# - 2025_Valencia_HYROX_TEAM_RELAY_-_Sunday
# - 2025_World_Championships_HYROX_ELITE_15_-_Thursday
# - 2026_Auckland_HYROX_TEAM_RELAY_-_Thursday
# - 2026_Fortaleza_HYROX
# - 2026_Fortaleza_HYROX_ADAPTIVE
# - 2026_Fortaleza_HYROX_DOUBLES
# - 2026_Fortaleza_HYROX_PRO
# - 2026_Fortaleza_HYROX_PRO_DOUBLES
# - 2026_Fortaleza_HYROX_TEAM_RELAY
# - 2026_Phoenix_HYROX_ELITE_15_-_Thursday
# - 2026_Phoenix_HYROX_ELITE_15_DOUBLES_-_Friday
# - 2026_Washington_DC_HYROX_-_Overall
# - 2026_Washington_DC_HYROX_-_Saturday
# - 2026_Washington_DC_HYROX_-_Sunday
# - 2026_Washington_DC_HYROX_DOUBLES_-_Overall
# - 2026_Washington_DC_HYROX_DOUBLES_-_Saturday
# - 2026_Washington_DC_HYROX_DOUBLES_-_Sunday
# - 2026_Washington_DC_HYROX_ELITE_15_-_Saturday
# - 2026_Washington_DC_HYROX_ELITE_15_DOUBLES_-_Sunday
# - 2026_Washington_DC_HYROX_TEAM_RELAY_-_Sunday
# - WorldChampionship_-_Leipzig_HYROX_ELITE
#
# ============================
# DATASETS CREATED
# ============================
# HYROX → 298175 rows
# HYROX_ADAPTIVE → 208 rows
# HYROX_DOUBLES → 181104 rows
# HYROX_ELITE_15_DOUBLES → 29 rows
# HYROX_GORUCK → 274 rows
# HYROX_GORUCK_DOUBLES → 77 rows
# HYROX_PRO → 70688 rows
# HYROX_PRO_DOUBLES → 21354 rows
# HYROX_YOUNGSTARS_8_9_YRS → 377 rows

# %%
HYROX_DOUBLES.tail()
# Out:
#                  Race                  Division Gender  Rank Overall  \
# 181099  2026 Auckland  HYROX DOUBLES - Thursday  Women           476
# 181100  2026 Auckland  HYROX DOUBLES - Thursday  Women           477
# 181101  2026 Auckland  HYROX DOUBLES - Thursday  Women           478
# 181102  2026 Auckland  HYROX DOUBLES - Thursday  Women           479
# 181103  2026 Auckland  HYROX DOUBLES - Thursday  Women           480
#
#        Rank Age Group                                  Name  Nation Age Group  \
# 181099            114   Clementine Smart, Samantha Collings     NaN     30-34
# 181100            115     Andrea Munokoatini, Jasmine Young     NaN     30-34
# 181101            105          Holley Hamill, Janine Hamill     NaN     35-39
# 181102             26      Connie Valivaka, Santana Webster     NaN     45-49
# 181103             27  Charlene Rewiri-Ulufonua, Penni Gray     NaN     45-49
#
#        Total Time                             source_file
# 181099   02:26:31  2026_Auckland_HYROX_DOUBLES_-_Thursday
# 181100   02:26:34  2026_Auckland_HYROX_DOUBLES_-_Thursday
# 181101   02:29:25  2026_Auckland_HYROX_DOUBLES_-_Thursday
# 181102   02:36:10  2026_Auckland_HYROX_DOUBLES_-_Thursday
# 181103   03:02:12  2026_Auckland_HYROX_DOUBLES_-_Thursday

# %%
# ---------------------------------
# GLOBAL DATA QUALITY SUMMARY (RAW DATA)
# ---------------------------------

total_rows_all_divisions = 0
total_duplicate_rows_global = 0
files_with_duplicates = set()

for division, df in division_datasets.items():

    total_rows_all_divisions += len(df)

    duplicate_mask = df.duplicated(keep=False)

    if duplicate_mask.any():

        duplicates_df = df.loc[duplicate_mask]
        total_duplicate_rows_global += len(duplicates_df)

        dup_files = duplicates_df["source_file"].unique()
        files_with_duplicates.update(dup_files)


# Total files processed
all_files_processed = set()

for division, df in division_datasets.items():
    all_files_processed.update(df["source_file"].unique())

all_files_processed.update(empty_files_detected)

total_files = len(all_files_processed)

files_with_issues = set(empty_files_detected).union(files_with_duplicates)

print("\n============================")
print("GLOBAL DATA QUALITY SUMMARY (RAW)")
print("============================")

print(f"Total rows across all divisions: {total_rows_all_divisions}")
print(f"Total duplicate rows detected: {total_duplicate_rows_global}")

if total_rows_all_divisions > 0:
    print(f"Duplicate rows percentage: {(total_duplicate_rows_global / total_rows_all_divisions) * 100:.2f}%")

print("\nTotal files processed:", total_files)
print("Files with issues (empty or duplicates):", len(files_with_issues))
print(f"Percentage of files with issues: {(len(files_with_issues)/total_files)*100:.2f}%")
# Out:
# ============================
# GLOBAL DATA QUALITY SUMMARY (RAW)
# ============================
# Total rows across all divisions: 572286
# Total duplicate rows detected: 12291
# Duplicate rows percentage: 2.15%
#
# Total files processed: 1088
# Files with issues (empty or duplicates): 356
# Percentage of files with issues: 32.72%

# %% [markdown]
# # CHECK 1: Duplicated rows.

# %%
for division, df in division_datasets.items():

    before = len(df)

    duplicate_mask = df.duplicated(keep=False)

    if duplicate_mask.any():

        duplicates_df = df.loc[duplicate_mask]

        print(f"\n{division}:")
        print(f"Total duplicate rows detected: {len(duplicates_df)}")
        print(f"Rows that will be removed: {before - len(df.drop_duplicates())}")
        print("\nDuplicate breakdown per source file:\n")

        # Group duplicates by source_file
        grouped = duplicates_df.groupby("source_file")

        for file_name, group in grouped:

            n_dupes = len(group)

            print(f"{file_name}")
            print(f"  Duplicate rows: {n_dupes}")

            # 3 example Rank Overall values
            if "Rank Overall" in group.columns:
                example_ranks = group["Rank Overall"].dropna().unique()[:3]
                print(f"  Example Rank Overall values: {list(example_ranks)}")
            else:
                print("  Rank Overall column not found.")

            print()

    df.drop_duplicates(inplace=True)
# Out:
# HYROX:
# Total duplicate rows detected: 7228
# Rows that will be removed: 3623
#
# Duplicate breakdown per source file:
#
# 2019_Hamburg_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [4]
#
# 2019_Hannover_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [142, 246]
#
# 2019_Karlsruhe_HYROX
#   Duplicate rows: 8
#   Example Rank Overall values: [21, 38, 54]
#
# 2020_Hannover_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [168]
#
# 2021_Dallas_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [15]
#
# 2021_Hamburg_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [3]
#
# 2021_Leipzig_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [29]
#
# 2021_Madrid_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [32]
#
# 2022_Basel_HYROX
#   Duplicate rows: 57
#   Example Rank Overall values: [2, 4, 5]
#
# 2022_Bremen_HYROX
#   Duplicate rows: 25
#   Example Rank Overall values: [2, 9, 31]
#
# 2022_Chicago_HYROX
#   Duplicate rows: 6
#   Example Rank Overall values: [62, 95]
#
# 2022_Dallas_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [61, 45]
#
# 2022_Essen_HYROX
#   Duplicate rows: 90
#   Example Rank Overall values: [4, 6, 15]
#
# 2022_Frankfurt_HYROX
#   Duplicate rows: 151
#   Example Rank Overall values: [19, 28, 31]
#
# 2022_Hamburg_HYROX
#   Duplicate rows: 112
#   Example Rank Overall values: [3, 4, 5]
#
# 2022_Hong_Kong_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [9, 36]
#
# 2022_London_HYROX
#   Duplicate rows: 437
#   Example Rank Overall values: [3, 13, 14]
#
# 2022_Maastricht_HYROX
#   Duplicate rows: 38
#   Example Rank Overall values: [3, 4, 10]
#
# 2022_Madrid_HYROX
#   Duplicate rows: 22
#   Example Rank Overall values: [3, 13, 78]
#
# 2022_Manchester_HYROX
#   Duplicate rows: 146
#   Example Rank Overall values: [2, 9, 11]
#
# 2022_München_HYROX
#   Duplicate rows: 61
#   Example Rank Overall values: [5, 11, 19]
#
# 2022_New_York_HYROX
#   Duplicate rows: 8
#   Example Rank Overall values: [7, 204, 12]
#
# 2022_Valencia_HYROX
#   Duplicate rows: 24
#   Example Rank Overall values: [13, 16, 61]
#
# 2022_Wien_HYROX
#   Duplicate rows: 30
#   Example Rank Overall values: [1, 7, 12]
#
# 2023_Barcelona_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [128, 136]
#
# 2023_Bilbao_HYROX
#   Duplicate rows: 10
#   Example Rank Overall values: [6, 47, 73]
#
# 2023_Birmingham_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [697, 741]
#
# 2023_Dallas_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [3]
#
# 2023_Dublin_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [63, 457]
#
# 2023_Glasgow_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [216, 4]
#
# 2023_Hamburg_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [14, 83]
#
# 2023_Hong_Kong_HYROX
#   Duplicate rows: 8
#   Example Rank Overall values: [11, 258, 275]
#
# 2023_Houston_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [13]
#
# 2023_Karlsruhe_HYROX
#   Duplicate rows: 42
#   Example Rank Overall values: [3, 8, 12]
#
# 2023_London_HYROX
#   Duplicate rows: 30
#   Example Rank Overall values: [70, 162, 814]
#
# 2023_Maastricht_European_Championships_HYROX
#   Duplicate rows: 6
#   Example Rank Overall values: [1, 160, 35]
#
# 2023_Madrid_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [2, 36]
#
# 2023_Malaga_HYROX
#   Duplicate rows: 53
#   Example Rank Overall values: [2, 6, 11]
#
# 2023_Manchester_HYROX
#   Duplicate rows: 335
#   Example Rank Overall values: [1, 2, 3]
#
# 2023_Milan_HYROX
#   Duplicate rows: 6
#   Example Rank Overall values: [296, 9, 15]
#
# 2023_New_York_HYROX
#   Duplicate rows: 5
#   Example Rank Overall values: [154, 248]
#
# 2023_Paris_HYROX
#   Duplicate rows: 6
#   Example Rank Overall values: [21, 27, 152]
#
# 2023_Rimini_HYROX
#   Duplicate rows: 16
#   Example Rank Overall values: [12, 24, 36]
#
# 2023_Stockholm_HYROX
#   Duplicate rows: 6
#   Example Rank Overall values: [21, 134, 187]
#
# 2023_Stuttgart_HYROX
#   Duplicate rows: 126
#   Example Rank Overall values: [4, 6, 15]
#
# 2023_Sydney_HYROX
#   Duplicate rows: 8
#   Example Rank Overall values: [8, 231, 13]
#
# 2023_Valencia_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [50, 72]
#
# 2023_Wien_HYROX
#   Duplicate rows: 48
#   Example Rank Overall values: [2, 3, 4]
#
# 2024_Amsterdam_HYROX_-_Friday
#   Duplicate rows: 2
#   Example Rank Overall values: [45]
#
# 2024_Amsterdam_HYROX_-_Saturday
#   Duplicate rows: 2
#   Example Rank Overall values: [223]
#
# 2024_Ciudad_de_Mexico_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [2]
#
# 2024_Gdansk_HYROX
#   Duplicate rows: 6
#   Example Rank Overall values: [26, 335, 34]
#
# 2024_Glasgow_HYROX
#   Duplicate rows: 12
#   Example Rank Overall values: [3, 58, 132]
#
# 2024_Karlsruhe_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [1]
#
# 2024_Maastricht_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [1]
#
# 2024_Madrid_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [3, 440]
#
# 2024_Malaga_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [2]
#
# 2024_Milan_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [32]
#
# 2024_Nice_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [9]
#
# 2024_Poznan_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [539]
#
# 2024_Rimini_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [38, 50]
#
# 2024_Vienna_-_European_Championship_HYROX
#   Duplicate rows: 4
#   Example Rank Overall values: [25, 3]
#
# 2024_Washington_-_North_American_Championships_HYROX
#   Duplicate rows: 2
#   Example Rank Overall values: [29]
#
# 2025_Cologne_HYROX_-_Overall
#   Duplicate rows: 5198
#   Example Rank Overall values: [1, 2, 3]
#
# 2025_Las_Vegas_HYROX_-_Overall
#   Duplicate rows: 4
#   Example Rank Overall values: [200, 100]
#
#
# HYROX_DOUBLES:
# Total duplicate rows detected: 3198
# Rows that will be removed: 1605
#
# Duplicate breakdown per source file:
#
# 2019_Essen_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [67]
#
# 2019_Leipzig_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [25]
#
# 2019_Miami_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [11]
#
# 2021_Birmingham_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [23]
#
# 2021_Leipzig_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [3]
#
# 2022_Basel_HYROX_DOUBLES
#   Duplicate rows: 4
#   Example Rank Overall values: [5, 15]
#
# 2022_Bremen_HYROX_DOUBLES
#   Duplicate rows: 4
#   Example Rank Overall values: [3, 59]
#
# 2022_Dallas_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [4]
#
# 2022_Essen_HYROX_DOUBLES
#   Duplicate rows: 26
#   Example Rank Overall values: [1, 2, 89]
#
# 2022_Frankfurt_HYROX_DOUBLES
#   Duplicate rows: 41
#   Example Rank Overall values: [1, 7, 33]
#
# 2022_Hamburg_HYROX_DOUBLES
#   Duplicate rows: 10
#   Example Rank Overall values: [30, 22, 128]
#
# 2022_Las_Vegas_HYROX_DOUBLES
#   Duplicate rows: 10
#   Example Rank Overall values: [1, 18, 3]
#
# 2022_London_HYROX_DOUBLES
#   Duplicate rows: 44
#   Example Rank Overall values: [2, 40, 102]
#
# 2022_Maastricht_HYROX_DOUBLES
#   Duplicate rows: 6
#   Example Rank Overall values: [1, 6]
#
# 2022_Madrid_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [79]
#
# 2022_Manchester_HYROX_DOUBLES
#   Duplicate rows: 33
#   Example Rank Overall values: [6, 22, 33]
#
# 2022_München_HYROX_DOUBLES
#   Duplicate rows: 8
#   Example Rank Overall values: [8, 15, 43]
#
# 2022_Valencia_HYROX_DOUBLES
#   Duplicate rows: 6
#   Example Rank Overall values: [3, 25, 62]
#
# 2022_Wien_HYROX_DOUBLES
#   Duplicate rows: 12
#   Example Rank Overall values: [3, 28, 52]
#
# 2023_Barcelona_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [45]
#
# 2023_Bilbao_HYROX_DOUBLES
#   Duplicate rows: 4
#   Example Rank Overall values: [27, 55]
#
# 2023_Birmingham_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [29]
#
# 2023_Dubai_HYROX_DOUBLES
#   Duplicate rows: 4
#   Example Rank Overall values: [1, 61]
#
# 2023_Dublin_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [1]
#
# 2023_Glasgow_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [55]
#
# 2023_Hong_Kong_HYROX_DOUBLES
#   Duplicate rows: 12
#   Example Rank Overall values: [2, 4, 16]
#
# 2023_Karlsruhe_HYROX_DOUBLES
#   Duplicate rows: 34
#   Example Rank Overall values: [2, 8, 29]
#
# 2023_London_HYROX_DOUBLES
#   Duplicate rows: 8
#   Example Rank Overall values: [25, 90, 243]
#
# 2023_Maastricht_European_Championships_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [33]
#
# 2023_Madrid_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [40]
#
# 2023_Manchester_HYROX_DOUBLES
#   Duplicate rows: 172
#   Example Rank Overall values: [1, 3, 8]
#
# 2023_München_HYROX_DOUBLES
#   Duplicate rows: 4
#   Example Rank Overall values: [8, 22]
#
# 2023_Rimini_HYROX_DOUBLES
#   Duplicate rows: 8
#   Example Rank Overall values: [7, 16, 17]
#
# 2023_Stockholm_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [1]
#
# 2023_Stuttgart_HYROX_DOUBLES
#   Duplicate rows: 66
#   Example Rank Overall values: [2, 4, 6]
#
# 2023_Sydney_HYROX_DOUBLES
#   Duplicate rows: 4
#   Example Rank Overall values: [6, 29]
#
# 2023_Wien_HYROX_DOUBLES
#   Duplicate rows: 42
#   Example Rank Overall values: [1, 4, 6]
#
# 2023_World_Championships_Manchester_HYROX_DOUBLES
#   Duplicate rows: 4
#   Example Rank Overall values: [37, 239]
#
# 2024_Fort_Lauderdale_HYROX_DOUBLES
#   Duplicate rows: 593
#   Example Rank Overall values: [1, 2, 3]
#
# 2024_Karlsruhe_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [4]
#
# 2024_Malaga_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [56]
#
# 2024_Paris_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [191]
#
# 2024_Perth_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [43]
#
# 2024_Rimini_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [71]
#
# 2024_Turin_HYROX_DOUBLES
#   Duplicate rows: 1981
#   Example Rank Overall values: [1, 2, 3]
#
# 2025_Acapulco_HYROX_DOUBLES
#   Duplicate rows: 4
#   Example Rank Overall values: [10, 59]
#
# 2025_Boston_HYROX_DOUBLES_-_Friday
#   Duplicate rows: 2
#   Example Rank Overall values: [608]
#
# 2025_Boston_HYROX_DOUBLES_-_Sunday
#   Duplicate rows: 2
#   Example Rank Overall values: [313]
#
# 2025_Brisbane_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [10]
#
# 2025_Katowice_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [87]
#
# 2025_Las_Vegas_HYROX_DOUBLES_-_Saturday
#   Duplicate rows: 2
#   Example Rank Overall values: [100]
#
# 2025_Maastricht_HYROX_DOUBLES
#   Duplicate rows: 4
#   Example Rank Overall values: [300, 99]
#
# 2025_Toulouse_HYROX_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [300]
#
#
# HYROX_PRO:
# Total duplicate rows detected: 1220
# Rows that will be removed: 627
#
# Duplicate breakdown per source file:
#
# 2018_Hamburg_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [18]
#
# 2018_Wien_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [25]
#
# 2019_Frankfurt_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [3]
#
# 2019_Hannover_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [9]
#
# 2019_Karlsruhe_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [6, 71]
#
# 2019_Leipzig_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [3]
#
# 2019_Miami_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [4]
#
# 2019_New_York_HYROX_PRO
#   Duplicate rows: 3
#   Example Rank Overall values: [1]
#
# 2020_Dallas_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [2, 14]
#
# 2020_Hannover_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [1, 10]
#
# 2020_Karlsruhe_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [2]
#
# 2021_Amsterdam_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [1]
#
# 2021_Austin_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [2]
#
# 2021_Dallas_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [1]
#
# 2021_Hamburg_HYROX_PRO
#   Duplicate rows: 9
#   Example Rank Overall values: [1, 2, 3]
#
# 2021_Leipzig_HYROX_PRO
#   Duplicate rows: 3
#   Example Rank Overall values: [1]
#
# 2021_London_HYROX_PRO
#   Duplicate rows: 5
#   Example Rank Overall values: [1, 2]
#
# 2021_Los_Angeles_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [1]
#
# 2021_New_York_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [1, 20]
#
# 2022_Basel_HYROX_PRO
#   Duplicate rows: 19
#   Example Rank Overall values: [1, 3, 6]
#
# 2022_Birmingham_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [8]
#
# 2022_Bremen_HYROX_PRO
#   Duplicate rows: 10
#   Example Rank Overall values: [1, 3, 20]
#
# 2022_Chicago_HYROX_PRO
#   Duplicate rows: 17
#   Example Rank Overall values: [1, 4, 9]
#
# 2022_Dallas_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [2]
#
# 2022_Essen_HYROX_PRO
#   Duplicate rows: 18
#   Example Rank Overall values: [10, 17, 36]
#
# 2022_Frankfurt_HYROX_PRO
#   Duplicate rows: 79
#   Example Rank Overall values: [2, 22, 23]
#
# 2022_Hamburg_HYROX_PRO
#   Duplicate rows: 28
#   Example Rank Overall values: [1, 5, 8]
#
# 2022_Hong_Kong_HYROX_PRO
#   Duplicate rows: 6
#   Example Rank Overall values: [5, 12, 26]
#
# 2022_Karlsruhe_HYROX_PRO
#   Duplicate rows: 32
#   Example Rank Overall values: [1, 4, 12]
#
# 2022_Las_Vegas_HYROX_PRO
#   Duplicate rows: 101
#   Example Rank Overall values: [11, 19, 26]
#
# 2022_London_HYROX_PRO
#   Duplicate rows: 143
#   Example Rank Overall values: [4, 5, 10]
#
# 2022_Los_Angeles_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [2]
#
# 2022_Maastricht_HYROX_PRO
#   Duplicate rows: 14
#   Example Rank Overall values: [1, 5, 6]
#
# 2022_Madrid_HYROX_PRO
#   Duplicate rows: 8
#   Example Rank Overall values: [2, 23, 25]
#
# 2022_Manchester_HYROX_PRO
#   Duplicate rows: 50
#   Example Rank Overall values: [4, 5, 6]
#
# 2022_München_HYROX_PRO
#   Duplicate rows: 45
#   Example Rank Overall values: [2, 4, 8]
#
# 2022_New_York_HYROX_PRO
#   Duplicate rows: 11
#   Example Rank Overall values: [38, 47, 60]
#
# 2022_Valencia_HYROX_PRO
#   Duplicate rows: 24
#   Example Rank Overall values: [1, 2, 8]
#
# 2022_Wien_HYROX_PRO
#   Duplicate rows: 18
#   Example Rank Overall values: [1, 5, 11]
#
# 2023_Amsterdam_HYROX_PRO
#   Duplicate rows: 6
#   Example Rank Overall values: [2, 3, 5]
#
# 2023_Barcelona_HYROX_PRO
#   Duplicate rows: 8
#   Example Rank Overall values: [10, 20, 8]
#
# 2023_Bilbao_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [7, 8]
#
# 2023_Birmingham_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [7]
#
# 2023_Chicago_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [1]
#
# 2023_Dallas_HYROX_PRO
#   Duplicate rows: 8
#   Example Rank Overall values: [22, 1, 6]
#
# 2023_Dubai_HYROX_PRO
#   Duplicate rows: 6
#   Example Rank Overall values: [13, 38, 19]
#
# 2023_Dublin_HYROX_PRO
#   Duplicate rows: 8
#   Example Rank Overall values: [1, 2, 23]
#
# 2023_Glasgow_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [13, 28]
#
# 2023_Hamburg_HYROX_PRO
#   Duplicate rows: 6
#   Example Rank Overall values: [15, 98, 20]
#
# 2023_Hong_Kong_HYROX_PRO
#   Duplicate rows: 6
#   Example Rank Overall values: [4, 24, 8]
#
# 2023_Houston_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [5, 28]
#
# 2023_Karlsruhe_HYROX_PRO
#   Duplicate rows: 56
#   Example Rank Overall values: [1, 3, 7]
#
# 2023_Köln_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [2, 37]
#
# 2023_London_HYROX_PRO
#   Duplicate rows: 34
#   Example Rank Overall values: [3, 7, 10]
#
# 2023_Los_Angeles_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [1]
#
# 2023_Madrid_HYROX_PRO
#   Duplicate rows: 8
#   Example Rank Overall values: [55, 72, 6]
#
# 2023_Malaga_HYROX_PRO
#   Duplicate rows: 26
#   Example Rank Overall values: [3, 7, 18]
#
# 2023_Malmö_HYROX_PRO
#   Duplicate rows: 8
#   Example Rank Overall values: [5, 29, 51]
#
# 2023_Manchester_HYROX_PRO
#   Duplicate rows: 104
#   Example Rank Overall values: [3, 4, 5]
#
# 2023_Milan_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [4, 1]
#
# 2023_München_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [87, 33]
#
# 2023_Rimini_HYROX_PRO
#   Duplicate rows: 12
#   Example Rank Overall values: [4, 5, 32]
#
# 2023_Stockholm_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [3, 20]
#
# 2023_Stuttgart_HYROX_PRO
#   Duplicate rows: 61
#   Example Rank Overall values: [2, 4, 12]
#
# 2023_Valencia_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [8, 76]
#
# 2023_Warschau_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [1, 52]
#
# 2023_Wien_HYROX_PRO
#   Duplicate rows: 18
#   Example Rank Overall values: [1, 7, 9]
#
# 2023_World_Championships_Manchester_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [24, 1]
#
# 2024_Amsterdam_HYROX_PRO_-_Friday
#   Duplicate rows: 4
#   Example Rank Overall values: [5, 88]
#
# 2024_Amsterdam_HYROX_PRO_-_Saturday
#   Duplicate rows: 2
#   Example Rank Overall values: [63]
#
# 2024_Cape_Town_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [78]
#
# 2024_Gainful_Anaheim_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [1, 10]
#
# 2024_Gdansk_HYROX_PRO
#   Duplicate rows: 14
#   Example Rank Overall values: [1, 14, 21]
#
# 2024_Glasgow_HYROX_PRO
#   Duplicate rows: 8
#   Example Rank Overall values: [57, 68, 173]
#
# 2024_Karlsruhe_HYROX_PRO
#   Duplicate rows: 14
#   Example Rank Overall values: [28, 60, 89]
#
# 2024_Katowice_HYROX_PRO
#   Duplicate rows: 6
#   Example Rank Overall values: [9, 96, 1]
#
# 2024_Maastricht_HYROX_PRO
#   Duplicate rows: 4
#   Example Rank Overall values: [4, 7]
#
# 2024_Madrid_HYROX_PRO
#   Duplicate rows: 6
#   Example Rank Overall values: [6, 26, 43]
#
# 2024_Malaga_HYROX_PRO
#   Duplicate rows: 6
#   Example Rank Overall values: [54, 60, 108]
#
# 2024_Milan_HYROX_PRO
#   Duplicate rows: 10
#   Example Rank Overall values: [58, 65, 110]
#
# 2024_New_York_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [11]
#
# 2024_Nice_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [1]
#
# 2024_Singapore_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [8]
#
# 2024_World_Championships_Nice_HYROX_PRO
#   Duplicate rows: 18
#   Example Rank Overall values: [3, 15, 35]
#
# 2025_Gent_HYROX_PRO_-_Sunday
#   Duplicate rows: 2
#   Example Rank Overall values: [2]
#
# 2025_Johannesburg_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [20]
#
# U.S._Championships_of_Fitness_2021_-_Chicago_HYROX_PRO
#   Duplicate rows: 2
#   Example Rank Overall values: [2]
#
#
# HYROX_GORUCK:
# Total duplicate rows detected: 13
# Rows that will be removed: 7
#
# Duplicate breakdown per source file:
#
# 2022_New_York_HYROX_GORUCK
#   Duplicate rows: 5
#   Example Rank Overall values: [1, 3]
#
# 2023_Houston_HYROX_GORUCK
#   Duplicate rows: 2
#   Example Rank Overall values: [1]
#
# 2024_Washington_-_North_American_Championships_HYROX_GORUCK
#   Duplicate rows: 6
#   Example Rank Overall values: [2, 4]
#
#
# HYROX_PRO_DOUBLES:
# Total duplicate rows detected: 632
# Rows that will be removed: 316
#
# Duplicate breakdown per source file:
#
# 2024_Malaga_HYROX_PRO_DOUBLES
#   Duplicate rows: 2
#   Example Rank Overall values: [11]
#
# 2024_World_Championships_Nice_HYROX_PRO_DOUBLES
#   Duplicate rows: 8
#   Example Rank Overall values: [3, 285, 44]
#
# 2025_Cologne_HYROX_PRO_DOUBLES_-_Overall
#   Duplicate rows: 622
#   Example Rank Overall values: [1, 2, 3]

# %% [markdown]
# #### Notes:
# * Cologne has all rows duplicated in the doubles (https://results.hyrox.com/season-7/?page=1&event=HDP_COLOGNE25_OVERALL&num_results=100&pid=list&pidp=ranking_nav&ranking=time_finish_netto&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search%5Bnation%5D=%25)
# * Same in other datasets.

# %%
# ---------------------------------
# GLOBAL DATA HEALTH SUMMARY
# ---------------------------------

total_rows_all_divisions = 0
total_duplicate_rows = 0
files_with_duplicates = set()

for division, df in division_datasets.items():

    # Count total rows AFTER cleaning
    total_rows_all_divisions += len(df)

    # Detect duplicates again on original logic (before drop)
    duplicate_mask = df.duplicated(keep=False)

    if duplicate_mask.any():
        duplicates_df = df.loc[duplicate_mask]
        total_duplicate_rows += len(duplicates_df)

        dup_files = duplicates_df["source_file"].unique()
        files_with_duplicates.update(dup_files)

# Total unique files processed
all_files_processed = set()

for division, df in division_datasets.items():
    all_files_processed.update(df["source_file"].unique())

# Add empty files to total file count
all_files_processed.update(empty_files_detected)

total_files = len(all_files_processed)

# Files with issues
files_with_issues = set(empty_files_detected).union(files_with_duplicates)

n_files_with_issues = len(files_with_issues)

# Percentages
if total_files > 0:
    pct_files_with_issues = (n_files_with_issues / total_files) * 100
else:
    pct_files_with_issues = 0


print("\n============================")
print("GLOBAL DATA QUALITY SUMMARY")
print("============================")

print(f"Total rows across all divisions: {total_rows_all_divisions}")
print(f"Total duplicate rows detected: {total_duplicate_rows}")

if total_rows_all_divisions > 0:
    print(f"Duplicate rows percentage: {(total_duplicate_rows / total_rows_all_divisions) * 100:.2f}%")

print("\nTotal files processed:", total_files)
print("Files with issues (empty or duplicates):", n_files_with_issues)
print(f"Percentage of files with issues: {pct_files_with_issues:.2f}%")
# Out:
# ============================
# GLOBAL DATA QUALITY SUMMARY
# ============================
# Total rows across all divisions: 566108
# Total duplicate rows detected: 0
# Duplicate rows percentage: 0.00%
#
# Total files processed: 1088
# Files with issues (empty or duplicates): 145
# Percentage of files with issues: 13.33%

# %% [markdown]
# # CHECK 2: Races where scraping only ran the first page

# %%
# Check row counts per combination of Race, Division, and Gender in DOUBLES
doubles_counts_gender = HYROX.groupby(['Race', 'Division', 'Gender']).size()
doubles_100 = doubles_counts_gender[doubles_counts_gender == 100]
print("DOUBLES dataset counts (exactly 100 rows for Race+Division+Gender):")
print(doubles_100)

# Check row counts per combination of Race, Division, and Gender in HYROX_pro
pro_counts_gender = HYROX_PRO.groupby(['Race', 'Division', 'Gender']).size()
pro_100 = pro_counts_gender[pro_counts_gender == 100]
print("\nHYROX_pro dataset counts (exactly 100 rows for Race+Division+Gender):")
print(pro_100)
# Out:
# DOUBLES dataset counts (exactly 100 rows for Race+Division+Gender):
# Race            Division  Gender
# 2023 Stuttgart  HYROX     Women     100
# dtype: int64
#
# HYROX_pro dataset counts (exactly 100 rows for Race+Division+Gender):
# Race             Division   Gender
# 2023 Manchester  HYROX PRO  Men       100
# 2025 Manchester  HYROX PRO  Women     100
# dtype: int64

# %%
import os

root_folder = r"Datasets\Hyrox"

# Function to find and delete CSVs containing a specific combination
def delete_csvs_with_combinations(df, combinations):
    for subdir, _, files in os.walk(root_folder):
        for file in files:
            if file.lower().endswith(".csv") and file not in ["DOUBLES.csv", "HYROX_pro.csv"]:
                file_path = os.path.join(subdir, file)
                temp_df = pd.read_csv(file_path)
                
                # Check if any of the "exactly 100 rows" combinations are fully contained in this CSV
                for comb in combinations.index:
                    race, division, gender = comb
                    matching_rows = temp_df[
                        (temp_df['Race'] == race) &
                        (temp_df['Division'] == division) &
                        (temp_df['Gender'] == gender)
                    ]
                    if len(matching_rows) == 100:
                        print(f"Deleting {file_path} (matches {comb})")
                        os.remove(file_path)
                        break  # move to next file once deleted

# Delete for DOUBLES
if not doubles_100.empty:
    delete_csvs_with_combinations(DOUBLES_df, doubles_100)

# Delete for HYROX_pro
if not pro_100.empty:
    delete_csvs_with_combinations(HYROX_pro_df, pro_100)

# %% [markdown]
# # CHECK 3: Empty datasets

# %%
import os
import pandas as pd

root_folder = r"Datasets\Hyrox"

# Delete CSVs with only headers
for subdir, _, files in os.walk(root_folder):
    for file in files:
        if file.lower().endswith(".csv") and file not in ["DOUBLES.csv", "HYROX_pro.csv"]:
            file_path = os.path.join(subdir, file)
            temp_df = pd.read_csv(file_path)
            if temp_df.shape[0] == 0:  # only header
                os.remove(file_path)
                print(f"Deleted empty file: {file_path}")

print("Empty CSV files removed.")

# %% [markdown]
# # CHECK 4: Duplicated races - overall + Saturday or other day

# %%
# Columns to check for duplicates (ignoring Division)
subset_cols = ['Race', 'Gender', 'Name', 'Nation', 'Age Group', 'Total Time']

# Set display options for wide output
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 2000)
pd.set_option('display.max_colwidth', None)

# Show duplicate rows in DOUBLES based on subset
duplicates_doubles_rows = DOUBLES_df[DOUBLES_df.duplicated(subset=subset_cols, keep=False)]
print(f"DOUBLES dataset duplicate rows based on {subset_cols} ({len(duplicates_doubles_rows)} total):")
print(duplicates_doubles_rows)

# Show duplicate rows in HYROX_pro based on subset
duplicates_pro_rows = HYROX_pro_df[HYROX_pro_df.duplicated(subset=subset_cols, keep=False)]
print(f"HYROX_pro dataset duplicate rows based on {subset_cols} ({len(duplicates_pro_rows)} total):")
print(duplicates_pro_rows)

# %% [markdown]
# # CHECK 5: Missing genders in races.

# %%
# Function to check missing genders per Race+Division
def check_missing_genders(df, expected_genders):
    missing_info = {}
    for (race, division), group in df.groupby(['Race', 'Division']):
        present_genders = set(group['Gender'].unique())
        missing = set(expected_genders) - present_genders
        if missing:
            missing_info[(race, division)] = missing
    return missing_info

# DOUBLES dataset (expected genders: Men, Women, Mixed)
doubles_missing_genders = check_missing_genders(DOUBLES_df, ['Men', 'Women', 'Mixed'])
print("DOUBLES missing genders per Race+Division:")
print(doubles_missing_genders)

# HYROX_pro dataset (expected genders: Men, Women)
pro_missing_genders = check_missing_genders(HYROX_pro_df, ['Men', 'Women'])
print("\nHYROX_pro missing genders per Race+Division:")
print(pro_missing_genders)
