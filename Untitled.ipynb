# %%
import time
import random
import pandas as pd
import os
from concurrent.futures import ThreadPoolExecutor

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, TimeoutException

# ==========================
# CONFIG
# ==========================

BASE_URLS = {
    "Season_1": "https://results.hyrox.com/season-1/",
    "Season_2": "https://results.hyrox.com/season-2/",
    "Season_3": "https://results.hyrox.com/season-3/",
    "Season_4": "https://results.hyrox.com/season-4/",
    "Season_5": "https://results.hyrox.com/season-5/"
}

SAVE_ROOT = r"Datasets\Hyrox"
MAX_THREADS = 20  # number of concurrent races

def human_pause(a=3, b=7):
    time.sleep(random.uniform(a, b))

# ==========================
# SELENIUM DRIVER
# ==========================

def create_driver():
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.add_argument("--headless=new")  # headless for parallel threads
    options.add_argument(
        "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
    return webdriver.Chrome(options=options)

# ==========================
# SCRAPE FUNCTION
# ==========================

def scrape_pages(driver, race_name, division, gender_label, race_results):
    """Scrape all pages for a given race/division/gender."""
    is_doubles = "DOUBLES" in division.upper()
    page_number = 1

    while True:
        try:
            WebDriverWait(driver, 25).until(lambda d: 
                "There are currently no results available" in d.page_source
                or len(d.find_elements(By.CSS_SELECTOR, "li.list-group-item.row")) > 1
            )
        except TimeoutException:
            print(f"[{race_name}] Timeout waiting for results in {division} - {gender_label}")
            return False

        # Check no-results message
        try:
            no_result_elem = driver.find_element(By.XPATH,
                "//*[contains(text(),'There are currently no results available')]"
            )
            if no_result_elem.is_displayed():
                print(f"[{race_name}] No results for {division} - {gender_label}")
                return False
        except NoSuchElementException:
            pass

        rows = driver.find_elements(By.CSS_SELECTOR, "li.list-group-item.row")
        rows = [r for r in rows if "list-group-header" not in r.get_attribute("class")]

        if not rows:
            print(f"[{race_name}] No rows found for {division} - {gender_label}")
            return False

        scraped_any = False
        for row in rows:
            try:
                rank = row.find_element(By.CSS_SELECTOR, ".place-primary").text
                age_rank = row.find_element(By.CSS_SELECTOR, ".place-secondary").text
                total_time = row.find_element(By.CSS_SELECTOR, ".type-time").text.replace("Total", "").strip()
                age_group = row.find_element(By.CSS_SELECTOR, ".type-age_class").text.replace("Age Group", "").strip()

                if is_doubles:
                    members = row.find_elements(By.CSS_SELECTOR, ".type-relay_member a")
                    member_names = " & ".join([m.text for m in members])
                    race_results.append([
                        race_name, division, gender_label,
                        rank, age_rank, member_names, "",
                        age_group, total_time
                    ])
                else:
                    name = row.find_element(By.CSS_SELECTOR, "h4.type-fullname").text
                    nation = row.find_element(By.CSS_SELECTOR, ".nation__abbr").text
                    race_results.append([
                        race_name, division, gender_label,
                        rank, age_rank, name, nation,
                        age_group, total_time
                    ])
                scraped_any = True
            except:
                continue

        print(f"[{race_name}] Page {page_number} scraped for {division} - {gender_label}")
        page_number += 1

        # Go to next page
        try:
            next_button = driver.find_element(By.XPATH, "//a[text()='>']")
            driver.execute_script("arguments[0].click();", next_button)
            human_pause(3, 6)
        except NoSuchElementException:
            break

    return scraped_any

# ==========================
# RACE SCRAPER (THREAD TARGET)
# ==========================

def scrape_race(season, base_url, race_name, race_value):
    driver = create_driver()
    season_folder = os.path.join(SAVE_ROOT, season)
    os.makedirs(season_folder, exist_ok=True)

    safe_name = race_name.replace(" ", "_").replace("/", "-")
    print(f"\n[{race_name}] Starting race scraping")

    driver.get(base_url)
    human_pause(4, 6)
    Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
    human_pause(2,4)
    select_division = Select(driver.find_element(By.ID, "default-lists-event"))
    available = [o.text for o in select_division.options]

    def build_priority(base_name):
        priority = []
        if base_name in available:
            priority.append(base_name)
        overall = f"{base_name} - Overall"
        if overall in available:
            priority.append(overall)
        other = [d for d in available if d.startswith(f"{base_name} -") and d not in priority]
        priority.extend(other)
        return priority

    def process_group(base_name):
        priority_list = build_priority(base_name)
        if not priority_list:
            print(f"[{race_name}] No {base_name} divisions available")
            return

        for div in priority_list:
            div_safe = div.replace(" ", "_").replace("/", "-")
            file_path = os.path.join(season_folder, f"{safe_name}_{div_safe}.csv")
            if os.path.exists(file_path):
                print(f"[{race_name}] {div} already scraped")
                continue

            print(f"[{race_name}] Trying {div}")
            is_doubles = "DOUBLES" in div.upper()
            genders = [("M","Male"),("W","Women")] if not is_doubles else [("M","Male"),("W","Female"),("X","Mixed")]

            division_results = []
            division_has_data = False

            driver.get(base_url)
            human_pause(3,6)
            Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
            human_pause(2,4)
            Select(driver.find_element(By.ID, "default-lists-event")).select_by_visible_text(div)
            human_pause(2,4)

            try:
                gender_dropdown = Select(driver.find_element(By.ID, "default-lists-sex"))
                available_gender_values = [o.get_attribute("value") for o in gender_dropdown.options]
            except NoSuchElementException:
                available_gender_values = []

            valid_genders = [(code, label) for code, label in genders if code in available_gender_values]
            if not valid_genders:
                print(f"[{race_name}] {div} has no gender categories")
                continue

            for idx, (gender_code, gender_label) in enumerate(valid_genders):
                print(f"[{race_name}] Scraping gender: {gender_label} in {div}")
                driver.get(base_url)
                human_pause(3,6)
                Select(driver.find_element(By.ID, "default-lists-event_main_group")).select_by_value(race_value)
                human_pause(2,4)
                Select(driver.find_element(By.ID, "default-lists-event")).select_by_visible_text(div)
                human_pause(2,4)
                Select(driver.find_element(By.ID, "default-lists-sex")).select_by_value(gender_code)
                Select(driver.find_element(By.ID, "default-num_results")).select_by_value("100")
                human_pause(2,4)
                driver.find_element(By.ID, "default-submit").click()
                human_pause(5,10)

                has_data = scrape_pages(driver, race_name, div, gender_label, division_results)
                if idx == 0 and not has_data:
                    print(f"[{race_name}] {div} had NO DATA")
                    division_has_data = False
                    break
                if has_data:
                    division_has_data = True

            if division_has_data:
                df = pd.DataFrame(
                    division_results,
                    columns=["Race","Division","Gender",
                             "Rank Overall","Rank Age Group",
                             "Name","Nation","Age Group","Total Time"]
                )
                df.to_csv(file_path,index=False)
                print(f"[{race_name}] Saved {len(df)} rows for {div}")

    process_group("HYROX PRO")
    process_group("HYROX PRO DOUBLES")

    driver.quit()
    return f"[{race_name}] Finished scraping"

# ==========================
# MAIN LOOP
# ==========================

all_tasks = []
for season, base_url in BASE_URLS.items():
    driver_main = create_driver()
    driver_main.get(base_url)
    human_pause(4,6)
    try:
        WebDriverWait(driver_main, 25).until(EC.presence_of_element_located((By.ID, "default-lists-event_main_group")))
    except TimeoutException:
        continue
    race_dropdown = Select(driver_main.find_element(By.ID, "default-lists-event_main_group"))
    races = [(race_dropdown.options[i].text, race_dropdown.options[i].get_attribute("value")) for i in range(len(race_dropdown.options))]
    driver_main.quit()
    for race_name, race_value in races:
        all_tasks.append((season, base_url, race_name, race_value))

# Threaded execution
with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
    futures = [executor.submit(scrape_race, *task) for task in all_tasks]
    for f in futures:
        print(f.result())

print("\nALL DONE.")
# Out:
# [2019 Oberhausen] Starting race scraping
#
# [2019 Karlsruhe] Starting race scraping
#
# [2020 Dallas] Starting race scraping
#
# [2018 Essen] Starting race scraping
#
# [2019 Wien] Starting race scraping
#
# [2018 Wien] Starting race scraping
# [2020 Karlsruhe] Starting race scraping
#
# [2018 Stuttgart] Starting race scraping
#
#
# [2019 Nürnberg] Starting race scraping
#
# [World Championships] Starting race scraping
#
# [2020 Hannover] Starting race scraping
#
# [2019 Frankfurt] Starting race scraping
#
# [2019 Hannover] Starting race scraping
#
# [2019 New York] Starting race scraping
#
# [2018 Leipzig] Starting race scraping
#
# [2020 Chicago] Starting race scraping
#
# [2020 Elite 12] Starting race scraping
#
# [2019 Hamburg] Starting race scraping
#
# [2019 Essen] Starting race scraping
#
# [2018 Hamburg] Starting race scraping
# [2020 Dallas] Trying HYROX PRO
# [2019 Karlsruhe] Trying HYROX PRO
# [2019 Oberhausen] Trying HYROX PRO
# [2019 Frankfurt] Trying HYROX PRO
# [2019 New York] Trying HYROX PRO
# [2020 Elite 12] No HYROX PRO divisions available
# [2020 Elite 12] No HYROX PRO DOUBLES divisions available
# [2018 Leipzig] Trying HYROX PRO
# [2019 Nürnberg] Trying HYROX PRO
# [2020 Chicago] Trying HYROX PRO
# [2019 Wien] Trying HYROX PRO
# [2018 Stuttgart] Trying HYROX PRO
# [2018 Essen] Trying HYROX PRO
# [2019 Hamburg] Trying HYROX PRO
# [2018 Wien] Trying HYROX PRO
# [2019 Hannover] Trying HYROX PRO
# [2018 Hamburg] Trying HYROX PRO
# [2019 Essen] Trying HYROX PRO
# [2020 Hannover] Trying HYROX PRO
# [2020 Karlsruhe] Trying HYROX PRO
# [2019 Oberhausen] Scraping gender: Male in HYROX PRO
# [2020 Dallas] Scraping gender: Male in HYROX PRO
# [2019 Karlsruhe] Scraping gender: Male in HYROX PRO
#
# [2019 Leipzig] Starting race scraping
# [2019 Frankfurt] Scraping gender: Male in HYROX PRO
# [2019 New York] Scraping gender: Male in HYROX PRO
# [2018 Stuttgart] Scraping gender: Male in HYROX PRO
# [2018 Wien] Scraping gender: Male in HYROX PRO
# [2019 Hamburg] Scraping gender: Male in HYROX PRO
# [2018 Leipzig] Scraping gender: Male in HYROX PRO
# [2019 Nürnberg] Scraping gender: Male in HYROX PRO
# [2020 Hannover] Scraping gender: Male in HYROX PRO
# [World Championships] Trying HYROX PRO
# [2019 Wien] Scraping gender: Male in HYROX PRO
# [2018 Essen] Scraping gender: Male in HYROX PRO
# [2020 Chicago] Scraping gender: Male in HYROX PRO
# [2019 Hannover] Scraping gender: Male in HYROX PRO
# [2020 Karlsruhe] Scraping gender: Male in HYROX PRO
# [2019 Essen] Scraping gender: Male in HYROX PRO
# [2018 Hamburg] Scraping gender: Male in HYROX PRO
# [2019 Leipzig] Trying HYROX PRO
# [World Championships] Scraping gender: Male in HYROX PRO
# [2019 Leipzig] Scraping gender: Male in HYROX PRO
# [World Championships] No results for HYROX PRO - Male
# [World Championships] HYROX PRO had NO DATA
# [World Championships] No HYROX PRO DOUBLES divisions available
# [2018 Essen] Page 1 scraped for HYROX PRO - Male
# [2018 Essen] Scraping gender: Women in HYROX PRO
# [2018 Leipzig] Page 1 scraped for HYROX PRO - Male
# [2018 Leipzig] Scraping gender: Women in HYROX PRO
# [2018 Wien] Page 1 scraped for HYROX PRO - Male
# [2018 Wien] Scraping gender: Women in HYROX PRO
# [2019 Wien] Page 1 scraped for HYROX PRO - Male
# [2019 Wien] Scraping gender: Women in HYROX PRO
# [2019 Oberhausen] Page 1 scraped for HYROX PRO - Male
# [2019 Oberhausen] Scraping gender: Women in HYROX PRO
# [2018 Stuttgart] Page 1 scraped for HYROX PRO - Male
# [2018 Stuttgart] Scraping gender: Women in HYROX PRO
# [2020 Dallas] Page 1 scraped for HYROX PRO - Male
# [2020 Dallas] Scraping gender: Women in HYROX PRO
# [2019 Frankfurt] Page 1 scraped for HYROX PRO - Male
# [2019 Frankfurt] Scraping gender: Women in HYROX PRO
# [2020 Chicago] Page 1 scraped for HYROX PRO - Male
# [2020 Chicago] Scraping gender: Women in HYROX PRO
# [2019 Essen] Page 1 scraped for HYROX PRO - Male
# [2019 Essen] Scraping gender: Women in HYROX PRO
# [2019 Leipzig] Page 1 scraped for HYROX PRO - Male
# [2019 Leipzig] Scraping gender: Women in HYROX PRO
# [2019 Karlsruhe] Page 1 scraped for HYROX PRO - Male
# [2019 Nürnberg] Page 1 scraped for HYROX PRO - Male
# [2019 Nürnberg] Scraping gender: Women in HYROX PRO
# [2020 Karlsruhe] Page 1 scraped for HYROX PRO - Male
# [2020 Karlsruhe] Scraping gender: Women in HYROX PRO
# [2018 Essen] Page 1 scraped for HYROX PRO - Women
# [2018 Essen] Saved 48 rows for HYROX PRO
# [2018 Essen] No HYROX PRO DOUBLES divisions available
# [2019 Hamburg] Page 1 scraped for HYROX PRO - Male
# [2020 Hannover] Page 1 scraped for HYROX PRO - Male
# [World Championships] Finished scraping
# [2019 Hannover] Page 1 scraped for HYROX PRO - Male
# [2019 New York] Page 1 scraped for HYROX PRO - Male
# [2019 New York] Scraping gender: Women in HYROX PRO
# [2018 Leipzig] Page 1 scraped for HYROX PRO - Women
# [2019 Karlsruhe] Page 2 scraped for HYROX PRO - Male
# [2019 Karlsruhe] Scraping gender: Women in HYROX PRO
# [2018 Leipzig] Saved 47 rows for HYROX PRO
# [2018 Leipzig] No HYROX PRO DOUBLES divisions available
#
# [2019 Miami] Starting race scraping
# [2019 Oberhausen] Page 1 scraped for HYROX PRO - Women
# [2018 Wien] Page 1 scraped for HYROX PRO - Women
# [2018 Stuttgart] Page 1 scraped for HYROX PRO - Women
# [2019 Hannover] Page 2 scraped for HYROX PRO - Male
# [2019 Hannover] Scraping gender: Women in HYROX PRO
# [2019 Oberhausen] Saved 49 rows for HYROX PRO
# [2019 Oberhausen] No HYROX PRO DOUBLES divisions available
# [2018 Stuttgart] Saved 77 rows for HYROX PRO
# [2018 Stuttgart] No HYROX PRO DOUBLES divisions available
# [2018 Wien] Saved 54 rows for HYROX PRO
# [2018 Wien] No HYROX PRO DOUBLES divisions available
# [2019 Wien] Page 1 scraped for HYROX PRO - Women
# [2019 Leipzig] Page 1 scraped for HYROX PRO - Women
# [2019 Miami] Trying HYROX PRO[2019 Leipzig] Saved 69 rows for HYROX PRO
# [2019 Leipzig] No HYROX PRO DOUBLES divisions available
#
# [2019 Wien] Saved 72 rows for HYROX PRO
# [2019 Wien] No HYROX PRO DOUBLES divisions available
# [2019 Frankfurt] Page 1 scraped for HYROX PRO - Women
# [2019 Frankfurt] Saved 90 rows for HYROX PRO
# [2019 Frankfurt] No HYROX PRO DOUBLES divisions available
# [2019 Essen] Page 1 scraped for HYROX PRO - Women
# [2020 Hannover] Page 2 scraped for HYROX PRO - Male
# [2020 Hannover] Scraping gender: Women in HYROX PRO
# [2019 Essen] Saved 70 rows for HYROX PRO
# [2019 Essen] No HYROX PRO DOUBLES divisions available
# [2020 Chicago] Page 1 scraped for HYROX PRO - Women
# [2020 Dallas] Page 1 scraped for HYROX PRO - Women
# [2020 Chicago] Saved 116 rows for HYROX PRO
# [2020 Chicago] No HYROX PRO DOUBLES divisions available
# [2020 Dallas] Saved 98 rows for HYROX PRO
# [2020 Dallas] No HYROX PRO DOUBLES divisions available
# [2020 Karlsruhe] Page 1 scraped for HYROX PRO - Women
# [2020 Karlsruhe] Saved 118 rows for HYROX PRO
# [2020 Karlsruhe] No HYROX PRO DOUBLES divisions available
# [2018 Hamburg] Page 1 scraped for HYROX PRO - Male
# [2019 Hamburg] Page 2 scraped for HYROX PRO - Male
# [2019 Hamburg] Scraping gender: Women in HYROX PRO
# [2019 Miami] Scraping gender: Male in HYROX PRO
# [2019 Oberhausen] Finished scraping
#
# [2021 Dallas] Starting race scraping
#
# [2021 Orlando] Starting race scraping
#
# [2021 Chicago] Starting race scraping
#
# [2021 Austin] Starting race scraping
#
# [2022 Los Angeles] Starting race scraping
# [2019 Nürnberg] Page 1 scraped for HYROX PRO - Women
# [2019 Nürnberg] Saved 85 rows for HYROX PRO
# [2019 Nürnberg] No HYROX PRO DOUBLES divisions available
# [2021 Chicago] Trying HYROX PRO
# [2019 Karlsruhe] Page 1 scraped for HYROX PRO - Women
# [2019 Karlsruhe] Saved 127 rows for HYROX PRO
# [2019 Karlsruhe] No HYROX PRO DOUBLES divisions available
# [2021 Dallas] Trying HYROX PRO
# [2021 Orlando] Trying HYROX PRO
# [2019 New York] Page 1 scraped for HYROX PRO - Women
# [2021 Austin] Trying HYROX PRO
# [2019 New York] Saved 91 rows for HYROX PRO
# [2019 New York] No HYROX PRO DOUBLES divisions available
# [2022 Los Angeles] Trying HYROX PRO
# [2021 Orlando] Scraping gender: Male in HYROX PRO
# [2021 Dallas] Scraping gender: Male in HYROX PRO
# [2021 Chicago] Scraping gender: Male in HYROX PRO
# [2019 Hannover] Page 1 scraped for HYROX PRO - Women
# [2019 Hannover] Saved 138 rows for HYROX PRO
# [2019 Hannover] No HYROX PRO DOUBLES divisions available
# [2021 Austin] Scraping gender: Male in HYROX PRO
#
# [2022 Frankfurt] Starting race scraping
# [2022 Los Angeles] Scraping gender: Male in HYROX PRO
# [2019 Karlsruhe] Finished scraping
# [2019 Nürnberg] Finished scraping
#
# [2022 Dallas] Starting race scraping
# [2019 Hannover] Finished scraping
# [2018 Stuttgart] Finished scraping
# [2018 Wien] Finished scraping
# [2018 Essen] Finished scraping
#
# [2022 London] Starting race scraping
#
# [2022 Essen] Starting race scraping
#
# [U.S. Championships of Fitness 2021 - Chicago] Starting race scraping
#
# [2022 Chicago] Starting race scraping
#
# [2022 Las Vegas] Starting race scraping
#
# [2022 Maastricht] Starting race scraping
#
# [2022 Karlsruhe] Starting race scraping
#
# [2022 Wien] Starting race scraping
#
# [2022 Bremen] Starting race scraping
# [2022 Frankfurt] Trying HYROX PRO
# [2022 Dallas] Trying HYROX PRO
# [2022 Chicago] Trying HYROX PRO[2022 London] Trying HYROX PRO
#
# [2022 Las Vegas] Trying HYROX PRO
# [2022 Maastricht] Trying HYROX PRO[2022 Wien] Trying HYROX PRO
# [2022 Essen] Trying HYROX PRO
#
# [2022 Bremen] Trying HYROX PRO
# [2020 Hannover] Page 1 scraped for HYROX PRO - Women
# [2022 Frankfurt] Scraping gender: Male in HYROX PRO
# [2019 Miami] Page 1 scraped for HYROX PRO - Male
# [2019 Miami] Scraping gender: Women in HYROX PRO
# [U.S. Championships of Fitness 2021 - Chicago] Trying HYROX PRO
# [2022 Karlsruhe] Trying HYROX PRO
# [2020 Hannover] Saved 175 rows for HYROX PRO
# [2020 Hannover] No HYROX PRO DOUBLES divisions available
# [2022 Dallas] Scraping gender: Male in HYROX PRO
# [2022 Chicago] Scraping gender: Male in HYROX PRO
# [2018 Hamburg] Page 2 scraped for HYROX PRO - Male
# [2018 Hamburg] Scraping gender: Women in HYROX PRO
# [2022 London] Scraping gender: Male in HYROX PRO
# [2022 Las Vegas] Scraping gender: Male in HYROX PRO
# [2019 Hamburg] Page 1 scraped for HYROX PRO - Women
# [2019 Hamburg] Saved 192 rows for HYROX PRO
# [2019 Hamburg] No HYROX PRO DOUBLES divisions available
# [2021 Orlando] Page 1 scraped for HYROX PRO - Male
# [2021 Orlando] Scraping gender: Women in HYROX PRO
# [2022 Maastricht] Scraping gender: Male in HYROX PRO
# [2022 Bremen] Scraping gender: Male in HYROX PRO
# [2022 Wien] Scraping gender: Male in HYROX PRO
# [2022 Essen] Scraping gender: Male in HYROX PRO
# [2022 Karlsruhe] Scraping gender: Male in HYROX PRO
# [U.S. Championships of Fitness 2021 - Chicago] Scraping gender: Male in HYROX PRO
# [2021 Austin] Page 1 scraped for HYROX PRO - Male
# [2021 Austin] Scraping gender: Women in HYROX PRO
#
# [2021 New York] Starting race scraping
# [2022 Los Angeles] Page 1 scraped for HYROX PRO - Male
# [2022 Los Angeles] Scraping gender: Women in HYROX PRO
# [2021 Dallas] Page 1 scraped for HYROX PRO - Male
# [2021 Dallas] Scraping gender: Women in HYROX PRO
# [2019 Miami] Page 1 scraped for HYROX PRO - Women
# [2021 New York] Trying HYROX PRO
# [2019 Miami] Saved 53 rows for HYROX PRO
# [2019 Miami] No HYROX PRO DOUBLES divisions available
# [2021 Chicago] Page 1 scraped for HYROX PRO - Male
# [2021 Chicago] Scraping gender: Women in HYROX PRO
# [2021 Orlando] Page 1 scraped for HYROX PRO - Women
# [2021 Orlando] Saved 40 rows for HYROX PRO
# [2021 Orlando] No HYROX PRO DOUBLES divisions available
# [2022 Bremen] Page 1 scraped for HYROX PRO - Male
# [2022 Bremen] Scraping gender: Women in HYROX PRO
# [2021 New York] Scraping gender: Male in HYROX PRO
# [2021 Austin] Page 1 scraped for HYROX PRO - Women
# [2021 Austin] Saved 56 rows for HYROX PRO
# [2021 Austin] No HYROX PRO DOUBLES divisions available
# [2021 Dallas] Page 1 scraped for HYROX PRO - Women
# [2022 Los Angeles] Page 1 scraped for HYROX PRO - Women
# [2021 Dallas] Saved 66 rows for HYROX PRO
# [2021 Dallas] No HYROX PRO DOUBLES divisions available
# [2022 Los Angeles] Saved 66 rows for HYROX PRO
# [2022 Los Angeles] No HYROX PRO DOUBLES divisions available
# [2022 Essen] Page 1 scraped for HYROX PRO - Male
# [2022 Essen] Scraping gender: Women in HYROX PRO
# [2018 Hamburg] Page 1 scraped for HYROX PRO - Women
# [2018 Hamburg] Saved 197 rows for HYROX PRO
# [2018 Hamburg] No HYROX PRO DOUBLES divisions available
# [2022 Chicago] Page 1 scraped for HYROX PRO - Male
# [2022 Wien] Page 1 scraped for HYROX PRO - Male
# [2022 Chicago] Scraping gender: Women in HYROX PRO
# [2022 Wien] Scraping gender: Women in HYROX PRO
# [U.S. Championships of Fitness 2021 - Chicago] Page 1 scraped for HYROX PRO - Male
# [U.S. Championships of Fitness 2021 - Chicago] Scraping gender: Women in HYROX PRO
# [2022 Frankfurt] Page 1 scraped for HYROX PRO - Male
# [2022 Frankfurt] Scraping gender: Women in HYROX PRO
# [2021 Chicago] Page 1 scraped for HYROX PRO - Women
# [2021 Chicago] Saved 49 rows for HYROX PRO
# [2021 Chicago] No HYROX PRO DOUBLES divisions available
# [2022 Karlsruhe] Page 1 scraped for HYROX PRO - Male
# [2022 Karlsruhe] Scraping gender: Women in HYROX PRO
# [2022 Dallas] Page 1 scraped for HYROX PRO - Male
# [2022 Dallas] Scraping gender: Women in HYROX PRO
# [2022 Bremen] Page 1 scraped for HYROX PRO - Women
# [2022 Bremen] Saved 76 rows for HYROX PRO
# [2022 Bremen] No HYROX PRO DOUBLES divisions available
# [2018 Hamburg] Finished scraping
# [2018 Leipzig] Finished scraping
# [2020 Elite 12] Finished scraping
# [2020 Karlsruhe] Finished scraping
# [2020 Dallas] Finished scraping
# [2020 Hannover] Finished scraping
# [2020 Chicago] Finished scraping
# [2019 New York] Finished scraping
# [2019 Frankfurt] Finished scraping
# [2019 Wien] Finished scraping
# [2019 Hamburg] Finished scraping
# [2019 Essen] Finished scraping
# [2019 Leipzig] Finished scraping
#
# [2022 München] Starting race scraping
#
# [2022 Manchester] Starting race scraping
#
# [2021 Madrid] Starting race scraping
#
# [2021 Hamburg] Starting race scraping
# [2022 London] Page 1 scraped for HYROX PRO - Male
#
# [2021 Dallas] Starting race scraping
# [2022 Las Vegas] Page 1 scraped for HYROX PRO - Male
# [2022 München] Trying HYROX PRO
# [2022 Manchester] Trying HYROX PRO
# [2021 Madrid] Trying HYROX PRO
# [2021 Hamburg] Trying HYROX PRO
# [2022 Essen] Page 1 scraped for HYROX PRO - Women
# [2022 Essen] Saved 71 rows for HYROX PRO
# [2022 Essen] No HYROX PRO DOUBLES divisions available
# [2022 Maastricht] Page 1 scraped for HYROX PRO - Male
# [2022 Manchester] Scraping gender: Male in HYROX PRO
# [2021 Madrid] Scraping gender: Male in HYROX PRO
# [2022 Wien] Page 1 scraped for HYROX PRO - Women
# [2022 Wien] Saved 75 rows for HYROX PRO
# [2022 Wien] No HYROX PRO DOUBLES divisions available
# [2022 München] Scraping gender: Male in HYROX PRO
# [2019 Miami] Finished scraping
# [2022 Karlsruhe] Page 1 scraped for HYROX PRO - Women
# [2022 Karlsruhe] Saved 80 rows for HYROX PRO
# [2022 Karlsruhe] No HYROX PRO DOUBLES divisions available
# [2021 Hamburg] Scraping gender: Male in HYROX PRO
# [2022 Frankfurt] Page 1 scraped for HYROX PRO - Women
# [2022 Frankfurt] Saved 102 rows for HYROX PRO
# [2022 Frankfurt] No HYROX PRO DOUBLES divisions available
# [2022 Dallas] Page 1 scraped for HYROX PRO - Women
# [2022 Maastricht] Page 2 scraped for HYROX PRO - Male
# [2022 Maastricht] Scraping gender: Women in HYROX PRO
# [U.S. Championships of Fitness 2021 - Chicago] Page 1 scraped for HYROX PRO - Women
# [2021 New York] Page 1 scraped for HYROX PRO - Male
# [2021 New York] Scraping gender: Women in HYROX PRO
# [2021 Dallas] Trying HYROX PRO
# [U.S. Championships of Fitness 2021 - Chicago] Saved 70 rows for HYROX PRO
# [U.S. Championships of Fitness 2021 - Chicago] No HYROX PRO DOUBLES divisions available
# [2022 Dallas] Saved 105 rows for HYROX PRO
# [2022 Dallas] No HYROX PRO DOUBLES divisions available
#
# [2021 Berlin] Starting race scraping
# [2022 London] Page 2 scraped for HYROX PRO - Male
# [2022 London] Scraping gender: Women in HYROX PRO
# [2022 Chicago] Page 1 scraped for HYROX PRO - Women
# [2022 Chicago] Saved 108 rows for HYROX PRO
# [2022 Chicago] No HYROX PRO DOUBLES divisions available
#
# [2021 Birmingham] Starting race scraping
#
# [2021 Stuttgart] Starting race scraping
# [2021 Dallas] Finished scraping
# [2021 Chicago] Finished scraping
# [2021 Orlando] Finished scraping
# [2021 Austin] Finished scraping
# [2022 Los Angeles] Finished scraping
#
# [2021 Amsterdam] Starting race scraping
# [2021 Dallas] Scraping gender: Male in HYROX PRO
# [2021 Berlin] Trying HYROX PRO
# [2021 Birmingham] Trying HYROX PRO[2021 Stuttgart] Trying HYROX PRO
#
# [2021 Amsterdam] Trying HYROX PRO
# [2021 Berlin] Scraping gender: Male in HYROX PRO
#
# [2021 Los Angeles] Starting race scraping
# [2021 Birmingham] Scraping gender: Male in HYROX PRO
# [2021 Stuttgart] Scraping gender: Male in HYROX PRO
# [2022 Las Vegas] Page 2 scraped for HYROX PRO - Male
# [2021 New York] Page 1 scraped for HYROX PRO - Women
# [2021 New York] Saved 91 rows for HYROX PRO
# [2021 New York] No HYROX PRO DOUBLES divisions available
# [2021 Amsterdam] Scraping gender: Male in HYROX PRO
# [2022 Maastricht] Page 1 scraped for HYROX PRO - Women
# [2022 Maastricht] Saved 143 rows for HYROX PRO
# [2022 Maastricht] No HYROX PRO DOUBLES divisions available
# [2021 Los Angeles] Trying HYROX PRO
#
# [2021 London] Starting race scraping
# [2022 Frankfurt] Finished scraping
#
# [WorldChampionship - Leipzig] Starting race scraping
# [2022 Dallas] Finished scraping
#
# [2023 Stockholm] Starting race scraping
#
# [2021 Leipzig] Starting race scraping
#
# [2023 London] Starting race scraping
#
# [2023 Dallas] Starting race scraping
# [2023 Hong Kong] Starting race scraping
#
# [2021 Los Angeles] Scraping gender: Male in HYROX PRO
# [2021 London] Trying HYROX PRO[WorldChampionship - Leipzig] Trying HYROX PRO
#
#
# [2023 Barcelona] Starting race scraping
# [2022 London] Page 1 scraped for HYROX PRO - Women
# [2023 London] Trying HYROX PRO
# [2022 London] Saved 199 rows for HYROX PRO
# [2022 London] No HYROX PRO DOUBLES divisions available
# [2021 Leipzig] Trying HYROX PRO
# [2023 Stockholm] Trying HYROX PRO
# [2021 London] Scraping gender: Male in HYROX PRO
# [2023 Hong Kong] Trying HYROX PRO
# [2023 Dallas] Trying HYROX PRO
# [2022 London] Finished scraping
# [2022 Essen] Finished scraping
# [2022 Chicago] Finished scraping
# [U.S. Championships of Fitness 2021 - Chicago] Finished scraping
# [WorldChampionship - Leipzig] Scraping gender: Male in HYROX PRO
# [2023 London] Scraping gender: Male in HYROX PRO
# [2023 Barcelona] Trying HYROX PRO
# [2021 Berlin] Page 1 scraped for HYROX PRO - Male
# [2021 Berlin] Scraping gender: Women in HYROX PRO
# [2021 Leipzig] Scraping gender: Male in HYROX PRO
# [2023 Stockholm] Scraping gender: Male in HYROX PRO
# [2023 Dallas] Scraping gender: Male in HYROX PRO
# [2022 Manchester] Page 1 scraped for HYROX PRO - Male
# [2023 Hong Kong] Scraping gender: Male in HYROX PRO
# [2021 Madrid] Page 1 scraped for HYROX PRO - Male
# [2021 Dallas] Page 1 scraped for HYROX PRO - Male
# [2021 Dallas] Scraping gender: Women in HYROX PRO
# [2022 München] Page 1 scraped for HYROX PRO - Male
#
# [2023 Hamburg] Starting race scraping
# [2022 München] Page 2 scraped for HYROX PRO - Male
# [2022 München] Scraping gender: Women in HYROX PRO
# [2021 Birmingham] Page 1 scraped for HYROX PRO - Male
# [2021 Birmingham] Scraping gender: Women in HYROX PRO
# [2023 Barcelona] Scraping gender: Male in HYROX PRO
# [2021 Stuttgart] Page 1 scraped for HYROX PRO - Male
# [2021 Stuttgart] Scraping gender: Women in HYROX PRO
# [2021 Hamburg] Page 1 scraped for HYROX PRO - Male
# [2021 Hamburg] Scraping gender: Women in HYROX PRO
# [2021 Los Angeles] Page 1 scraped for HYROX PRO - Male
# [2021 Los Angeles] Scraping gender: Women in HYROX PRO
# [2021 Amsterdam] Page 1 scraped for HYROX PRO - Male
# [2021 Amsterdam] Scraping gender: Women in HYROX PRO
# [2021 Madrid] Page 2 scraped for HYROX PRO - Male
# [2021 Madrid] Scraping gender: Women in HYROX PRO
# [2022 Manchester] Page 2 scraped for HYROX PRO - Male
# [2022 Manchester] Scraping gender: Women in HYROX PRO
# [2023 Hamburg] Trying HYROX PRO
# [2021 Berlin] Page 1 scraped for HYROX PRO - Women
# [2022 Las Vegas] Page 3 scraped for HYROX PRO - Male
# [2021 Berlin] Saved 34 rows for HYROX PRO
# [2021 Berlin] No HYROX PRO DOUBLES divisions available
# [2021 Dallas] Page 1 scraped for HYROX PRO - Women
# [2021 Dallas] Saved 83 rows for HYROX PRO
# [2021 Dallas] No HYROX PRO DOUBLES divisions available
# [2021 Birmingham] Page 1 scraped for HYROX PRO - Women
# [2022 Las Vegas] Page 4 scraped for HYROX PRO - Male
# [2022 Las Vegas] Scraping gender: Women in HYROX PRO
# [2021 Birmingham] Saved 62 rows for HYROX PRO
# [2021 Birmingham] No HYROX PRO DOUBLES divisions available
# [2021 Stuttgart] Page 1 scraped for HYROX PRO - Women
# [2021 Leipzig] Page 1 scraped for HYROX PRO - Male
# [2021 Leipzig] Scraping gender: Women in HYROX PRO
# [2023 Hamburg] Scraping gender: Male in HYROX PRO
# [2021 London] Page 1 scraped for HYROX PRO - Male
# [2021 London] Scraping gender: Women in HYROX PRO
# [2021 Stuttgart] Saved 62 rows for HYROX PRO
# [2021 Stuttgart] No HYROX PRO DOUBLES divisions available
# [2023 Stockholm] Page 1 scraped for HYROX PRO - Male
# [2023 Stockholm] Scraping gender: Women in HYROX PRO
# [2022 München] Page 1 scraped for HYROX PRO - Women
# [2022 München] Saved 138 rows for HYROX PRO
# [2022 München] No HYROX PRO DOUBLES divisions available
# [2023 Dallas] Page 1 scraped for HYROX PRO - Male
# [2023 Dallas] Scraping gender: Women in HYROX PRO
# [2023 Hong Kong] Page 1 scraped for HYROX PRO - Male
# [2023 Hong Kong] Scraping gender: Women in HYROX PRO
# [2021 Hamburg] Page 1 scraped for HYROX PRO - Women
# [2021 Los Angeles] Page 1 scraped for HYROX PRO - Women
# [2021 Los Angeles] Saved 59 rows for HYROX PRO
# [2021 Los Angeles] No HYROX PRO DOUBLES divisions available
# [2021 Hamburg] Saved 114 rows for HYROX PRO
# [2021 Hamburg] No HYROX PRO DOUBLES divisions available
# [2021 Amsterdam] Page 1 scraped for HYROX PRO - Women
# [2021 Amsterdam] Saved 77 rows for HYROX PRO
# [2021 Amsterdam] No HYROX PRO DOUBLES divisions available
